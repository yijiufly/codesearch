# %% [markdown]
# # Index MongoDB

# %%
import mongowrapper.MongoWrapper as mdb
import numpy as np
import os
from library import Library
import pickle as p
def addToMongoDB(db_instance, my_dict):
    db_instance.save(my_dict)
    return db_instance

def loadOneBinary(funcnamepath, embFile):
    names = p.load(open(funcnamepath, 'r'))
    data = p.load(open(embFile, 'r'))
        #self.ind2emb=dict()
    funcName2emb=dict()
    for i in range(len(names)):
        funcName2emb[names[i]]=data[i]
    return funcName2emb
            
def build2gramMongodb(db, folder, lib):
    emb_path = os.path.join(path_lib, folder, lib+'.so.ida.emb')
    nam_path = os.path.join(path_lib, folder, lib+'.so.ida_filted1.nam')
    nam_path_full = os.path.join(path_lib, folder, lib+'.so.ida.nam')
    names = p.load(open(nam_path, 'r'))
    #names_full = p.load(open(nam_path,'r'))
    #data = p.load(open(emb_path, 'r'))
    func2emb = loadOneBinary(nam_path_full, emb_path)
    for i in range(len(names)):
        data = func2emb[names[i]]
        my_dict = {"name": names[i], "data": data, "version": folder}
        db.save(my_dict)

    print('load ' + lib + ',' + folder)

# %%
libraryName = 'libcrypto'
db = mdb('oss', libraryName + '_collection')
global path_lib
path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl'
for folder in os.listdir(path_lib):
    build2gramMongodb(db, folder,libraryName)
# Out:
# load libcrypto,openssl-OpenSSL_1_0_2g
# load libcrypto,openssl-OpenSSL_0_9_7j
# load libcrypto,openssl-OpenSSL_1_0_0d
# load libcrypto,openssl-OpenSSL_0_9_8h
# load libcrypto,openssl-OpenSSL_1_0_1d
# load libcrypto,openssl-OpenSSL_0_9_7i
# load libcrypto,openssl-OpenSSL_0_9_8a
# load libcrypto,openssl-OpenSSL_0_9_7h
# load libcrypto,openssl-OpenSSL_0_9_8u
# load libcrypto,openssl-OpenSSL_1_0_0f
# load libcrypto,openssl-OpenSSL_1_1_0a
# load libcrypto,openssl-OpenSSL_0_9_8b
# load libcrypto,openssl-OpenSSL_1_0_1m
# load libcrypto,openssl-OpenSSL_1_1_0b
# load libcrypto,openssl-OpenSSL_1_0_1q
# load libcrypto,openssl-OpenSSL_0_9_7e
# load libcrypto,openssl-OpenSSL_0_9_7g
# load libcrypto,openssl-OpenSSL_1_0_0t
# load libcrypto,openssl-OpenSSL_0_9_7
# load libcrypto,openssl-OpenSSL_1_0_2f
# load libcrypto,openssl-OpenSSL_1_0_1t
# load libcrypto,openssl-OpenSSL_1_0_2j
# load libcrypto,openssl-OpenSSL_1_0_1i
# load libcrypto,openssl-OpenSSL_0_9_8y
# load libcrypto,openssl-OpenSSL_0_9_8n
# load libcrypto,openssl-OpenSSL_1_1_0c
# load libcrypto,openssl-OpenSSL_1_0_2n
# load libcrypto,openssl-OpenSSL_1_0_2a
# load libcrypto,openssl-OpenSSL_1_0_2c
# load libcrypto,openssl-OpenSSL_1_0_1
# load libcrypto,openssl-OpenSSL_0_9_8r
# load libcrypto,openssl-OpenSSL_1_1_0g
# load libcrypto,openssl-OpenSSL_1_0_2d
# load libcrypto,openssl-OpenSSL_0_9_8w
# load libcrypto,openssl-OpenSSL_1_0_1f
# load libcrypto,openssl-OpenSSL_0_9_8v
# load libcrypto,openssl-OpenSSL_0_9_8c
# load libcrypto,openssl-OpenSSL_1_0_1o
# load libcrypto,openssl-OpenSSL_1_0_0a
# load libcrypto,openssl-OpenSSL_0_9_8m
# load libcrypto,openssl-OpenSSL_0_9_7f
# load libcrypto,openssl-OpenSSL_0_9_8
# load libcrypto,openssl-OpenSSL_1_0_0j
# load libcrypto,openssl-OpenSSL_1_0_1p
# load libcrypto,openssl-OpenSSL_1_0_2o
# load libcrypto,openssl-OpenSSL_1_0_1c
# load libcrypto,openssl-OpenSSL_1_0_0e
# load libcrypto,openssl-OpenSSL_1_0_1e
# load libcrypto,openssl-OpenSSL_1_1_0
# load libcrypto,openssl-OpenSSL_1_0_1l
# load libcrypto,openssl-OpenSSL_0_9_8p
# load libcrypto,openssl-OpenSSL_1_0_0l
# load libcrypto,openssl-OpenSSL_1_0_1b
# load libcrypto,openssl-OpenSSL_0_9_8e
# load libcrypto,openssl-OpenSSL_1_0_0o
# load libcrypto,openssl-OpenSSL_1_0_1a
# load libcrypto,openssl-OpenSSL_1_0_1g
# load libcrypto,openssl-OpenSSL_1_0_0c
# load libcrypto,openssl-OpenSSL_1_0_0b
# load libcrypto,openssl-OpenSSL_1_0_0g
# load libcrypto,openssl-OpenSSL_1_0_0m
# load libcrypto,openssl-OpenSSL_1_0_2q
# load libcrypto,openssl-OpenSSL_0_9_8s
# load libcrypto,openssl-OpenSSL_0_9_8i
# load libcrypto,openssl-OpenSSL_1_0_0h
# load libcrypto,openssl-OpenSSL_1_0_1r
# load libcrypto,openssl-OpenSSL_0_9_8g
# load libcrypto,openssl-OpenSSL_1_0_1h
# load libcrypto,openssl-OpenSSL_0_9_7a
# load libcrypto,openssl-OpenSSL_1_0_2m
# load libcrypto,openssl-OpenSSL_0_9_8f
# load libcrypto,openssl-OpenSSL_1_0_0s
# load libcrypto,openssl-OpenSSL_1_0_2h
# load libcrypto,openssl-OpenSSL_0_9_7b
# load libcrypto,openssl-OpenSSL_0_9_8o
# load libcrypto,openssl-OpenSSL_0_9_7l
# load libcrypto,openssl-OpenSSL_0_9_8k
# load libcrypto,openssl-OpenSSL_1_0_1n
# load libcrypto,openssl-OpenSSL_1_0_0k
# load libcrypto,openssl-OpenSSL_1_0_2e
# load libcrypto,openssl-OpenSSL_1_1_0d
# load libcrypto,openssl-OpenSSL_0_9_8d
# load libcrypto,openssl-OpenSSL_1_1_0f
# load libcrypto,openssl-OpenSSL_1_0_2b
# load libcrypto,openssl-OpenSSL_1_1_0e
# load libcrypto,openssl-OpenSSL_0_9_7c
# load libcrypto,openssl-OpenSSL_1_0_0i
# load libcrypto,openssl-OpenSSL_0_9_8q
# load libcrypto,openssl-OpenSSL_1_0_2l
# load libcrypto,openssl-OpenSSL_0_9_7m
# load libcrypto,openssl-OpenSSL_1_0_1j
# load libcrypto,openssl-OpenSSL_0_9_7k
# load libcrypto,openssl-OpenSSL_0_9_8x
# load libcrypto,openssl-OpenSSL_0_9_8l
# load libcrypto,openssl-OpenSSL_1_0_0p
# load libcrypto,openssl-OpenSSL_1_0_1s
# load libcrypto,openssl-OpenSSL_1_0_2
# load libcrypto,openssl-OpenSSL_0_9_8t
# load libcrypto,openssl-OpenSSL_1_0_1k
# load libcrypto,openssl-OpenSSL_1_1_0h
# load libcrypto,openssl-OpenSSL_1_0_2i
# load libcrypto,openssl-OpenSSL_1_0_0
# load libcrypto,openssl-OpenSSL_0_9_7d
# load libcrypto,openssl-OpenSSL_1_0_0q
# load libcrypto,openssl-OpenSSL_1_0_0n
# load libcrypto,openssl-OpenSSL_0_9_8j
# load libcrypto,openssl-OpenSSL_1_0_2k
# load libcrypto,openssl-OpenSSL_1_0_0r

# %%
db.connection.drop_database('oss')

# %% [markdown]
# # Search MongoDB

# %%
db.load({"name":'_init'})
# Out:
# [{u'_id': ObjectId('5d549bfd6c1581c39db9fc19'),
#   u'_npObjectIDs': [ObjectId('5d549bfd6c1581c39db9fc17')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 45, 938000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2g'},
#  {u'_id': ObjectId('5d549c006c1581c39dba0183'),
#   u'_npObjectIDs': [ObjectId('5d549c006c1581c39dba0181')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 48, 730000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7j'},
#  {u'_id': ObjectId('5d549c016c1581c39dba04aa'),
#   u'_npObjectIDs': [ObjectId('5d549c016c1581c39dba04a8')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 49, 152000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0d'},
#  {u'_id': ObjectId('5d549c016c1581c39dba092a'),
#   u'_npObjectIDs': [ObjectId('5d549c016c1581c39dba0928')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 49, 716000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8h'},
#  {u'_id': ObjectId('5d549c026c1581c39dba0d08'),
#   u'_npObjectIDs': [ObjectId('5d549c026c1581c39dba0d06')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 50, 199000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1d'},
#  {u'_id': ObjectId('5d549c026c1581c39dba1218'),
#   u'_npObjectIDs': [ObjectId('5d549c026c1581c39dba1216')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 50, 849000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7i'},
#  {u'_id': ObjectId('5d549c036c1581c39dba153f'),
#   u'_npObjectIDs': [ObjectId('5d549c036c1581c39dba153d')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 51, 329000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8a'},
#  {u'_id': ObjectId('5d549c036c1581c39dba1917'),
#   u'_npObjectIDs': [ObjectId('5d549c036c1581c39dba1915')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 51, 804000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7h'},
#  {u'_id': ObjectId('5d549c046c1581c39dba1c3e'),
#   u'_npObjectIDs': [ObjectId('5d549c046c1581c39dba1c3c')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 52, 206000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8u'},
#  {u'_id': ObjectId('5d549c046c1581c39dba207c'),
#   u'_npObjectIDs': [ObjectId('5d549c046c1581c39dba207a')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 52, 736000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0f'},
#  {u'_id': ObjectId('5d549c056c1581c39dba24ff'),
#   u'_npObjectIDs': [ObjectId('5d549c056c1581c39dba24fd')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 53, 315000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_1_0a'},
#  {u'_id': ObjectId('5d549c066c1581c39dba2b95'),
#   u'_npObjectIDs': [ObjectId('5d549c066c1581c39dba2b93')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 54, 231000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8b'},
#  {u'_id': ObjectId('5d549c066c1581c39dba2f67'),
#   u'_npObjectIDs': [ObjectId('5d549c066c1581c39dba2f65')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 54, 733000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1m'},
#  {u'_id': ObjectId('5d549c076c1581c39dba3483'),
#   u'_npObjectIDs': [ObjectId('5d549c076c1581c39dba3481')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 55, 399000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_1_0b'},
#  {u'_id': ObjectId('5d549c086c1581c39dba3b19'),
#   u'_npObjectIDs': [ObjectId('5d549c086c1581c39dba3b17')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 56, 242000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1q'},
#  {u'_id': ObjectId('5d549c086c1581c39dba4038'),
#   u'_npObjectIDs': [ObjectId('5d549c086c1581c39dba4036')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 56, 909000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7e'},
#  {u'_id': ObjectId('5d549c096c1581c39dba4359'),
#   u'_npObjectIDs': [ObjectId('5d549c096c1581c39dba4357')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 57, 326000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7g'},
#  {u'_id': ObjectId('5d549c096c1581c39dba467a'),
#   u'_npObjectIDs': [ObjectId('5d549c096c1581c39dba4678')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 57, 778000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0t'},
#  {u'_id': ObjectId('5d549c0a6c1581c39dba4b21'),
#   u'_npObjectIDs': [ObjectId('5d549c0a6c1581c39dba4b1f')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 58, 709000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7'},
#  {u'_id': ObjectId('5d549c0b6c1581c39dba4e42'),
#   u'_npObjectIDs': [ObjectId('5d549c0b6c1581c39dba4e40')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 40, 59, 589000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2f'},
#  {u'_id': ObjectId('5d549c0c6c1581c39dba53fa'),
#   u'_npObjectIDs': [ObjectId('5d549c0c6c1581c39dba53f8')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 0, 725000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1t'},
#  {u'_id': ObjectId('5d549c0d6c1581c39dba58c8'),
#   u'_npObjectIDs': [ObjectId('5d549c0d6c1581c39dba58c6')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 1, 773000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2j'},
#  {u'_id': ObjectId('5d549c0e6c1581c39dba5e35'),
#   u'_npObjectIDs': [ObjectId('5d549c0e6c1581c39dba5e33')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 2, 849000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1i'},
#  {u'_id': ObjectId('5d549c0f6c1581c39dba634b'),
#   u'_npObjectIDs': [ObjectId('5d549c0f6c1581c39dba6349')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 3, 482000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8y'},
#  {u'_id': ObjectId('5d549c106c1581c39dba679e'),
#   u'_npObjectIDs': [ObjectId('5d549c106c1581c39dba679c')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 4, 45000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8n'},
#  {u'_id': ObjectId('5d549c106c1581c39dba6bd3'),
#   u'_npObjectIDs': [ObjectId('5d549c106c1581c39dba6bd1')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 4, 643000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_1_0c'},
#  {u'_id': ObjectId('5d549c116c1581c39dba7269'),
#   u'_npObjectIDs': [ObjectId('5d549c116c1581c39dba7267')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 5, 511000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2n'},
#  {u'_id': ObjectId('5d549c126c1581c39dba77dc'),
#   u'_npObjectIDs': [ObjectId('5d549c126c1581c39dba77da')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 6, 378000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2a'},
#  {u'_id': ObjectId('5d549c136c1581c39dba7d8e'),
#   u'_npObjectIDs': [ObjectId('5d549c136c1581c39dba7d8c')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 7, 378000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2c'},
#  {u'_id': ObjectId('5d549c146c1581c39dba8343'),
#   u'_npObjectIDs': [ObjectId('5d549c146c1581c39dba8341')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 8, 266000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1'},
#  {u'_id': ObjectId('5d549c156c1581c39dba883e'),
#   u'_npObjectIDs': [ObjectId('5d549c156c1581c39dba883c')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 9, 235000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8r'},
#  {u'_id': ObjectId('5d549c166c1581c39dba8c76'),
#   u'_npObjectIDs': [ObjectId('5d549c166c1581c39dba8c74')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 10, 264000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_1_0g'},
#  {u'_id': ObjectId('5d549c176c1581c39dba931e'),
#   u'_npObjectIDs': [ObjectId('5d549c176c1581c39dba931c')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 11, 82000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2d'},
#  {u'_id': ObjectId('5d549c176c1581c39dba98d3'),
#   u'_npObjectIDs': [ObjectId('5d549c176c1581c39dba98d1')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 11, 781000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8w'},
#  {u'_id': ObjectId('5d549c186c1581c39dba9d11'),
#   u'_npObjectIDs': [ObjectId('5d549c186c1581c39dba9d0f')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 12, 316000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1f'},
#  {u'_id': ObjectId('5d549c186c1581c39dbaa224'),
#   u'_npObjectIDs': [ObjectId('5d549c186c1581c39dbaa222')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 12, 954000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8v'},
#  {u'_id': ObjectId('5d549c196c1581c39dbaa662'),
#   u'_npObjectIDs': [ObjectId('5d549c196c1581c39dbaa660')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 13, 488000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8c'},
#  {u'_id': ObjectId('5d549c196c1581c39dbaaa31'),
#   u'_npObjectIDs': [ObjectId('5d549c196c1581c39dbaaa2f')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 13, 965000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1o'},
#  {u'_id': ObjectId('5d549c1a6c1581c39dbaaf50'),
#   u'_npObjectIDs': [ObjectId('5d549c1a6c1581c39dbaaf4e')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 14, 613000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0a'},
#  {u'_id': ObjectId('5d549c1b6c1581c39dbab3d0'),
#   u'_npObjectIDs': [ObjectId('5d549c1b6c1581c39dbab3ce')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
# ...
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 55, 290000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0p'},
#  {u'_id': ObjectId('5d549c436c1581c39dbbb693'),
#   u'_npObjectIDs': [ObjectId('5d549c436c1581c39dbbb691')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 55, 891000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1s'},
#  {u'_id': ObjectId('5d549c446c1581c39dbbbb64'),
#   u'_npObjectIDs': [ObjectId('5d549c446c1581c39dbbbb62')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 56, 501000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2'},
#  {u'_id': ObjectId('5d549c456c1581c39dbbc110'),
#   u'_npObjectIDs': [ObjectId('5d549c456c1581c39dbbc10e')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 57, 474000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8t'},
#  {u'_id': ObjectId('5d549c466c1581c39dbbc54b'),
#   u'_npObjectIDs': [ObjectId('5d549c466c1581c39dbbc549')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 58, 413000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_1k'},
#  {u'_id': ObjectId('5d549c476c1581c39dbbca64'),
#   u'_npObjectIDs': [ObjectId('5d549c476c1581c39dbbca62')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 59, 113000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_1_0h'},
#  {u'_id': ObjectId('5d549c476c1581c39dbbd10f'),
#   u'_npObjectIDs': [ObjectId('5d549c476c1581c39dbbd10d')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 41, 59, 978000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2i'},
#  {u'_id': ObjectId('5d549c486c1581c39dbbd67c'),
#   u'_npObjectIDs': [ObjectId('5d549c486c1581c39dbbd67a')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 0, 666000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0'},
#  {u'_id': ObjectId('5d549c496c1581c39dbbdaff'),
#   u'_npObjectIDs': [ObjectId('5d549c496c1581c39dbbdafd')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 1, 246000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_7d'},
#  {u'_id': ObjectId('5d549c496c1581c39dbbde20'),
#   u'_npObjectIDs': [ObjectId('5d549c496c1581c39dbbde1e')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 1, 727000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0q'},
#  {u'_id': ObjectId('5d549c4a6c1581c39dbbe2c1'),
#   u'_npObjectIDs': [ObjectId('5d549c4a6c1581c39dbbe2bf')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 2, 351000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0n'},
#  {u'_id': ObjectId('5d549c4a6c1581c39dbbe75c'),
#   u'_npObjectIDs': [ObjectId('5d549c4a6c1581c39dbbe75a')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 2, 942000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_0_9_8j'},
#  {u'_id': ObjectId('5d549c4b6c1581c39dbbeb6a'),
#   u'_npObjectIDs': [ObjectId('5d549c4b6c1581c39dbbeb68')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 3, 466000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_2k'},
#  {u'_id': ObjectId('5d549c4c6c1581c39dbbf0d7'),
#   u'_npObjectIDs': [ObjectId('5d549c4c6c1581c39dbbf0d5')],
#   u'data': array([ 1.3143042 ,  0.6370126 , -1.4398222 ,  0.5033144 ,  1.5617046 ,
#          -0.760426  ,  0.6207162 , -0.474633  , -1.1031591 , -0.50029445,
#          -0.13191916,  0.22171645,  0.4471913 ,  0.70698416,  0.9043882 ,
#           0.8879889 ,  0.44077158, -0.32081613,  1.3458557 , -1.1199375 ,
#          -3.1099312 , -1.6830784 ,  1.3339134 ,  1.138686  ,  0.7198933 ,
#           0.5310473 ,  1.6754402 , -0.9897256 ,  2.1244118 , -0.41577917,
#           2.0193665 , -0.17490907,  2.6298406 , -0.95096815, -0.22085229,
#          -0.6524981 ,  1.1267282 ,  2.6346803 ,  0.7323775 , -2.447609  ,
#           0.51820856, -0.6220708 , -0.09495795, -0.05529763, -0.91369486,
#          -0.08805767, -1.020882  , -0.0341909 ,  1.5662508 ,  1.5425507 ,
#           1.0295261 ,  0.54892987, -1.6760607 ,  0.7600167 ,  0.16562451,
#          -1.0952786 ,  0.32421172,  0.8816155 , -0.8026448 , -1.0433966 ,
#          -1.3574485 ,  1.3427435 ,  2.1583564 ,  2.9093509 ], dtype=float32),
#   u'insertion_date': datetime.datetime(2019, 8, 14, 16, 42, 4, 174000),
#   u'name': u'_init',
#   u'version': u'openssl-OpenSSL_1_0_0r'}]

# %% [markdown]
# # check the quality of the embeddings

# %% [markdown]
# ## Draw CDF

# %%
import pickle as p
name = 'nginx-{openssl-1.0.1d}{zlib-1.2.11}'
#dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1j}{zlib-1.2.7.3}/'
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/'+name+'/'
embfiles = name + '.ida_newmodel.emb'
namfiles = name + '.ida_newmodel_withsize.nam'
filted = 1
def loadOneBinary(funcnamepath, embFile, filted_size=0):
    names = p.load(open(funcnamepath, 'r'))
    data = p.load(open(embFile, 'r'))
    funcName2emb=dict()
    for i in range(len(data)):
        (name, size) = names[i]
        if size > filted_size:
            funcName2emb[name]=data[i]
    return funcName2emb

# %%
func2emb_test = loadOneBinary(dir+namfiles, dir+embfiles, filted)
#dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1l/'
dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1d/'
emb = 'libcrypto.so.ida_newmodel.emb'
nam = 'libcrypto.so.ida_newmodel_withsize.nam'
#name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
func2emb_openssl = loadOneBinary(dir_openssl+nam, dir_openssl+emb, filted)

# %%
import numpy as np
from collections import defaultdict
distribution=[]
count = 0
for key in func2emb_test.keys():
    if key in func2emb_openssl:# and key in name_filted:
        a=func2emb_test[key]
        b=func2emb_openssl[key]
        from numpy.linalg import norm
        result = np.inner(a, b)/(norm(a)*norm(b))
        if not np.isnan(result):
            distribution.append(result)
        if result > 0.95:
            count +=1
print count
# Out:
# 1987
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in float_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
import matplotlib.pyplot as plt
def cdf(x, plot=True):
    num_bins = 100
    counts, bin_edges = np.histogram (x, bins=num_bins, normed=True)
    cdf = np.cumsum (counts)
    plt.axis([0, 1, 0, 1])
    plt.title('CDF: similarity between openssl functions in the library and nginx(filtering size=1)')
    plt.xlabel('similarity')
    plt.ylabel('cumulative distribution ')
    plt.plot (bin_edges[1:], cdf/cdf[-1])
# x=np.array(distribution)
# x.sort()
# print len(x)
# cdf(np.array(distribution))

# %%
import pickle as p
import os
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test2/idafiles/e907458106a1e3ccaa51a6f7ebc59137f07c3518dca7c9cdae275e53729a3dca/'
embfiles = 'nginx-{openssl-1.0.1j}{zlib-1.2.7.3}.ida.emb'
namfiles = 'nginx-{openssl-1.0.1j}{zlib-1.2.7.3}.ida.nam'
func2emb_test2 = loadOneBinary(dir+namfiles, dir+embfiles)
distribution2=[]
openssl_dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test2/funcemb_output_openssl/'
func2emb_openssl = os.listdir(openssl_dir)
count = 0
total = 0
for key in func2emb_test.keys():
    filename = 'OpenSSL_1_0_1j_libcrypto.so{' + key + '}.emb'
    if filename in func2emb_openssl:
        a=func2emb_test[key]
        b = p.load(open(openssl_dir+filename, 'r'))
        from numpy.linalg import norm
        result = np.inner(a, b)/(norm(a)*norm(b))
        if not np.isnan(result):
            distribution2.append(result)
        if result > 0.99:
            count += 1
        total += 1
print count, total
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in float_scalars
# 0 1666

# %%
cdf(np.array(distribution2))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Draw ROC

# %%
import sys
sys.path.insert(0, './embedding_w2v')
from embedding_w2v.embedding import Embedding
emb = Embedding()
# Out:
# siamese model  object initialized
# defined training operations
# initializing global variables
# INFO:tensorflow:Restoring parameters from /home/yijiufly/Downloads/codesearch/embedding_w2v/model/model.ckpt

# %%
import numpy as np
import matplotlib.pyplot as plt
def drawROC(resultMat, name_test, name_lib, linelabel):
    rank_index_list = []
    for s in resultMat:
        a = sorted(range(len(s)), key=lambda k: s[k], reverse=True)
        rank_index_list.append(a)
    func_counts = len(rank_index_list)
    total_tp = []
    total_fp = []
    for func in range(func_counts):
        real_name = name_test[func]
        tp = [0]
        fp = [0]
        for rank, idx in enumerate(rank_index_list[func]):
            if name_lib[idx] == real_name:
                tp.append(1)
                fp.append(fp[-1])
            else:
                tp.append(max(tp[-1], 0))
                fp.append(fp[-1] + 1)
            #if rank == 30 and tp[-1] == 0:
            #    print func, real_name
                    
        total_tp.append(tp)
        total_fp.append(fp)
    num_positive = func_counts
    num_negative = func_counts * len(resultMat[0]) - num_positive
    total_tp = np.sum(total_tp, axis=0, dtype=np.float) / func_counts
    total_fp = np.sum(total_fp, axis=0, dtype=np.float) / num_negative
    print total_tp[:30], total_fp[:30]
    plt.figure(1)
    plt.title('ROC')
    plt.plot(total_fp, total_tp, 'r-', label=linelabel)
    # plt.plot(total_fp2, total_tp2, 'b-', label='acfg_0')

    plt.legend(loc='lower right')
    plt.xlim([-0.1, 1.1])
    plt.ylim([-0.1, 1.1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    return rank_index_list

# %%
#draw ROC for functions
import pickle as p
name = 'nginx-{openssl-1.0.1d}{zlib-1.2.11}'
#dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1j}{zlib-1.2.7.3}/'
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/'+name+'/'
embfiles = name + '.ida_newmodel.emb'
namfiles = name + '.ida_newmodel_withsize.nam'
filted = 1
def loadOneBinary(funcnamepath, embFile, filted_size=0):
    names = p.load(open(funcnamepath, 'r'))
    data = p.load(open(embFile, 'r'))
    funcName2emb=dict()
    for i in range(len(data)):
        (name, size) = names[i]
        if size > filted_size:
            funcName2emb[name]=data[i]
    return funcName2emb
func2emb_test = loadOneBinary(dir+namfiles, dir+embfiles, filted)
#dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1l/'
dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/'
folder = 'openssl-OpenSSL_1_0_1d/'
embfile = 'libcrypto.so.ida_newmodel.emb'
nam = 'libcrypto.so.ida_newmodel_withsize.nam'
sslembfile = 'libssl.so.ida_newmodel.emb'
sslnam = 'libssl.so.ida_newmodel_withsize.nam'
func2emb_ssl = loadOneBinary(dir_openssl+folder+sslnam, dir_openssl+folder+sslembfile, filted)
#name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
func2emb_openssl = loadOneBinary(dir_openssl+folder+nam, dir_openssl+folder+embfile, filted)
name_test=[]
emb_test=[]
for key in func2emb_test.keys():
    if key in func2emb_openssl.keys() or key in func2emb_ssl.keys():
        name_test.append(key)
        emb_test.append(func2emb_test[key])

# %%
import os
import numpy as np
name_openssl_all = ['0']
resultMat_all = [[0] for i in range(len(name_test))]
for folder in os.listdir(dir_openssl)[:5]:
    print folder
    embfile = '/libcrypto.so.ida_newmodel.emb'
    nam = '/libcrypto.so.ida_newmodel_withsize.nam'
    sslembfile = '/libssl.so.ida_newmodel.emb'
    sslnam = '/libssl.so.ida_newmodel_withsize.nam'
    func2emb_ssl = loadOneBinary(dir_openssl+folder+sslnam, dir_openssl+folder+sslembfile, filted)
    #name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
    func2emb_openssl = loadOneBinary(dir_openssl+folder+nam, dir_openssl+folder+embfile, filted)
    name_openssl=func2emb_openssl.keys()
    name_openssl.extend(func2emb_ssl.keys())
    emb_openssl=func2emb_openssl.values()
    emb_openssl.extend(func2emb_ssl.values())
    name_openssl_all.extend(name_openssl)
    resultMat = emb.test_similarity(emb_test, emb_openssl)
    # print len(name_test)
    # resultMat = emb.test_similarity(emb_test, emb_openssl)
    resultMat_all = np.concatenate((resultMat_all, resultMat), axis=1)
rank = drawROC(resultMat_all, name_test, name_openssl_all, 'func')
# Out:
# openssl-OpenSSL_1_0_2g
# openssl-OpenSSL_0_9_7j
# openssl-OpenSSL_1_0_0d
# openssl-OpenSSL_0_9_8h
# openssl-OpenSSL_1_0_1d
# [0.         0.22115753 0.24338827 0.25450364 0.26101955 0.26485243
#  0.26830203 0.2694519  0.27021847 0.27175163 0.27290149 0.27328478
#  0.27405136 0.27443465 0.27520123 0.27558452 0.2759678  0.2759678
#  0.2759678  0.2759678  0.27635109 0.27635109 0.27635109 0.27635109
#  0.27673438 0.27750096 0.27750096 0.27750096 0.27750096 0.27750096] [0.00000000e+00 5.74028942e-05 1.29467256e-04 2.02350852e-04
#  2.75573441e-04 3.48993777e-04 4.22442362e-04 4.96060444e-04
#  5.69706775e-04 6.43296608e-04 7.16914689e-04 7.90589270e-04
#  8.64207352e-04 9.37853683e-04 1.01150001e-03 1.08514635e-03
#  1.15879268e-03 1.23246726e-03 1.30617009e-03 1.37987292e-03
#  1.45354750e-03 1.52725033e-03 1.60095316e-03 1.67465599e-03
#  1.74833057e-03 1.82194865e-03 1.89562323e-03 1.96932606e-03
#  2.04302889e-03 2.11673172e-03]

# %%
folders = os.listdir(dir_openssl)
print folders.index('openssl-OpenSSL_1_0_1d')
# Out:
# 4

# %%
# draw ROC for 2-grams
from binary import TestBinary
from library import Library
import os
name = 'nginx-{openssl-1.0.1d}{zlib-1.2.11}'
#dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1j}{zlib-1.2.7.3}/'
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/'+name+'/'
filter_size = 1
dotPath = os.path.join(dir, name + '_bn.dot')
embPath = os.path.join(dir, name + '.ida.emb')
namPath = os.path.join(dir, name + '.ida_newmodel_withsize.nam')
namPathFull = os.path.join(dir,  name + '.ida.nam')
testbin = TestBinary(name, dotPath, embPath, namPath, filter_size)
testbin.buildNGram(namPathFull)

path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl'
lib='libcrypto'
folder = 'openssl-OpenSSL_1_0_1d'
dotfile = lib+'.so_bn.dot'
dot_path = os.path.join(path_lib, folder, dotfile)
libraryName = folder.split('-')[1] + '_' + dotfile.rsplit('.',1)[0]
emb_path = os.path.join(path_lib, folder, lib+'.so.ida.emb')
nam_path = os.path.join(path_lib, folder, lib+'.so.ida_newmodel_withsize.nam')
nam_path_full = os.path.join(path_lib, folder, lib+'.so.ida.nam')
libitem = Library(libraryName, dot_path, emb_path, nam_path,filter_size)
libitem.buildNGram(nam_path_full)
# Out:
# init testing binary
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/nginx-{openssl-1.0.1d}{zlib-1.2.11}_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded

# %%
name_test=[]
emb_test=[]
name_openssl=[i[1] for i in libitem.twoGramList]
emb_openssl=[i[0] for i in libitem.twoGramList]
for twogram in testbin.twoGramList:
    if twogram[1] in name_openssl:
        name_test.append(twogram[1])
        emb_test.append(twogram[0])

resultMat = emb.test_similarity(emb_test, emb_openssl)
rank_index_list = drawROC(resultMat, name_test, name_openssl, '2-gram')
# Out:
# [0.         0.64353612 0.7031052  0.72671103 0.74271229 0.75269328
#  0.76029785 0.76869455 0.77376426 0.77740811 0.78073511 0.78342839
#  0.78612167 0.78833967 0.79103295 0.79293409 0.79546895 0.79816223
#  0.80038023 0.8024398  0.80465779 0.80624208 0.80782636 0.80988593
#  0.81162864 0.81368821 0.81479721 0.81622307 0.81685678 0.81796578] [0.00000000e+00 4.37593762e-05 1.59109092e-04 2.78893091e-04
#  3.99688418e-04 5.21222792e-04 6.43048895e-04 7.64738858e-04
#  8.86876139e-04 1.00918846e-03 1.13153967e-03 1.25396868e-03
#  1.37635880e-03 1.49884615e-03 1.62127516e-03 1.74376252e-03
#  1.86621098e-03 1.98863999e-03 2.11112734e-03 2.23363415e-03
#  2.35612150e-03 2.47868666e-03 2.60125181e-03 2.72375861e-03
#  2.84630431e-03 2.96881112e-03 3.09143461e-03 3.21401921e-03
#  3.33670105e-03 3.45932455e-03]

# %%
# 3-gram
name_test=[]
emb_test=[]
name_openssl=[i[1] for i in libitem.threeGramList]
emb_openssl=[i[0] for i in libitem.threeGramList]
for twogram in testbin.threeGramList:
    if twogram[1] in name_openssl:
        name_test.append(twogram[1])
        emb_test.append(twogram[0])
resultMat = []
for i in range(0, len(emb_test), 500):
    resultMat.extend(emb.test_similarity(emb_test[i:i+500], emb_openssl))
rank_index_list = drawROC(resultMat, name_test, name_openssl, '3-gram')
# Out:
# [0.         0.64299116 0.69829358 0.72670419 0.74528723 0.75565085
#  0.76529974 0.7757527  0.7815599  0.78495488 0.78968998 0.79237023
#  0.79567587 0.79826677 0.80166175 0.80380595 0.80639686 0.80889842
#  0.81157867 0.8133655  0.81515233 0.81711784 0.81836862 0.82078085
#  0.82229965 0.82435451 0.82551595 0.82685607 0.82783883 0.82908961] [0.00000000e+00 2.13458203e-05 7.77551953e-05 1.35740400e-04
#  1.94409356e-04 2.53559072e-04 3.12772891e-04 3.71938633e-04
#  4.31360781e-04 4.90937842e-04 5.50445459e-04 6.10065254e-04
#  6.69658340e-04 7.29283477e-04 7.88871221e-04 8.48533750e-04
#  9.08169571e-04 9.67800049e-04 1.02743053e-03 1.08711442e-03
#  1.14678764e-03 1.20646085e-03 1.26617680e-03 1.32582330e-03
#  1.38552322e-03 1.44519109e-03 1.50491238e-03 1.56462299e-03
#  1.62435496e-03 1.68407091e-03]

# %%
# Out:
# 16726

# %%
resultMat = np.zeros((len(emb_test), len(emb_openssl)))
from collections import defaultdict
name2ind_openssl = defaultdict(int)
for i, name in enumerate(name_openssl):
    name2ind_openssl[name]=i
name2ind_test = defaultdict(int)
for i, name in enumerate(name_test):
    name2ind_test[name]=i
for knn in testkNN:
    testname = knn[0][0]
    if testname in name2ind_test:
        index1 = name2ind_test[testname]
        for openssl in knn[1]:
            opensslname = openssl[0]
            if opensslname in name2ind_openssl:
                index2 = name2ind_openssl[opensslname]
                resultMat[index1, index2] = knn[2]
rank_index_list = drawROC(resultMat, name_test, name_openssl, '3-gram')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-498fbcca1841> in <module>()
#       3     testname = knn[0][0]
#       4     opensslname = knn[1][0]
# ----> 5     if testname in emb_openssl and opensslname in name_openssl:
#       6         index1 = emb_openssl.index(testname)
#       7         index2 = name_openssl.index(opensslname)
#
# KeyboardInterrupt:

# %%
#analyse the functions with low precision and recall
from numpy.linalg import norm
a = emb_test[141]
b = emb_openssl[name_openssl.index(('CRYPTO_get_new_dynlockid', 'sk_find'))]
result = np.inner(a, b)/(norm(a)*norm(b))
ranks=[]
for i, ranklist in enumerate(rank_index_list):
    name = name_test[i]
    index_openssl = name_openssl.index(name)
    a = emb_test[i]
    b = emb_openssl[index_openssl]
    result = np.inner(a, b)/(norm(a)*norm(b))
    rank = ranklist.index(index_openssl)
    if rank < 10:
        ranks.append(result)
        print i, name
        print rank, result
cdf(np.array(ranks))
# Out:
# 0 ('PKCS7_simple_smimecap', 'OBJ_nid2obj')
# 0 0.9977308
# 1 ('PKCS7_simple_smimecap', 'ASN1_INTEGER_set')
# 0 0.99986905
# 2 ('PKCS7_simple_smimecap', 'ASN1_OBJECT_free')
# 0 0.99864566
# 4 ('X509_PURPOSE_get_count', 'sk_num')
# 2 1.0000001
# 5 ('RSA_padding_check_PKCS1_type_2', 'ERR_put_error')
# 0 0.98619556
# 6 ('RSA_padding_check_PKCS1_type_1', 'ERR_put_error')
# 0 0.98772174
# 7 ('PEM_read_bio_Parameters', 'EVP_PKEY_new')
# 0 0.9992056
# 8 ('PEM_read_bio_Parameters', 'pem_check_suffix')
# 0 0.99959326
# 9 ('PEM_read_bio_Parameters', 'EVP_PKEY_free')
# 0 0.99876827
# 10 ('PEM_read_bio_Parameters', 'CRYPTO_free')
# 0 0.99958324
# 11 ('PEM_read_bio_Parameters', 'PEM_bytes_read_bio')
# 0 0.99244386
# 12 ('PEM_read_bio_Parameters', 'ERR_put_error')
# 0 0.99146134
# 13 ('PEM_read_bio_Parameters', 'EVP_PKEY_set_type_str')
# 0 0.9986799
# 16 ('BN_mod_add_quick', 'BN_uadd')
# 0 0.9999993
# 17 ('BN_mod_add_quick', 'BN_ucmp')
# 0 0.9999999
# 18 ('print_qualifiers', 'BIO_printf')
# 0 0.99360543
# 19 ('print_qualifiers', 'sk_num')
# 2 0.9935647
# 20 ('print_qualifiers', 'BIO_puts')
# 0 0.9952501
# 21 ('print_qualifiers', 'i2s_ASN1_INTEGER')
# 0 0.9939556
# 22 ('print_qualifiers', 'i2a_ASN1_OBJECT')
# 0 0.99336135
# 24 ('print_qualifiers', 'CRYPTO_free')
# 0 0.9937432
# 25 ('print_qualifiers', 'sk_value')
# 2 0.9936382
# 26 ('ASN1_d2i_bio', 'asn1_d2i_read_bio.constprop.0')
# 0 0.9985651
# 27 ('ASN1_d2i_bio', 'BUF_MEM_free')
# 0 0.99998057
# 28 ('camellia_256_ofb_cipher', 'CRYPTO_ofb128_encrypt')
# 1 0.9999999
# 29 ('RSA_generate_key_ex', 'BN_gcd')
# 0 0.99964803
# 30 ('RSA_generate_key_ex', 'BN_cmp')
# 0 0.9996041
# 31 ('RSA_generate_key_ex', 'BN_CTX_end')
# 0 0.9995944
# 32 ('RSA_generate_key_ex', 'BN_GENCB_call')
# 0 0.99959636
# 33 ('RSA_generate_key_ex', 'BN_mul')
# 0 0.99966955
# 34 ('RSA_generate_key_ex', 'BN_CTX_new')
# 0 0.99957776
# 35 ('RSA_generate_key_ex', 'BN_new')
# 0 0.99957573
# 36 ('RSA_generate_key_ex', 'BN_CTX_start')
# 0 0.9995945
# 37 ('RSA_generate_key_ex', 'BN_CTX_get')
# 0 0.99959767
# 38 ('RSA_generate_key_ex', 'ERR_put_error')
# 0 0.9991505
# 39 ('RSA_generate_key_ex', 'BN_mod_inverse')
# 0 0.9997949
# 40 ('RSA_generate_key_ex', 'BN_CTX_free')
# 0 0.9996001
# 41 ('RSA_generate_key_ex', 'BN_copy')
# 2 0.9978205
# 43 ('RSA_generate_key_ex', 'BN_div')
# 0 0.9997151
# 44 ('RSA_generate_key_ex', 'BN_sub')
# 0 0.9996073
# 45 ('read_string_inner', 'UI_set_result')
# 0 0.9995786
# 46 ('read_string_inner', 'OPENSSL_cleanse')
# 0 0.99970526
# 47 ('asn1_check_tlen', 'ASN1_get_object')
# 0 0.9997694
# 48 ('asn1_check_tlen', 'ERR_put_error')
# 0 0.9973153
# 49 ('X509_OBJECT_retrieve_match', 'sk_value')
# 0 1.0000001
# 50 ('X509_OBJECT_retrieve_match', 'sk_num')
# 0 1.0
# 51 ('X509_OBJECT_retrieve_match', 'sk_find')
# 0 0.99768263
# 53 ('X509_ALGOR_set0', 'ASN1_TYPE_set')
# 0 0.99917865
# 54 ('X509_ALGOR_set0', 'ASN1_OBJECT_free')
# 0 0.9986279
# 55 ('ASN1_template_new', 'ERR_put_error')
# 0 0.9626494
# 58 ('PKCS7_add_certificate', 'ERR_put_error')
# 3 0.9801942
# 63 ('X509_VERIFY_PARAM_lookup', 'sk_find')
# 0 0.9967517
# 64 ('X509_VERIFY_PARAM_lookup', 'sk_value')
# 0 0.9962381
# 66 ('bn_extract_to_array_512', 'BN_bn2bin')
# 0 0.9751909
# 67 ('ERR_load_CONF_strings', 'ERR_load_strings')
# 0 0.9985667
# 68 ('ERR_load_CONF_strings', 'ERR_func_error_string')
# 0 0.9904341
# 70 ('rsa_item_sign', 'X509_ALGOR_set0')
# 0 0.9997618
# 72 ('rsa_item_sign', 'EVP_PKEY_CTX_ctrl')
# 0 0.99972624
# 73 ('rsa_item_sign', 'EVP_PKEY_size')
# 0 0.9998593
# 74 ('rsa_item_sign', 'EVP_MD_CTX_md')
# 0 0.99985844
# 75 ('rsa_item_sign', 'EVP_MD_size')
# 0 0.9998508
# 76 ('rsa_item_sign', 'OBJ_nid2obj')
# 0 0.99942774
# 77 ('rsa_item_sign', 'ASN1_STRING_free')
# 0 0.9998601
# 78 ('rsa_item_sign', 'ASN1_item_pack')
# 0 0.9996906
# 79 ('rsa_item_sign', 'ASN1_INTEGER_set')
# 0 0.9998569
# 80 ('rsa_item_sign', 'EVP_PKEY_bits')
# 1 0.9998593
# 84 ('BN_rshift1', 'bn_expand2')
# 0 0.99999994
# 85 ('PKCS12_pack_p7data', 'ASN1_item_pack')
# 0 0.9990714
# 86 ('PKCS12_pack_p7data', 'ASN1_STRING_type_new')
# 0 0.9986328
# 87 ('PKCS12_pack_p7data', 'ERR_put_error')
# 1 0.977021
# 88 ('PKCS12_pack_p7data', 'OBJ_nid2obj')
# 0 0.99771243
# 89 ('CAST_cbc_encrypt', 'CAST_encrypt')
# 0 0.9979675
# 90 ('CAST_cbc_encrypt', 'CAST_decrypt')
# 0 0.99758404
# 91 ('OBJ_cleanup', 'lh_doall')
# 0 0.9971651
# 92 ('OBJ_cleanup', 'lh_free')
# 0 0.9969942
# 94 ('PKCS7_get_smimecap', 'PKCS7_get_signed_attribute')
# 0 0.9998694
# 95 ('EVP_DigestSignInit', 'EVP_PKEY_CTX_ctrl')
# 1 0.9995175
# 96 ('EVP_DigestSignInit', 'EVP_DigestInit_ex')
# 1 0.9998357
# 97 ('EVP_DigestSignInit', 'EVP_PKEY_get_default_digest_nid')
# 1 0.9999003
# 98 ('EVP_DigestSignInit', 'EVP_PKEY_sign_init')
# 1 0.9997831
# 99 ('EVP_DigestSignInit', 'OBJ_nid2sn')
# 1 0.99867207
# 101 ('EVP_DigestSignInit', 'ERR_put_error')
# 1 0.99440366
# 102 ('EC_GROUP_get_trinomial_basis', 'ERR_put_error')
# 0 0.9776246
# 103 ('PKCS7_get_attribute', 'sk_num')
# 1 1.0
# 104 ('PKCS7_get_attribute', 'sk_value')
# 1 0.9999999
# 105 ('PKCS7_get_attribute', 'OBJ_nid2obj')
# 2 0.9976012
# 106 ('PKCS7_get_attribute', 'OBJ_cmp')
# 1 1.0
# 108 ('engine_table_register', 'ERR_put_error')
# 4 0.9927148
# 109 ('engine_table_register', 'engine_cleanup_add_first')
# 0 0.99635303
# 110 ('engine_table_register', 'engine_unlocked_finish')
# 0 0.9976021
# 111 ('engine_table_register', 'CRYPTO_lock')
# 0 0.9957718
# 113 ('engine_table_register', 'CRYPTO_malloc')
# 0 0.997387
# 114 ('engine_table_register', 'lh_insert')
# 0 0.99802667
# 115 ('engine_table_register', 'engine_unlocked_init')
# 0 0.9973831
# 116 ('engine_table_register', 'CRYPTO_free')
# 0 0.9973256
# 117 ('engine_table_register', 'lh_retrieve')
# 0 0.99755734
# 118 ('BUF_MEM_free', 'CRYPTO_free')
# 0 1.0000001
# 119 ('file_ctrl', 'ERR_put_error')
# 0 0.9984149
# 120 ('file_ctrl', 'BUF_strlcpy')
# 0 0.99952906
# 121 ('file_ctrl', 'ERR_add_error_data')
# 0 0.99952155
# 122 ('BN_RECP_CTX_free', 'BN_free')
# 0 0.9998666
# 123 ('DSA_generate_key', 'BN_CTX_free')
# 0 0.9997955
# 124 ('DSA_generate_key', 'BN_CTX_new')
# 0 0.9996246
# 125 ('DSA_generate_key', 'BN_free')
# 0 0.9997738
# 127 ('DSA_generate_key', 'BN_new')
# 0 0.999608
# 130 ('EC_KEY_set_public_key', 'EC_POINT_free')
# 0 0.9999999
# 131 ('RSA_padding_check_X931', 'ERR_put_error')
# 0 0.9903144
# 136 ('ASN1_BIT_STRING_set_bit', 'CRYPTO_realloc_clean')
# 4 0.97651315
# 137 ('ASN1_BIT_STRING_set_bit', 'CRYPTO_malloc')
# 0 0.9988615
# 138 ('ASN1_BIT_STRING_set_bit', 'ERR_put_error')
# 0 0.9911525
# 139 ('ERR_get_err_state_table', 'CRYPTO_lock')
# 1 0.9789536
# 140 ('BIO_asn1_set_suffix', 'BIO_ctrl')
# 0 0.9997305
# 141 ('aes_ccm_cipher', 'CRYPTO_ccm128_decrypt_ccm64')
# 0 0.9960621
# 142 ('aes_ccm_cipher', 'CRYPTO_ccm128_decrypt')
# 0 0.9946701
# 143 ('aes_ccm_cipher', 'CRYPTO_ccm128_encrypt')
# 0 0.9959278
# 144 ('aes_ccm_cipher', 'CRYPTO_ccm128_encrypt_ccm64')
# 0 0.9956186
# 145 ('aes_ccm_cipher', 'CRYPTO_ccm128_tag')
# 0 0.99996036
# 146 ('aes_ccm_cipher', 'CRYPTO_ccm128_setiv')
# 0 0.999889
# 147 ('aes_ccm_cipher', 'OPENSSL_cleanse')
# 0 0.99990994
# 148 ('aes_ccm_cipher', 'CRYPTO_ccm128_aad')
# 0 0.99996185
# 151 ('X509_check_issued', 'x509v3_cache_extensions.part.6')
# 0 0.9991735
# 152 ('X509_check_issued', 'X509_NAME_cmp')
# 0 0.9997766
# 153 ('X509_check_issued', 'X509_check_akid')
# 0 1.0
# 154 ('ec_GFp_simple_cmp', 'EC_POINT_is_at_infinity')
# 0 0.99994123
# 155 ('ec_GFp_simple_cmp', 'BN_CTX_start')
# 0 0.9999495
# 156 ('ec_GFp_simple_cmp', 'BN_CTX_end')
# 0 0.99999213
# 157 ('ec_GFp_simple_cmp', 'BN_CTX_get')
# 0 0.99994695
# 158 ('ec_GFp_simple_cmp', 'BN_cmp')
# 0 1.0000001
# 159 ('ec_GFp_simple_cmp', 'BN_CTX_new')
# 0 0.9999341
# 160 ('ec_GFp_simple_cmp', 'BN_CTX_free')
# 0 0.99999684
# 161 ('EC_POINT_point2hex', 'CRYPTO_free')
# 0 0.99777806
# 162 ('EC_POINT_point2hex', 'CRYPTO_malloc')
# 0 0.9979278
# 163 ('EC_POINT_point2hex', 'EC_POINT_point2oct')
# 0 0.9985967
# 165 ('dynamic_ctrl', 'ERR_put_error')
# 0 0.9972777
# 166 ('dynamic_ctrl', 'sk_insert')
# 0 0.998278
# 168 ('dynamic_ctrl', 'CRYPTO_malloc')
# 0 0.9982967
# 169 ('dynamic_ctrl', 'CRYPTO_lock')
# 0 0.99794674
# 170 ('dynamic_ctrl', 'CRYPTO_free')
# 0 0.99829125
# 171 ('RSA_sign_ASN1_OCTET_STRING', 'CRYPTO_malloc')
# 0 0.996588
# 173 ('RSA_sign_ASN1_OCTET_STRING', 'OPENSSL_cleanse')
# 0 0.996059
# 174 ('RSA_sign_ASN1_OCTET_STRING', 'CRYPTO_free')
# 0 0.99624026
# 176 ('ASN1_STRING_free', 'CRYPTO_free')
# 0 1.0000001
# 177 ('OBJ_find_sigid_by_algs', 'sk_value')
# 0 0.9987455
# 178 ('OBJ_find_sigid_by_algs', 'sk_find')
# 0 0.9963068
# 179 ('camellia_256_cbc_cipher', 'Camellia_cbc_encrypt')
# 0 0.99857527
# 180 ('vpaes_cbc_encrypt', '_vpaes_encrypt_core')
# 1 0.9879069
# 181 ('vpaes_cbc_encrypt', '_vpaes_decrypt_core')
# 0 0.99997026
# 182 ('pkey_ec_paramgen', 'EC_KEY_free')
# 0 0.99987024
# 183 ('pkey_ec_paramgen', 'ERR_put_error')
# 3 0.96107143
# 184 ('pkey_ec_paramgen', 'EC_KEY_new')
# 0 0.99844384
# 186 ('pkey_ec_paramgen', 'EC_KEY_set_group')
# 0 0.9999063
# 187 ('CAST_ofb64_encrypt', 'CAST_encrypt')
# 0 0.9962176
# 189 ('ECParameters_print', 'EVP_PKEY_free')
# 0 0.99767655
# 190 ('ECParameters_print', 'EVP_PKEY_new')
# 0 0.99699074
# 191 ('ECParameters_print', 'EVP_PKEY_print_params')
# 0 0.9998195
# 192 ('ERR_get_error_line_data', 'CRYPTO_free')
# 0 0.9985887
# 193 ('ERR_get_error_line_data', 'ERR_get_state')
# 0 0.99742717
# 194 ('RAND_poll', 'OPENSSL_cleanse')
# 0 0.99782777
# 196 ('RAND_poll', 'RAND_query_egd_bytes')
# 0 0.9980445
# 197 ('ASN1_OBJECT_create', 'OBJ_dup')
# 0 0.9989247
# 198 ('long_c2i', 'ERR_put_error')
# 0 0.995561
# 199 ('X509V3_get_string', 'ERR_put_error')
# 3 0.9438126
# 209 ('BN_div_word', 'BN_num_bits_word')
# 0 0.9978166
# 210 ('BN_div_word', 'BN_lshift')
# 0 0.9993333
# 211 ('RSA_padding_add_none', 'ERR_put_error')
# 0 0.93670034
# 212 ('dh_pub_decode', 'X509_ALGOR_get0')
# 0 0.9988223
# 213 ('dh_pub_decode', 'ASN1_INTEGER_to_BN')
# 0 0.9987334
# 214 ('dh_pub_decode', 'DH_free')
# 0 0.9994733
# 215 ('dh_pub_decode', 'X509_PUBKEY_get0_param')
# 0 0.9988031
# 216 ('dh_pub_decode', 'ERR_put_error')
# 2 0.98902273
# 220 ('mime_hdr_new', 'CRYPTO_malloc')
# 0 0.99982727
# 221 ('mime_hdr_new', 'sk_new')
# 0 0.9996324
# 222 ('X509_to_X509_REQ', 'X509_get_pubkey')
# 0 0.99939775
# 224 ('X509_to_X509_REQ', 'X509_REQ_set_pubkey')
# 1 0.9993861
# 225 ('X509_to_X509_REQ', 'EVP_PKEY_free')
# 0 0.99813575
# 226 ('X509_to_X509_REQ', 'CRYPTO_malloc')
# 0 0.9994816
# 227 ('X509_to_X509_REQ', 'X509_REQ_set_subject_name')
# 0 0.9993861
# 228 ('X509_to_X509_REQ', 'ASN1_item_sign')
# 0 0.9982568
# 229 ('SMIME_read_ASN1', 'ASN1_item_d2i_bio')
# 0 0.9947458
# 230 ('SMIME_read_ASN1', 'sk_find')
# 1 0.99318326
# 231 ('SMIME_read_ASN1', 'sk_free')
# 2 0.9947479
# 232 ('SMIME_read_ASN1', 'multi_split')
# 0 0.99500394
# 234 ('SMIME_read_ASN1', 'mime_parse_hdr')
# 0 0.9953725
# 235 ('SMIME_read_ASN1', 'sk_pop_free')
# 5 0.9936617
# 237 ('SMIME_read_ASN1', 'sk_value')
# 0 0.9947499
# 238 ('SMIME_read_ASN1', 'sk_num')
# 0 0.99475104
# 239 ('SMIME_read_ASN1', 'BIO_ctrl')
# 1 0.99476904
# 240 ('SMIME_read_ASN1', 'BIO_free')
# 0 0.9947372
# 242 ('SMIME_read_ASN1', 'ERR_add_error_data')
# 1 0.99473554
# 243 ('SMIME_read_ASN1', 'ERR_put_error')
# 0 0.9938295
# 244 ('ENGINE_register_all_RAND', 'ENGINE_get_next')
# 1 0.97488046
# 245 ('ENGINE_register_all_RAND', 'ENGINE_get_first')
# 1 0.97423816
# 246 ('X509V3_EXT_conf_nid', 'CONF_set_nconf')
# 4 0.9983073
# 247 ('X509V3_EXT_conf_nid', 'X509V3_EXT_nconf_nid')
# 0 0.98466504
# 248 ('X509at_get_attr', 'sk_num')
# 0 1.0000001
# 249 ('PKCS5_v2_PBKDF2_keyivgen', 'EVP_PBE_find')
# 0 0.9973615
# 250 ('PKCS5_v2_PBKDF2_keyivgen', 'OBJ_nid2sn')
# 0 0.99671817
# 251 ('PKCS5_v2_PBKDF2_keyivgen', 'ERR_put_error')
# 3 0.9930213
# 252 ('PKCS5_v2_PBKDF2_keyivgen', 'PKCS5_PBKDF2_HMAC')
# 0 0.9976078
# 253 ('PKCS5_v2_PBKDF2_keyivgen', 'EVP_CipherInit_ex')
# 2 0.9941962
# 255 ('PKCS5_v2_PBKDF2_keyivgen', 'ASN1_INTEGER_get')
# 0 0.9974841
# 256 ('PKCS5_v2_PBKDF2_keyivgen', 'OPENSSL_cleanse')
# 0 0.9967194
# 257 ('PKCS5_v2_PBKDF2_keyivgen', 'OPENSSL_showfatal')
# 0 0.9967402
# 258 ('UI_ctrl', 'ERR_put_error')
# 0 0.96641564
# 259 ('aes_cfb1_cipher', 'CRYPTO_cfb128_1_encrypt')
# 0 0.99963856
# 261 ('obj_trust', 'sk_num')
# 0 1.0000001
# 262 ('obj_trust', 'sk_value')
# 0 1.0
# 264 ('ec_GFp_simple_dbl', 'BN_mod_sub_quick')
# 0 0.99999917
# 265 ('ec_GFp_simple_dbl', 'BN_copy')
# 2 0.9969456
# 266 ('ec_GFp_simple_dbl', 'BN_mod_lshift1_quick')
# 0 0.9999992
# 267 ('ec_GFp_simple_dbl', 'BN_mod_lshift_quick')
# 0 0.99999166
# 268 ('ec_GFp_simple_dbl', 'BN_CTX_new')
# 0 0.9999641
# 269 ('ec_GFp_simple_dbl', 'BN_set_word')
# 6 0.99736136
# 270 ('ec_GFp_simple_dbl', 'BN_CTX_end')
# 0 0.999995
# 271 ('ec_GFp_simple_dbl', 'BN_CTX_get')
# 0 0.9999687
# 272 ('ec_GFp_simple_dbl', 'EC_POINT_is_at_infinity')
# 0 0.9999678
# 273 ('ec_GFp_simple_dbl', 'BN_mod_add_quick')
# 0 0.9999992
# 274 ('ec_GFp_simple_dbl', 'BN_CTX_free')
# 0 0.99999744
# 275 ('ec_GFp_simple_dbl', 'BN_CTX_start')
# 0 0.99997073
# 276 ('app_info_free', 'app_info_free')
# 0 1.0
# 277 ('app_info_free', 'CRYPTO_free')
# 0 1.0000001
# 278 ('ASN1_INTEGER_set', 'CRYPTO_malloc')
# 0 0.9998804
# 279 ('ASN1_INTEGER_set', 'ERR_put_error')
# 0 0.99734074
# 280 ('ASN1_INTEGER_set', 'CRYPTO_free')
# 0 0.99988043
# 281 ('ERR_release_err_state_table', 'CRYPTO_lock')
# 1 0.9777335
# 282 ('SXNET_add_id_ulong', 'ASN1_STRING_free')
# 0 0.9998953
# 284 ('SXNET_add_id_ulong', 'ASN1_STRING_type_new')
# 0 0.99671805
# 285 ('SXNET_add_id_ulong', 'ASN1_INTEGER_set')
# 0 0.99987674
# 286 ('e_rsax_rsa_finish', 'BN_MONT_CTX_free')
# 0 0.9999999
# 287 ('e_rsax_rsa_finish', 'CRYPTO_free')
# 0 1.0
# 288 ('i2a_ASN1_STRING', 'BIO_write')
# 0 0.9972449
# 291 ('ENGINE_ctrl_cmd_string', 'ERR_clear_error')
# 2 0.9829595
# 292 ('ENGINE_ctrl_cmd_string', 'ERR_put_error')
# 1 0.9938842
# 293 ('rc4_hmac_md5_ctrl', 'MD5_Update')
# 0 0.99993056
# 294 ('rc4_hmac_md5_ctrl', 'MD5_Final')
# 0 0.9898928
# 296 ('X509_STORE_load_locations', 'X509_LOOKUP_ctrl')
# 0 1.0
# 298 ('CMS_add0_RevocationInfoChoice', 'ERR_put_error')
# 0 0.9889392
# 299 ('CMS_add0_RevocationInfoChoice', 'ASN1_item_free')
# 2 0.9894788
# 300 ('CMS_add0_RevocationInfoChoice', 'ASN1_item_new')
# 3 0.9835714
# 305 ('WHIRLPOOL_Update', 'WHIRLPOOL_BitUpdate')
# 0 0.99948376
# 306 ('ec_GF2m_simple_add', 'BN_CTX_end')
# 0 0.9999952
# 307 ('ec_GF2m_simple_add', 'BN_ucmp')
# 0 0.99999994
# 308 ('ec_GF2m_simple_add', 'EC_POINT_is_at_infinity')
# 0 0.999964
# 309 ('ec_GF2m_simple_add', 'EC_POINT_copy')
# 0 0.9999685
# 310 ('ec_GF2m_simple_add', 'BN_CTX_new')
# 0 0.99995977
# 311 ('ec_GF2m_simple_add', 'BN_CTX_start')
# 0 0.99996775
# 312 ('ec_GF2m_simple_add', 'BN_CTX_get')
# 0 0.99996555
# 313 ('ec_GF2m_simple_add', 'BN_copy')
# 2 0.9965339
# 314 ('ec_GF2m_simple_add', 'EC_POINT_get_affine_coordinates_GF2m')
# 1 0.99996483
# 315 ('ec_GF2m_simple_add', 'EC_POINT_set_affine_coordinates_GF2m')
# 0 0.99996483
# 316 ('ec_GF2m_simple_add', 'BN_CTX_free')
# 0 0.99999803
# 317 ('ec_GF2m_simple_add', 'EC_POINT_set_to_infinity')
# 1 0.999964
# 318 ('ec_GF2m_simple_add', 'BN_GF2m_add')
# 0 0.99999166
# 319 ('eckey_pub_decode', 'X509_PUBKEY_get0_param')
# 0 0.9993931
# 321 ('eckey_pub_decode', 'o2i_ECPublicKey')
# 0 0.99922323
# 322 ('eckey_pub_decode', 'X509_ALGOR_get0')
# 0 0.99940944
# 323 ('eckey_pub_decode', 'EC_KEY_free')
# 0 0.9995592
# 324 ('eckey_pub_decode', 'ERR_put_error')
# 6 0.9811968
# 325 ('eckey_pub_decode', 'eckey_type2param')
# 0 0.999437
# 326 ('v2i_AUTHORITY_INFO_ACCESS', 'ERR_put_error')
# 1 0.9939553
# 327 ('v2i_AUTHORITY_INFO_ACCESS', 'CRYPTO_free')
# 0 0.998809
# 328 ('v2i_AUTHORITY_INFO_ACCESS', 'CRYPTO_malloc')
# 0 0.9988063
# 329 ('v2i_AUTHORITY_INFO_ACCESS', 'sk_value')
# 0 0.9988081
# 331 ('v2i_AUTHORITY_INFO_ACCESS', 'sk_num')
# 0 0.9988076
# 332 ('v2i_AUTHORITY_INFO_ACCESS', 'sk_pop_free')
# 0 0.9949128
# 333 ('v2i_AUTHORITY_INFO_ACCESS', 'ERR_add_error_data')
# 0 0.99877536
# 336 ('i2d_PKCS8PrivateKey_nid_fp', 'BIO_new_fp')
# 0 0.99934965
# 337 ('i2d_PKCS8PrivateKey_nid_fp', 'BIO_free')
# 1 0.9995676
# 338 ('i2d_PKCS8PrivateKey_nid_fp', 'do_pk8pkey')
# 0 0.99569225
# 340 ('X509_PKEY_new', 'ERR_put_error')
# 8 0.9561177
# 341 ('X509_PKEY_new', 'CRYPTO_malloc')
# 0 0.9986424
# 342 ('X509_PKEY_new', 'ASN1_STRING_type_new')
# 0 0.99685055
# 348 ('ecdsa_check', 'CRYPTO_lock')
# 2 0.9785593
# 350 ('X509_policy_check', 'sk_num')
# 0 0.99841106
# 351 ('X509_policy_check', 'tree_find_sk')
# 0 0.99839854
# 352 ('X509_policy_check', 'X509_check_purpose')
# 6 0.9973513
# 353 ('X509_policy_check', 'OBJ_nid2obj')
# 1 0.99825346
# 354 ('X509_policy_check', 'CRYPTO_malloc')
# 0 0.9983973
# 355 ('X509_policy_check', 'sk_find')
# 0 0.9984026
# 356 ('X509_policy_check', 'sk_value')
# 0 0.9984085
# 357 ('X509_policy_check', 'level_find_node')
# 0 0.99839216
# 358 ('X509_policy_check', 'sk_delete')
# 0 0.9984007
# 359 ('X509_policy_check', 'CRYPTO_free')
# 0 0.9984046
# 360 ('X509_policy_check', 'policy_data_free')
# 0 0.9984001
# 361 ('X509_policy_check', 'policy_data_new')
# 0 0.9982999
# 362 ('X509_policy_check', 'policy_cache_set')
# 0 0.9967637
# 363 ('X509_policy_check', 'level_add_node')
# 0 0.99824363
# 364 ('X509_policy_check', 'X509_policy_tree_get0_user_policies')
# 0 0.99840677
# 366 ('X509_policy_check', 'sk_free')
# 0 0.9984037
# 367 ('X509_policy_check', 'policy_node_match')
# 0 0.99838805
# 368 ('X509_policy_check', 'OBJ_obj2nid')
# 2 0.9979728
# 369 ('X509_NAME_add_entry', 'sk_value')
# 0 0.9999894
# 370 ('X509_NAME_add_entry', 'sk_num')
# 0 0.99998957
# 371 ('X509_NAME_add_entry', 'sk_insert')
# 0 0.9998953
# 372 ('X509_NAME_add_entry', 'ERR_put_error')
# 1 0.9943199
# 373 ('pubkey_cb', 'EVP_PKEY_free')
# 0 0.9975575
# 374 ('pkey_rsa_cleanup', 'CRYPTO_free')
# 0 1.0000001
# 375 ('pkey_rsa_cleanup', 'BN_free')
# 0 0.99989915
# 376 ('dsa_cmp_parameters', 'BN_cmp')
# 0 1.0
# 381 ('ERR_remove_thread_state', 'CRYPTO_THREADID_current')
# 0 0.98595226
# 382 ('ERR_remove_thread_state', 'CRYPTO_lock')
# 0 0.9861754
# 383 ('UI_dup_verify_string', 'ERR_put_error')
# 0 0.99058276
# 384 ('UI_dup_verify_string', 'CRYPTO_malloc')
# 0 0.99925375
# 386 ('UI_dup_verify_string', 'CRYPTO_free')
# 0 0.9992346
# 387 ('cast5_ecb_cipher', 'CAST_ecb_encrypt')
# 1 0.99999994
# 388 ('CMS_RecipientInfo_ktri_get0_algs', 'ERR_put_error')
# 0 0.9615555
# 389 ('EVP_CipherInit_ex', 'ENGINE_get_cipher')
# 0 0.9974514
# 390 ('EVP_CipherInit_ex', 'ERR_put_error')
# 0 0.99661887
# 391 ('EVP_CipherInit_ex', 'ENGINE_init')
# 6 0.9944902
# 392 ('EVP_CipherInit_ex', 'CRYPTO_malloc')
# 0 0.9976496
# 393 ('EVP_CipherInit_ex', 'OPENSSL_showfatal')
# 0 0.99774253
# 395 ('TXT_DB_create_index', 'sk_num')
# 0 1.0
# 396 ('TXT_DB_create_index', 'sk_find')
# 0 0.99728525
# 397 ('TXT_DB_create_index', 'lh_insert')
# 0 0.99926615
# 398 ('TXT_DB_create_index', 'lh_free')
# 0 1.0
# 399 ('TXT_DB_create_index', 'sk_value')
# 0 1.0
# 400 ('engine_list_cleanup', 'ENGINE_remove')
# 0 0.9996052
# 401 ('PKCS5_PBKDF2_HMAC', 'HMAC')
# 3 0.98137975
# 402 ('PKCS5_PBKDF2_HMAC', 'HMAC_Init_ex')
# 0 0.997755
# 403 ('PKCS5_PBKDF2_HMAC', 'EVP_MD_size')
# 0 0.9986963
# 404 ('PKCS5_PBKDF2_HMAC', 'HMAC_Final')
# 0 0.9986684
# 405 ('PKCS5_PBKDF2_HMAC', 'EVP_MD_CTX_cleanup')
# 0 0.9987167
# 406 ('CRYPTO_dup_ex_data', 'CRYPTO_lock')
# 3 0.9791315
# 407 ('OBJ_NAME_get', 'lh_retrieve')
# 0 0.99833083
# 413 ('RAND_egd_bytes', 'RAND_query_egd_bytes')
# 0 0.99906874
# 420 ('EC_POINT_clear_free', 'OPENSSL_cleanse')
# 0 0.999221
# 421 ('EC_EX_DATA_free_data', 'CRYPTO_free')
# 0 1.0
# 422 ('open_console', 'CRYPTO_lock')
# 0 0.98591405
# 423 ('X509_REQ_add_extensions_nid', 'ASN1_item_i2d')
# 0 0.9988825
# 424 ('X509_REQ_add_extensions_nid', 'OBJ_nid2obj')
# 0 0.99806464
# 425 ('trust_1oid', 'sk_value')
# 0 1.0
# 426 ('trust_1oid', 'sk_num')
# 0 1.0
# 430 ('EVP_EncryptFinal_ex', 'ERR_put_error')
# 0 0.9826643
# 431 ('EVP_EncryptFinal_ex', 'OPENSSL_showfatal')
# 0 0.996042
# 432 ('ERR_load_ECDSA_strings', 'ERR_func_error_string')
# 1 0.9904341
# 433 ('ERR_load_ECDSA_strings', 'ERR_load_strings')
# 1 0.9985667
# 436 ('enc_write', 'BIO_write')
# 0 0.99954814
# 437 ('OTHERNAME_cmp', 'OBJ_cmp')
# 0 1.0
# 442 ('lh_delete', 'CRYPTO_free')
# 0 0.9998589
# 443 ('EC_POINT_new', 'CRYPTO_free')
# 0 0.99839854
# 444 ('EC_POINT_new', 'CRYPTO_malloc')
# 0 0.99849343
# 445 ('EC_POINT_new', 'ERR_put_error')
# 9 0.9763442
# 451 ('dh_priv_decode', 'DH_free')
# 0 0.99964315
# 452 ('dh_priv_decode', 'X509_ALGOR_get0')
# 0 0.99911535
# 453 ('dh_priv_decode', 'PKCS8_pkey_get0')
# 0 0.99921876
# 454 ('dh_priv_decode', 'ASN1_INTEGER_to_BN')
# 0 0.99897504
# 457 ('ENGINE_add', 'ERR_put_error')
# 0 0.9910595
# 458 ('ENGINE_add', 'CRYPTO_lock')
# 0 0.9948577
# 459 ('ENGINE_add', 'engine_cleanup_add_last')
# 0 0.99497914
# 460 ('BN_free', 'CRYPTO_free')
# 0 0.9998594
# 461 ('UI_set_result', 'BUF_strlcpy')
# 0 0.99932975
# 462 ('UI_set_result', 'ERR_add_error_data')
# 0 0.99929434
# 463 ('UI_set_result', 'BIO_snprintf')
# 2 0.9910861
# 464 ('UI_set_result', 'ERR_put_error')
# 0 0.9956266
# 465 ('int_thread_get', 'lh_new')
# 0 0.96657157
# 466 ('int_thread_get', 'CRYPTO_pop_info')
# 6 0.97426367
# 468 ('int_thread_get', 'CRYPTO_lock')
# 0 0.9778448
# 471 ('OCSP_check_validity', 'X509_cmp_time')
# 8 0.9792722
# 472 ('OCSP_check_validity', 'ASN1_STRING_cmp')
# 0 0.9985433
# 473 ('OCSP_check_validity', 'ERR_put_error')
# 0 0.9907557
# 474 ('OCSP_check_validity', 'ASN1_GENERALIZEDTIME_check')
# 0 0.99820405
# 475 ('pkey_rsa_ctrl_str', 'BN_free')
# 0 0.98134845
# 476 ('pkey_rsa_ctrl_str', 'BN_asc2bn')
# 0 0.9817685
# 477 ('pkey_rsa_ctrl_str', 'EVP_PKEY_CTX_ctrl')
# 0 0.982789
# 478 ('pkey_rsa_ctrl_str', 'ERR_put_error')
# 2 0.978393
# 479 ('HMAC_Final', 'EVP_MD_CTX_copy_ex')
# 0 0.99947965
# 480 ('HMAC_Final', 'EVP_DigestFinal_ex')
# 0 0.99785626
# 481 ('RSA_padding_add_PKCS1_PSS_mgf1', 'EVP_MD_CTX_cleanup')
# 0 0.9999002
# 482 ('RSA_padding_add_PKCS1_PSS_mgf1', 'RAND_bytes')
# 3 0.9971724
# 483 ('RSA_padding_add_PKCS1_PSS_mgf1', 'PKCS1_MGF1')
# 0 0.99982536
# 485 ('RSA_padding_add_PKCS1_PSS_mgf1', 'EVP_DigestFinal_ex')
# 0 0.9999161
# 486 ('RSA_padding_add_PKCS1_PSS_mgf1', 'EVP_MD_size')
# 0 0.99993014
# 487 ('RSA_padding_add_PKCS1_PSS_mgf1', 'CRYPTO_malloc')
# 0 0.99993217
# 488 ('RSA_padding_add_PKCS1_PSS_mgf1', 'EVP_DigestInit_ex')
# 0 0.9999077
# 489 ('RSA_padding_add_PKCS1_PSS_mgf1', 'CRYPTO_free')
# 0 0.9999323
# 490 ('RSA_padding_add_PKCS1_PSS_mgf1', 'ERR_put_error')
# 0 0.9994644
# 492 ('engine_pkey_meths_free', 'EVP_PKEY_meth_free')
# 0 0.99828327
# 493 ('aesni_cbc_hmac_sha1_cipher', 'aesni_cbc_sha1_enc')
# 0 0.99991864
# 494 ('aesni_cbc_hmac_sha1_cipher', 'SHA1_Final')
# 0 0.99941504
# 495 ('aesni_cbc_hmac_sha1_cipher', 'sha1_block_data_order')
# 0 0.99991405
# 496 ('aesni_cbc_hmac_sha1_cipher', 'aesni_cbc_encrypt')
# 0 0.99977183
# 497 ('aesni_cbc_hmac_sha1_cipher', 'SHA1_Update')
# 0 0.9999225
# 499 ('EVP_PBE_CipherInit', 'OBJ_nid2sn')
# 9 0.9902024
# 501 ('EVP_PBE_CipherInit', 'BUF_strlcpy')
# 5 0.99259675
# 505 ('bf_cfb64_cipher', 'BF_cfb64_encrypt')
# 0 0.9908619
# 506 ('X509V3_EXT_add_nconf_sk', 'sk_value')
# 0 0.99999994
# 507 ('X509V3_EXT_add_nconf_sk', 'X509V3_EXT_nconf')
# 0 0.99067
# 508 ('X509V3_EXT_add_nconf_sk', 'X509v3_add_ext')
# 0 0.99965334
# 509 ('X509V3_EXT_add_nconf_sk', 'sk_num')
# 0 1.0
# 510 ('X509V3_EXT_add_nconf_sk', 'NCONF_get_section')
# 0 0.9995073
# 511 ('X509_ATTRIBUTE_set1_object', 'ASN1_OBJECT_free')
# 1 0.99811506
# 512 ('X509_ATTRIBUTE_set1_object', 'OBJ_dup')
# 1 0.998926
# 513 ('PKCS5_PBE_keyivgen', 'ASN1_INTEGER_get')
# 0 0.99807024
# 514 ('PKCS5_PBE_keyivgen', 'EVP_MD_CTX_cleanup')
# 0 0.9980035
# 515 ('PKCS5_PBE_keyivgen', 'EVP_CipherInit_ex')
# 2 0.99281645
# 516 ('PKCS5_PBE_keyivgen', 'EVP_DigestInit_ex')
# 0 0.99873066
# 517 ('PKCS5_PBE_keyivgen', 'OPENSSL_cleanse')
# 0 0.9978052
# 518 ('PKCS5_PBE_keyivgen', 'EVP_MD_size')
# 0 0.9978347
# 519 ('PKCS5_PBE_keyivgen', 'ERR_put_error')
# 0 0.9960544
# 520 ('PKCS5_PBE_keyivgen', 'EVP_DigestFinal_ex')
# 0 0.9978051
# 521 ('PKCS5_PBE_keyivgen', 'OPENSSL_showfatal')
# 0 0.9978294
# 525 ('EVP_PKEY_free', 'sk_pop_free')
# 0 0.98844135
# 527 ('EC_GROUP_get_degree', 'ERR_put_error')
# 2 0.9074647
# 528 ('rsa_sig_print', 'i2a_ASN1_INTEGER')
# 0 0.99761677
# 530 ('rsa_sig_print', 'X509_signature_dump')
# 0 0.9977108
# 531 ('rsa_sig_print', 'BIO_puts')
# 0 0.99786
# 532 ('rsa_sig_print', 'i2a_ASN1_OBJECT')
# 0 0.997249
# 533 ('rsa_sig_print', 'OBJ_obj2nid')
# 6 0.9909733
# 534 ('hex_to_string', 'CRYPTO_malloc')
# 0 0.9904411
# 535 ('hex_to_string', 'ERR_put_error')
# 0 0.9686167
# 537 ('OBJ_NAME_add', 'CRYPTO_free')
# 0 0.988414
# 538 ('OBJ_NAME_add', 'CRYPTO_malloc')
# 0 0.989599
# 539 ('OBJ_NAME_add', 'sk_value')
# 0 0.9876713
# 540 ('OBJ_NAME_add', 'sk_num')
# 0 0.9871139
# 541 ('OBJ_NAME_add', 'lh_insert')
# 0 0.99661016
# 542 ('X509V3_parse_list', 'BUF_strdup')
# 3 0.99138755
# 543 ('X509V3_parse_list', 'ERR_put_error')
# 0 0.9983254
# 544 ('X509V3_parse_list', 'sk_pop_free')
# 0 0.99849856
# 545 ('X509V3_parse_list', 'X509V3_add_value')
# 0 0.99885917
# 546 ('X509V3_parse_list', 'CRYPTO_free')
# 0 0.9988399
# 547 ('dh_pub_cmp', 'BN_cmp')
# 0 1.0
# 549 ('X509_ATTRIBUTE_set1_data', 'ASN1_STRING_set_by_NID')
# 3 0.98975956
# 550 ('X509_ATTRIBUTE_set1_data', 'ASN1_TYPE_set')
# 0 0.99991274
# 552 ('X509_ATTRIBUTE_set1_data', 'ERR_put_error')
# 0 0.9945904
# 553 ('X509_ATTRIBUTE_set1_data', 'ASN1_STRING_set')
# 0 0.9997525
# 554 ('X509_ATTRIBUTE_set1_data', 'ASN1_STRING_type_new')
# 0 0.99971
# 555 ('ASN1_template_d2i', 'ASN1_get_object')
# 0 0.99934983
# 556 ('ASN1_template_d2i', 'ERR_put_error')
# 0 0.9958643
# 557 ('ASN1_template_d2i', 'asn1_template_noexp_d2i')
# 1 0.9815986
# 559 ('WHIRLPOOL_BitUpdate', 'whirlpool_block')
# 0 0.9994643
# 560 ('cms_EnvelopedData_init_bio', 'EVP_PKEY_encrypt_init')
# 0 0.9977701
# 561 ('cms_EnvelopedData_init_bio', 'ERR_put_error')
# 1 0.9965062
# 562 ('cms_EnvelopedData_init_bio', 'EVP_PKEY_CTX_free')
# 0 0.9978992
# 563 ('cms_EnvelopedData_init_bio', 'EVP_PKEY_CTX_ctrl')
# 0 0.99779296
# 564 ('cms_EnvelopedData_init_bio', 'EVP_PKEY_encrypt')
# 0 0.99782306
# 565 ('cms_EnvelopedData_init_bio', 'cms_EncryptedContent_init_bio')
# 0 0.99851084
# 566 ('cms_EnvelopedData_init_bio', 'AES_wrap_key')
# 0 0.99778605
# 567 ('cms_EnvelopedData_init_bio', 'OPENSSL_cleanse')
# 0 0.99775404
# 568 ('cms_EnvelopedData_init_bio', 'CRYPTO_malloc')
# 0 0.9977819
# 569 ('cms_EnvelopedData_init_bio', 'sk_value')
# 0 0.9977568
# 570 ('cms_EnvelopedData_init_bio', 'cms_RecipientInfo_pwri_crypt')
# 0 0.99776816
# 571 ('cms_EnvelopedData_init_bio', 'BIO_free')
# 0 0.9978276
# 572 ('cms_EnvelopedData_init_bio', 'ASN1_STRING_set0')
# 0 0.99775344
# 574 ('cms_EnvelopedData_init_bio', 'sk_num')
# 0 0.99775064
# 575 ('cms_EnvelopedData_init_bio', 'CRYPTO_free')
# 0 0.99776566
# 576 ('BIO_set_cipher', 'EVP_CipherInit_ex')
# 0 0.9976339
# 577 ('check_policy', 'X509_policy_check')
# 0 0.99831736
# 578 ('check_policy', 'sk_value')
# 0 0.99938214
# 579 ('check_policy', 'sk_num')
# 0 0.9993649
# 580 ('check_policy', 'ERR_put_error')
# 1 0.9873909
# 581 ('BN_from_montgomery_word', 'bn_mul_add_words')
# 0 0.99512434
# 582 ('BN_from_montgomery_word', 'bn_expand2')
# 0 0.9988762
# 583 ('BN_from_montgomery_word', 'bn_sub_words')
# 0 0.99884874
# 586 ('BN_GF2m_mod_sqr', 'BN_GF2m_mod_sqr_arr')
# 6 0.9739199
# 589 ('BN_mod_exp2_mont', 'BN_is_bit_set')
# 0 0.9998641
# 590 ('BN_mod_exp2_mont', 'BN_div')
# 0 0.99979794
# 591 ('BN_mod_exp2_mont', 'BN_MONT_CTX_free')
# 0 0.99986416
# 592 ('BN_mod_exp2_mont', 'BN_from_montgomery')
# 0 0.9998643
# 593 ('BN_mod_exp2_mont', 'BN_MONT_CTX_set')
# 0 0.99986213
# 594 ('BN_mod_exp2_mont', 'BN_ucmp')
# 0 0.9998643
# 595 ('BN_mod_exp2_mont', 'BN_MONT_CTX_new')
# 0 0.9998484
# 596 ('BN_mod_exp2_mont', 'BN_mod_mul_montgomery')
# 0 0.999864
# 597 ('BN_mod_exp2_mont', 'BN_CTX_start')
# 0 0.99985456
# 599 ('BN_mod_exp2_mont', 'BN_CTX_get')
# 0 0.9998539
# 600 ('BN_mod_exp2_mont', 'BN_set_word')
# 3 0.99897796
# 601 ('BN_mod_exp2_mont', 'BN_CTX_end')
# 0 0.99986285
# 602 ('BN_mod_exp2_mont', 'ERR_put_error')
# 0 0.99957657
# 603 ('def_load_bio', 'CRYPTO_free')
# 0 0.99991107
# 604 ('def_load_bio', 'BUF_MEM_grow')
# 0 0.99990374
# 605 ('def_load_bio', 'CRYPTO_malloc')
# 0 0.9999111
# 606 ('def_load_bio', 'ERR_add_error_data')
# 0 0.99991083
# 607 ('def_load_bio', 'CONF_free')
# 7 0.9998142
# 608 ('def_load_bio', 'BIO_snprintf')
# 6 0.99965876
# 609 ('def_load_bio', '_CONF_add_string')
# 0 0.9999111
# 610 ('def_load_bio', 'ERR_put_error')
# 0 0.9997934
# 611 ('def_load_bio', 'BUF_MEM_free')
# 0 0.99991107
# 612 ('def_load_bio', '_CONF_new_section')
# 0 0.9998639
# 613 ('def_load_bio', 'str_copy')
# 0 0.99990505
# 614 ('def_load_bio', '_CONF_get_section')
# 0 0.99991065
# 615 ('def_load_bio', 'BUF_MEM_new')
# 0 0.99989426
# 616 ('def_load_bio', 'BUF_strlcpy')
# 0 0.9999107
# 617 ('def_load_bio', '_CONF_new_data')
# 0 0.9999094
# 618 ('def_load_bio', 'BIO_gets')
# 0 0.9999097
# 619 ('EVP_PKEY_asn1_add0', 'sk_sort')
# 0 0.99984974
# 620 ('EVP_PKEY_asn1_add0', 'sk_new')
# 0 0.998745
# 621 ('ERR_put_error', 'ERR_get_state')
# 1 0.9971955
# 622 ('ERR_put_error', 'CRYPTO_free')
# 0 0.93658197
# 623 ('b64_free', 'CRYPTO_free')
# 0 0.9997035
# 624 ('OBJ_find_sigid_algs', 'sk_find')
# 0 0.99634236
# 625 ('OBJ_find_sigid_algs', 'sk_value')
# 0 0.9986803
# 626 ('ec_GFp_mont_field_mul', 'ERR_put_error')
# 1 0.9135192
# 633 ('X509_STORE_CTX_set0_param', 'X509_VERIFY_PARAM_free')
# 0 0.99066776
# 635 ('BIO_read', 'ERR_put_error')
# 0 0.98495215
# 637 ('rsa_pub_print', 'CRYPTO_free')
# 0 0.99865365
# 638 ('rsa_pub_print', 'ASN1_bn_print')
# 0 0.9985263
# 640 ('rsa_pub_print', 'CRYPTO_malloc')
# 0 0.9987027
# 641 ('rsa_pub_print', 'ERR_put_error')
# 2 0.9890204
# 643 ('rsa_pub_print', 'BIO_printf')
# 0 0.99857664
# 644 ('RC2_ofb64_encrypt', 'RC2_encrypt')
# 0 0.9980365
# 645 ('X509_reject_clear', 'sk_pop_free')
# 3 0.97419655
# 646 ('X509_EXTENSION_set_object', 'ASN1_OBJECT_free')
# 0 0.99811506
# 647 ('X509_EXTENSION_set_object', 'OBJ_dup')
# 0 0.998926
# 648 ('sig_cb', 'CRYPTO_malloc')
# 0 0.99844694
# 649 ('sig_cb', 'ERR_put_error')
# 0 0.9525792
# 650 ('MD4_Update', 'md4_block_data_order')
# 0 0.99366164
# 653 ('enc_read', 'BIO_read')
# 0 0.9997487
# 654 ('X509_PUBKEY_set', 'ERR_put_error')
# 0 0.9864814
# 656 ('ERR_load_COMP_strings', 'ERR_load_strings')
# 2 0.9985667
# 657 ('ERR_load_COMP_strings', 'ERR_func_error_string')
# 2 0.9904341
# 658 ('ec_GFp_mont_field_encode', 'ERR_put_error')
# 3 0.90877956
# 659 ('RIPEMD160_Update', 'ripemd160_block_data_order')
# 0 0.9999764
# 660 ('dsa_param_print', 'ERR_put_error')
# 3 0.98889464
# 661 ('dsa_param_print', 'CRYPTO_malloc')
# 0 0.9975514
# 663 ('dsa_param_print', 'CRYPTO_free')
# 0 0.9974576
# 664 ('dsa_param_print', 'ASN1_bn_print')
# 0 0.9979936
# 665 ('ENGINE_load_rsax', 'ENGINE_add')
# 0 0.99369085
# 666 ('ENGINE_load_rsax', 'ENGINE_set_id')
# 6 0.98947483
# 667 ('ENGINE_load_rsax', 'ENGINE_set_name')
# 3 0.9894847
# 668 ('ENGINE_load_rsax', 'ENGINE_new')
# 1 0.98952854
# 669 ('X509_POLICY_NODE_print', 'BIO_printf')
# 0 0.9932306
# 670 ('X509_POLICY_NODE_print', 'i2a_ASN1_OBJECT')
# 0 0.9938106
# 671 ('X509_POLICY_NODE_print', 'BIO_puts')
# 0 0.9985493
# 672 ('DSO_merge', 'ERR_put_error')
# 0 0.9648597
# 678 ('BN_mod_exp_recp', 'BN_copy')
# 2 0.9967112
# 679 ('BN_mod_exp_recp', 'BN_CTX_end')
# 0 0.99998534
# 680 ('BN_mod_exp_recp', 'BN_nnmod')
# 6 0.9982663
# 681 ('BN_mod_exp_recp', 'BN_RECP_CTX_set')
# 0 0.99998945
# 682 ('BN_mod_exp_recp', 'BN_RECP_CTX_free')
# 0 0.9999899
# 683 ('BN_mod_exp_recp', 'ERR_put_error')
# 0 0.9990883
# 684 ('BN_mod_exp_recp', 'BN_CTX_get')
# 0 0.99995893
# 686 ('BN_mod_exp_recp', 'BN_set_word')
# 3 0.99714583
# 688 ('BN_mod_exp_recp', 'BN_CTX_start')
# 0 0.99996096
# 689 ('BN_mod_exp_recp', 'BN_is_bit_set')
# 0 0.9999899
# 690 ('X509_print_ex', 'X509_signature_print')
# 2 0.9944965
# 691 ('X509_print_ex', 'X509_get_pubkey')
# 0 0.9973396
# 692 ('X509_print_ex', 'EVP_PKEY_free')
# 0 0.99584603
# 693 ('X509_print_ex', 'ASN1_INTEGER_get')
# 0 0.9953721
# 694 ('X509_print_ex', 'EVP_PKEY_print_public')
# 0 0.9972962
# 695 ('X509_print_ex', 'X509V3_extensions_print')
# 3 0.99458325
# 696 ('X509_print_ex', 'BIO_printf')
# 0 0.9973334
# 698 ('X509_print_ex', 'X509_NAME_print_ex')
# 2 0.9893969
# 699 ('X509_print_ex', 'BIO_puts')
# 0 0.9959535
# 700 ('X509_print_ex', 'BIO_write')
# 0 0.995903
# 702 ('EVP_PKEY_sign_init', 'ERR_put_error')
# 7 0.9634655
# 703 ('EC_GROUP_new_curve_GFp', 'ERR_peek_last_error')
# 0 1.0
# 704 ('EC_GROUP_new_curve_GFp', 'ERR_clear_error')
# 0 0.98988235
# 706 ('EC_GROUP_new_curve_GFp', 'EC_GROUP_set_curve_GFp')
# 0 0.99989915
# 707 ('EC_GROUP_new_curve_GFp', 'EC_GROUP_new')
# 0 0.99841166
# 710 ('bn_rand_range', 'ERR_put_error')
# 0 0.9961169
# 711 ('bn_rand_range', 'BN_cmp')
# 0 0.9987438
# 712 ('bn_rand_range', 'BN_is_bit_set')
# 0 0.9993243
# 713 ('bn_rand_range', 'BN_sub')
# 0 0.99864364
# 714 ('cms_si_cb', 'EVP_PKEY_free')
# 0 0.9976305
# 715 ('X509_NAME_print_ex', 'X509_NAME_ENTRY_get_object')
# 0 0.99922395
# 716 ('X509_NAME_print_ex', 'X509_NAME_get_entry')
# 0 0.9992262
# 717 ('X509_NAME_print_ex', 'OBJ_obj2txt')
# 0 0.9967132
# 718 ('X509_NAME_print_ex', 'X509_NAME_ENTRY_get_data')
# 0 0.999224
# 719 ('X509_NAME_print_ex', 'do_print_ex.constprop.3')
# 0 0.9995699
# 720 ('X509_NAME_print_ex', 'OBJ_nid2sn')
# 0 0.9990414
# 721 ('X509_NAME_print_ex', 'OBJ_obj2nid')
# 5 0.9951367
# 722 ('X509_NAME_print_ex', 'X509_NAME_entry_count')
# 0 0.9992238
# 723 ('X509_NAME_print_ex', 'OBJ_nid2ln')
# 0 0.99905026
# 724 ('X509_NAME_print_ex', 'BIO_write')
# 0 0.9991937
# 725 ('X509_NAME_print_ex', 'X509_NAME_print')
# 0 0.9992448
# 726 ('ERR_load_ERR_strings', 'CRYPTO_lock')
# 0 0.99004644
# 728 ('PKCS7_get_issuer_and_serial', 'sk_num')
# 0 1.0
# 729 ('PKCS7_get_issuer_and_serial', 'sk_value')
# 0 1.0
# 730 ('OBJ_NAME_new_index', 'CRYPTO_malloc')
# 0 0.99973017
# 731 ('OBJ_NAME_new_index', 'ERR_put_error')
# 1 0.987889
# 732 ('OBJ_NAME_new_index', 'sk_value')
# 0 0.9997123
# 733 ('OBJ_NAME_new_index', 'CRYPTO_mem_ctrl')
# 0 0.9971627
# 734 ('OBJ_NAME_new_index', 'sk_num')
# 0 0.9997058
# 735 ('PEM_bytes_read_bio', 'PEM_read_bio')
# 0 0.9916884
# 736 ('PEM_bytes_read_bio', 'ENGINE_finish')
# 9 0.98754567
# 737 ('PEM_bytes_read_bio', 'CRYPTO_free')
# 3 0.9919339
# 738 ('PEM_bytes_read_bio', 'ERR_peek_error')
# 6 0.9919006
# 739 ('PEM_bytes_read_bio', 'PEM_do_header')
# 0 0.9921228
# 740 ('PEM_bytes_read_bio', 'ERR_add_error_data')
# 4 0.9919257
# 741 ('PEM_bytes_read_bio', 'PEM_get_EVP_CIPHER_INFO')
# 0 0.99184805
# 742 ('PEM_bytes_read_bio', 'EVP_PKEY_asn1_find_str')
# 0 0.9911759
# 743 ('ENGINE_remove', 'CRYPTO_lock')
# 0 0.9968177
# 744 ('ENGINE_remove', 'ERR_put_error')
# 0 0.99188596
# 745 ('ENGINE_remove', 'engine_free_util')
# 0 0.9995372
# 746 ('get_cert_by_subject', 'X509_load_crl_file')
# 1 0.9989523
# 747 ('get_cert_by_subject', 'CRYPTO_malloc')
# 0 0.99886036
# 748 ('get_cert_by_subject', 'BUF_MEM_free')
# 0 0.9988568
# 749 ('get_cert_by_subject', 'BIO_snprintf')
# 3 0.99627864
# 750 ('get_cert_by_subject', 'X509_load_cert_file')
# 0 0.9989523
# 751 ('get_cert_by_subject', 'X509_NAME_hash')
# 0 0.99885315
# 752 ('get_cert_by_subject', 'CRYPTO_free')
# 0 0.99885654
# 753 ('get_cert_by_subject', 'sk_value')
# 0 0.998854
# 754 ('get_cert_by_subject', 'sk_num')
# 0 0.9988522
# 755 ('get_cert_by_subject', 'BUF_MEM_new')
# 0 0.9987263
# 756 ('get_cert_by_subject', 'BUF_MEM_grow')
# 0 0.9988491
# 757 ('get_cert_by_subject', 'ERR_put_error')
# 1 0.99778754
# 758 ('get_cert_by_subject', 'CRYPTO_lock')
# 0 0.9984763
# 759 ('get_cert_by_subject', 'sk_find')
# 0 0.99803
# 760 ('rc2_ofb_cipher', 'RC2_ofb64_encrypt')
# 0 0.9984728
# 762 ('PEM_get_EVP_CIPHER_INFO', 'ERR_put_error')
# 0 0.9935857
# 763 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_CTX_end')
# 0 0.9992658
# 764 ('ec_GFp_simple_point_get_affine_coordinates', 'ERR_put_error')
# 0 0.99809855
# 765 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_CTX_free')
# 0 0.9992888
# 766 ('ec_GFp_simple_point_get_affine_coordinates', 'EC_POINT_is_at_infinity')
# 0 0.9992324
# 767 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_CTX_start')
# 0 0.999289
# 768 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_CTX_new')
# 0 0.99922055
# 769 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_mod_sqr')
# 0 0.9992615
# 770 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_CTX_get')
# 0 0.99930435
# 771 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_mod_mul')
# 0 0.99800974
# 772 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_mod_inverse')
# 0 0.99979395
# 773 ('ec_GFp_simple_point_get_affine_coordinates', 'BN_copy')
# 2 0.9948393
# 775 ('DSA_free', 'CRYPTO_free_ex_data')
# 1 0.9984101
# 777 ('DSA_free', 'BN_clear_free')
# 0 0.9998466
# 782 ('X509at_add1_attr', 'sk_free')
# 0 0.9993604
# 784 ('ENGINE_register_all_DH', 'ENGINE_get_next')
# 3 0.97488046
# 785 ('ENGINE_register_all_DH', 'ENGINE_get_first')
# 3 0.9742381
# 786 ('X509_STORE_new', 'X509_VERIFY_PARAM_new')
# 0 0.9923227
# 787 ('X509_STORE_new', 'sk_new')
# 0 0.996161
# 788 ('X509_STORE_new', 'CRYPTO_free')
# 0 0.9962688
# 789 ('X509_STORE_new', 'CRYPTO_malloc')
# 0 0.99691564
# 790 ('X509_STORE_new', 'sk_free')
# 0 0.99637216
# 791 ('X509_STORE_new', 'CRYPTO_new_ex_data')
# 0 0.9848516
# 799 ('OPENSSL_cpuid_setup', 'OPENSSL_ia32_cpuid')
# 0 0.9979934
# 800 ('EVP_DigestSignFinal', 'EVP_MD_CTX_cleanup')
# 0 0.9979207
# 801 ('EVP_DigestSignFinal', 'EVP_PKEY_sign')
# 0 0.99765426
# 802 ('EVP_DigestSignFinal', 'EVP_MD_CTX_copy_ex')
# 0 0.99879867
# 803 ('EVP_DigestSignFinal', 'EVP_DigestFinal_ex')
# 0 0.99691206
# 804 ('EVP_DigestSignFinal', 'EVP_MD_size')
# 0 0.99682033
# 805 ('i2r_PKEY_USAGE_PERIOD', 'BIO_printf')
# 0 0.9940807
# 806 ('i2r_PKEY_USAGE_PERIOD', 'ASN1_GENERALIZEDTIME_print')
# 0 0.9980599
# 807 ('i2r_PKEY_USAGE_PERIOD', 'BIO_write')
# 0 0.9978373
# 808 ('X509_NAME_get_entry', 'sk_num')
# 0 1.0
# 809 ('dsa_pub_decode', 'ERR_put_error')
# 0 0.99268925
# 810 ('dsa_pub_decode', 'X509_ALGOR_get0')
# 0 0.9988947
# 811 ('dsa_pub_decode', 'X509_PUBKEY_get0_param')
# 0 0.99888176
# 813 ('dsa_pub_decode', 'DSA_free')
# 0 0.9993648
# 814 ('dsa_pub_decode', 'ASN1_INTEGER_to_BN')
# 0 0.99882954
# 815 ('dlfcn_bind_var', 'ERR_add_error_data')
# 0 0.99854636
# 816 ('dlfcn_bind_var', 'ERR_put_error')
# 0 0.98013103
# 817 ('dlfcn_bind_var', 'sk_num')
# 0 0.99859303
# 818 ('dlfcn_bind_var', 'sk_value')
# 0 0.99862653
# 819 ('str_copy', 'BUF_MEM_new')
# 0 0.99981374
# 820 ('str_copy', 'BUF_MEM_grow')
# 0 0.99987864
# 821 ('str_copy', 'ERR_put_error')
# 0 0.99915016
# 822 ('str_copy', 'BUF_MEM_grow_clean')
# 0 0.9998577
# 823 ('str_copy', 'CRYPTO_free')
# 0 0.99991703
# 824 ('str_copy', 'BUF_MEM_free')
# 0 0.99991685
# 825 ('str_copy', '_CONF_get_string')
# 0 0.9998871
# 826 ('ENGINE_register_all_ECDH', 'ENGINE_get_next')
# 4 0.97488046
# 827 ('ENGINE_register_all_ECDH', 'ENGINE_get_first')
# 4 0.97423816
# 828 ('EVP_MD_do_all', 'OBJ_NAME_do_all')
# 0 0.9996171
# 829 ('MDC2_Update', 'mdc2_body')
# 0 0.99662983
# 832 ('cms_ri_cb', 'OPENSSL_cleanse')
# 0 0.9995998
# 833 ('cms_ri_cb', 'EVP_PKEY_free')
# 0 0.9984194
# 834 ('cms_ri_cb', 'CRYPTO_free')
# 0 1.0
# 836 ('EC_KEY_set_private_key', 'BN_clear_free')
# 0 1.0000001
# 837 ('X509_ATTRIBUTE_create', 'ASN1_TYPE_set')
# 0 0.9862085
# 838 ('X509_ATTRIBUTE_create', 'OBJ_nid2obj')
# 0 0.99256635
# 839 ('BN_gcd', 'BN_CTX_end')
# 0 0.9999858
# 840 ('BN_gcd', 'BN_CTX_start')
# 0 0.9999242
# 841 ('BN_gcd', 'BN_CTX_get')
# 0 0.99992174
# 842 ('BN_gcd', 'BN_copy')
# 2 0.9922401
# 843 ('BN_gcd', 'BN_sub')
# 0 0.9999984
# 844 ('BN_gcd', 'BN_lshift')
# 0 0.99997854
# 845 ('BN_gcd', 'BN_rshift1')
# 0 0.9999984
# 846 ('BN_gcd', 'BN_cmp')
# 0 0.9999986
# 847 ('CMS_get0_SignerInfos', 'ERR_put_error')
# 0 0.94435227
# 850 ('CRYPTO_dbg_malloc', 'CRYPTO_THREADID_current')
# 0 0.9911452
# 851 ('CRYPTO_dbg_malloc', 'lh_insert')
# 1 0.98680425
# 852 ('CRYPTO_dbg_malloc', 'lh_retrieve')
# 2 0.9909742
# 853 ('CRYPTO_dbg_malloc', 'CRYPTO_malloc')
# 0 0.9918203
# 854 ('CRYPTO_dbg_malloc', 'CRYPTO_free')
# 0 0.992176
# 855 ('EC_GROUP_check_discriminant', 'ERR_put_error')
# 5 0.90080243
# 856 ('seed_ecb_cipher', 'SEED_ecb_encrypt')
# 0 0.9999998
# 858 ('PKCS7_set_type', 'ASN1_STRING_type_new')
# 0 0.99892217
# 859 ('PKCS7_set_type', 'OBJ_nid2obj')
# 0 0.99845344
# 860 ('PKCS7_set_type', 'ASN1_INTEGER_set')
# 0 0.99953216
# 861 ('PKCS7_set_type', 'ERR_put_error')
# 0 0.9946043
# 862 ('EC_POINT_invert', 'ERR_put_error')
# 9 0.9483896
# 863 ('CRYPTO_gcm128_release', 'OPENSSL_cleanse')
# 0 0.99868274
# 864 ('ASN1_TYPE_set', 'ASN1_primitive_free')
# 1 0.9850229
# 866 ('CRYPTO_dbg_free', 'lh_delete')
# 1 0.98726326
# 867 ('CRYPTO_dbg_free', 'CRYPTO_free')
# 4 0.99134564
# 868 ('CRYPTO_dbg_free', 'app_info_free')
# 2 0.9904021
# 869 ('xptable_free', 'CRYPTO_free')
# 0 1.0000001
# 870 ('ENGINE_register_ciphers', 'engine_table_register')
# 0 0.99723434
# 871 ('i2o_ECPublicKey', 'ERR_put_error')
# 3 0.9849446
# 872 ('i2o_ECPublicKey', 'CRYPTO_malloc')
# 0 0.99937755
# 873 ('i2o_ECPublicKey', 'EC_POINT_point2oct')
# 0 0.9993295
# 874 ('i2o_ECPublicKey', 'CRYPTO_free')
# 0 0.9993548
# 880 ('DSA_SIG_new', 'CRYPTO_malloc')
# 3 0.99448866
# 881 ('NCONF_get_string', '_CONF_get_string')
# 0 0.9993288
# 883 ('NCONF_get_string', 'ERR_add_error_data')
# 0 0.997926
# 884 ('ecdh_compute_key', 'EC_POINT_get_affine_coordinates_GF2m')
# 0 0.99879616
# 885 ('ecdh_compute_key', 'BN_CTX_new')
# 0 0.99876237
# 886 ('ecdh_compute_key', 'BN_bn2bin')
# 0 0.99705297
# 888 ('ecdh_compute_key', 'EC_POINT_get_affine_coordinates_GFp')
# 1 0.99879616
# 890 ('ecdh_compute_key', 'EC_POINT_new')
# 0 0.99876577
# 891 ('ecdh_compute_key', 'BN_CTX_start')
# 0 0.99896336
# 892 ('ecdh_compute_key', 'EC_GROUP_get_degree')
# 0 0.9988347
# 893 ('ecdh_compute_key', 'EC_POINT_free')
# 0 0.9988538
# 894 ('ecdh_compute_key', 'BN_CTX_get')
# 0 0.99900824
# 895 ('ecdh_compute_key', 'ERR_put_error')
# 1 0.9962573
# 896 ('ecdh_compute_key', 'BN_CTX_end')
# 0 0.99886364
# 897 ('ecdh_compute_key', 'BN_CTX_free')
# 0 0.99893093
# 898 ('ecdh_compute_key', 'CRYPTO_free')
# 0 0.9988551
# 899 ('ecdh_compute_key', 'CRYPTO_malloc')
# 0 0.99886674
# 900 ('BN_bn2hex', 'ERR_put_error')
# 0 0.98348594
# 901 ('BN_bn2hex', 'CRYPTO_malloc')
# 0 0.9880794
# 902 ('X509_NAME_hash_old', 'EVP_DigestInit_ex')
# 0 0.9997123
# 903 ('X509_NAME_hash_old', 'EVP_MD_CTX_cleanup')
# 0 0.99870795
# 904 ('X509_NAME_hash_old', 'EVP_DigestFinal_ex')
# 0 0.99740255
# 905 ('dsa_sign_setup', 'BN_mod_inverse')
# 0 0.9994535
# 906 ('dsa_sign_setup', 'BN_div')
# 0 0.99876875
# 907 ('dsa_sign_setup', 'BN_copy')
# 7 0.9906898
# 909 ('dsa_sign_setup', 'BN_mod_exp_mont')
# 0 0.99869233
# 911 ('dsa_sign_setup', 'BN_CTX_free')
# 0 0.99620295
# 912 ('dsa_sign_setup', 'BN_add')
# 0 0.9961727
# 913 ('dsa_sign_setup', 'BN_MONT_CTX_set_locked')
# 1 0.9954794
# 916 ('dsa_sign_setup', 'BN_clear_free')
# 0 0.99613565
# 917 ('EVP_DecryptUpdate', 'OPENSSL_showfatal')
# 7 0.96536916
# 918 ('EC_POINT_is_at_infinity', 'ERR_put_error')
# 3 0.9475764
# 924 ('dynamic_load', 'DSO_free')
# 0 0.99931186
# 925 ('dynamic_load', 'CRYPTO_free')
# 0 0.99942124
# 926 ('dynamic_load', 'sk_value')
# 0 0.9994171
# 927 ('dynamic_load', 'CRYPTO_get_mem_functions')
# 0 0.9994213
# 928 ('dynamic_load', 'ERR_get_implementation')
# 0 0.9985644
# 929 ('dynamic_load', 'DSO_merge')
# 0 0.99940276
# 930 ('dynamic_load', 'DSO_convert_filename')
# 0 0.9993356
# 931 ('dynamic_load', 'DSO_bind_func')
# 0 0.99929374
# 932 ('dynamic_load', 'ENGINE_add')
# 0 0.99736035
# 933 ('dynamic_load', 'sk_num')
# 0 0.9994143
# 934 ('dynamic_load', 'DSO_load')
# 1 0.9963411
# 935 ('dynamic_load', 'ERR_put_error')
# 1 0.99710625
# 936 ('dynamic_load', 'CRYPTO_get_ex_data_implementation')
# 1 0.9985644
# 937 ('dynamic_load', 'ERR_clear_error')
# 0 0.9923525
# 938 ('UI_add_verify_string', 'ERR_put_error')
# 3 0.98774505
# 939 ('UI_add_verify_string', 'CRYPTO_free')
# 0 0.99950176
# 940 ('UI_add_verify_string', 'CRYPTO_malloc')
# 0 0.99951804
# 941 ('ec_GFp_simple_invert', 'EC_POINT_is_at_infinity')
# 0 0.9981923
# 942 ('RSA_verify_ASN1_OCTET_STRING', 'ASN1_STRING_free')
# 0 0.999298
# 943 ('RSA_verify_ASN1_OCTET_STRING', 'CRYPTO_free')
# 0 0.9992843
# 944 ('RSA_verify_ASN1_OCTET_STRING', 'ERR_put_error')
# 3 0.98967105
# 945 ('RSA_verify_ASN1_OCTET_STRING', 'CRYPTO_malloc')
# 0 0.9993044
# 946 ('RSA_verify_ASN1_OCTET_STRING', 'OPENSSL_cleanse')
# 0 0.9990553
# 948 ('pkey_dsa_sign', 'DSA_sign')
# 0 0.9998977
# 949 ('d2i_ASN1_type_bytes', 'CRYPTO_free')
# 0 0.9997402
# 950 ('d2i_ASN1_type_bytes', 'ASN1_get_object')
# 0 0.9997676
# 951 ('d2i_ASN1_type_bytes', 'CRYPTO_malloc')
# 0 0.9997423
# 952 ('d2i_ASN1_type_bytes', 'ERR_put_error')
# 0 0.9958986
# 953 ('d2i_ASN1_type_bytes', 'ASN1_STRING_free')
# 0 0.9997424
# 954 ('d2i_ASN1_type_bytes', 'ASN1_tag2bit')
# 0 0.9991348
# 955 ('X509_load_crl_file', 'ERR_clear_error')
# 0 0.9913299
# 956 ('X509_load_crl_file', 'BIO_new')
# 0 0.9957102
# 957 ('X509_load_crl_file', 'ERR_put_error')
# 0 0.9952961
# 959 ('X509_load_crl_file', 'BIO_free')
# 0 0.99944687
# 960 ('X509_load_crl_file', 'BIO_ctrl')
# 1 0.9994614
# 961 ('X509_load_crl_file', 'ERR_peek_last_error')
# 0 0.99943686
# 962 ('X509_STORE_CTX_get1_chain', 'sk_num')
# 0 0.9998434
# 965 ('X509_STORE_CTX_get1_chain', 'sk_value')
# 0 0.99985164
# 966 ('seed_cfb128_cipher', 'CRYPTO_cfb128_encrypt')
# 0 0.9999999
# 967 ('do_pk8pkey', 'PKCS8_encrypt')
# 0 0.9962494
# 968 ('do_pk8pkey', 'PEM_ASN1_write_bio')
# 0 0.9937928
# 969 ('do_pk8pkey', 'ERR_put_error')
# 0 0.9913418
# 970 ('do_pk8pkey', 'OPENSSL_cleanse')
# 0 0.9956189
# 971 ('do_pk8pkey', 'PEM_def_callback')
# 0 0.99558413
# 972 ('des_ede_cfb64_cipher', 'DES_ede3_cfb64_encrypt')
# 0 0.99008447
# 973 ('_CONF_get_string', 'lh_retrieve')
# 0 0.9996513
# 974 ('asn1_enc_save', 'CRYPTO_malloc')
# 0 0.9998219
# 975 ('asn1_enc_save', 'CRYPTO_free')
# 0 0.99981296
# 976 ('asn1_enc_free', 'CRYPTO_free')
# 0 0.9991674
# 977 ('camellia_256_cfb1_cipher', 'CRYPTO_cfb128_1_encrypt')
# 0 0.9999999
# 982 ('b64_read', 'BIO_read')
# 0 0.9999447
# 983 ('b64_read', 'EVP_DecodeUpdate')
# 0 0.99957186
# 984 ('b64_read', 'EVP_DecodeBlock')
# 0 0.99984777
# 985 ('b64_read', 'OPENSSL_showfatal')
# 0 0.9999501
# 986 ('aesni_cbc_hmac_sha1_init_key', 'aesni_set_decrypt_key')
# 0 0.99999994
# 987 ('aesni_cbc_hmac_sha1_init_key', 'aesni_set_encrypt_key')
# 0 0.99998707
# 988 ('level_find_node', 'OBJ_cmp')
# 0 1.0
# 989 ('level_find_node', 'sk_num')
# 0 1.0
# 990 ('level_find_node', 'sk_value')
# 0 1.0
# 992 ('BN_to_ASN1_INTEGER', 'BN_bn2bin')
# 1 0.99251217
# 994 ('BN_to_ASN1_INTEGER', 'ERR_put_error')
# 0 0.9894961
# 995 ('BN_to_ASN1_INTEGER', 'ASN1_STRING_free')
# 0 0.99963284
# 996 ('BN_to_ASN1_INTEGER', 'ASN1_STRING_type_new')
# 0 0.99925506
# 997 ('SHA1_Final', 'sha1_block_data_order')
# 0 0.98417705
# 1000 ('EVP_EncodeUpdate', 'EVP_EncodeBlock')
# 0 0.99145573
# 1001 ('EVP_EncodeUpdate', 'OPENSSL_showfatal')
# 0 0.99376434
# 1004 ('PKCS7_add_crl', 'ERR_put_error')
# 2 0.9801942
# 1005 ('CMS_RecipientInfo_set0_key', 'ERR_put_error')
# 2 0.9063633
# 1006 ('EVP_PKEY_asn1_find_str', 'ENGINE_pkey_asn1_find_str')
# 0 0.9922602
# 1008 ('dsa_finish', 'BN_MONT_CTX_free')
# 0 1.0000001
# 1009 ('EVP_CIPHER_CTX_ctrl', 'ERR_put_error')
# 4 0.96403456
# 1010 ('ec_GF2m_simple_group_copy', 'bn_expand2')
# 0 1.0
# 1011 ('ec_GF2m_simple_group_copy', 'BN_copy')
# 0 0.9800285
# 1017 ('ec_copy_parameters', 'EC_KEY_set_group')
# 0 1.0
# 1018 ('mem_puts', 'BUF_MEM_grow_clean')
# 0 0.9986783
# 1020 ('BN_GF2m_arr2poly', 'BN_set_bit')
# 0 0.9876905
# 1022 ('NCONF_load', 'ERR_put_error')
# 1 0.9080376
# 1023 ('ec_GFp_simple_add', 'BN_CTX_end')
# 0 0.9999215
# 1024 ('ec_GFp_simple_add', 'BN_CTX_start')
# 0 0.9999044
# 1025 ('ec_GFp_simple_add', 'BN_copy')
# 2 0.9979275
# 1026 ('ec_GFp_simple_add', 'BN_CTX_free')
# 0 0.99992347
# 1027 ('ec_GFp_simple_add', 'EC_POINT_dbl')
# 0 0.9999015
# 1028 ('ec_GFp_simple_add', 'BN_mod_lshift1_quick')
# 0 0.9999244
# 1029 ('ec_GFp_simple_add', 'EC_POINT_is_at_infinity')
# 0 0.9999021
# 1030 ('ec_GFp_simple_add', 'BN_set_word')
# 8 0.998227
# 1031 ('ec_GFp_simple_add', 'BN_add')
# 0 0.9999251
# 1032 ('ec_GFp_simple_add', 'BN_mod_sub_quick')
# 0 0.99992424
# 1033 ('ec_GFp_simple_add', 'BN_CTX_get')
# 0 0.9999029
# 1034 ('ec_GFp_simple_add', 'BN_mod_add_quick')
# 0 0.9999244
# 1035 ('ec_GFp_simple_add', 'BN_rshift1')
# 0 0.9999251
# 1036 ('ec_GFp_simple_add', 'BN_CTX_new')
# 0 0.9999003
# 1037 ('def_destroy_data', '_CONF_free_data')
# 0 0.99936014
# 1038 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_get_affine_coordinates_GFp')
# 2 0.99892676
# 1039 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_set_affine_coordinates_GF2m')
# 0 0.99892676
# 1040 ('EC_KEY_set_public_key_affine_coordinates', 'ERR_put_error')
# 0 0.9942355
# 1041 ('EC_KEY_set_public_key_affine_coordinates', 'EC_KEY_check_key')
# 0 0.9970526
# 1042 ('EC_KEY_set_public_key_affine_coordinates', 'BN_CTX_free')
# 0 0.99899006
# 1043 ('EC_KEY_set_public_key_affine_coordinates', 'BN_CTX_get')
# 0 0.9985355
# 1044 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_get_affine_coordinates_GF2m')
# 1 0.99892676
# 1045 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_free')
# 0 0.9992855
# 1046 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_set_affine_coordinates_GFp')
# 3 0.99892676
# 1047 ('EC_KEY_set_public_key_affine_coordinates', 'BN_cmp')
# 0 0.9989443
# 1048 ('EC_KEY_set_public_key_affine_coordinates', 'EC_POINT_new')
# 0 0.9982782
# 1049 ('EC_KEY_set_public_key_affine_coordinates', 'BN_CTX_new')
# 0 0.99898714
# 1050 ('int_err_del', 'lh_free')
# 0 0.99737966
# 1051 ('int_err_del', 'CRYPTO_lock')
# 1 0.9842136
# 1052 ('pkey_hmac_cleanup', 'OPENSSL_cleanse')
# 0 0.99730295
# 1053 ('pkey_hmac_cleanup', 'CRYPTO_free')
# 0 0.997833
# 1054 ('pkey_hmac_cleanup', 'EVP_MD_CTX_cleanup')
# 0 0.9989343
# 1055 ('BN_rand', 'OPENSSL_cleanse')
# 0 0.99967504
# 1058 ('BN_rand', 'ERR_put_error')
# 0 0.99073833
# 1060 ('BN_rand', 'CRYPTO_malloc')
# 0 0.9998953
# 1062 ('BN_rand', 'CRYPTO_free')
# 0 0.9998985
# 1063 ('EVP_CIPHER_type', 'OBJ_nid2obj')
# 2 0.9622735
# 1064 ('EVP_CIPHER_type', 'ASN1_OBJECT_free')
# 1 0.9631797
# 1065 ('EVP_PKEY_derive_set_peer', 'ERR_put_error')
# 0 0.9956169
# 1067 ('EVP_PKEY_derive_set_peer', 'EVP_PKEY_free')
# 0 0.99868065
# 1068 ('EVP_PKEY_derive_set_peer', 'EVP_PKEY_missing_parameters')
# 0 0.99893415
# 1069 ('EVP_PKEY_derive_set_peer', 'EVP_PKEY_cmp_parameters')
# 0 0.9989403
# 1070 ('X509V3_EXT_get_nid', 'sk_find')
# 1 0.9969384
# 1071 ('X509V3_EXT_get_nid', 'sk_value')
# 0 0.9997223
# 1072 ('DSO_convert_filename', 'BUF_strlcpy')
# 0 0.99938506
# 1073 ('DSO_convert_filename', 'ERR_put_error')
# 0 0.9883911
# 1074 ('DSO_convert_filename', 'CRYPTO_malloc')
# 0 0.9993623
# 1075 ('pkey_rsa_ctrl', 'CMS_RecipientInfo_ktri_get0_algs')
# 0 0.99980706
# 1076 ('pkey_rsa_ctrl', 'RSA_X931_hash_id')
# 0 0.999803
# 1077 ('pkey_rsa_ctrl', 'X509_ALGOR_get0')
# 0 0.9998089
# 1078 ('pkey_rsa_ctrl', 'ERR_put_error')
# 0 0.99921715
# 1079 ('pkey_rsa_ctrl', 'OBJ_obj2nid')
# 0 0.994716
# 1082 ('long_i2c', 'BN_num_bits_word')
# 0 1.0000001
# 1084 ('bsaes_xts_decrypt', '_bsaes_decrypt8')
# 0 0.9971022
# 1085 ('bsaes_xts_decrypt', '_bsaes_key_convert')
# 1 0.99641365
# ...
# 0 0.9989305
# 5963 ('bn_mul_low_recursive', 'bn_mul_low_normal')
# 0 0.9997868
# 5964 ('EVP_DecryptFinal_ex', 'ERR_put_error')
# 0 0.9992442
# 5965 ('EVP_DecryptFinal_ex', 'OPENSSL_showfatal')
# 0 0.99984246
# 5969 ('int_engine_module_init', 'ENGINE_by_id')
# 0 0.9969067
# 5970 ('int_engine_module_init', 'sk_num')
# 0 0.9970174
# 5971 ('int_engine_module_init', 'NCONF_get_number_e')
# 0 0.9959072
# 5972 ('int_engine_module_init', 'sk_value')
# 0 0.99701464
# 5974 ('int_engine_module_init', 'NCONF_get_section')
# 0 0.99702233
# 5975 ('int_engine_module_init', 'ERR_put_error')
# 0 0.9964118
# 5977 ('int_engine_module_init', 'ERR_add_error_data')
# 0 0.99700505
# 5980 ('int_engine_module_init', 'ERR_clear_error')
# 0 0.9933958
# 5981 ('eckey_priv_decode', 'X509_ALGOR_get0')
# 0 0.99946845
# 5982 ('eckey_priv_decode', 'ERR_put_error')
# 0 0.9950165
# 5983 ('eckey_priv_decode', 'EC_POINT_new')
# 0 0.9992347
# 5985 ('eckey_priv_decode', 'd2i_ECPrivateKey')
# 0 0.99937594
# 5986 ('eckey_priv_decode', 'EC_KEY_set_public_key')
# 0 0.9994525
# 5987 ('eckey_priv_decode', 'eckey_type2param')
# 0 0.99946606
# 5988 ('eckey_priv_decode', 'EC_POINT_free')
# 0 0.999458
# 5989 ('eckey_priv_decode', 'EC_KEY_free')
# 0 0.99951386
# 5990 ('eckey_priv_decode', 'EC_POINT_mul')
# 4 0.9930405
# 5991 ('eckey_priv_decode', 'EC_POINT_copy')
# 0 0.9993823
# 5992 ('eckey_priv_decode', 'PKCS8_pkey_get0')
# 0 0.9994853
# 5997 ('ec_GF2m_simple_cmp', 'BN_CTX_free')
# 0 0.9999924
# 5998 ('ec_GF2m_simple_cmp', 'BN_CTX_start')
# 0 0.9998879
# 5999 ('ec_GF2m_simple_cmp', 'BN_cmp')
# 0 1.0
# 6000 ('ec_GF2m_simple_cmp', 'BN_CTX_get')
# 0 0.9998877
# 6001 ('ec_GF2m_simple_cmp', 'EC_POINT_get_affine_coordinates_GF2m')
# 0 0.9998497
# 6002 ('ec_GF2m_simple_cmp', 'BN_CTX_end')
# 0 0.999979
# 6003 ('ec_GF2m_simple_cmp', 'EC_POINT_is_at_infinity')
# 0 0.99984646
# 6004 ('ec_GF2m_simple_cmp', 'BN_CTX_new')
# 0 0.9998251
# 6005 ('dlfcn_load', 'ERR_add_error_data')
# 0 0.9949585
# 6006 ('dlfcn_load', 'DSO_convert_filename')
# 0 0.9981027
# 6007 ('dlfcn_load', 'ERR_put_error')
# 0 0.9643198
# 6008 ('dlfcn_load', 'CRYPTO_free')
# 0 0.99542713
# 6009 ('idea_ecb_cipher', 'idea_ecb_encrypt')
# 0 1.0000001
# 6010 ('DES_ofb64_encrypt', 'DES_encrypt1')
# 1 0.9805153
# 6011 ('EVP_PKEY_CTX_ctrl', 'ERR_put_error')
# 0 0.98462695
# 6012 ('ENGINE_set_default_pkey_asn1_meths', 'engine_table_register')
# 5 0.99723464
# 6013 ('pkey_rsa_verifyrecover', 'CRYPTO_malloc')
# 0 0.9994528
# 6014 ('pkey_rsa_verifyrecover', 'RSA_X931_hash_id')
# 0 0.99941444
# 6015 ('pkey_rsa_verifyrecover', 'ERR_put_error')
# 0 0.99421614
# 6016 ('pkey_rsa_verifyrecover', 'EVP_MD_size')
# 0 0.99940246
# 6017 ('pkey_rsa_verifyrecover', 'int_rsa_verify')
# 0 0.9994026
# 6018 ('pkey_rsa_verifyrecover', 'EVP_PKEY_size')
# 0 0.99943906
# 6020 ('X509V3_EXT_add', 'ERR_put_error')
# 7 0.9606785
# 6021 ('X509V3_EXT_add', 'sk_new')
# 0 0.9985854
# 6024 ('X509at_get_attr_by_OBJ', 'sk_num')
# 0 0.99997455
# 6025 ('X509at_get_attr_by_OBJ', 'sk_value')
# 0 0.99997693
# 6026 ('X509at_get_attr_by_OBJ', 'OBJ_cmp')
# 0 0.9999741
# 6029 ('ASN1_GENERALIZEDTIME_print', 'BIO_write')
# 0 0.99857926
# 6030 ('ASN1_GENERALIZEDTIME_print', 'BIO_printf')
# 0 0.9984327
# 6031 ('dsa_pub_print', 'ASN1_bn_print')
# 0 0.9982102
# 6032 ('dsa_pub_print', 'ERR_put_error')
# 2 0.99088436
# 6033 ('dsa_pub_print', 'CRYPTO_malloc')
# 0 0.9980315
# 6035 ('dsa_pub_print', 'CRYPTO_free')
# 0 0.99796546
# 6036 ('BUF_MEM_grow', 'CRYPTO_malloc')
# 0 0.9990011
# 6038 ('BUF_MEM_grow', 'ERR_put_error')
# 0 0.9780321
# 6039 ('i2v_AUTHORITY_KEYID', 'hex_to_string')
# 0 0.9907898
# 6040 ('i2v_AUTHORITY_KEYID', 'X509V3_add_value')
# 0 0.99926984
# 6041 ('i2v_AUTHORITY_KEYID', 'CRYPTO_free')
# 0 0.9994309
# 6042 ('i2v_AUTHORITY_KEYID', 'i2v_GENERAL_NAMES')
# 0 0.999496
# 6044 ('PKCS12_unpack_p7data', 'ERR_put_error')
# 5 0.91896516
# 6045 ('aesni_ccm_init_key', 'aesni_set_encrypt_key')
# 4 0.96081996
# 6046 ('aes_ccm_ctrl', 'CRYPTO_ccm128_tag')
# 0 0.99990565
# 6047 ('write_string', 'UI_get0_output_string')
# 0 1.0
# 6048 ('write_string', 'UI_get_string_type')
# 0 1.0
# 6049 ('ECDSA_do_sign_ex', 'ecdsa_check')
# 1 0.9821518
# 6051 ('PKCS7_dataInit', 'sk_value')
# 0 0.99942714
# 6052 ('PKCS7_dataInit', 'OBJ_obj2nid')
# 8 0.997365
# 6054 ('PKCS7_dataInit', 'X509_get_pubkey')
# 0 0.99942714
# 6055 ('PKCS7_dataInit', 'OBJ_nid2sn')
# 0 0.99937433
# 6057 ('PKCS7_dataInit', 'ERR_put_error')
# 1 0.9992092
# 6060 ('PKCS7_dataInit', 'sk_num')
# 0 0.99942684
# 6062 ('PKCS7_dataInit', 'OBJ_nid2obj')
# 0 0.9993782
# 6063 ('PKCS7_dataInit', 'OPENSSL_cleanse')
# 0 0.9994218
# 6064 ('PKCS7_dataInit', 'BIO_new_mem_buf')
# 0 0.9994242
# 6065 ('PKCS7_dataInit', 'ASN1_STRING_set0')
# 0 0.9994271
# 6066 ('PKCS7_dataInit', 'BIO_ctrl')
# 0 0.9994282
# 6067 ('PKCS7_dataInit', 'EVP_CIPHER_param_to_asn1')
# 9 0.99903333
# 6068 ('PKCS7_dataInit', 'CRYPTO_malloc')
# 0 0.9994278
# 6069 ('PKCS7_dataInit', 'CRYPTO_free')
# 0 0.9994273
# 6070 ('PKCS7_dataInit', 'BIO_new')
# 1 0.9992135
# 6071 ('PKCS7_dataInit', 'EVP_PKEY_CTX_ctrl')
# 0 0.9994147
# 6072 ('PKCS7_dataInit', 'BIO_free')
# 0 0.999427
# 6073 ('PKCS7_dataInit', 'EVP_CipherInit_ex')
# 1 0.99579865
# 6074 ('PKCS7_dataInit', 'EVP_PKEY_CTX_free')
# 0 0.99943167
# 6075 ('PKCS7_dataInit', 'PKCS7_ctrl')
# 0 0.9994333
# 6076 ('PKCS7_dataInit', 'EVP_CIPHER_type')
# 0 0.99525607
# 6077 ('PKCS7_dataInit', 'EVP_PKEY_encrypt_init')
# 0 0.9994253
# 6078 ('PKCS7_dataInit', 'EVP_PKEY_free')
# 0 0.9994002
# 6079 ('PKCS7_dataInit', 'EVP_PKEY_encrypt')
# 0 0.9994217
# 6080 ('rc4_hmac_md5_cipher', 'RC4')
# 0 0.9995137
# 6081 ('rc4_hmac_md5_cipher', 'rc4_md5_enc')
# 0 0.99885553
# 6082 ('rc4_hmac_md5_cipher', 'MD5_Update')
# 0 0.9992941
# 6083 ('rc4_hmac_md5_cipher', 'MD5_Final')
# 0 0.99581707
# 6091 ('EC_POINT_point2oct', 'ERR_put_error')
# 0 0.98006976
# 6094 ('bn_mul_low_normal', 'bn_mul_words')
# 0 0.98673296
# 6095 ('bn_mul_low_normal', 'bn_mul_add_words')
# 1 0.975201
# 6096 ('dh_param_print', 'CRYPTO_free')
# 1 0.9973185
# 6098 ('dh_param_print', 'ASN1_bn_print')
# 0 0.99780613
# 6099 ('dh_param_print', 'BIO_printf')
# 1 0.99725264
# 6101 ('dh_param_print', 'CRYPTO_malloc')
# 1 0.9973821
# 6102 ('dh_param_print', 'ERR_put_error')
# 3 0.9915041
# 6103 ('ECPKParameters_print', 'EC_POINT_point2bn')
# 0 0.9985478
# 6104 ('ECPKParameters_print', 'BIO_write')
# 0 0.9985537
# 6105 ('ECPKParameters_print', 'EC_GROUP_get_curve_GF2m')
# 0 0.9985428
# 6106 ('ECPKParameters_print', 'BN_new')
# 0 0.9985321
# 6107 ('ECPKParameters_print', 'ASN1_bn_print')
# 0 0.9985417
# 6108 ('ECPKParameters_print', 'CRYPTO_free')
# 0 0.9985463
# 6109 ('ECPKParameters_print', 'EC_GROUP_get_basis_type')
# 0 0.99855214
# 6110 ('ECPKParameters_print', 'EC_GROUP_get_cofactor')
# 0 0.99854416
# 6111 ('ECPKParameters_print', 'BN_CTX_new')
# 0 0.99853384
# 6112 ('ECPKParameters_print', 'BIO_printf')
# 0 0.99854404
# 6114 ('ECPKParameters_print', 'OBJ_nid2sn')
# 0 0.99848026
# 6115 ('ECPKParameters_print', 'BN_CTX_free')
# 0 0.9985603
# 6116 ('ECPKParameters_print', 'EC_GROUP_get_curve_GFp')
# 1 0.9985428
# 6117 ('ECPKParameters_print', 'BN_free')
# 0 0.9985507
# 6119 ('ECPKParameters_print', 'EC_GROUP_get_order')
# 0 0.9985443
# 6120 ('ECPKParameters_print', 'CRYPTO_malloc')
# 0 0.9985487
# 6121 ('ECPKParameters_print', 'ERR_put_error')
# 0 0.998226
# 6122 ('set_reasons', 'sk_value')
# 0 0.99920297
# 6123 ('set_reasons', 'sk_pop_free')
# 0 0.99307305
# 6124 ('set_reasons', 'sk_num')
# 0 0.9991983
# 6125 ('set_reasons', 'X509V3_parse_list')
# 0 0.99883235
# 6126 ('set_reasons', 'ASN1_BIT_STRING_set_bit')
# 0 0.99898565
# 6127 ('rsa_pub_cmp', 'BN_cmp')
# 0 1.0
# 6128 ('dh_private_print', 'ERR_put_error')
# 0 0.99392456
# 6130 ('dh_private_print', 'BIO_printf')
# 0 0.9978326
# 6132 ('dh_private_print', 'CRYPTO_malloc')
# 0 0.9979077
# 6133 ('dh_private_print', 'CRYPTO_free')
# 0 0.9978705
# 6134 ('dh_private_print', 'ASN1_bn_print')
# 0 0.9980746
# 6138 ('SRP_VBASE_new', 'CRYPTO_malloc')
# 0 0.9986146
# 6139 ('SRP_VBASE_new', 'CRYPTO_free')
# 0 0.99849015
# 6141 ('SRP_VBASE_new', 'sk_free')
# 0 0.9985097
# 6142 ('BN_CTX_free', 'BN_clear_free')
# 0 0.9999714
# 6143 ('BN_CTX_free', 'CRYPTO_free')
# 0 0.9999637
# 6144 ('ec_GF2m_simple_invert', 'EC_POINT_make_affine')
# 0 0.9984241
# 6145 ('ec_GF2m_simple_invert', 'EC_POINT_is_at_infinity')
# 0 0.99844396
# 6146 ('md_ctrl', 'EVP_DigestInit_ex')
# 0 0.9998537
# 6147 ('md_ctrl', 'BIO_ctrl')
# 0 0.99995106
# 6148 ('md_ctrl', 'EVP_MD_CTX_copy_ex')
# 0 0.9997903
# 6149 ('OBJ_obj2txt', 'CRYPTO_free')
# 0 0.9983906
# 6150 ('OBJ_obj2txt', 'BN_set_word')
# 2 0.99729556
# 6151 ('OBJ_obj2txt', 'BN_lshift')
# 0 0.9979356
# 6152 ('OBJ_obj2txt', 'BUF_strlcpy')
# 0 0.9983086
# 6153 ('OBJ_obj2txt', 'BIO_snprintf')
# 0 0.99771476
# 6154 ('OBJ_obj2txt', 'BN_add_word')
# 3 0.99306375
# 6155 ('OBJ_obj2txt', 'OBJ_obj2nid')
# 4 0.9954345
# 6156 ('OBJ_obj2txt', 'BN_bn2dec')
# 0 0.9970187
# 6157 ('OBJ_obj2txt', 'BN_new')
# 0 0.99834156
# 6158 ('OBJ_obj2txt', 'BN_sub_word')
# 0 0.9959582
# 6159 ('OBJ_obj2txt', 'BN_free')
# 0 0.99832165
# 6160 ('int_err_set_item', 'CRYPTO_lock')
# 0 0.98373914
# 6161 ('int_err_set_item', 'lh_insert')
# 0 0.99697256
# 6162 ('X509_pubkey_digest', 'X509_get0_pubkey_bitstr')
# 0 1.0
# 6164 ('cms_SignerIdentifier_cert_cmp', 'X509_NAME_cmp')
# 0 0.99959004
# 6165 ('EC_POINT_point2bn', 'EC_POINT_point2oct')
# 0 0.999409
# 6167 ('EC_POINT_point2bn', 'CRYPTO_free')
# 0 0.99971044
# 6168 ('EC_POINT_point2bn', 'CRYPTO_malloc')
# 0 0.999746
# 6169 ('X509_NAME_print', 'BIO_write')
# 0 0.9995438
# 6170 ('X509_NAME_print', 'CRYPTO_free')
# 0 0.99981815
# 6171 ('X509_NAME_print', 'X509_NAME_oneline')
# 0 0.999665
# 6172 ('X509_NAME_print', 'ERR_put_error')
# 0 0.99235225
# 6173 ('_CONF_free_data', 'lh_doall')
# 0 0.9997791
# 6174 ('_CONF_free_data', 'lh_doall_arg')
# 0 0.9997751
# 6177 ('CAST_ecb_encrypt', 'CAST_encrypt')
# 0 0.9979304
# 6178 ('CAST_ecb_encrypt', 'CAST_decrypt')
# 0 0.9846535
# 6180 ('ENGINE_load_public_key', 'ERR_put_error')
# 3 0.97650385
# 6181 ('ENGINE_load_public_key', 'CRYPTO_lock')
# 1 0.99262565
# 6182 ('bn_expand_internal', 'ERR_put_error')
# 0 0.9879482
# 6183 ('bn_expand_internal', 'CRYPTO_malloc')
# 0 0.9990352
# 6184 ('aes_gcm_cleanup', 'OPENSSL_cleanse')
# 0 0.99864054
# 6185 ('aes_gcm_cleanup', 'CRYPTO_free')
# 0 0.9999999
# 6186 ('EVP_SignFinal', 'EVP_DigestFinal_ex')
# 0 0.99861085
# 6187 ('EVP_SignFinal', 'EVP_MD_CTX_cleanup')
# 0 0.99873847
# 6188 ('EVP_SignFinal', 'EVP_PKEY_sign_init')
# 0 0.9986715
# 6189 ('EVP_SignFinal', 'EVP_PKEY_CTX_ctrl')
# 0 0.99858505
# 6190 ('EVP_SignFinal', 'EVP_PKEY_CTX_free')
# 0 0.9989633
# 6191 ('EVP_SignFinal', 'EVP_MD_CTX_copy_ex')
# 0 0.9991157
# 6192 ('EVP_SignFinal', 'EVP_PKEY_sign')
# 0 0.99868566
# 6193 ('EVP_SignFinal', 'EVP_PKEY_size')
# 0 0.9987258
# 6194 ('EVP_SignFinal', 'ERR_put_error')
# 0 0.99410284
# 6200 ('policy_cache_find_data', 'sk_find')
# 0 0.99748373
# 6201 ('policy_cache_find_data', 'sk_value')
# 0 1.0000001
# 6205 ('get_issuer_sk', 'sk_num')
# 0 0.99986976
# 6206 ('get_issuer_sk', 'sk_value')
# 0 0.99987465
# 6207 ('PEM_read_DSAPrivateKey', 'PEM_read_PrivateKey')
# 2 0.99963504
# 6208 ('PEM_read_DSAPrivateKey', 'DSA_free')
# 1 0.9998403
# 6209 ('PEM_read_DSAPrivateKey', 'EVP_PKEY_get1_DSA')
# 5 0.99960583
# 6210 ('PEM_read_DSAPrivateKey', 'EVP_PKEY_free')
# 5 0.99788064
# 6211 ('eckey_priv_encode', 'i2d_ECPrivateKey')
# 0 0.99855417
# 6212 ('eckey_priv_encode', 'CRYPTO_free')
# 0 0.9990203
# 6213 ('eckey_priv_encode', 'PKCS8_pkey_set0')
# 0 0.9990775
# 6214 ('eckey_priv_encode', 'ERR_put_error')
# 0 0.99375045
# 6215 ('eckey_priv_encode', 'OBJ_nid2obj')
# 0 0.9982797
# 6217 ('eckey_priv_encode', 'ASN1_STRING_free')
# 0 0.99903166
# 6218 ('eckey_priv_encode', 'CRYPTO_malloc')
# 0 0.9990395
# 6219 ('b64_new', 'CRYPTO_malloc')
# 0 0.99954194
# 6221 ('ec_GF2m_simple_group_set_curve', 'ERR_put_error')
# 0 0.99133205
# 6222 ('ec_GF2m_simple_group_set_curve', 'BN_GF2m_poly2arr')
# 0 0.99991214
# 6223 ('ec_GF2m_simple_group_set_curve', 'bn_expand2')
# 0 0.99991435
# 6224 ('ec_GF2m_simple_group_set_curve', 'BN_copy')
# 0 0.9817475
# 6225 ('c2i_ASN1_BIT_STRING', 'CRYPTO_free')
# 0 0.9996882
# 6226 ('c2i_ASN1_BIT_STRING', 'ASN1_STRING_type_new')
# 0 0.99938166
# 6227 ('c2i_ASN1_BIT_STRING', 'CRYPTO_malloc')
# 0 0.9996898
# 6228 ('c2i_ASN1_BIT_STRING', 'ASN1_STRING_free')
# 0 0.999692
# 6229 ('c2i_ASN1_BIT_STRING', 'ERR_put_error')
# 0 0.9910944
# 6230 ('pkey_cmac_keygen', 'CMAC_CTX_new')
# 0 0.9987816
# 6232 ('pkey_cmac_keygen', 'CMAC_CTX_copy')
# 0 0.99939525
# 6233 ('pkey_cmac_keygen', 'EVP_CIPHER_CTX_cleanup')
# 0 0.9997632
# 6234 ('pkey_cmac_keygen', 'OPENSSL_cleanse')
# 0 0.99866337
# 6235 ('sxnet_i2r', 'BIO_printf')
# 0 0.9982059
# 6236 ('sxnet_i2r', 'ASN1_INTEGER_get')
# 0 0.999855
# 6237 ('sxnet_i2r', 'sk_num')
# 0 0.99804217
# 6238 ('sxnet_i2r', 'i2s_ASN1_INTEGER')
# 0 0.9989557
# 6239 ('sxnet_i2r', 'CRYPTO_free')
# 0 0.9987943
# 6240 ('sxnet_i2r', 'ASN1_STRING_print')
# 0 0.99816936
# 6241 ('sxnet_i2r', 'sk_value')
# 0 0.9984355
# 6242 ('RSA_sign', 'CRYPTO_free')
# 0 0.9967702
# 6243 ('RSA_sign', 'ERR_put_error')
# 1 0.99176836
# 6244 ('RSA_sign', 'OPENSSL_cleanse')
# 0 0.9967724
# 6245 ('RSA_sign', 'CRYPTO_malloc')
# 0 0.99685955
# 6246 ('RSA_sign', 'OBJ_nid2obj')
# 0 0.99612725
# 6249 ('PKCS12_key_gen_uni', 'EVP_DigestInit_ex')
# 0 0.9995638
# 6250 ('PKCS12_key_gen_uni', 'CRYPTO_malloc')
# 0 0.999525
# 6251 ('PKCS12_key_gen_uni', 'BN_bn2bin')
# 1 0.9989744
# 6252 ('PKCS12_key_gen_uni', 'CRYPTO_free')
# 0 0.9995232
# 6253 ('PKCS12_key_gen_uni', 'EVP_DigestFinal_ex')
# 0 0.99949545
# 6254 ('PKCS12_key_gen_uni', 'EVP_MD_size')
# 0 0.99951637
# 6255 ('PKCS12_key_gen_uni', 'EVP_MD_CTX_cleanup')
# 0 0.99946135
# 6256 ('PKCS12_key_gen_uni', 'ERR_put_error')
# 1 0.99864817
# 6257 ('PKCS12_key_gen_uni', 'BN_new')
# 0 0.99947757
# 6258 ('PKCS12_key_gen_uni', 'BN_add')
# 0 0.99953216
# 6261 ('PKCS12_key_gen_uni', 'BN_free')
# 0 0.9995222
# 6262 ('PKCS7_signatureVerify', 'BIO_ctrl')
# 1 0.9966588
# 6263 ('PKCS7_signatureVerify', 'EVP_DigestInit_ex')
# 0 0.9939367
# 6264 ('PKCS7_signatureVerify', 'X509_get_pubkey')
# 0 0.9971927
# 6265 ('PKCS7_signatureVerify', 'EVP_MD_CTX_md')
# 0 0.99723846
# 6266 ('PKCS7_signatureVerify', 'ASN1_item_i2d')
# 0 0.9964772
# 6267 ('PKCS7_signatureVerify', 'EVP_PKEY_free')
# 2 0.9955363
# 6269 ('PKCS7_signatureVerify', 'BIO_find_type')
# 0 0.9966466
# 6270 ('PKCS7_signatureVerify', 'EVP_MD_CTX_cleanup')
# 1 0.9954281
# 6271 ('PKCS7_signatureVerify', 'EVP_VerifyFinal')
# 0 0.9942409
# 6273 ('PKCS7_signatureVerify', 'EVP_MD_CTX_copy_ex')
# 2 0.99445784
# 6274 ('PKCS7_signatureVerify', 'OBJ_nid2sn')
# 8 0.994783
# 6275 ('PKCS7_signatureVerify', 'CRYPTO_free')
# 1 0.99713653
# 6276 ('PKCS7_signatureVerify', 'EVP_DigestFinal_ex')
# 0 0.99692774
# 6277 ('PKCS7_signatureVerify', 'BIO_next')
# 0 0.997237
# 6278 ('PKCS7_signatureVerify', 'sk_num')
# 0 0.9972457
# 6279 ('multi_split', 'BIO_ctrl')
# 0 0.9999167
# 6280 ('multi_split', 'BIO_gets')
# 0 0.9999021
# 6281 ('multi_split', 'BIO_new')
# 0 0.9970118
# 6282 ('multi_split', 'BIO_write')
# 0 0.9997523
# 6283 ('EC_GROUP_set_curve_GF2m', 'ERR_put_error')
# 4 0.9074647
# 6284 ('EC_KEY_insert_key_method_data', 'EC_EX_DATA_get_data')
# 0 0.9996663
# 6285 ('EC_KEY_insert_key_method_data', 'CRYPTO_lock')
# 0 0.98413
# 6286 ('EC_KEY_insert_key_method_data', 'EC_EX_DATA_set_data')
# 0 0.9993698
# 6287 ('EVP_PKEY_verify_recover_init', 'ERR_put_error')
# 6 0.964859
# 6288 ('i2d_ASN1_SET', 'sk_value')
# 0 0.9990344
# 6289 ('i2d_ASN1_SET', 'ERR_put_error')
# 1 0.99484754
# 6290 ('i2d_ASN1_SET', 'CRYPTO_malloc')
# 0 0.99906224
# 6291 ('i2d_ASN1_SET', 'ASN1_object_size')
# 0 0.99910533
# 6292 ('i2d_ASN1_SET', 'sk_num')
# 0 0.99902683
# 6293 ('i2d_ASN1_SET', 'ASN1_put_object')
# 0 0.99918103
# 6294 ('i2d_ASN1_SET', 'CRYPTO_free')
# 0 0.99904525
# 6295 ('SXNET_get_id_INTEGER', 'sk_num')
# 0 1.0
# 6296 ('SXNET_get_id_INTEGER', 'ASN1_STRING_cmp')
# 0 1.0000001
# 6297 ('SXNET_get_id_INTEGER', 'sk_value')
# 0 1.0
# 6298 ('bn_c2i', 'BN_clear_free')
# 0 0.9998904
# 6300 ('bn_c2i', 'BN_free')
# 0 0.99982667
# 6301 ('bn_c2i', 'BN_new')
# 0 0.9988914
# 6302 ('ASN1_item_d2i_bio', 'BUF_MEM_free')
# 0 0.9999793
# 6304 ('ASN1_item_d2i_bio', 'asn1_d2i_read_bio.constprop.0')
# 0 0.9985661
# 6306 ('bn_mul_recursive', 'bn_sub_part_words')
# 1 0.9762672
# 6307 ('bn_mul_recursive', 'bn_mul_recursive')
# 0 0.9809015
# 6308 ('bn_mul_recursive', 'bn_add_words')
# 7 0.98063624
# 6309 ('bn_mul_recursive', 'bn_sub_words')
# 8 0.98063666
# 6310 ('bn_mul_recursive', 'bn_mul_normal')
# 1 0.97736025
# 6311 ('sk_find', 'OBJ_bsearch_ex_')
# 1 0.99763036
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   after removing the cwd from sys.path.

# %%
# name_test=[]
# emb_test=[]
# name_openssl=[i[1] for i in libitem.twoGramList]
# emb_openssl=[i[0] for i in libitem.twoGramList]
# for twogram in testbin.twoGramList:
#     if twogram[1] in name_openssl:
#         name_test.append(twogram[1])
#         emb_test.append(twogram[0])
import os
path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl'
lib='libcrypto'
#folder = 'openssl-OpenSSL_1_0_1d'
emb_openssl = []
for folder in os.listdir(path_lib):
    dotfile = lib+'.so_bn.dot'
    dot_path = os.path.join(path_lib, folder, dotfile)
    libraryName = folder.split('-')[1] + '_' + dotfile.rsplit('.',1)[0]
    emb_path = os.path.join(path_lib, folder, lib+'.so.ida.emb')
    nam_path = os.path.join(path_lib, folder, lib+'.so.ida_newmodel_withsize.nam')
    nam_path_full = os.path.join(path_lib, folder, lib+'.so.ida.nam')
    libitem = Library(libraryName, dot_path, emb_path, nam_path,filter_size)
    libitem.buildNGram(nam_path_full)
    emb_openssl.extend([i[0] for i in libitem.twoGramList])
import random
distribution=[]
for idx, twogram in enumerate(emb_test):
    a = twogram
    #ind = name_openssl.index(twogram[1])
    ind = random.randrange(0,len(emb_openssl))
    b = emb_openssl[ind]
    from numpy.linalg import norm
    result = np.inner(a, b)/(norm(a)*norm(b))
    if not np.isnan(result):
        distribution.append(result)

fp=open('dany','w')
for item in distribution:
    fp.write('%g\n' % item)
fp.close()
# Out:
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7j/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7i/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8u/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1m/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1q/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0t/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1t/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2j/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1i/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8y/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8n/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2n/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8r/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8w/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8v/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1o/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8m/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0j/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1p/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2o/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1l/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8p/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0l/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0o/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0m/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2q/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8s/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8i/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1r/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8g/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7a/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2m/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0s/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8o/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7l/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8k/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1n/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0k/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0f/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2b/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0e/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7c/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0i/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8q/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2l/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7m/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1j/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7k/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8x/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8l/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0p/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1s/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8t/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_1k/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_1_0h/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2i/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_7d/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0q/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0n/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_0_9_8j/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_2k/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/openssl/openssl-OpenSSL_1_0_0r/libcrypto.so_bn.dot
# edges loaded
# n-gram loaded

# %%
# Out:
# 20

# %%
from redis import Redis
from lshknn import getHashMap, doSearch
import pickle as p
redis_object = Redis(host='localhost', port=6379, db=0)
hashMap = getHashMap(["filted1-2gram-binary","filted1-2gram-binary2","filted1-2gram-binary0"], redis_object, dim=128)
keys = hashMap.engine.storage.get_all_bucket_keys(hashMap.lshash[0].hash_name)
vectors=[]
print hashMap.engine.storage.load_hash_configuration("filted1-2gram-binary")
print hashMap.engine.storage.load_hash_configuration("filted1-2gram-binary2")
print hashMap.engine.storage.load_hash_configuration("filted1-2gram-binary0")
# for key in keys:
#     bucket_content = hashMap.engine.storage.get_bucket(hashMap.lshash[0].hash_name, key,)
#     print key
#     #print bucket_content[:100]
#     print len(bucket_content)
# Out:
# using redis
# {'dim': 128, 'hash_name': 'filted1-2gram-binary', 'projection_count': 50, 'normals': array([[ 0.06188924,  0.08116734,  0.49421447, ..., -0.53436184,
#         -0.78674854,  0.56805442],
#        [ 1.50515104,  1.50641285,  1.3431165 , ...,  1.34457196,
#         -0.39962293,  0.23128159],
#        [ 0.95140261, -1.8757084 , -1.73423495, ...,  0.32343432,
#         -0.60829625, -0.54356097],
#        ...,
#        [ 1.04254455,  0.06239415, -0.99960762, ..., -0.3674681 ,
#         -0.65134406, -1.3731256 ],
#        [ 0.88834096,  1.0526517 , -0.58850005, ..., -0.9316314 ,
#          0.6928167 ,  0.29756116],
#        [ 0.92996111, -0.64432609,  0.82917896, ...,  0.61833676,
#          0.31223214,  0.16389735]])}
# {'dim': 128, 'hash_name': 'filted1-2gram-binary2', 'projection_count': 50, 'normals': array([[ 0.23880145, -0.89216052, -0.40855197, ...,  1.91353545,
#          0.40865853,  1.01819495],
#        [ 1.47158576, -0.7237471 ,  0.49338311, ..., -0.04185552,
#         -0.70805599, -0.12919118],
#        [-0.70711629, -0.82933179, -1.63232609, ..., -0.37976981,
#          1.75145821, -0.16498591],
#        ...,
#        [-1.47661061,  0.25076621,  3.66390757, ...,  0.69803939,
#          1.24450135, -0.876218  ],
#        [-0.84671767,  0.65686393, -0.08799101, ...,  1.19984976,
#          0.69099859, -0.04029187],
#        [-0.01047357, -0.56608224,  1.84030176, ...,  0.87042867,
#         -0.21196739, -0.30106065]])}
# {'dim': 128, 'hash_name': 'filted1-2gram-binary0', 'projection_count': 50, 'normals': array([[-0.93135703, -0.08166952,  0.04239513, ..., -0.25922841,
#         -1.28985753, -1.22384585],
#        [-1.71611842,  0.33191359, -0.22748167, ...,  2.58147894,
#          0.21328176,  1.00352897],
#        [-0.71684269, -0.92339962,  0.9625649 , ...,  1.68821534,
#         -0.76002382, -0.0043181 ],
#        ...,
#        [ 1.04602832,  0.23187946,  0.15624743, ...,  1.22276301,
#          0.5105424 ,  0.525863  ],
#        [-0.18933094, -1.14834369,  1.1101481 , ..., -1.82485343,
#          0.32558287, -1.07966461],
#        [-1.13622562,  0.91363338, -0.79650228, ...,  0.24680335,
#         -1.434387  , -1.31059194]])}

# %%
keys = hashMap.engine.storage.get_all_bucket_keys(hashMap.lshash[2].hash_name)
bucket_distribution =[]
for key in keys:
    bucket_content = hashMap.engine.storage.get_bucket(hashMap.lshash[2].hash_name, key,)
    #print key
    #print bucket_content[:100]
    bucket_distribution.append(len(bucket_content))

# %%
plt.hist(bucket_distribution, bins=100)
plt.ylabel('Probability')
plt.show()

# %%
bucket_distribution.sort()
bucket_distribution[-10:]
# Out:
# [1359, 1632, 2445, 2649, 3162, 3422, 4329, 4614, 4662, 5500]

# %%
a=[1,2]
print a[1:]
# Out:
# [2]

# %%
a=[['a',(1,2)]]
b=['libcrypto', 'openssl-OpenSSL_1_0_2g', ('PKCS7_simple_smimecap', 'OBJ_nid2obj'), 1]
print len(b[0])
# Out:
# 2

# %%
projection=[1,2,3,-1,3,4,5,-5,-8]
print [''.join(['1' if x > 0.0 else '0' for x in projection])]
# Out:
# ['111011100']

# %%
import pickle as p
global_dict = p.load(open('global_dict','r'))
funcnames = global_dict.keys()
print funcnames[0], global_dict[funcnames[0]]
# Out:
# ngx_http_parse_chunked [('RSA_verify_PKCS1_PSS', 'libcrypto'), ('RSA_padding_add_PKCS1_PSS_mgf1', 'libcrypto'), ('BN_GF2m_mod_arr', 'libcrypto'), ('RC4', 'libcrypto'), ('CRYPTO_ccm128_encrypt', 'libcrypto'), ('tls1_PRF.constprop.2', 'libssl'), ('tls1_PRF.constprop.1', 'libssl'), ('ssl_set_cert_masks', 'libssl'), ('BN_usub', 'libcrypto'), ('ASN1_get_object', 'libcrypto'), ('SHA512_Update', 'libcrypto'), ('ssl_parse_serverhello_tlsext', 'libssl'), ('None', 'None')]

# %%
nginx = []
for key in funcnames:
    if key not in name_test:
        nginx.append(key)
print len(nginx)

prediction = p.load(open('prediction','r'))
tp=[]
for key in prediction:
    #print prediction[key]
    if key in [i[0] for i in prediction[key]]:
        tp.append(key)
#     elif prediction[key]==set([('None','None')]):
#         print key, global_dict[key]
print len(tp)
# Out:
# 1663
# 1420

# %%
knn = p.load(open(dir + 'test_kNN_0905_2gram.p','r'))

# %%
from collections import defaultdict
nginx_dict=defaultdict(set)
for k in knn:
    if k[2] < 0.9:
        continue
    src = k[0][0][0]
    des = k[0][0][1]
    if src not in nginx and des not in nginx:
        for predict in k[1]:
            nginx_dict[src].add(predict[2][0])
            nginx_dict[des].add(predict[2][1])

#     if src in nginx:
#         nginx_set.add((src, k[2]))
#     if des in nginx:
#         nginx_set.add((des, k[2]))
for key in nginx_dict:
    print len(nginx_dict[key])
# Out:
# 26
# 16
# 13
# 1
# 3
# 25
# 1
# 20
# 69
# 29
# 39
# 39
# 13
# 25
# 8
# 2
# 4
# 16
# 28
# 34
# 46
# 40
# 1
# 1
# 13
# 14
# 10
# 15
# 25
# 15
# 2
# 13
# 7
# 28
# 4
# 26
# 11
# 6
# 5
# 24
# 5
# 138
# 126
# 1
# 5
# 4
# 39
# 4
# 51
# 2
# 6
# 21
# 5
# 22
# 17
# 13
# 4
# 60
# 30
# 24
# 6
# 20
# 21
# 13
# 15
# 18
# 22
# 3
# 14
# 16
# 2
# 3
# 10
# 15
# 18
# 15
# 18
# 15
# 3
# 1
# 14
# 11
# 20
# 16
# 7
# 8
# 8
# 19
# 2
# 6
# 47
# 22
# 14
# 9
# 20
# 47
# 5
# 6
# 24
# 49
# 6
# 9
# 6
# 30
# 7
# 10
# 23
# 2
# 14
# 16
# 17
# 13
# 34
# 16
# 19
# 8
# 6
# 16
# 15
# 14
# 23
# 11
# 12
# 10
# 5
# 1
# 10
# 10
# 19
# 24
# 7
# 32
# 8
# 6
# 16
# 52
# 4
# 14
# 44
# 10
# 28
# 9
# 16
# 10
# 5
# 32
# 8
# 24
# 4
# 4
# 10
# 27
# 13
# 1
# 15
# 24
# 18
# 13
# 8
# 16
# 22
# 8
# 7
# 63
# 6
# 27
# 24
# 30
# 103
# 17
# 18
# 4
# 4
# 4
# 25
# 47
# 1
# 14
# 12
# 3
# 14
# 9
# 2
# 11
# 9
# 28
# 20
# 7
# 2
# 16
# 46
# 63
# 177
# 31
# 17
# 28
# 20
# 1
# 2
# 18
# 12
# 26
# 4
# 14
# 4
# 15
# 1
# 7
# 2
# 7
# 32
# 17
# 13
# 5
# 19
# 7
# 9
# 9
# 29
# 20
# 45
# 20
# 7
# 21
# 4
# 42
# 8
# 4
# 49
# 8
# 15
# 2
# 32
# 12
# 4
# 20
# 17
# 34
# 11
# 1
# 7
# 2
# 112
# 5
# 4
# 20
# 4
# 1
# 9
# 11
# 40
# 22
# 13
# 24
# 10
# 3
# 7
# 6
# 31
# 8
# 18
# 28
# 6
# 6
# 12
# 10
# 18
# 3
# 68
# 14
# 3
# 34
# 18
# 1
# 28
# 28
# 1
# 10
# 30
# 22
# 17
# 13
# 7
# 6
# 5
# 10
# 35
# 12
# 18
# 7
# 10
# 18
# 17
# 23
# 24
# 1
# 16
# 15
# 6
# 28
# 8
# 45
# 16
# 2
# 3
# 21
# 7
# 35
# 11
# 21
# 39
# 19
# 6
# 3
# 3
# 9
# 8
# 19
# 9
# 16
# 24
# 12
# 26
# 1
# 13
# 23
# 4
# 30
# 24
# 26
# 18
# 15
# 1
# 1
# 12
# 6
# 17
# 1
# 57
# 28
# 19
# 1
# 12
# 5
# 11
# 21
# 22
# 7
# 20
# 29
# 19
# 25
# 5
# 9
# 1
# 5
# 18
# 12
# 8
# 1
# 115
# 20
# 1
# 42
# 44
# 8
# 4
# 24
# 58
# 7
# 1
# 21
# 21
# 4
# 23
# 9
# 16
# 11
# 8
# 11
# 1
# 1
# 13
# 3
# 14
# 2
# 6
# 11
# 9
# 6
# 24
# 6
# 5
# 1
# 21
# 32
# 3
# 17
# 7
# 23
# 14
# 15
# 7
# 41
# 8
# 2
# 2
# 3
# 14
# 41
# 1
# 22
# 24
# 9
# 30
# 21
# 9
# 7
# 3
# 6
# 3
# 38
# 3
# 13
# 9
# 5
# 5
# 13
# 10
# 1
# 5
# 8
# 15
# 51
# 8
# 14
# 30
# 23
# 32
# 16
# 3
# 21
# 6
# 2
# 3
# 1
# 6
# 13
# 25
# 34
# 10
# 34
# 3
# 13
# 79
# 19
# 19
# 3
# 2
# 9
# 11
# 9
# 5
# 24
# 27
# 28
# 8
# 16
# 13
# 7
# 9
# 45
# 2
# 32
# 9
# 7
# 28
# 27
# 43
# 31
# 6
# 11
# 23
# 35
# 6
# 5
# 1
# 8
# 23
# 28
# 28
# 8
# 5
# 2
# 19
# 8
# 21
# 14
# 12
# 7
# 28
# 23
# 2
# 26
# 4
# 35
# 5
# 1
# 1
# 9
# 17
# 12
# 3
# 13
# 61
# 56
# 20
# 21
# 31
# 61
# 9
# 10
# 9
# 26
# 1
# 7
# 12
# 46
# 1
# 26
# 31
# 20
# 15
# 15
# 15
# 22
# 28
# 25
# 4
# 63
# 12
# 8
# 53
# 7
# 21
# 26
# 31
# 12
# 32
# 98
# 23
# 15
# 13
# 6
# 10
# 16
# 10
# 3
# 18
# 18
# 9
# 8
# 13
# 18
# 7
# 13
# 13
# 45
# 21
# 1
# 1
# 40
# 6
# 16
# 17
# 15
# 10
# 20
# 24
# 73
# 9
# 15
# 41
# 6
# 5
# 7
# 2
# 3
# 37
# 8
# 36
# 26
# 46
# 23
# 33
# 5
# 24
# 8
# 12
# 8
# 1
# 2
# 2
# 24
# 20
# 17
# 40
# 33
# 11
# 4
# 18
# 34
# 41
# 14
# 7
# 4
# 12
# 27
# 89
# 15
# 17
# 29
# 32
# 28
# 2
# 15
# 16
# 10
# 28
# 5
# 11
# 3
# 9
# 52
# 15
# 21
# 8
# 13
# 8
# 30
# 3
# 16
# 8
# 7
# 17
# 31
# 14
# 24
# 7
# 6
# 44
# 22
# 7
# 12
# 21
# 31
# 6
# 16
# 6
# 3
# 28
# 7
# 2
# 2
# 19
# 16
# 11
# 7
# 6
# 2
# 15
# 21
# 1
# 3
# 11
# 14
# 328
# 6
# 20
# 20
# 30
# 11
# 17
# 54
# 9
# 28
# 6
# 10
# 3
# 4
# 33
# 19
# 1
# 5
# 6
# 20
# 3
# 17
# 33
# 12
# 17
# 32
# 7
# 17
# 7
# 3
# 22
# 4
# 26
# 2
# 2
# 14
# 1
# 3
# 14
# 4
# 5
# 31
# 20
# 25
# 8
# 12
# 22
# 34
# 9
# 6
# 12
# 24
# 1
# 10
# 5
# 19
# 11
# 12
# 26
# 26
# 37
# 4
# 5
# 9
# 26
# 25
# 11
# 9
# 3
# 38
# 11
# 8
# 9
# 5
# 40
# 1
# 39
# 16
# 12
# 7
# 21
# 3
# 2
# 4
# 20
# 8
# 4
# 69
# 8
# 6
# 4
# 11
# 64
# 1
# 7
# 3
# 9
# 5
# 11
# 20
# 11
# 22
# 3
# 8
# 26
# 9
# 59
# 8
# 12
# 10
# 8
# 16
# 13
# 1
# 13
# 38
# 18
# 15
# 10
# 2
# 25
# 25
# 19
# 1
# 9
# 6
# 8
# 35
# 6
# 12
# 26
# 4
# 10
# 14
# 20
# 28
# 7
# 46
# 35
# 14
# 3
# 14
# 4
# 18
# 15
# 1
# 19
# 11
# 12
# 41
# 41
# 8
# 27
# 11
# 2
# 37
# 22
# 7
# 17
# 6
# 24
# 18
# 22
# 15
# 106
# 13
# 30
# 44
# 1
# 33
# 35
# 16
# 9
# 4
# 26
# 20
# 5
# 25
# 1
# 137
# 3
# 5
# 10
# 21
# 8
# 8
# 3
# 1
# 10
# 7
# 2
# 8
# 2
# 37
# 35
# 7
# 21
# 14
# 35
# 6
# 4
# 19
# 14
# 41
# 4
# 4
# 24
# 1
# 28
# 9
# 14
# 19
# 26
# 2
# 17
# 10
# 7
# 18
# 6
# 11
# 13
# 25
# 6
# 16
# 6
# 27
# 18
# 18
# 5
# 15
# 11
# 3
# 24
# 4
# 25
# 5
# 13
# 16
# 27
# 4
# 38
# 16
# 6
# 41
# 19
# 19
# 4
# 40
# 33
# 29
# 25
# 14
# 14
# 12
# 8
# 39
# 32
# 14
# 13
# 3
# 10
# 21
# 12
# 11
# 5
# 2
# 20
# 17
# 28
# 11
# 22
# 31
# 59
# 15
# 3
# 32
# 10
# 28
# 47
# 17
# 39
# 18
# 15
# 4
# 42
# 24
# 3
# 8
# 2
# 30
# 6
# 19
# 12
# 17
# 24
# 5
# 31
# 28
# 10
# 3
# 54
# 34
# 11
# 30
# 5
# 10
# 21
# 17
# 29
# 7
# 26
# 3
# 5
# 37
# 9
# 7
# 9
# 7
# 13
# 8
# 2
# 43
# 7
# 13
# 136
# 14
# 21
# 11
# 10
# 27
# 8
# 52
# 8
# 4
# 6
# 7
# 28
# 10
# 4
# 26
# 8
# 130
# 8
# 70
# 2
# 5
# 28
# 12
# 32
# 12
# 6
# 23
# 29
# 18
# 1
# 64
# 4
# 21
# 1
# 3
# 26
# 15
# 43
# 52
# 28
# 14
# 7
# 5
# 5
# 12
# 99
# 8
# 5
# 21
# 11
# 14
# 19
# 25
# 3
# 1
# 9
# 25
# 32
# 5
# 34
# 2
# 5
# 11
# 24
# 3
# 5
# 8
# 7
# 23
# 4
# 3
# 29
# 20
# 4
# 12
# 9
# 28
# 1
# 16
# 27
# 4
# 4
# 14
# 2
# 2
# 14
# 28
# 17
# 107
# 14
# 33
# 8
# 64
# 17
# 15
# 1
# 1
# 15
# 15
# 3
# 2
# 5
# 23
# 56
# 1
# 10
# 14
# 5
# 9
# 4
# 7
# 10
# 2
# 30
# 9
# 25
# 5
# 18
# 25
# 10
# 15
# 12
# 4
# 22
# 12
# 8
# 22
# 6
# 5
# 9
# 20
# 14
# 4
# 27
# 5
# 15
# 4
# 17
# 5
# 1
# 15
# 6
# 46
# 7
# 27
# 29
# 10
# 41
# 42
# 12
# 38
# 9
# 23
# 19
# 28
# 8
# 3
# 25
# 12
# 14
# 9
# 12
# 12
# 28
# 17
# 17
# 38
# 12
# 9
# 17
# 22
# 12
# 7
# 11
# 15
# 8
# 18
# 10
# 5
# 27
# 1
# 9
# 77
# 1
# 16
# 23
# 2
# 11
# 24
# 19
# 29
# 35
# 22
# 28
# 4
# 4
# 9
# 26
# 4
# 8
# 2
# 1
# 22
# 53
# 6
# 4
# 26
# 114
# 5
# 11
# 30
# 32
# 11
# 3
# 44
# 3
# 4
# 13
# 23
# 22
# 16
# 7
# 2
# 14
# 6
# 19
# 32
# 19
# 3
# 12
# 27
# 28
# 9
# 25
# 19
# 14
# 3
# 12
# 31
# 40
# 22
# 12
# 2
# 31
# 22
# 12
# 4
# 20
# 5
# 23
# 13
# 30
# 28
# 5
# 203
# 9
# 4
# 6
# 60
# 6
# 44
# 15
# 8
# 6
# 3
# 1
# 4
# 27
# 44
# 6
# 1
# 35
# 28
# 10
# 21
# 5
# 42
# 20
# 19
# 13
# 3
# 17
# 4
# 2
# 14
# 17
# 9
# 2
# 27
# 7
# 15
# 30
# 27
# 6
# 12
# 17
# 7
# 2
# 21
# 28
# 8
# 10
# 23
# 19
# 1
# 11
# 15
# 10
# 10
# 4
# 28
# 8
# 18
# 8
# 8
# 28
# 1
# 19
# 6
# 6
# 8
# 11
# 34
# 2
# 14
# 13
# 24
# 18
# 27
# 4
# 5
# 37
# 23
# 18
# 37
# 12
# 21
# 4
# 10
# 21
# 7
# 8
# 39
# 2
# 22
# 2
# 16
# 11
# 10
# 6
# 33
# 26
# 4
# 22
# 7
# 26
# 13
# 2
# 17
# 9
# 1
# 11
# 2
# 3
# 31
# 18
# 7
# 16
# 10
# 8
# 8
# 25
# 36
# 33
# 23
# 29
# 107
# 23
# 6
# 2
# 28
# 6
# 18
# 20
# 5
# 5
# 26
# 36
# 1
# 4
# 17
# 7
# 4
# 5
# 45
# 7
# 27
# 2
# 5
# 87
# 30
# 1
# 22
# 28
# 26
# 124
# 17
# 3
# 22
# 33
# 94
# 9
# 5
# 3
# 10
# 16
# 10
# 20
# 9
# 18
# 8
# 6
# 14
# 19
# 10
# 28
# 4
# 57
# 17
# 9
# 46
# 37
# 4
# 2
# 12
# 394
# 11
# 1
# 39
# 3
# 10
# 34
# 37
# 23
# 27
# 9
# 8
# 9
# 15
# 2
# 8
# 11
# 4
# 30
# 89
# 11
# 37
# 10
# 3
# 16
# 14
# 24
# 1
# 22
# 28
# 21
# 8
# 40
# 9
# 50
# 19
# 9
# 26
# 7
# 29
# 10
# 2
# 14
# 17
# 5
# 21
# 72
# 90
# 44
# 17
# 1
# 17
# 8
# 11
# 20
# 23
# 41
# 3
# 9
# 10
# 1
# 20
# 4
# 2
# 35
# 8
# 25
# 5
# 9
# 13
# 20
# 4
# 27
# 48
# 14
# 31
# 5
# 9
# 22
# 23
# 6
# 8
# 9
# 24
# 10
# 5
# 6
# 2
# 37
# 23
# 10
# 10
# 1
# 52
# 1
# 1
# 49
# 50
# 29
# 6
# 56
# 43
# 29
# 2
# 2
# 7
# 15
# 9
# 5
# 1
# 21
# 29
# 18
# 7
# 32
# 14
# 1
# 22
# 37
# 11
# 109
# 13
# 21
# 10
# 12
# 17
# 4
# 3
# 1
# 4
# 61
# 9
# 1
# 1
# 14
# 29
# 5
# 6
# 15
# 2
# 6
# 8
# 38
# 12
# 4
# 11
# 8
# 15
# 4
# 20
# 16
# 36
# 4
# 1
# 9
# 5
# 14
# 10
# 11
# 2
# 12
# 11
# 5
# 7
# 19
# 15
# 22
# 14
# 9
# 35
# 25
# 8
# 30
# 9
# 28
# 10
# 7
# 8
# 28
# 23
# 20
# 2
# 24
# 24
# 14
# 66
# 32
# 3
# 7
# 1
# 31
# 12
# 12
# 9
# 9
# 7
# 28
# 1
# 10
# 22
# 9
# 12
# 39
# 24
# 10
# 21
# 19
# 26
# 4
# 1
# 5
# 35
# 15
# 19
# 1
# 19
# 22
# 14
# 29
# 30
# 10
# 3
# 9
# 3
# 220
# 20
# 27
# 6
# 7
# 8
# 2
# 2
# 16
# 5
# 9
# 3
# 47
# 38
# 27
# 13
# 10
# 9
# 46
# 22
# 11
# 25
# 12
# 15
# 13
# 14
# 24
# 41
# 93
# 27
# 21
# 14
# 15
# 4
# 23
# 9
# 4
# 1
# 1
# 40
# 22
# 12
# 12
# 13
# 34
# 32
# 45
# 5
# 21
# 15
# 11
# 22
# 1
# 32
# 3
# 6
# 10
# 12
# 17
# 20
# 12
# 1
# 9
# 9
# 6
# 4
# 5
# 12
# 22
# 49
# 1
# 92
# 16
# 13
# 10
# 21
# 4
# 19
# 10
# 6
# 2
# 76
# 23
# 28
# 19
# 8
# 52
# 6
# 25
# 3
# 23
# 3
# 8
# 33
# 18
# 9
# 13
# 1
# 36
# 10
# 2
# 62
# 6
# 3
# 4
# 28
# 39
# 3
# 11
# 7
# 14
# 24
# 21
# 9
# 8
# 29
# 15
# 14
# 28
# 6
# 3
# 1
# 18
# 15
# 12
# 5
# 3
# 37
# 8
# 1
# 46
# 1
# 40
# 23
# 21
# 36
# 20
# 16
# 10
# 6
# 22
# 1
# 3
# 17
# 4
# 13
# 35
# 8
# 5
# 28
# 7
# 13
# 6
# 8
# 10
# 8
# 7
# 32
# 29
# 43
# 21
# 1
# 11
# 15
# 31
# 25
# 9
# 2
# 8
# 12
# 57
# 25
# 11
# 9
# 43
# 24
# 16
# 16
# 21
# 35
# 28
# 23
# 31
# 13
# 32
# 1
# 28
# 361
# 11
# 11
# 15
# 133
# 61
# 7
# 15
# 11
# 1
# 25
# 2
# 7
# 18
# 2
# 7
# 5
# 2
# 9
# 15
# 8
# 27
# 2
# 25
# 1
# 99
# 20
# 35
# 19
# 3
# 5
# 5
# 5
# 7
# 18
# 19
# 20
# 13
# 4
# 24
# 12
# 24
# 11
# 3
# 23
# 12
# 12
# 7
# 23
# 40
# 21
# 8
# 2
# 17
# 39
# 4
# 34
# 46
# 19
# 30
# 43
# 29
# 7
# 12
# 24
# 21
# 8
# 21
# 28
# 1
# 40
# 5
# 38
# 13
# 23
# 18
# 2
# 16
# 33
# 6
# 6
# 26
# 19
# 44
# 1
# 28
# 17
# 16
# 11
# 9
# 9
# 33
# 2
# 87
# 32
# 1
# 8
# 33
# 21
# 6
# 22
# 42
# 13
# 4
# 5
# 19
# 22
# 28
# 16
# 22
# 26
# 19
# 12
# 14
# 1
# 1
# 62
# 10
# 17
# 5
# 4
# 25
# 16
# 20
# 18
# 3
# 5
# 4
# 8
# 2
# 67
# 33
# 14
# 6
# 34
# 28
# 10
# 18
# 7
# 14
# 1
# 12
# 7
# 22
# 2
# 9
# 13
# 48
# 17
# 2
# 1
# 4
# 23
# 24
# 20
# 44
# 73
# 26
# 41
# 29
# 5
# 27
# 11
# 3
# 9
# 1
# 17
# 4
# 7
# 22
# 40
# 5
# 28
# 11
# 3
# 34
# 12
# 27
# 3
# 28
# 27
# 5
# 1
# 9
# 4
# 3
# 33
# 18
# 23
# 78
# 15
# 20
# 13
# 12
# 25
# 7
# 5
# 9
# 9
# 15
# 7
# 7
# 46
# 21
# 24
# 15
# 29
# 36
# 18
# 9
# 9
# 15
# 3
# 7
# 10
# 13
# 21
# 2
# 1
# 8
# 4
# 28
# 18
# 42
# 35
# 37
# 20
# 13
# 2
# 58
# 29
# 22
# 17
# 13
# 9
# 13
# 9
# 103
# 17
# 22
# 62
# 63
# 7
# 5
# 6
# 1
# 14
# 26
# 1
# 21
# 4
# 6
# 13
# 32
# 1
# 16
# 39
# 49
# 3
# 94
# 3
# 16
# 28
# 20
# 1
# 38
# 29
# 13
# 25
# 24
# 24
# 5
# 4
# 20
# 2
# 4
# 7
# 2
# 13
# 2
# 111
# 4
# 4
# 11
# 8
# 13
# 9
# 13
# 48
# 20
# 31
# 36
# 13
# 6
# 1
# 10
# 3
# 12
# 34
# 1
# 53
# 23
# 12
# 38
# 25
# 4
# 27
# 33
# 15
# 6
# 6
# 14
# 2
# 33
# 22
# 5
# 5
# 31
# 12
# 15
# 1
# 22
# 6
# 2
# 24
# 6
# 21
# 8
# 18
# 13
# 15

# %%
print nginx_set
# Out:
# set(['ngx_http_parse_chunked', 'ngx_http_proxy_pass.part.4', 'cswift_rsa_mod_exp', 'ngx_mail_auth_http_read_handler', 'ngx_http_copy_thread_handler', 'ngx_destroy_pool', 'ngx_http_autoindex_create_loc_conf', 'ngx_open_and_stat_file', 'emit_mov_byte', 'ngx_resolver_cleanup', 'ngx_http_mp4_read_stss_atom', 'ngx_http_fastcgi_create_request', 'ngx_http_uwsgi_cache_key', 'ngx_http_validate_host', 'ngx_http_file_cache_valid_set_slot', 'do_revertframes.isra.42', 'ngx_http_block_reading', 'ngx_create_temp_buf', 'ngx_http_rewrite_if', 'ngx_array_create', 'ngx_http_v2_state_headers', 'ngx_reusable_connection', 'ngx_http_process_request_headers', 'ngx_ssl_free_buffer', 'fast_forward_first_char2', 'ngx_http_headers_create_conf', 'ngx_stream_proxy_bind', 'ngx_http_process_unique_header_line', 'ngx_http_merge_locations', 'ngx_http_mp4_read_stts_atom', 'ngx_event_find_timer', 'add_label_addr.isra.30', 'ngx_escape_uri', 'ngx_event_process_init', 'ngx_http_ssi_endif', 'ngx_event_accept', 'ngx_close_connection', 'pkey_ctrl_gost', 'pub_print_gost01', 'VKO_compute_key.isra.0', 'ngx_crc32_short', 'ngx_http_send_header', 'ngx_rstrncmp', 'ngx_ssl_create_connection', 'ngx_mail_starttls_only', 'ngx_http_dav_delete_path.isra.2', 'ngx_ssl_ocsp_resolve_handler', 'ngx_stream_upstream_hash', 'pcre_study', 'ngx_http_ssl_handshake', 'ngx_mail_send', 'ngx_http_set_charset_slot', 'ngx_http_script_full_name_code', 'ngx_mail_salt', 'sljit_emit_fast_enter.constprop.57', 'ngx_http_discarded_request_body_handler', 'ngx_ssl_get_session_id', 'ngx_http_memcached_create_loc_conf', 'ngx_http_upstream_bind_set_slot', 'ngx_mail_auth_plain', 'ngx_ext_rename_file', 'ngx_thread_mutex_lock', 'ERR_load_GOST_strings', 'compile_regex', 'get_chr_property_list.isra.3', 'emit_cum_binary', 'ngx_http_realip_from', 'ngx_stream_proxy_ssl_password_file', 'ngx_create_listening', 'ngx_http_types_slot', 'ngx_resolve_addr', 'ngx_event_expire_timers', 'ngx_start_worker_processes', 'atalla_mod_exp', 'ngx_event_pipe_copy_input_filter', 'ngx_http_charset_map', 'ngx_thread_task_post', 'ngx_http_userid_add_variables', 'ngx_mail_session_internal_server_error', 'ngx_http_v2_state_save', 'sljit_alloc_memory', 'ngx_http_variable_document_root', 'ngx_mail_core_listen', 'ngx_mail_smtp_greeting', 'ngx_ssl_write', 'ngx_http_process_request_line', 'ngx_http_upstream_finalize_request', 'ngx_http_create_locations_list', 'ngx_http_add_listen', 'ngx_init_modules', 'ngx_http_parse_uri', 'atalla_dsa_mod_exp', 'hwcrhk_load_pubkey', 'ngx_mail_smtp_resolve_addr_handler', 'ngx_read_ahead', 'ngx_time_update', 'ngx_http_process_request_header', 'ngx_http_run_posted_requests', 'aep_get_connection', 'gost_init', 'ngx_ssl_ocsp_connect', 'ngx_http_fastcgi_non_buffered_filter', 'ngx_event_init_conf', 'ngx_http_index_create_loc_conf', 'ngx_http_charset_merge_loc_conf', 'ngx_unescape_uri', 'pub_decode_gost94', 'ngx_http_upstream_init_chash_peer', 'ngx_http_v2_read_client_request_body_handler', 'ngx_http_v2_pool_cleanup', 'getbnfrombuf', 'ngx_http_uwsgi_store', 'ngx_utf8_cpystrn', 'ngx_utf8_decode', 'hwcrhk_load_privkey', 'ngx_atotm', 'ngx_slab_free_locked', 'ngx_conf_include', 'ngx_http_memcached_process_header', 'emit_load_imm64', 'ngx_log_error_core', 'ngx_write_chain_to_file', 'ngx_http_core_try_files', 'fill_GOST2001_params', 'ngx_http_map_uri_to_path', 'ngx_http_gzip_add_variables', 'register_ameth_gost', 'ngx_http_cache_send', 'ngx_mail_smtp_log_rejected_command.isra.2.part.3', 'ngx_http_v2_connection_error', 'ngx_chain_add_copy', 'ngx_http_v2_state_push_promise', 'ngx_http_core_open_file_cache', 'ngx_http_upstream_upgraded_write_downstream', 'do_casefulcmp.isra.43', 'is_counted_repeat.part.0', 'compile_dnref_search', 'ngx_shmtx_lock', 'ngx_atofp', 'ngx_http_geo_cidr_add', 'ngx_http_gzip_static_create_conf', 'ngx_mail_proxy_init', 'ngx_http_sub_output', 'inflate', 'compile_recurse', 'adjust_recurse.isra.5', 'ngx_proxy_protocol_read', 'ngx_mail_smtp_parse_command', 'ngx_start_cache_manager_processes', 'ngx_resolver_tcp ...

# %%
components = p.load(open('component','r'))
for component in components:
    if len(component) < 2:
        print component
# Out:
# set(['ngx_crc32_short##libssl#ssl3_renegotiate_check'])
# set(['c2i_ASN1_OBJECT##libcrypto#RSA_verify_PKCS1_PSS_mgf1'])
# set(['X509_NAME_get_entry##libcrypto#CRYPTO_malloc'])
# set(['sk_push##libcrypto#c2i_ASN1_BIT_STRING'])
# set(['sk_push##libcrypto#OBJ_bsearch'])
# set(['BIO_snprintf##libcrypto#EVP_CIPHER_CTX_cleanup'])
# set(['hwcrhk_load_privkey##libcrypto#asn1_d2i_ex_primitive'])
# set(['X509_STORE_get_by_subject##libcrypto#RSA_print'])
# set(['X509V3_EXT_add_nconf##libcrypto#BN_sqr'])
# set(['tls1_ec_nid2curve_id##libssl#tls1_shared_curve'])
# set(['ngx_http_core_location##libcrypto#BN_div'])
# set(['ssl_get_server_send_pkey##libssl#tls1_enc'])
# set(['X509_PUBKEY_get0_param##libcrypto#BIO_read'])
# set(['CRYPTO_free##libcrypto#ASN1_STRING_clear_free'])
# set(['CRYPTO_malloc##libssl#ssl3_cleanup_key_block'])
# set(['BN_lshift##libcrypto#BN_GF2m_add'])
# set(['NAME_CONSTRAINTS_check##libcrypto#CMS_add0_cert'])
# set(['CRYPTO_free_ex_data##libcrypto#ERR_SUREWARE_error.constprop.5'])
# set(['ngx_http_variables_init_vars##libcrypto#CRYPTO_malloc'])
# set(['ngx_destroy_pool##libcrypto#BIO_gets'])
# set(['EC_POINT_new##libcrypto#BIO_ctrl'])
# set(['X509_VERIFY_PARAM_inherit##libssl#dtls1_do_write'])
# set(['CMS_dataFinal##libcrypto#d2i_ASN1_bytes'])
# set(['ngx_destroy_pool##libcrypto#BN_is_prime_fasttest_ex'])
# set(['EVP_PKEY_encrypt_init##libcrypto#EVP_DigestFinal_ex'])
# set(['RSA_new##libcrypto#DH_free'])
# set(['X509_TRUST_add##libcrypto#dh_copy_parameters'])
# set(['UI_set_result##libssl#dtls1_send_client_key_exchange'])
# set(['sk_new##libcrypto#EC_POINT_copy'])
# set(['ngx_handle_read_event##libssl#dtls1_buffer_record.isra.7.part.8'])
# set(['dtls1_process_heartbeat##libcrypto#BN_mod_mul_montgomery'])
# set(['BIO_new_fp##libcrypto#BN_new'])
# set(['asn1_get_field_ptr##libcrypto#OPENSSL_cleanse'])
# set(['X509_get_pubkey##libcrypto#BIO_push'])
# set(['ENGINE_finish##libcrypto#ASN1_INTEGER_to_BN'])
# set(['BN_is_bit_set##libcrypto#BN_is_odd'])
# set(['OBJ_nid2obj##libcrypto#X509_check_private_key'])
# set(['hwcrhk_get_pass##libcrypto#BN_nist_mod_192'])
# set(['ngx_atosz##libcrypto#ASN1_template_free'])
# set(['UI_get0_action_string##libcrypto#ERR_put_error'])
# set(['tls12_get_sigid##libcrypto#BN_num_bits'])
# set(['BIO_write##libssl#ssl_bytes_to_cipher_list'])
# set(['cms_EncryptedData_init_bio##libcrypto#RAND_status'])
# set(['ssl3_do_write##libcrypto#BUF_MEM_grow'])
# set(['OBJ_bsearch_##libcrypto#ASN1_item_i2d'])
# set(['ngx_http_send_special##libcrypto#BN_mod_exp'])
# set(['ssl_verify_alarm_type##libcrypto#ASN1_TYPE_get'])
# set(['sk_new##libcrypto#BUF_MEM_grow_clean'])
# set(['RSA_new##libssl#ssl3_send_alert'])
# set(['lh_num_items##libcrypto#BN_CTX_end'])
# set(['ngx_snprintf##libcrypto#OCSP_id_cmp'])
# set(['sk_push##libcrypto#BIO_accept'])
# set(['ngx_http_weak_etag##libcrypto#ASN1_primitive_free'])
# set(['BIO_free##libcrypto#RSA_padding_check_PKCS1_type_1'])
# set(['ngx_http_split_args##libssl#pqueue_insert'])
# set(['ngx_resolve_name_done##libcrypto#EVP_PKEY_CTX_new'])
# set(['bn_GF2m_mul_2x2##libcrypto#BN_num_bits'])
# set(['EVP_PKEY_CTX_new##libcrypto#d2i_ECPrivateKey'])
# set(['OBJ_nid2sn##libcrypto#EVP_PKEY_CTX_new'])
# set(['X509_NAME_ENTRY_get_data##libcrypto#BIO_next'])
# set(['ASN1_UTCTIME_print##libcrypto#ERR_add_error_data'])
# set(['BN_new##libcrypto#EC_KEY_new'])
# set(['BN_GF2m_poly2arr##libcrypto#BN_GF2m_poly2arr'])
# set(['OBJ_cmp##libcrypto#HMAC_Update'])
# set(['CRYPTO_free##libssl#tls1_set_server_sigalgs'])
# set(['ngx_pnalloc##libcrypto#ERR_print_errors_cb'])
# set(['X509_get1_ocsp##libcrypto#OBJ_obj2nid'])
# set(['PKCS7_content_new##libcrypto#do_ext_nconf'])
# set(['ngx_resolver_free_node.isra.5##libssl#ssl_get_prev_session'])
# set(['ngx_pnalloc##libssl#ssl2_enc_init'])
# set(['encode_gost_algor_params##libcrypto#EVP_SignFinal'])
# set(['ngx_shmtx_lock##libssl#dtls1_process_buffered_records'])
# set(['SSL_set_srp_server_param##libcrypto#dsa_do_sign'])
# set(['EC_POINT_clear_free##libcrypto#BN_BLINDING_free'])
# set(['ssl_get_handshake_digest##libcrypto#BIO_free_all'])
# set(['ASN1_STRING_dup##libssl#dtls1_do_write'])
# set(['EVP_BytesToKey##libssl#tls1_final_finish_mac'])
# set(['ngx_http_parse_expires##libcrypto#ASN1_item_free'])
# set(['ngx_ssl_ocsp_connect##libssl#dtls1_do_write'])
# set(['EVP_PKEY_encrypt_init##libcrypto#CRYPTO_clear_free'])
# set(['sk_is_sorted##libssl#ssl3_do_compress'])
# set(['ngx_chain_get_free_buf##libcrypto#ERR_put_error'])
# set(['EVP_PKEY_base_id##libcrypto#BN_BLINDING_new'])
# set(['ERR_put_error##libcrypto#X509_find_by_subject'])
# set(['ngx_log_error_core##libssl#ssl_cipher_apply_rule.isra.0.constprop.6'])
# set(['int_thread_get_item##libcrypto#rsa_item_sign'])
# set(['X509_EXTENSION_create_by_OBJ##libcrypto#EVP_DigestInit_ex'])
# set(['CRYPTO_mem_ctrl##libcrypto#BN_copy'])
# set(['ngx_open_dir##libcrypto#ERR_put_error'])
# set(['sk_is_sorted##libcrypto#BN_num_bits'])
# set(['EVP_PKEY_verify_init##libssl#ssl_sess_cert_new'])
# set(['BN_bn2dec##libcrypto#EVP_DigestInit_ex'])
# set(['lh_retrieve##libcrypto#ASN1_get_object'])
# set(['dtls1_enc##libcrypto#ec_GF2m_simple_point2oct'])
# set(['deflateInit2_##libssl#ssl3_read_n'])
# set(['getbnfrombuf##libcrypto#X509_policy_tree_free'])
# set(['pkey_gost_mac_ctrl_str##libssl#SSL_clear'])
# set(['PEM_def_callback##libcrypto#i2o_ECPublicKey'])
# set(['decode_gost_algor_params##libcrypto#PEM_SealFinal'])
# set(['ngx_http_set_charset_slot##libcrypto#asn1_d2i_ex_primitive'])
# set(['X509_NAME_get_entry##libcrypto#BN_CTX_new'])
# set(['X509V3_get_section##libssl#ssl_replace_hash'])
# set(['X509V3_get_value_int##libcrypto#RSA_eay_private_encrypt'])
# set(['BUF_strdup##libcrypto#o2i_ECPublicKey'])
# set(['BN_GF2m_mod_div##libcrypto#BN_exp'])
# set(['ngx_slab_free_locked##libssl#ssl_set_cert_masks'])
# set(['PEM_def_callback##libcrypto#BIO_free'])
# set(['BN_clear_free##libcrypto#RSA_free'])
# set(['ngx_reusable_connection##libcrypto#bn_bn2binpad'])
# set(['ngx_rbtree_insert##libssl#ssl3_read_n'])
# set(['ngx_hash_keys_array_init##libcrypto#BN_mod_mul'])
# set(['gost_do_sign##libcrypto#PEM_read_bio_Parameters'])
# set(['ngx_ssl_check_name##libcrypto#X509_NAME_cmp'])
# set(['decode_gost_algor_params##libcrypto#BN_sub'])
# set(['ngx_regex_module_init##libcrypto#rc4_hmac_md5_ctrl'])
# set(['ngx_create_temp_buf##libcrypto#BN_dup'])
# set(['ssl_get_server_send_cert##libssl#ssl3_client_hello'])
# set(['ECDSA_DATA_new_method.constprop.1##libssl#SSL_CTX_free'])
# set(['X509_VERIFY_PARAM_free##libcrypto#DSO_load'])
# set(['name_cmp##libcrypto#DSA_SIG_free'])
# set(['ngx_shmtx_lock##libcrypto#BN_copy'])
# set(['sk_value##libssl#ssl3_comp_find'])
# set(['BIO_ctrl##libcrypto#BIO_callback_ctrl'])
# set(['CRYPTO_THREADID_current##libssl#ssl3_new'])
# set(['BIO_free##libcrypto#d2i_DHxparams'])
# set(['BUF_strdup##libcrypto#CRYPTO_set_ex_data'])
# set(['EVP_PKEY_set_type##libcrypto#EVP_PKEY_copy_parameters'])
# set(['ngx_thread_read##libcrypto#bn_correct_top'])
# set(['ngx_http_limit_conn##libssl#dtls1_send_client_key_exchange'])
# set(['SSL_use_PrivateKey##libcrypto#BN_clear_free'])
# set(['ngx_http_complex_value##libssl#ssl_parse_serverhello_use_srtp_ext'])
# set(['CRYPTO_lock##libcrypto#engine_cleanup_add_last'])
# set(['BN_CTX_free##libcrypto#BUF_MEM_grow_clean'])
# set(['ASN1_STRING_free##libcrypto#X509_NAME_set'])
# set(['EVP_PKEY_free##libcrypto#i2d_ASN1_SET'])
# set(['ngx_http_ssi_get_variable.isra.1##libcrypto#CRYPTO_malloc'])
# set(['ssl3_do_uncompress##libssl#ssl3_setup_write_buffer'])
# set(['i2d_SSL_SESSION##libcrypto#X509_verify_cert'])
# set(['ASN1_STRING_free##libcrypto#BIO_pop'])
# set(['EVP_PKEY_new##libcrypto#PEM_def_callback'])
# set(['ngx_chain_get_free_buf##libcrypto#i2a_ASN1_OBJECT'])
# set(['CRYPTO_add_lock##libcrypto#EVP_SignFinal'])
# set(['ngx_http_v2_send_window_update##libssl#ssl3_finish_mac'])
# set(['BN_CTX_get##libcrypto#X509_verify_cert'])
# set(['ngx_ssl_create##libssl#dtls1_send_client_key_exchange'])
# set(['ERR_get_next_error_library##libssl#tls1_check_curve'])
# set(['sk_push##libcrypto#BUF_strdup'])
# set(['OBJ_NAME_new_index##libcrypto#X509_ATTRIBUTE_set1_data'])
# set(['X509_PUBKEY_set0_param##libcrypto#PKCS8_pkey_set0'])
# set(['ASN1_STRING_free##libcrypto#BN_bn2bin'])
# set(['ngx_strncasecmp##libcrypto#OBJ_obj2nid'])
# set(['ngx_array_push##libcrypto#BN_div_word'])
# set(['BN_mod_mul##libcrypto#BIO_puts'])
# set(['sk_value##libcrypto#EVP_PKEY_cmp_parameters'])
# set(['ngx_close_cached_file##libssl#ssl3_write_pending'])
# set(['sljit_emit_cmp##libcrypto#BN_rshift'])
# set(['ngx_sock_ntop##libssl#SSL_clear'])
# set(['ERR_put_error##libssl#tls12_get_psigalgs'])
# set(['BN_set_word##libcrypto#RAND_pseudo_bytes'])
# set(['ngx_http_set_etag##libcrypto#ASN1_STRING_free'])
# set(['ngx_http_send_refresh##libcrypto#BN_nnmod'])
# set(['ngx_chain_get_free_buf##libssl#ssl_bytes_to_cipher_list'])
# set(['BN_new##libcrypto#policy_data_free'])
# set(['DSO_bind_func##libcrypto#ENGINE_add'])
# set(['X509_time_adj_ex##libcrypto#ASN1_TIME_adj'])
# set(['lh_new##libcrypto#RAND_bytes'])
# set(['ngx_ssl_create_connection##libcrypto#CRYPTO_malloc'])
# set(['X509_pubkey_digest##libcrypto#EVP_PKEY_get_default_digest_nid'])
# set(['dh_cb##libcrypto#dsa_cb'])
# set(['BIO_pop##libcrypto#BIO_ctrl'])
# set(['EC_GROUP_dup##libcrypto#X509_PUBKEY_get0'])
# set(['ngx_http_script_start_code##libssl#ssl3_renegotiate'])
# set(['BIO_new_NDEF##libcrypto#SMIME_crlf_copy'])
# set(['BN_BLINDING_convert_ex##libcrypto#BN_kronecker'])
# set(['ngx_pnalloc##libssl#ssl23_write_bytes'])
# set(['ngx_memalign##libssl#ssl3_send_alert'])
# set(['ngx_create_pool##libcrypto#ASN1_TYPE_set'])
# set(['ssl3_send_alert##libcrypto#RSA_padding_check_PKCS1_type_2'])
# set(['ngx_hash_find##libcrypto#BN_mod_exp'])
# set(['emit_mov.part.17##libcrypto#RSA_padding_check_PKCS1_type_1'])
# set(['CRYPTO_gcm128_finish##libcrypto#sha1_block_data_order'])
# set(['X509_check_issued##libcrypto#X509_check_ca'])
# set(['sk_num##libcrypto#ASN1_item_ex_new'])
# set(['CRYPTO_malloc##libcrypto#TS_check_imprints'])
# set(['lh_num_items##libcrypto#lh_num_items'])
# set(['load_builtin_compressions##libcrypto#def_get_class'])
# set(['ngx_http_time##libcrypto#CRYPTO_malloc'])
# set(['BN_CTX_free##libcrypto#OPENSSL_sk_pop_free'])
# set(['ngx_http_discard_request_body##libssl#ssl_parse_clienthello_tlsext'])
# set(['bn_dup_expand##libssl#ssl3_get_server_certificate'])
# set(['ngx_open_file_cache_init##libssl#ssl3_digest_cached_records'])
# set(['X509V3_extensions_print##libcrypto#i2a_ASN1_OBJECT'])
# set(['SSL_get_error##libcrypto#BN_rand_range'])
# set(['ENGINE_finish##libcrypto#PEM_def_callback'])
# set(['ngx_strcasecmp##libcrypto#BN_rshift1'])
# set(['sk_pop##libcrypto#sk_value'])
# set(['ERR_SUREWARE_error.constprop.5##libcrypto#PKCS12_unpack_authsafes'])
# set(['bn_GF2m_mul_2x2##libcrypto#bn_GF2m_mul_2x2'])
# set(['BN_rshift##libcrypto#SMIME_text'])
# set(['BN_CTX_new##libcrypto#DSO_merge'])
# set(['ngx_array_push##libssl#SSL_ctrl'])
# set(['ngx_pnalloc##libcrypto#_CONF_get_string'])
# set(['ASN1_STRING_dup##libcrypto#BN_bin2bn'])
# set(['bn_expand2##libcrypto#ASN1_STRING_free'])
# set(['int_cleanup##libcrypto#OBJ_NAME_cleanup'])
# set(['ngx_ssl_free_buffer##libssl#ssl3_init_finished_mac'])
# set(['ngx_pcalloc##libcrypto#ASN1_STRING_TABLE_add'])
# set(['BN_CTX_new##libcrypto#sk_free'])
# set(['ASN1_STRING_free##libcrypto#NCONF_get_string'])
# set(['bn_expand2##libcrypto#CRYPTO_set_ex_data'])
# set(['BIO_free##libcrypto#setup_blinding'])
# set(['ngx_hash_key_lc##libssl#ssl3_do_compress'])
# set(['BN_to_ASN1_ENUMERATED##libcrypto#cms_DigestedData_do_final'])
# set(['ngx_http_file_cache_delete##libssl#ssl_prepare_clienthello_tlsext'])
# set(['ngx_http_cookie_time##libssl#ssl_parse_serverhello_renegotiate_ext'])
# set(['BN_CTX_new##libcrypto#CRYPTO_lock'])
# set(['BN_GF2m_mod_mul_arr##libcrypto#BN_from_montgomery_word'])
# set(['ERR_put_error##libcrypto#EC_POINT_add'])
# set(['CRYPTO_dbg_malloc##libcrypto#pkey_rsa_verify'])
# set(['OBJ_ln2nid##libcrypto#ASN1_UTCTIME_adj'])
# set(['ngx_stream_limit_conn_zone##libcrypto#asn1_d2i_read_bio.constprop.0'])
# set(['TXT_DB_free##libcrypto#ok_write'])
# set(['ngx_http_get_variable##libcrypto#RSA_padding_add_PKCS1_OAEP'])
# set(['sk_new_null##libcrypto#BIO_push'])
# set(['EVP_CIPHER_CTX_ctrl##libcrypto#BN_CTX_new'])
# set(['dsa_pub_decode##libssl#SSL_dup'])
# set(['BN_BLINDING_free##libcrypto#BN_CTX_free'])
# set(['CRYPTO_gcm128_init##libcrypto#CRYPTO_gcm128_init'])
# set(['ngx_conf_log_error##libssl#ssl_parse_clienthello_tlsext'])
# set(['ssl_sess_cert_new##libcrypto#CRYPTO_clear_free'])
# set(['ngx_shmtx_lock##libcrypto#RAND_poll'])
# set(['sk_new##libcrypto#SCT_new'])
# set(['ngx_conf_log_error##libcrypto#ASN1_generate_v3'])
# set(['ssl3_digest_cached_records##libssl#ssl_get_prev_session'])
# set(['BUF_MEM_new##libcrypto#CRYPTO_strdup'])
# set(['ngx_mail_send##libcrypto#RAND_poll'])
# set(['ngx_sprintf##libcrypto#setup_blinding'])
# set(['ngx_chain_add_copy##libcrypto#CRYPTO_malloc'])
# set(['ngx_palloc##libcrypto#CRYPTO_lock'])
# set(['EC_POINT_free##libcrypto#BUF_MEM_new'])
# set(['ssl_verify_cert_chain##libcrypto#EVP_MD_CTX_copy_ex'])
# set(['ngx_hash_find##libssl#dtls1_buffer_record.isra.7.part.8'])
# set(['byte_sequence_compare##libssl#ssl_bytes_to_cipher_list'])
# set(['ngx_http_regex_exec##libcrypto#OBJ_obj2txt'])
# set(['OCSP_id_cmp##libcrypto#OPENSSL_sk_value'])
# set(['sk_new_null##libcrypto#ASN1_INTEGER_get'])
# set(['ngx_parse_size##libssl#ssl3_choose_cipher'])
# set(['PKCS8_pkey_get0##libcrypto#BIO_find_type'])
# set(['ngx_mail_smtp_resolve_name_handler##libcrypto#ASN1_item_print'])
# set(['BN_is_prime_fasttest_ex##libcrypto#BN_div'])
# set(['BN_GF2m_mod_solve_quad_arr##libcrypto#BN_gcd'])
# set(['RSA_sign##libcrypto#X509_verify_cert'])
# set(['i2o_ECPublicKey##libssl#SSL_CTX_use_certificate'])
# set(['BN_num_bits##libcrypto#BUF_MEM_grow_clean'])
# set(['CMS_SignerInfo_verify##libssl#dtls1_send_client_verify'])
# set(['X509V3_get_section##libcrypto#PKCS7_add_signature'])
# set(['ASN1_object_size##libcrypto#BN_set_word'])
# set(['ngx_mail_smtp_invalid_pipelining##libssl#do_ssl3_write'])
# set(['X509_EXTENSION_get_object##libcrypto#sk_is_sorted'])
# set(['ngx_array_push##libcrypto#OPENSSL_sk_value'])
# set(['ssl3_init_finished_mac##libssl#ssl3_get_client_certificate'])
# set(['RAND_add##libcrypto#EVP_PKEY_free'])
# set(['DH_free##libcrypto#CRYPTO_malloc'])
# set(['X509_get_pubkey##libcrypto#sk_dup'])
# set(['X509_PURPOSE_get0##libcrypto#X509_PURPOSE_get0'])
# set(['timeout_LHASH_DOALL_ARG##libcrypto#md_ctrl'])
# set(['CRYPTO_malloc##libcrypto#ASN1_STRING_set_by_NID'])
# set(['EC_GROUP_copy##libcrypto#cswift_mod_exp_mont'])
# set(['ssl_get_new_session##libssl#ssl_add_clienthello_tlsext'])
# set(['ngx_http_regex_exec##libssl#tls1_process_ticket'])
# set(['sk_set##libssl#ssl_sess_cert_new'])
# set(['X509_NAME_cmp##libcrypto#EVP_PKEY_CTX_ctrl'])
# set(['CRYPTO_add_lock##libcrypto#PKCS5_pbkdf2_set'])
# set(['BN_free##libcrypto#sk_find'])
# set(['ngx_array_push##libcrypto#BN_from_montgomery'])
# set(['CRYPTO_lock##libcrypto#ASN1_OBJECT_new'])
# set(['RAND_add##libcrypto#BN_bin2bn'])
# set(['ngx_event_pipe_write_chain_to_temp_file##libssl#ssl3_free'])
# set(['ASN1_put_object##libcrypto#OPENSSL_hexstr2buf'])
# set(['ngx_mail_auth_plain##libcrypto#pkey_hmac_ctrl_str'])
# set(['PKCS7_add_certificate##libcrypto#X509_STORE_add_cert'])
# set(['ENGINE_ctrl_cmd_string##libcrypto#dynamic_ctrl'])
# set(['B64_write_ASN1##libcrypto#PKCS7_sign'])
# set(['X509_NAME_oneline##libcrypto#BN_nist_mod_224'])
# set(['pitem_free##libcrypto#CRYPTO_THREAD_lock_free'])
# set(['x509_object_idx_cnt##libssl#ssl_cipher_list_to_bytes'])
# set(['SSL_ctrl##libcrypto#EVP_CIPHER_asn1_to_param'])
# set(['ENGINE_set_name##libcrypto#ERR_add_error_data'])
# set(['BN_sub_word##libcrypto#ASN1_item_free'])
# set(['SRP_Calc_B##libcrypto#ec_GFp_simple_group_set_curve'])
# set(['X509_get_pubkey##libcrypto#X509_NAME_get_index_by_NID'])
# set(['ngx_resolver_export##libcrypto#BN_mod_mul_montgomery'])
# set(['EVP_PKEY_CTX_ctrl##libcrypto#PKCS7_digest_from_attributes'])
# set(['ngx_pnalloc##libssl#ssl_add_serverhello_use_srtp_ext'])
# set(['X509V3_EXT_print##libcrypto#e_rsax_get_ctx'])
# set(['sk_pop_free##libcrypto#lh_doall'])
# set(['EVP_CIPHER_CTX_cleanup##libcrypto#EVP_DigestVerifyInit'])
# set(['ngx_array_push##libcrypto#asn1_add_error'])
# set(['BN_new##libcrypto#BN_clear_free'])
# set(['EVP_PKEY_new_mac_key##libssl#dtls1_send_server_key_exchange'])
# set(['ngx_array_create##libcrypto#BN_clear_free'])
# set(['ASN1_item_pack##libcrypto#ecdsa_check'])
# set(['i2v_GENERAL_NAME##libcrypto#CRYPTO_free'])
# set(['sk_push##libcrypto#EVP_DigestSignInit'])
# set(['ngx_mail_core_listen##libcrypto#sub_1802a0'])
# set(['X509V3_get_section##libcrypto#DSO_bind_func'])
# set(['dtls1_retransmit_message##libssl#ssl3_do_write'])
# set(['ERR_put_error##libcrypto#X509_NAME_ENTRY_get_data'])
# set(['X509_print##libcrypto#X509v3_asid_is_canonical'])
# set(['EC_POINT_new##libssl#ssl_get_sign_pkey'])
# set(['BIO_read##libcrypto#EVP_DecodeBlock'])
# set(['ERR_get_next_error_library##libcrypto#CRYPTO_is_mem_check_on'])
# set(['ASN1_item_sign_ctx##libcrypto#PKCS7_dataInit'])
# set(['ngx_strcasecmp##libcrypto#OPENSSL_cleanse'])
# set(['ngx_stream_upstream_zone##libcrypto#PKCS7_verify'])
# set(['sk_new_null##libcrypto#X509_VERIFY_PARAM_free'])
# set(['ngx_http_compile_complex_value##libssl#ssl_get_prev_session'])
# set(['sk_new_null##libcrypto#DSO_set_filename'])
# set(['policy_data_free##libcrypto#EVP_MD_size'])
# set(['EVP_PKEY_encrypt_init##libcrypto#BIO_new'])
# set(['BN_sub_word##libcrypto#X509_NAME_cmp'])
# set(['EC_POINT_is_at_infinity##libcrypto#CRYPTO_malloc'])
# set(['X509_PKEY_new##libcrypto#CMS_ReceiptRequest_create0'])
# set(['ngx_utf8_cpystrn##libcrypto#CRYPTO_malloc'])
# set(['EVP_PKEY_missing_parameters##libcrypto#EVP_PKEY_missing_parameters'])
# set(['ngx_sock_ntop##libssl#ssl3_choose_cipher'])
# set(['pkey_gost94cp_keygen##libcrypto#ECDH_set_method'])
# set(['ngx_hash_init##libssl#ssl_parse_clienthello_tlsext'])
# set(['aep_mod_exp.part.0##libcrypto#engine_unlocked_finish'])
# set(['level_add_node##libcrypto#RSA_eay_private_encrypt'])
# set(['BN_CTX_start##libssl#ssl_generate_master_secret'])
# set(['ngx_strncasecmp##libssl#SSL_clear'])
# set(['ngx_debug_point##libcrypto#i2s_ASN1_INTEGER'])
# set(['ngx_radix_tree_create##libssl#dtls_get_message'])
# set(['EVP_PKEY_new##libssl#ssl3_comp_find'])
# set(['asn1_do_adb##libcrypto#BN_CTX_start'])
# set(['ngx_hash_find##libcrypto#BN_num_bits_word'])
# set(['BN_bin2bn##libcrypto#CRYPTO_malloc'])
# set(['ec_GF2m_simple_point2oct##libcrypto#add_cert_dir.isra.0'])
# set(['ASN1_item_free##libcrypto#OCSP_basic_sign'])
# set(['EVP_PKEY_new##libcrypto#BN_set_word'])
# set(['emit_cum_binary##libssl#ssl2_accept'])
# set(['ngx_pool_cleanup_add##libssl#dtls1_buffer_message'])
# set(['CRYPTO_realloc_clean##libcrypto#CRYPTO_realloc_clean'])
# set(['BIO_free##libcrypto#X509_REQ_extension_nid'])
# set(['ngx_create_temp_buf##libcrypto#OPENSSL_sk_num'])
# set(['SSL_CTX_flush_sessions##libcrypto#BN_MONT_CTX_new'])
# set(['ASN1_BIT_STRING_get_bit##libcrypto#BN_BLINDING_convert_ex'])
# set(['BN_dup##libcrypto#OBJ_find_sigid_by_algs'])
# set(['sk_pop_free##libcrypto#EVP_PKEY_free'])
# set(['ngx_ssl_get_fingerprint##libcrypto#srp_Calc_k'])
# set(['RAND_pseudo_bytes##libcrypto#OPENSSL_sk_value'])
# set(['SSL_get_version##libcrypto#CRYPTO_malloc'])
# set(['ngx_stream_upstream_init_round_robin_peer##libcrypto#BN_CTX_free'])
# set(['BUF_MEM_grow##libcrypto#BN_cmp'])
# set(['CRYPTO_free##libcrypto#EVP_PKEY_verify'])
# set(['CRYPTO_free##libcrypto#srp_Calc_k'])
# set(['sk_new##libcrypto#CRYPTO_strdup'])
# set(['BN_bntest_rand##libcrypto#acpt_write'])
# set(['X509V3_EXT_d2i##libcrypto#X509_STORE_CTX_init'])
# set(['X509_NAME_hash##libcrypto#BN_num_bits'])
# set(['EC_GROUP_new##libcrypto#BN_num_bits'])
# set(['B64_write_ASN1##libcrypto#EVP_DigestFinal_ex'])
# set(['ngx_http_core_error_page##libcrypto#ASN1_d2i_bio'])
# set(['BN_rshift##libcrypto#bn_mul_fixed_top'])
# set(['CRYPTO_mem_ctrl.constprop.5##libcrypto#CRYPTO_is_mem_check_on'])
# set(['fill_GOST2001_params##libcrypto#DSA_verify'])
# set(['lh_delete##libcrypto#PKCS12_key_gen_uni'])
# set(['HMAC_Init##libcrypto#PKCS12_key_gen_uni'])
# set(['OBJ_bsearch_##libcrypto#EVP_EncryptFinal_ex'])
# set(['i2s_ASN1_ENUMERATED##libcrypto#OBJ_create'])
# set(['CMS_add0_CertificateChoices##libcrypto#BIO_free'])
# set(['sk_free##libcrypto#ERR_add_error_data'])
# set(['AES_unwrap_key##libcrypto#ASN1_item_i2d'])
# set(['value_free_stack_LHASH_DOALL##libcrypto#ASN1_template_free'])
# set(['SSL_SESSION_get_id##libcrypto#BN_num_bits'])
# set(['BN_mod_exp##libcrypto#BN_div'])
# set(['ngx_file_aio_read##libssl#ssl3_read_n'])
# set(['BN_BLINDING_free##libcrypto#EVP_DigestSignFinal'])
# set(['EVP_CIPHER_CTX_copy##libcrypto#EVP_CIPHER_CTX_copy'])
# set(['sk_pop##libcrypto#BIO_ctrl'])
# set(['X509V3_EXT_CRL_add_nconf##libcrypto#X509V3_EXT_add_nconf_sk'])
# set(['ASN1_item_i2d##libcrypto#PKCS7_ctrl'])
# set(['X509_TRUST_add##libssl#ssl3_get_server_hello'])
# set(['CRYPTO_lock##libcrypto#EVP_CIPHER_CTX_set_key_length'])
# set(['EVP_MD_CTX_md##libcrypto#bn_wexpand'])
# set(['ibm_4758_cca_finish##libcrypto#EVP_PKEY_asn1_add0'])
# set(['RAND_add##libcrypto#BN_copy'])
# set(['ASN1_item_pack##libcrypto#d2i_ECPrivateKey'])
# set(['UI_add_input_string##libcrypto#BN_copy'])
# set(['ngx_http_free_request##libssl#ssl_check_serverhello_tlsext'])
# set(['init_frame.isra.32##libssl#ssl3_write'])
# set(['CRYPTO_malloc##libcrypto#i2o_ECPublicKey'])
# set(['EVP_PKEY_size##libcrypto#BIO_next'])
# set(['BIO_asn1_set_suffix##libcrypto#PKCS7_cert_from_signer_info'])
# set(['ngx_strcasecmp##libcrypto#BUF_MEM_grow'])
# set(['set_reasons##libcrypto#SMIME_crlf_copy'])
# set(['BN_sqr##libcrypto#BN_mod_exp_mont'])
# set(['BN_BLINDING_free##libcrypto#PKCS12_pack_p7encdata'])
# set(['X509_load_crl_file##libcrypto#sk_find'])
# set(['sk_new##libcrypto#CRYPTO_free'])
# set(['SSL_CTX_flush_sessions##libcrypto#RAND_add'])
# set(['ngx_resolve_addr_done##libcrypto#BN_div'])
# set(['sljit_emit_cmp##libcrypto#BN_set_bit'])
# set(['EVP_PKEY_new##libssl#ssl3_send_alert'])
# set(['BN_num_bits##libcrypto#EVP_EncryptUpdate'])
# set(['ERR_put_error##libcrypto#EVP_EncodeUpdate'])
# set(['X509_STORE_add_lookup##libcrypto#ec_GF2m_simple_is_on_curve'])
# set(['BN_mod_mul##libcrypto#EVP_MD_CTX_cleanup'])
# set(['ngx_http_regex_exec##libcrypto#print'])
# set(['ASN1_ENUMERATED_get##libcrypto#X509_cmp_time'])
# set(['EVP_MD_CTX_destroy##libssl#SSL_CTX_free'])
# set(['ngx_http_referer_merge_conf##libssl#ssl23_connect'])
# set(['gost2001_do_sign##libcrypto#BN_GF2m_mod_exp_arr'])
# set(['SHA1_Final##libcrypto#BN_CTX_get'])
# set(['cms_DigestAlgorithm_find_ctx##libcrypto#X509V3_EXT_i2d'])
# set(['CRYPTO_lock##libcrypto#RSA_padding_check_none'])
# set(['ngx_ssl_shutdown##libcrypto#BN_rand'])
# set(['ngx_unescape_uri##libssl#dtls1_get_message_fragment'])
# set(['ngx_http_discard_request_body##libcrypto#aesni_cbc_hmac_sha1_ctrl'])
# set(['ngx_setproctitle##libssl#custom_ext_parse'])
# set(['add_cert_dir.isra.0##libcrypto#ec_wNAF_precompute_mult'])
# set(['ngx_close_connection##libssl#ssl3_write_pending'])
# set(['OBJ_find_sigid_algs##libcrypto#EVP_DigestFinal_ex'])
# set(['updatewindow##libcrypto#BN_CTX_start'])
# set(['init_frame.isra.32##libssl#ssl3_write_pending'])
# set(['ngx_pcalloc##libssl#ssl3_finish_mac'])
# set(['OBJ_find_sigid_algs##libcrypto#X509_signature_dump'])
# set(['BN_bn2bin##libcrypto#RAND_add'])
# set(['a2i_ipadd##libcrypto#CONF_parse_list'])
# set(['ngx_event_pipe_write_chain_to_temp_file##libssl#dtls1_enc'])
# set(['ASN1_item_new##libcrypto#BN_set_word'])
# set(['OBJ_create##libcrypto#OBJ_txt2obj'])
# set(['EVP_DigestFinal_ex##libcrypto#EVP_PKEY_decrypt'])
# set(['EVP_MD_size##libssl#dtls1_hm_fragment_free'])
# set(['EVP_DigestInit_ex##libcrypto#c2i_ASN1_INTEGER'])
# set(['BN_CTX_new##libcrypto#pem_check_suffix'])
# set(['ngx_array_create##libssl#ssl_session_strndup'])
# set(['BN_GF2m_mod_arr.part.0##libcrypto#BN_add_word'])
# set(['ngx_read_file##libssl#ssl3_choose_cipher'])
# set(['BIO_printf##libcrypto#ERR_peek_last_error'])
# set(['sk_pop_free##libcrypto#X509V3_NAME_from_section'])
# set(['ngx_escape_uri##libcrypto#X509V3_section_free'])
# set(['BN_lshift##libcrypto#ASN1_get_object'])
# set(['BN_new##libcrypto#BUF_strdup'])
# set(['BN_copy##libcrypto#BN_GF2m_mod_sqrt_arr'])
# set(['ngx_destroy_pool##libssl#ssl3_write_pending'])
# set(['ECDSA_get_ex_data##libcrypto#TS_compute_imprint'])
# set(['d2i_EC_PUBKEY##libcrypto#X509_PUBKEY_set'])
# set(['ASN1_PRINTABLE_type##libcrypto#ASN1_PRINTABLE_type'])
# set(['DSA_generate_parameters_ex##libcrypto#pkey_dsa_paramgen'])
# set(['compile_iterator_matchingpath.isra.45##libssl#ssl_add_clienthello_tlsext'])
# set(['ssl_verify_alarm_type##libcrypto#BN_num_bits'])
# set(['check_str_end##libssl#ssl3_send_alert'])
# set(['obj_trust##libcrypto#CRYPTO_dbg_pop_info'])
# set(['ngx_ssl_create_connection##libcrypto#EVP_MD_CTX_cleanup'])
# set(['BN_CTX_new##libcrypto#BN_secure_new'])
# set(['OBJ_obj2nid##libcrypto#X509V3_extensions_print'])
# set(['EVP_PKEY_asn1_find##libcrypto#TS_check_imprints'])
# set(['ASN1_item_d2i_fp##libcrypto#SCT_new_from_base64'])
# set(['X509_EXTENSION_get_object##libcrypto#OPENSSL_sk_num'])
# set(['def_destroy_data##libcrypto#def_destroy'])
# set(['ENGINE_finish##libcrypto#cms_env_asn1_ctrl'])
# set(['SRP_generate_client_master_secret##libcrypto#srp_Calc_k'])
# set(['EVP_PKEY_set_type##libcrypto#EVP_PBE_find'])
# set(['emit_load_imm64##libcrypto#PKCS7_set_attributes'])
# set(['ENGINE_ctrl##libcrypto#v2i_BASIC_CONSTRAINTS'])
# set(['sljit_emit_label##libcrypto#BN_mod_mul'])
# set(['ngx_hash_find##libcrypto#BN_CTX_free'])
# set(['CRYPTO_add_lock##libcrypto#EVP_VerifyFinal'])
# set(['X509_NAME_get_entry##libcrypto#sk_pop_free'])
# set(['BN_mul##libcrypto#BN_is_prime_fasttest'])
# set(['RAND_add##libcrypto#PKCS7_get0_signers'])
# set(['RAND_pseudo_bytes##libcrypto#ENGINE_pkey_asn1_find_str'])
# set(['sk_value##libcrypto#bn_sub_words'])
# set(['B64_write_ASN1##libcrypto#BN_CTX_get'])
# set(['PKCS12_item_i2d_encrypt##libcrypto#PKCS12_item_i2d_encrypt'])
# set(['DSO_new##libcrypto#OBJ_obj2nid'])
# set(['EC_POINT_free##libcrypto#EVP_PKEY_assign'])
# set(['RAND_bytes##libcrypto#BN_CTX_start'])
# set(['ASN1_bn_print##libcrypto#BN_CTX_start'])
# set(['sk_push##libcrypto#BIO_get_host_ip'])
# set(['ngx_http_ssl_handshake##libcrypto#lh_insert'])
# set(['NCONF_get_section##libcrypto#X509_check_private_key'])
# set(['sk_pop_free##libcrypto#EC_POINT_cmp'])
# set(['ngx_ssl_handshake##libssl#dtls1_process_record'])
# set(['BIO_printf##libcrypto#EVP_CIPHER_CTX_set_key_length'])
# set(['ASN1_STRING_type_new##libcrypto#PKCS7_get_signer_info'])
# set(['X509V3_EXT_val_prn##libcrypto#BN_MONT_CTX_set'])
# set(['ASN1_item_d2i##libcrypto#CRYPTO_add_lock'])
# set(['ngx_ssl_error##libssl#ssl_check_serverhello_tlsext'])
# set(['bn_mul_add_words##libcrypto#bn_mul_add_words'])
# set(['ngx_http_file_cache_update_header##libcrypto#DH_check'])
# set(['ssl_cipher_list_to_bytes##libssl#ssl_parse_serverhello_tlsext'])
# set(['ngx_http_map_find##libcrypto#OCSP_request_verify'])
# set(['ngx_http_process_request_line##libcrypto#c2i_ASN1_OBJECT'])
# set(['OBJ_NAME_remove##libcrypto#ASN1_template_free'])
# set(['ngx_http_auth_request_handler##libcrypto#ASN1_item_free'])
# set(['sk_value##libssl#ssl3_choose_cipher'])
# set(['ngx_http_proxy_rewrite_domain_handler##libcrypto#OPENSSL_sk_deep_copy'])
# set(['i2d_ECParameters##libcrypto#int_get_new_index'])
# set(['X509V3_extensions_print##libcrypto#TXT_DB_create_index'])
# set(['pem_check_suffix##libcrypto#pem_check_suffix'])
# set(['OPENSSL_cleanse##libcrypto#X509_check_ca'])
# set(['PEM_def_callback##libcrypto#EVP_PKEY_free'])
# set(['EC_POINT_get_affine_coordinates_GFp##libcrypto#ASN1_STRING_set'])
# set(['BIO_write##libcrypto#aep_mod_exp.part.0'])
# set(['pem_check_suffix##libcrypto#ASN1_STRING_free'])
# set(['ngx_handle_write_event##libssl#tls1_process_sigalgs'])
# set(['MD5_Update##libcrypto#BN_lshift'])
# set(['OBJ_nid2sn##libcrypto#c2i_ASN1_OBJECT'])
# set(['ssl3_digest_cached_records##libcrypto#pkey_rsa_verifyrecover'])
# set(['ngx_http_set_disable_symlinks##libcrypto#doapr_outch.constprop.5'])
# set(['BIO_ctrl##libssl#ssl3_setup_write_buffer'])
# set(['ASN1_STRING_type_new##libcrypto#sk_free'])
# set(['sk_pop_free##libcrypto#BN_bin2bn'])
# set(['bn_expand2##libcrypto#sk_free'])
# set(['sk_find##libcrypto#EVP_BytesToKey'])
# set(['ngx_conf_log_error##libcrypto#BN_mod_exp'])
# set(['ngx_connection_error##libcrypto#BN_CTX_end'])
# set(['CMAC_Init##libcrypto#SHA1_Final'])
# set(['ngx_destroy_pool##libssl#ssl3_cbc_copy_mac'])
# set(['ngx_create_temp_buf##libcrypto#BN_set_word'])
# set(['EC_POINT_free##libcrypto#EC_POINT_clear_free'])
# set(['decode_gost_algor_params##libcrypto#EVP_DigestSignFinal'])
# set(['d2i_PrivateKey##libcrypto#PKCS5_pbkdf2_set'])
# set(['ngx_array_push##libcrypto#SHA1_Final'])
# set(['CRYPTO_lock##libcrypto#X509_NAME_set'])
# set(['ngx_mail_auth_cram_md5##libcrypto#BN_div_recp'])
# set(['ASN1_GENERALIZEDTIME_check##libcrypto#ASN1_GENERALIZEDTIME_check'])
# set(['sk_new##libcrypto#ASN1_STRING_to_UTF8'])
# set(['ASN1_STRING_free##libcrypto#CRYPTO_realloc'])
# set(['i2d_SSL_SESSION##libcrypto#EVP_CipherInit_ex'])
# set(['ngx_http_create_request##libssl#dtls1_buffer_message'])
# set(['ngx_http_close_request.isra.5##libssl#ssl_add_clienthello_tlsext'])
# set(['CRYPTO_free##libcrypto#BIO_new_file'])
# set(['ngx_ssl_write##libssl#ssl3_get_record'])
# set(['sk_push##libcrypto#X509V3_EXT_d2i'])
# set(['ASN1_item_new##libcrypto#PKCS7_add_signature'])
# set(['sk_value##libssl#ssl23_write_bytes'])
# set(['sljit_alloc_memory##libcrypto#BN_is_word'])
# set(['ngx_http_complex_value##libssl#dtls1_buffer_message'])
# set(['EC_POINT_is_at_infinity##libcrypto#EC_GROUP_get_degree'])
# set(['X509_POLICY_NODE_print##libcrypto#BN_mod_sub_quick'])
# set(['ngx_create_pool##libssl#ssl3_finish_mac'])
# set(['X509_EXTENSION_create_by_OBJ##libcrypto#OPENSSL_hexstr2buf'])
# set(['BN_num_bits##libcrypto#OPENSSL_sk_value'])
# set(['ngx_ssl_connection_error##libcrypto#ASN1_primitive_free'])
# set(['BN_CTX_get##libcrypto#CRYPTO_malloc'])
# set(['X509_ATTRIBUTE_create_by_txt##libcrypto#ec_GFp_simple_point_get_affine_coordinates'])
# set(['X509_signature_print##libcrypto#setup_blinding'])
# set(['ngx_array_create##libcrypto#BN_BLINDING_free'])
# set(['ngx_http_script_run##libcrypto#BN_gcd'])
# set(['CRYPTO_free##libssl#ssl3_renegotiate_check'])
# set(['CRYPTO_add_lock##libcrypto#BN_sub'])
# set(['added_obj_LHASH_HASH##libcrypto#added_obj_LHASH_HASH'])
# set(['ngx_pnalloc##libcrypto#ASN1_INTEGER_get'])
# set(['ASN1_INTEGER_get##libcrypto#EVP_SignFinal'])
# set(['OCSP_id_cmp##libcrypto#sk_free'])
# set(['cms_EncryptedData_init_bio##libcrypto#ERR_put_error'])
# set(['CRYPTO_mem_ctrl.constprop.5##libcrypto#BIO_free'])
# set(['ngx_array_create##libssl#SSL_clear'])
# set(['ngx_parse_addr##libssl#ssl_cipher_list_to_bytes'])
# set(['ngx_atoof##libcrypto#BN_mod_exp'])
# set(['X509_check_purpose##libcrypto#BIO_read'])
# set(['X509_ocspid_print##libcrypto#PKCS5_PBE_keyivgen'])
# set(['ngx_spinlock##libssl#dtls1_buffer_message'])
# set(['EVP_PKEY_new##libcrypto#BIO_pop'])
# set(['ngx_conf_log_error##libcrypto#SHA1_Final'])
# set(['trust_1oidany##libcrypto#ec_GFp_mont_group_set_curve_GFp'])
# set(['ASN1_STRING_type_new##libcrypto#sk_set'])
# set(['RAND_pseudo_bytes##libcrypto#s2i_ASN1_INTEGER'])
# set(['ngx_destroy_pool##libcrypto#X509_ALGOR_set0'])
# set(['sk_set##libcrypto#ENGINE_new'])
# set(['OBJ_find_sigid_algs##libcrypto#BUF_MEM_grow_clean'])
# set(['ngx_alloc##libcrypto#OPENSSL_sk_free'])
# set(['EVP_MD_size##libssl#ssl_cipher_list_to_bytes'])
# set(['ASN1_STRING_type_new##libcrypto#sk_pop_free'])
# set(['X509V3_EXT_REQ_add_conf##libcrypto#PEM_read_bio_PrivateKey'])
# set(['PEM_read_bio_PrivateKey##libcrypto#ec_GF2m_simple_set_compressed_coordinates'])
# set(['ngx_set_file_time##libcrypto#ASN1_generate_v3'])
# set(['CRYPTO_malloc##libcrypto#BN_div_word'])
# set(['sk_new_null##libcrypto#sk_insert'])
# set(['ASN1_STRING_new##libcrypto#SMIME_text'])
# set(['ERR_put_error##libcrypto#OPENSSL_sk_new'])
# set(['EC_POINT_new##libcrypto#PEM_def_callback'])
# set(['ngx_radix_tree_create##libssl#ssl3_cbc_copy_mac'])
# set(['UI_new_method##libcrypto#UI_construct_prompt'])
# set(['EC_GROUP_set_curve_GFp##libcrypto#EC_GROUP_set_curve_GFp'])
# set(['ngx_chain_get_free_buf##libssl#ssl_fill_hello_random'])
# set(['i2v_EXTENDED_KEY_USAGE##libcrypto#UI_free'])
# set(['ngx_alloc_chain_link##libcrypto#BN_MONT_CTX_new'])
# set(['compile_char1_matchingpath##libssl#dtls1_reassemble_fragment'])
# set(['ngx_time_update##libcrypto#compute_key'])
# set(['ASN1_STRING_new##libcrypto#RAND_bytes'])
# set(['BUF_MEM_new##libcrypto#BIO_snprintf'])
# set(['EC_GROUP_set_curve_GFp##libcrypto#sk_value'])
# set(['ngx_strncasecmp##libssl#custom_ext_init'])
# set(['OBJ_NAME_do_all_sorted##libcrypto#BUF_MEM_grow_clean'])
# set(['ngx_pcalloc##libcrypto#_CONF_new_section'])
# set(['obj_trust##libcrypto#ERR_add_error_data'])
# set(['RAND_query_egd_bytes##libcrypto#BN_mod_exp_mont'])
# set(['ECDSA_size##libcrypto#PKCS12_newpass'])
# set(['OBJ_obj2nid##libcrypto#OPENSSL_LH_free'])
# set(['BN_GF2m_mod_arr.part.0##libcrypto#BN_copy'])
# set(['ngx_rwlock_wlock##libssl#ssl3_setup_buffers'])
# set(['ngx_http_map_uri_to_path##libcrypto#doapr_outch.constprop.5'])
# set(['ngx_handle_write_event##libcrypto#asn1_check_tlen.constprop.1'])
# set(['bn_expand2##libcrypto#bn_wexpand'])
# set(['sk_new_null##libcrypto#PKCS5_pbe_set'])
# set(['EVP_MD_CTX_md##libcrypto#BN_MONT_CTX_free'])
# set(['PEM_get_EVP_CIPHER_INFO##libcrypto#pkey_rsa_ctrl'])
# set(['ERR_put_error##libssl#tls12_get_sigandhash'])
# set(['ec_GFp_simple_add##libcrypto#BN_mod_sqrt'])
# set(['pub_decode_gost94##libcrypto#dh_priv_encode'])
# set(['ngx_list_push##libssl#dtls1_buffer_record.isra.6.part.7'])
# set(['sk_find##libssl#ssl3_digest_cached_records'])
# set(['cms_RecipientInfo_pwri_crypt##libcrypto#cms_EncryptedContent_init_bio'])
# set(['BIO_int_ctrl##libcrypto#BN_CTX_start'])
# set(['CRYPTO_lock##libcrypto#sk_dup'])
# set(['EVP_MD_CTX_md##libcrypto#X509_pubkey_digest'])
# set(['ngx_http_script_run##libcrypto#sha256_block_data_order'])
# set(['BN_free##libcrypto#PKCS8_pkey_set0'])
# set(['EVP_CIPHER_CTX_cleanup##libcrypto#EVP_PKEY_derive'])
# set(['pqueue_insert##libcrypto#bn_probable_prime_dh'])
# set(['ASN1_object_size##libcrypto#ASN1_put_object'])
# set(['sk_free##libcrypto#OPENSSL_sk_free'])
# set(['dtls1_dispatch_alert##libssl#ssl3_change_cipher_state'])
# set(['ngx_ssl_error##libssl#ssl_parse_clienthello_tlsext'])
# set(['ngx_http_complex_value##libcrypto#EVP_MD_CTX_cleanup'])
# set(['ngx_stream_upstream_init_round_robin_peer##libcrypto#OBJ_obj2nid'])
# set(['RAND_status##libcrypto#CRYPTO_lock'])
# set(['sljit_emit_label##libcrypto#BN_MONT_CTX_set'])
# set(['BN_bn2bin##libcrypto#BN_free'])
# set(['ngx_http_upstream_cache_send##libssl#dtls1_write_bytes'])
# set(['pqueue_pop##libssl#dtls1_write_bytes'])
# set(['ngx_http_process_request_headers##libcrypto#BN_sqr'])
# set(['ngx_inet_addr##libcrypto#CRYPTO_malloc'])
# set(['sljit_alloc_memory##libcrypto#EVP_CIPHER_CTX_set_padding'])
# set(['BN_mod_lshift_quick##libcrypto#BN_sub_word'])
# set(['ngx_shmtx_lock##libcrypto#EVP_MD_CTX_copy_ex'])
# set(['sk_new_null##libcrypto#OCSP_id_cmp'])
# set(['ngx_inet_addr##libssl#ssl3_do_compress'])
# set(['OBJ_nid2obj##libcrypto#d2i_ASN1_OBJECT'])
# set(['EVP_PKEY_set_type##libcrypto#ASN1_item_sign'])
# set(['BN_new##libcrypto#PKCS12_verify_mac'])
# set(['ngx_ssl_certificate_status_callback##libssl#ssl3_get_server_certificate'])
# set(['ngx_ssl_certificate_status_callback##libcrypto#DH_check_params'])
# set(['ngx_pcalloc##libcrypto#BIO_snprintf'])
# set(['ngx_strcasecmp##libcrypto#ASN1_STRING_free'])
# set(['hashsum2bn##libcrypto#probable_prime'])
# set(['BN_GF2m_mod_exp_arr##libcrypto#BN_is_prime_fasttest_ex'])
# set(['ngx_http_index_set_index##libcrypto#asn1_d2i_read_bio.constprop.0'])
# set(['CRYPTO_add_lock##libcrypto#setup_blinding'])
# set(['ngx_http_writer##libcrypto#a2i_ASN1_STRING'])
# set(['ngx_chain_update_chains##libcrypto#ERR_print_errors_cb'])
# set(['i2s_ASN1_ENUMERATED##libcrypto#PKCS7_final'])
# set(['ngx_array_create##libcrypto#EC_POINT_copy'])
# set(['ssl3_do_uncompress##libssl#ssl3_do_uncompress'])
# set(['DSA_SIG_new##libcrypto#ERR_peek_last_error'])
# set(['BN_MONT_CTX_free##libcrypto#BN_clear_free'])
# set(['sk_set##libcrypto#ASN1_INTEGER_cmp'])
# set(['BN_CTX_start##libcrypto#EVP_PKEY_CTX_ctrl'])
# set(['EVP_DigestSignFinal##libcrypto#BN_MONT_CTX_set'])
# set(['sk_find##libcrypto#BN_sub_word'])
# set(['ngx_conf_log_error.constprop.1##libcrypto#ASN1_STRING_set'])
# set(['ngx_hash_strlow##libcrypto#ASN1_INTEGER_get'])
# set(['gost94_compute_public##libssl#ssl_clear_bad_session'])
# set(['cswift_dsa_sign##libcrypto#d2i_ASN1_type_bytes'])
# set(['EC_POINT_free##libcrypto#ERR_get_error'])
# set(['ASN1_INTEGER_cmp##libcrypto#OBJ_NAME_init'])
# set(['ngx_pnalloc##libcrypto#CRYPTO_ocb128_aad'])
# set(['BN_dup##libcrypto#ASN1_ENUMERATED_get_int64'])
# set(['CRYPTO_malloc##libcrypto#EVP_PKEY_sign_init'])
# set(['EVP_DigestSignFinal##libcrypto#BN_CTX_start'])
# set(['EVP_PKEY_new##libcrypto#X509_check_purpose'])
# set(['ngx_http_script_run##libcrypto#CRYPTO_realloc_clean'])
# set(['ASN1_item_d2i##libcrypto#OPENSSL_cleanse'])
# set(['PKCS5_v2_PBKDF2_keyivgen##libcrypto#cms_RecipientInfo_pwri_crypt'])
# set(['OBJ_txt2obj##libcrypto#DSO_load'])
# set(['ASN1_GENERALIZEDTIME_adj##libcrypto#EVP_CipherInit_ex'])
# set(['ngx_count_modules##libcrypto#BN_CTX_end'])
# set(['ngx_http_upstream_init_round_robin##libssl#tls1_process_sigalgs'])
# set(['ngx_pnalloc##libssl#tls12_get_psigalgs'])
# set(['UI_add_verify_string##libcrypto#CMS_ReceiptRequest_create0'])
# set(['BN_free##libcrypto#OPENSSL_sk_value'])
# set(['ASN1_ENUMERATED_get##libcrypto#BN_CTX_get'])
# set(['EC_POINT_new##libcrypto#OBJ_nid2obj'])
# set(['sub_4c4570##libssl#ssl3_setup_write_buffer'])
# set(['SSL_use_RSAPrivateKey_ASN1##libcrypto#PKCS7_encrypt'])
# set(['OBJ_find_sigid_algs##libcrypto#BUF_MEM_grow'])
# set(['SSL_get_error##libssl#ssl_cipher_list_to_bytes'])
# set(['BIO_puts##libcrypto#BN_copy'])
# set(['BN_MONT_CTX_set##libcrypto#EC_KEY_set_public_key_affine_coordinates'])
# set(['ssl3_cleanup_key_block##libssl#ssl_get_algorithm2'])
# set(['ssl_cert_free##libssl#ssl_cert_clear_certs'])
# set(['SSL_get_error##libcrypto#EVP_CipherInit_ex'])
# set(['DH_check_pub_key##libcrypto#CRYPTO_malloc'])
# set(['ngx_conf_log_error.constprop.1##libcrypto#EVP_SignFinal'])
# set(['dh_pub_decode##libcrypto#TS_compute_imprint'])
# set(['sk_pop_free##libcrypto#EVP_EncryptUpdate'])
# set(['v2i_subject_alt##libcrypto#i2d_RSA_NET'])
# set(['decode_gost_algor_params##libcrypto#EVP_PKEY_CTX_dup'])
# set(['ngx_array_push##libcrypto#bn_mul_words'])
# set(['X509V3_get_value_bool##libcrypto#EVP_DecryptUpdate'])
# set(['x509_name_canon.part.0##libcrypto#X509_verify_cert'])
# set(['ngx_event_use##libcrypto#ASN1_TIME_to_generalizedtime'])
# set(['BIO_new##libcrypto#X509V3_get_section'])
# set(['ngx_create_temp_buf##libssl#ssl_cipher_list_to_bytes'])
# set(['X509_NAME_get_index_by_NID##libcrypto#BN_sub'])
# set(['CRYPTO_malloc##libssl#tls1_set_server_sigalgs'])
# set(['ngx_close_cached_file##libssl#ssl_parse_serverhello_use_srtp_ext'])
# set(['ngx_pcalloc##libssl#ssl_get_server_send_pkey'])
# set(['dh_priv_decode##libcrypto#PKCS12_verify_mac'])
# set(['finish_hash##libcrypto#EVP_Digest'])
# set(['ngx_ssl_get_serial_number##libcrypto#SMIME_write_PKCS7'])
# set(['sk_new_null##libcrypto#EVP_PKEY_CTX_free'])
# set(['ASN1_object_size##libcrypto#EVP_CipherInit_ex'])
# set(['EVP_MD_CTX_cleanup##libcrypto#EVP_DigestSignFinal'])
# set(['UI_dup_verify_string##libssl#tls_get_message_body'])
# set(['ngx_ssl_create##libssl#ssl_cipher_strength_sort'])
# set(['BIO_ctrl##libcrypto#SMIME_text'])
# set(['OBJ_bsearch_##libcrypto#PKCS7_digest_from_attributes'])
# set(['BN_copy##libcrypto#BN_div_word'])
# set(['OBJ_bsearch_##libcrypto#OPENSSL_sk_pop_free'])
# set(['ngx_array_create##libcrypto#ASN1_item_d2i'])
# set(['BN_CTX_get##libcrypto#lh_retrieve'])
# set(['ngx_shmtx_unlock##libcrypto#sk_pop_free'])
# set(['BIO_printf##libcrypto#BN_free'])
# set(['BN_to_ASN1_INTEGER##libcrypto#d2i_ECParameters'])
# set(['BN_MONT_CTX_set_locked##libcrypto#BN_CTX_get'])
# set(['BN_bn2bin##libcrypto#EC_POINT_is_at_infinity'])
# set(['X509_PKEY_free##libcrypto#EC_KEY_free'])
# set(['ngx_shmtx_unlock##libssl#ssl3_choose_cipher'])
# set(['ngx_alloc##libcrypto#CRYPTO_realloc'])
# set(['ssl3_release_read_buffer##libcrypto#BN_CTX_end'])
# set(['ngx_create_path##libssl#dtls1_buffer_message'])
# set(['ngx_http_add_regex_referer.isra.1##libcrypto#X509_PUBKEY_set'])
# set(['ngx_snprintf##libssl#ssl_cipher_list_to_bytes'])
# set(['emit_do_imm32##libssl#ssl2_enc_init'])
# set(['BN_mod_word##libcrypto#X509_TRUST_get_by_id'])
# set(['bn_expand2##libcrypto#bn_mul_normal'])
# set(['BIO_ctrl##libcrypto#EVP_PKEY_decrypt_init'])
# set(['BUF_strlcat##libcrypto#PKCS12_verify_mac'])
# set(['EC_POINT_get_affine_coordinates_GFp##libcrypto#OBJ_nid2sn'])
# set(['ngx_http_dav_copy_move_handler.part.5##libssl#ssl_parse_clienthello_tlsext'])
# set(['c2i_ASN1_INTEGER##libcrypto#EVP_MD_CTX_cleanup'])
# set(['EC_KEY_free##libcrypto#ASN1_pack_string'])
# set(['BIO_printf##libcrypto#EVP_PKEY_missing_parameters'])
# set(['ENGINE_by_id##libcrypto#i2o_ECPublicKey'])
# set(['ngx_connection_error##libssl#ssl_cipher_list_to_bytes'])
# set(['EVP_CIPHER_CTX_ctrl##libcrypto#OPENSSL_cleanse'])
# set(['SSL_use_certificate_file##libcrypto#DSO_load'])
# set(['PKCS12_item_decrypt_d2i##libcrypto#NETSCAPE_SPKI_print'])
# set(['ASN1_STRING_dup##libcrypto#OBJ_obj2nid'])
# set(['ASN1_STRING_cmp##libcrypto#BN_CTX_free'])
# set(['EVP_PKEY_CTX_free##libcrypto#EVP_CIPHER_CTX_cleanup'])
# set(['i2r_idp##libcrypto#RSA_eay_public_encrypt'])
# set(['ngx_sock_ntop##libcrypto#BN_CTX_end'])
# set(['ngx_create_pool##libcrypto#X509_NAME_hash'])
# set(['ENGINE_new##libcrypto#ERR_add_error_data'])
# set(['CMS_add1_recipient_cert##libcrypto#do_PVK_body.isra.3'])
# set(['SSL_use_RSAPrivateKey##libcrypto#OBJ_create'])
# set(['BUF_MEM_grow##libcrypto#BN_CTX_free'])
# set(['BN_rand##libcrypto#RSA_padding_check_PKCS1_type_2'])
# set(['X509_PKEY_new##libcrypto#BN_BLINDING_invert_ex'])
# set(['aesni_cbc_sha1_enc##libcrypto#OPENSSL_cleanse'])
# set(['ngx_alloc_chain_link##libssl#SSL_get_wbio'])
# set(['BN_mod_add##libcrypto#BN_clear_free'])
# set(['ngx_sock_ntop##libcrypto#ASN1_item_i2d'])
# set(['BIO_indent##libcrypto#BN_mod_mul_montgomery'])
# set(['EVP_read_pw_string_min##libcrypto#EVP_read_pw_string'])
# set(['ngx_create_pidfile.part.4##libssl#dtls1_write_bytes'])
# set(['BN_mod_mul##libcrypto#OPENSSL_LH_retrieve'])
# set(['ngx_parse_addr##libssl#ssl_check_serverhello_tlsext'])
# set(['ASN1_TIME_adj##libcrypto#pkey_rsa_verifyrecover'])
# set(['OBJ_nid2obj##libcrypto#ECDH_compute_key'])
# set(['EVP_PKCS82PKEY##libcrypto#RSA_sign_ASN1_OCTET_STRING'])
# set(['ngx_stream_upstream_init_round_robin_peer##libcrypto#asn1_do_adb'])
# set(['lh_new##libcrypto#ERR_set_mark'])
# set(['asn1_template_ex_d2i##libcrypto#asn1_d2i_ex_primitive'])
# set(['PEM_do_header##libcrypto#do_PVK_body.isra.3'])
# set(['SHA1_Final##libcrypto#BN_rshift'])
# set(['ASN1_seq_unpack##libcrypto#d2i_AutoPrivateKey'])
# set(['X509_PKEY_new##libcrypto#X509_STORE_new'])
# set(['EC_POINT_new##libcrypto#EC_KEY_check_key'])
# set(['BN_GF2m_mod_solve_quad_arr##libcrypto#BN_from_montgomery_word'])
# set(['BN_CTX_free##libcrypto#DHparams_dup'])
# set(['DSO_free##libcrypto#PKCS7_add_certificate'])
# set(['X509_STORE_add_cert##libcrypto#PKCS12_pbe_crypt'])
# set(['ngx_http_ssi_include##libssl#dtls1_get_message'])
# set(['lh_new##libssl#SSL_COMP_get_compression_methods'])
# set(['sk_free##libcrypto#BIO_indent'])
# set(['ngx_close_connection##libssl#ssl3_get_client_hello'])
# set(['EC_POINT_copy##libcrypto#BN_CTX_free'])
# set(['pub_decode_gost94##libcrypto#PKCS7_decrypt'])
# set(['ngx_open_dir##libcrypto#ASN1_STRING_type_new'])
# set(['ngx_http_upstream_cache_send##libssl#ssl3_comp_find'])
# set(['RSA_verify##libcrypto#sub_93770'])
# set(['ASN1_STRING_type_new##libcrypto#PEM_def_callback'])
# set(['SXNET_get_id_ulong##libcrypto#X509_get_pubkey_parameters'])
# set(['ASN1_STRING_dup##libcrypto#X509_check_private_key'])
# set(['ssl_cipher_strength_sort##libssl#custom_ext_parse'])
# set(['ngx_http_cleanup_add##libssl#ssl3_do_compress'])
# set(['B64_write_ASN1##libcrypto#BN_MONT_CTX_set'])
# set(['CRYPTO_malloc##libcrypto#BN_set_bit'])
# set(['ERR_GOST_error##libcrypto#ASN1_TYPE_set'])
# set(['EC_KEY_new##libcrypto#PKCS5_pbe_set'])
# set(['SSL_CTX_set_timeout##libcrypto#sk_num'])
# set(['cswift_rand_bytes##libssl#ssl3_get_client_hello'])
# set(['ngx_http_set_virtual_server##libssl#ssl_cipher_list_to_bytes'])
# set(['ngx_array_push##libssl#dtls1_preprocess_fragment'])
# set(['ngx_sprintf##libssl#dtls1_query_mtu'])
# set(['ngx_alloc##libcrypto#asn1_do_lock'])
# set(['flush_pending##libcrypto#BN_set_word'])
# set(['EC_KEY_dup##libcrypto#RSA_free'])
# set(['EVP_SignFinal##libcrypto#BN_MONT_CTX_set'])
# set(['OBJ_bsearch_##libcrypto#EVP_PKEY_CTX_ctrl'])
# set(['ngx_atoi##libcrypto#EVP_DigestFinal_ex'])
# set(['pkey_GOST94cp_decrypt##libcrypto#SMIME_write_PKCS7'])
# set(['SSL_CTX_set_cipher_list##libcrypto#CRYPTO_malloc'])
# set(['ngx_ssl_write##libcrypto#BN_uadd'])
# set(['pkcs7_decrypt_rinfo##libssl#dtls1_send_finished'])
# set(['X509_STORE_new##libcrypto#EVP_PKEY_decrypt_init'])
# set(['ngx_http_rewrite##libssl#dtls1_process_record'])
# set(['ERR_add_error_data##libcrypto#NCONF_get_string'])
# set(['X509V3_EXT_add_nconf_sk##libcrypto#int_free_ex_data'])
# set(['ngx_mail_pop3_merge_srv_conf##libcrypto#aesni_cbc_hmac_sha1_cipher'])
# set(['EVP_DigestInit##libcrypto#EVP_PKEY_decrypt'])
# set(['lh_delete##libssl#ssl_parse_serverhello_tlsext'])
# set(['EVP_PKEY_asn1_find##libcrypto#OPENSSL_sk_value'])
# set(['EVP_PKEY_size##libcrypto#BN_MONT_CTX_new'])
# set(['ngx_http_add_variable##libcrypto#cms_EncryptedContent_init_bio'])
# set(['ASN1_ENUMERATED_set##libssl#ssl3_client_hello'])
# set(['BN_num_bits##libcrypto#bn_GF2m_mul_2x2'])
# set(['ASN1_STRING_set_by_NID##libcrypto#ASN1_STRING_set'])
# set(['ngx_http_v2_state_settings_params##libcrypto#c2i_ASN1_OBJECT'])
# set(['cswift_init##libcrypto#surewarehk_init'])
# set(['EC_POINT_get_affine_coordinates_GF2m##libcrypto#CRYPTO_malloc'])
# set(['ASN1_STRING_type_new##libcrypto#CMS_RecipientInfo_ktri_get0_algs'])
# set(['UI_free##libcrypto#ERR_set_mark'])
# set(['SSL_CTX_flush_sessions##libcrypto#OPENSSL_sk_pop_free'])
# set(['BUF_MEM_grow_clean##libssl#ssl3_init_finished_mac'])
# set(['EVP_MD_CTX_md##libssl#ssl_fill_hello_random'])
# set(['SSL_read##libssl#SSL_get_ciphers'])
# set(['BN_GF2m_mod_sqrt##libcrypto#BN_dec2bn'])
# set(['BIO_ctrl##libcrypto#ASN1_INTEGER_to_BN'])
# set(['ngx_http_upstream_create_round_robin_peer##libcrypto#ERR_put_error'])
# set(['CRYPTO_THREADID_current##libcrypto#BIO_ctrl'])
# set(['BN_CTX_free##libcrypto#DSO_free'])
# set(['EVP_PKEY_CTX_new_id##libcrypto#rsa_item_verify'])
# set(['ASN1_object_size##libcrypto#EVP_PKEY_decrypt_init'])
# set(['ngx_create_pool##libcrypto#BUF_MEM_new'])
# set(['CRYPTO_lock##libcrypto#EVP_PKEY_encrypt_init'])
# set(['check_partial##libssl#dtls1_preprocess_fragment'])
# set(['ec_copy_parameters##libcrypto#CMAC_CTX_new'])
# set(['BIO_write##libcrypto#BN_CTX_start'])
# set(['ec_GFp_mont_group_set_curve##libcrypto#RSA_generate_key_ex'])
# set(['ssl_check_clienthello_tlsext_early##libcrypto#BN_MONT_CTX_set'])
# set(['ngx_resolve_name_done##libcrypto#d2i_PrivateKey'])
# set(['ngx_http_v2_send_rst_stream##libcrypto#EVP_DigestInit_ex'])
# set(['EC_GROUP_get_order##libcrypto#sk_value'])
# set(['X509V3_EXT_print##libcrypto#x509_name_ex_i2d'])
# set(['sk_free##libcrypto#BN_MONT_CTX_set_locked'])
# set(['X509at_add1_attr##libcrypto#UI_dup_info_string'])
# set(['ssl3_get_req_cert_type##libcrypto#equal_case'])
# set(['ngx_clone_listening##libssl#SSL_use_certificate'])
# set(['sk_value##libcrypto#OPENSSL_sk_sort'])
# set(['ngx_array_push##libcrypto#BIO_callback_ctrl'])
# set(['NCONF_load##libcrypto#NCONF_load'])
# set(['ngx_http_v2_close_stream##libssl#ssl_parse_clienthello_tlsext'])
# set(['v2i_GENERAL_NAMES##libssl#tls12_check_peer_sigalg'])
# set(['ASN1_INTEGER_get##libcrypto#BN_set_word'])
# set(['ngx_memn2cmp##libcrypto#OPENSSL_hexchar2int'])
# set(['sljit_emit_cmp##libssl#ssl_bytes_to_cipher_list'])
# set(['gost_init##libcrypto#OPENSSL_sk_free'])
# set(['SSL_CTX_ctrl##libssl#ssl_parse_clienthello_renegotiate_ext'])
# set(['X509V3_section_free##libcrypto#BIO_free_all'])
# set(['X509_STORE_new##libcrypto#BIO_new_file'])
# set(['BUF_MEM_grow##libcrypto#BIO_puts'])
# set(['ngx_log_error_core##libcrypto#BN_CTX_end'])
# set(['sk_new_null##libcrypto#BN_new'])
# set(['ngx_sort##libcrypto#BN_copy'])
# set(['ngx_http_get_indexed_variable##libssl#ssl_parse_clienthello_renegotiate_ext'])
# set(['SSL_CTX_flush_sessions##libcrypto#CRYPTO_get_ex_data'])
# set(['ngx_pnalloc##libcrypto#BN_sub'])
# set(['ssl_get_new_session##libcrypto#BN_CTX_start'])
# set(['BN_CTX_get##libcrypto#BN_from_montgomery'])
# set(['ngx_sprintf##libcrypto#ASN1_INTEGER_get'])
# set(['X509_NAME_get_index_by_NID##libcrypto#BN_clear_free'])
# set(['ngx_strcasecmp##libssl#ssl_parse_clienthello_renegotiate_ext'])
# set(['sk_pop_free##libcrypto#ENGINE_init'])
# set(['EVP_MD_CTX_cleanup##libssl#ssl3_output_cert_chain'])
# set(['ERR_put_error##libcrypto#PEM_dek_info'])
# set(['ERR_load_strings##libcrypto#ASN1_STRING_free'])
# set(['sk_new_null##libcrypto#EVP_PKCS82PKEY'])
# set(['OPENSSL_cleanse##libcrypto#EC_EX_DATA_free_all_data'])
# set(['rsa_pub_print##libcrypto#dsa_sig_print'])
# set(['cms_EncryptedContent_init_bio##libcrypto#cms_RecipientInfo_pwri_crypt'])
# set(['ngx_rbtree_insert##libcrypto#bn_mul_part_recursive'])
# set(['ngx_chain_get_free_buf##libcrypto#asn1_do_adb'])
# set(['NCONF_get_section##libcrypto#EVP_CIPHER_CTX_set_key_length'])
# set(['ngx_conf_log_error##libcrypto#PKCS7_dataInit'])
# set(['ngx_pnalloc##libcrypto#EC_POINT_add'])
# set(['ngx_array_create##libcrypto#CMS_SignerInfo_get0_algs'])
# set(['RAND_pseudo_bytes##libcrypto#X509_check_private_key'])
# set(['BIO_free##libcrypto#PKCS7_add_signer'])
# set(['next_opcode.isra.8##libcrypto#ERR_add_error_data'])
# set(['PKCS7_add_crl##libcrypto#PKCS7_decrypt'])
# set(['EVP_PKEY_CTX_free##libcrypto#EVP_PKEY_encrypt'])
# set(['ngx_http_upstream_next##libssl#dtls1_process_record'])
# set(['ngx_http_parse_expires##libcrypto#BN_mul'])
# set(['sk_value##libcrypto#BN_RECP_CTX_set'])
# set(['ngx_http_add_listen##libssl#ssl_add_clienthello_tlsext'])
# set(['ngx_create_pool##libcrypto#X509v3_get_ext_by_NID'])
# set(['EVP_PKEY_asn1_find##libcrypto#ASN1_item_sign'])
# set(['BIO_printf##libcrypto#EC_EX_DATA_free_all_data'])
# set(['CMS_SignerInfo_sign##libcrypto#i2d_RSA_NET'])
# set(['ngx_close_connection##libssl#dtls1_process_record'])
# set(['OBJ_ln2nid##libcrypto#ERR_add_error_data'])
# set(['EVP_CIPHER_CTX_cleanup##libcrypto#EVP_DigestFinal_ex'])
# set(['ngx_hash_key_lc##libssl#dtls1_write_bytes'])
# set(['ERR_put_error##libssl#ssl_allow_compression'])
# set(['pitem_free##libcrypto#OPENSSL_sk_free'])
# set(['ASN1_INTEGER_get##libcrypto#EVP_VerifyFinal'])
# set(['OBJ_NAME_new_index##libcrypto#ASN1_verify'])
# set(['ngx_create_pool##libcrypto#BN_CTX_new'])
# set(['SHA1_Final##libcrypto#ASN1_ENUMERATED_get'])
# set(['BIO_new##libcrypto#BN_dup'])
# set(['i2d_RSA_PUBKEY##libcrypto#eckey_type2param'])
# set(['BN_CTX_end##libcrypto#OPENSSL_sk_sort'])
# set(['pub_decode_gost94##libssl#dtls1_send_client_certificate'])
# set(['ASN1_const_check_infinite_end##libcrypto#BN_CTX_end'])
# set(['sk_new_null##libcrypto#EVP_PKEY_new'])
# set(['UI_get0_result##libcrypto#sub_91788'])
# set(['ngx_shmtx_unlock##libssl#dtls1_query_mtu'])
# set(['ngx_stream_ssl_session_cache##libssl#ssl23_connect'])
# set(['ASN1_const_check_infinite_end##libcrypto#ERR_put_error'])
# set(['BN_dup##libcrypto#srp_Calc_xy'])
# set(['EVP_DigestFinal_ex##libcrypto#PKCS7_signatureVerify'])
# set(['ngx_chain_get_free_buf##libcrypto#X509_ALGOR_get0'])
# set(['ENGINE_finish##libcrypto#ASN1_item_i2d'])
# set(['ASN1_STRING_free##libcrypto#OPENSSL_sk_value'])
# set(['ngx_http_ssi_include##libssl#dtls1_do_write'])
# set(['BN_nnmod##libcrypto#X509V3_get_section'])
# set(['DH_check_pub_key##libcrypto#BN_mod_mul_reciprocal'])
# set(['lh_retrieve##libcrypto#BN_mod_mul_montgomery'])
# set(['sk_is_sorted##libcrypto#OPENSSL_sk_num'])
# set(['ngx_escape_uri##libcrypto#ASN1_STRING_free'])
# set(['ngx_alloc##libssl#dtls1_buffer_record.isra.7'])
# set(['OCSP_single_get0_status##libcrypto#OCSP_single_get0_status'])
# set(['lh_num_items##libcrypto#CRYPTO_malloc'])
# set(['ERR_get_next_error_library##libcrypto#BIO_pop'])
# set(['HMAC_Final##libcrypto#EVP_DigestFinal_ex'])
# set(['s2i_ASN1_IA5STRING##libcrypto#BIO_new'])
# set(['EC_KEY_dup##libcrypto#EC_GROUP_copy'])
# set(['BUF_strlcpy##libcrypto#BIO_read'])
# set(['ASN1_item_d2i##libcrypto#BN_num_bits'])
# set(['BN_CTX_free##libcrypto#ASN1_item_d2i'])
# set(['ngx_handle_write_event##libssl#do_ssl3_write'])
# set(['OBJ_ln2nid##libcrypto#CRYPTO_free_ex_data'])
# set(['BN_copy##libcrypto#BN_gcd'])
# set(['ngx_palloc##libcrypto#EC_POINT_new'])
# set(['OPENSSL_cleanse##libcrypto#BN_CTX_new'])
# set(['RAND_bytes##libcrypto#OBJ_find_sigid_by_algs'])
# set(['ngx_http_init_locations.isra.2##libssl#ssl_parse_serverhello_renegotiate_ext'])
# set(['bn_mul_recursive##libcrypto#bn_mul_recursive'])
# set(['EC_POINT_new##libcrypto#ecdh_check'])
# set(['X509_get_pubkey##libcrypto#OPENSSL_hexchar2int'])
# set(['BN_pseudo_rand##libcrypto#compute_key'])
# set(['BIO_pop##libcrypto#BN_CTX_start'])
# set(['ASN1_GENERALIZEDTIME_print##libcrypto#BUF_MEM_grow'])
# set(['UI_free##libcrypto#CRYPTO_clear_free'])
# set(['DSO_new##libssl#ssl_verify_cert_chain'])
# set(['ngx_parse_addr##libcrypto#BN_copy'])
# set(['ASN1_item_i2d##libssl#dtls1_buffer_message'])
# set(['ngx_chain_get_free_buf##libssl#ssl_parse_clienthello_renegotiate_ext'])
# set(['ngx_mail_send##libssl#dtls1_get_record'])
# set(['emit_do_imm32##libcrypto#ERR_put_error'])
# set(['ngx_hash_key_lc##libssl#SSL_get_ciphers'])
# set(['pkey_gost94cp_keygen##libcrypto#ECDSA_set_method'])
# set(['PKCS5_pbe2_set##libcrypto#i2d_RSA_NET'])
# set(['aep_rsa_mod_exp##libcrypto#hwcrhk_load_privkey'])
# set(['ngx_list_create##libcrypto#ASN1_STRING_free'])
# set(['BN_mod_add_quick##libcrypto#ERR_peek_last_error'])
# set(['CRYPTO_add_lock##libcrypto#cms_EncryptedContent_init'])
# set(['ASN1_object_size##libcrypto#TS_find_cert'])
# set(['sk_new_null##libcrypto#BN_CTX_end'])
# set(['ENGINE_load_ssl_client_cert##libcrypto#BN_clear_free'])
# set(['BN_GF2m_mod_solve_quad_arr##libcrypto#cms_SignedData_init_bio'])
# set(['BIO_write##libcrypto#EVP_MD_CTX_reset'])
# set(['ASN1_STRING_type_new##libcrypto#X509_CRL_add0_revoked'])
# set(['encode_gost_algor_params##libcrypto#d2i_PrivateKey'])

# %% [markdown]
# ### adjacent information

# %%
import pickle as p
import os
import random
from collections import defaultdict
def nam2dict(nam):
    namedict = defaultdict(int)
    for idx, (name,size) in enumerate(nam):
        namedict[name] = idx
        
    return namedict

dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/'
name = 'nginx-{openssl-1.0.1d}{zlib-1.2.11}'
namPath = os.path.join(dir, name + '.ida_newmodel_withsize.nam')
name_test = p.load(open(namPath, 'r'))
path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl'
folder = 'openssl-OpenSSL_1_0_1d'
nam_crypto = p.load(open(os.path.join(path_lib, folder, 'libcrypto.so.ida_newmodel_withsize.nam'), 'r'))
nam_ssl = p.load(open(os.path.join(path_lib, folder, 'libssl.so.ida_newmodel_withsize.nam'), 'r'))
name_test_dict = nam2dict(name_test)
nam_crypto_dict = nam2dict(nam_crypto)
nam_ssl_dict = nam2dict(nam_ssl)
prediction = dict(p.load(open('prediction','r')))
final_prediction = p.load(open('sure_dict','r'))
for key in prediction:
    idx = name_test_dict[key]
    (name_next, size) = name_test[idx+1]
    if name_next not in prediction:
        continue
    #print '\n', key, name_next
    for (p_name, library) in prediction[key]:
        for (p_name_next, library_next) in prediction[name_next]:
            if library == 'libcrypto' and library_next == 'libcrypto':
                #print '\t', p_name, p_name_next, nam_crypto_dict[p_name], nam_crypto_dict[p_name_next]
                if nam_crypto_dict[p_name] - nam_crypto_dict[p_name_next] > -3 and nam_crypto_dict[p_name] - nam_crypto_dict[p_name_next] < 3:
                    if p_name not in final_prediction[key]:
                        final_prediction[key].append(p_name)
                    if p_name_next not in final_prediction[name_next]:
                        final_prediction[name_next].append(p_name_next)
            if library == 'libssl' and library_next == 'libssl':
                #print '\t',p_name, p_name_next, nam_ssl_dict[p_name], nam_ssl_dict[p_name_next]
                if nam_ssl_dict[p_name] - nam_ssl_dict[p_name_next] > -3 and nam_ssl_dict[p_name] - nam_ssl_dict[p_name_next] < 3:
                    if p_name not in final_prediction[key]:
                        final_prediction[key].append(p_name)
                    if p_name_next not in final_prediction[name_next]:
                        final_prediction[name_next].append(p_name_next)
print len(final_prediction)
count = 0
for key in final_prediction:
    if key in final_prediction[key] or key in [i[0] for i in final_prediction[key]]:
        count += 1
    #else:
        print key
        print final_prediction[key]
print count
# Out:
# 1904
# ngx_execute
# ['ssl3_client_hello']
# ngx_http_copy_thread_handler
# ['dtls1_client_hello']
# ngx_http_mp4_read_stss_atom
# ['tls1_set_server_sigalgs']
# PKCS7_add_certificate
# ['TS_RESP_CTX_set_certs']
# ASN1_d2i_fp
# ['ASN1_item_d2i_bio', 'ASN1_d2i_bio']
# BN_mod_lshift1
# [('BN_reciprocal', 'libcrypto'), ('BN_nnmod', 'libcrypto')]
# ngx_create_temp_buf
# ['SSL_get_srtp_profiles']
# add_label_addr.isra.30
# ['ssl3_do_uncompress']
# X509at_add1_attr_by_OBJ
# ['OCSP_cert_id_new', 'TS_CONF_set_policies', 'TS_CONF_set_digests', 'X509v3_add_ext']
# VKO_compute_key.isra.0
# ['ENGINE_set_default_string']
# ngx_http_send_header
# ['ssl_init_wbio_buffer']
# ssl_set_cert
# ['ssl_set_pkey']
# pcre_study
# ['ssl3_write_bytes']
# X509V3_add_value_bool_nf
# ['OBJ_dup']
# ngx_destroy_pool
# ['ssl_parse_clienthello_renegotiate_ext']
# ngx_ssl_certificate
# ['tls1_check_duplicate_extensions']
# ngx_http_discarded_request_body_handler
# ['bn_mul_mont_fixed_top']
# ngx_ssl_get_serial_number
# ['CRYPTO_malloc', 'CRYPTO_realloc']
# EC_KEY_print_fp
# ['CMS_final']
# X509_NAME_add_entry_by_txt
# ['X509_add1_trust_object', 'X509_add1_reject_object', 'ASN1_TYPE_set1', 'OBJ_create']
# emit_mov_byte
# ['BIO_gets']
# ngx_event_expire_timers
# ['ssl3_client_hello']
# HMAC_Init
# ['HMAC_Init_ex']
# SSL_get_fd
# ['PKCS7_final', 'BIO_asn1_get_suffix', 'PEM_ASN1_read', 'BIO_asn1_get_prefix', 'PEM_read_PrivateKey', 'ASN1_item_d2i_fp', 'PEM_X509_INFO_read', 'ASN1_d2i_fp', 'PEM_read_DHparams']
# ngx_init_modules
# ['tls1_save_sigalgs', 'custom_ext_init', 'SSL_get_srtp_profiles', 'ssl_parse_clienthello_renegotiate_ext']
# ssl_prepare_clienthello_tlsext
# ['ssl_add_clienthello_tlsext']
# ngx_read_ahead
# ['SSL_get_ciphers', 'ssl_verify_cert_chain', 'ssl2_part_read']
# ngx_time_update
# ['ssl_parse_clienthello_renegotiate_ext']
# ecdsa_check
# [('BN_mod_mul', 'libcrypto'), ('BN_clear_free', 'libcrypto')]
# RSA_blinding_on
# [('RSA_setup_blinding', 'libcrypto'), ('e_rsax_get_ctx', 'libcrypto'), ('BN_BLINDING_create_param', 'libcrypto'), 'RSA_setup_blinding']
# ngx_utf8_decode
# ['SSL_get_srtp_profiles']
# ngx_atotm
# ['BN_copy']
# BUF_strdup
# [('CRYPTO_malloc', 'libcrypto'), ('BIO_ctrl', 'libcrypto'), ('SRP_gN_new_init', 'libcrypto'), ('SRP_user_pwd_set_sv.isra.4', 'libcrypto')]
# EVP_MD_CTX_copy
# ['EVP_MD_CTX_copy_ex']
# a2i_IPADDRESS_NC
# ['a2i_IPADDRESS', 'a2i_ipadd']
# ngx_http_upstream_upgraded_write_downstream
# ['sub_180080', 'sub_181390', 'sub_181240', 'sub_180000', 'sub_182b30', 'sub_1800e0', 'sub_180230', 'sub_1802a0', 'sub_182b00', 'sub_180050', 'sub_182c70', 'str_copy']
# do_casefulcmp.isra.43
# ['ssl3_init_finished_mac']
# is_counted_repeat.part.0
# ['tls1_save_sigalgs', 'custom_ext_init', 'ssl_parse_clienthello_renegotiate_ext', 'SSL_get_srtp_profiles']
# CMS_add1_crl
# ['cms_set1_ias']
# adjust_recurse.isra.5
# ['SSL_get_srtp_profiles']
# ngx_start_cache_manager_processes
# ['tls1_process_sigalgs']
# ngx_pool_cleanup_add
# ['custom_ext_parse']
# DH_new
# ['DH_new_method']
# BN_mod_add
# [('BN_reciprocal', 'libcrypto'), ('BN_nnmod', 'libcrypto'), 'BN_nnmod']
# X509V3_get_value_int
# ['s2i_ASN1_INTEGER']
# ubsec_finish
# ['cswift_finish', 'atalla_finish', 'nuron_finish']
# bn_mul_recursive.constprop.0
# ['bn_mul_recursive']
# ngx_http_file_cache_forced_expire
# ['ssl3_client_hello']
# ibm_4758_cca_finish
# ['cswift_finish', 'atalla_finish', 'nuron_finish']
# ngx_blocking
# ['ssl3_setup_buffers']
# check_newlinechar
# ['ssl3_send_alert']
# ngx_http_v2_header_filter
# ['ssl_parse_clienthello_tlsext']
# ngx_http_v2_send_window_update
# ['dtls1_client_hello', 'ssl3_client_hello']
# cswift_rand_bytes
# ['hwcrhk_insert_card']
# sub_5c8790
# [('sub_f6e98', 'libcrypto'), ('sub_1157b8', 'libcrypto'), ('sub_f6fd8', 'libcrypto'), ('sub_116028', 'libcrypto'), ('sub_114ab8', 'libcrypto'), ('sub_115a38', 'libcrypto'), ('sub_f64d8', 'libcrypto'), ('sub_f7128', 'libcrypto'), ('sub_114c38', 'libcrypto'), ('sub_f6f88', 'libcrypto'), ('sub_1157a8', 'libcrypto'), ('sub_f78a8', 'libcrypto'), ('sub_f8158', 'libcrypto'), ('sub_114c78', 'libcrypto'), ('sub_115d88', 'libcrypto'), ('sub_f65d8', 'libcrypto'), ('sub_f65a8', 'libcrypto'), ('sub_f6ff8', 'libcrypto'), ('sub_f7d28', 'libcrypto'), ('sub_f7098', 'libcrypto'), ('sub_115ea8', 'libcrypto'), ('sub_f75d8', 'libcrypto'), ('sub_f7168', 'libcrypto'), ('sub_116458', 'libcrypto'), ('sub_f6048', 'libcrypto'), ('sub_f7d98', 'libcrypto'), ('sub_1165a8', 'libcrypto'), ('sub_f8258', 'libcrypto'), ('sub_14fda8', 'libcrypto'), 'sub_115ea8', 'sub_114c38', 'sub_1165a8', 'sub_1157a8', 'sub_f65d8', 'sub_14fda8', 'sub_116458', 'sub_f6e98', 'sub_f64d8', 'sub_115a38', 'sub_f7d98', 'sub_114ab8', 'sub_f8258', 'sub_f78a8', 'sub_f6f88', 'sub_f6048', 'sub_f7098', 'sub_f8158', 'sub_f7168', 'sub_f7d28', 'sub_f6ff8', 'sub_114c78', 'sub_115d88', 'sub_f6fd8', 'sub_f75d8', 'sub_116028', 'sub_f7128', 'sub_f65a8']
# ngx_stream_upstream_init_least_conn
# ['tls1_set_server_sigalgs']
# X509_NAME_ENTRY_create_by_txt
# ['BN_exp', 'BN_BLINDING_create_param']
# BIO_free_all
# [('PKCS7_ctrl', 'libcrypto'), ('EVP_PKEY_encrypt', 'libcrypto'), ('EVP_PKEY_CTX_ctrl', 'libcrypto')]
# EVP_DecryptFinal
# [('EVP_DecryptFinal_ex', 'libcrypto'), 'EVP_DecryptFinal_ex']
# X509V3_EXT_add_conf
# ['ocsp_match_issuerid']
# CMS_add0_crl
# ['cms_set1_ias']
# ngx_epoll_process_events
# ['ssl23_connect']
# ngx_nonblocking
# ['ssl3_setup_buffers']
# is_anchored
# ['ssl3_read_n']
# engine_cleanup_add_first
# ['pkey_rsa_copy', 'pkey_ec_copy']
# ngx_event_cancel_timers
# ['ssl3_client_hello']
# gost2001_do_verify
# [('BN_MONT_CTX_set', 'libcrypto')]
# PKCS7_add_crl
# ['TS_RESP_CTX_set_certs']
# EVP_PKEY_asn1_find_str
# [('ssl_cipher_strength_sort', 'libssl')]
# sub_5c8ac0
# ['sub_115ad0', 'sub_f78f0', 'sub_f8470', 'sub_116830', 'sub_f6360', 'sub_c6f78', 'sub_114f90', 'sub_14fc10', 'sub_114dd0', 'sub_1168c0', 'sub_c97b8', 'sub_f7480', 'sub_c9028', 'sub_c95b8', 'sub_f71b0', 'sub_f85f0', 'sub_14fb90', 'sub_c6868', 'sub_116340', 'sub_f72a0', 'sub_114f50', 'sub_c6248', 'sub_f68f0', 'sub_f8720', 'sub_cd278', 'sub_f68c0', 'sub_cd058', 'sub_f8570', 'sub_c62d8', 'sub_152a60', 'sub_f7310', 'sub_1500c0', 'sub_cd0f8', 'sub_115b00', 'sub_116770', 'sub_cd148', 'sub_f7440', 'sub_f73b0', 'sub_1161c0', 'sub_f67f0', 'sub_115b40', 'sub_f7bc0', 'sub_115ac0', 'sub_f8040', 'sub_154340', 'sub_ccfd8', 'sub_1160a0', 'sub_cd088', 'sub_f72f0', 'sub_115d50', 'sub_c6d08', 'sub_150080']
# ngx_mail_imap_init_session
# ['ssl3_client_hello']
# ngx_stream_upstream_init_least_conn_peer
# ['tls1_set_server_sigalgs']
# ngx_http_script_file_code
# ['dtls1_client_hello', 'ssl3_client_hello']
# ngx_http_core_post_rewrite_phase
# ['dtls1_client_hello', 'ssl3_client_hello']
# SSL_CTX_SRP_CTX_free
# [('ok_free', 'libcrypto'), ('enc_free', 'libcrypto'), 'ok_free', 'enc_free']
# SRP_Verify_A_mod_N
# [('SRP_Verify_B_mod_N', 'libcrypto'), 'SRP_Verify_B_mod_N']
# X509_print
# ['X509_print_ex']
# ASN1_item_d2i_fp
# ['ASN1_item_d2i_bio', 'ASN1_d2i_bio']
# ngx_os_init
# ['ssl_parse_serverhello_renegotiate_ext']
# sljit_emit_jump
# ['ssl3_read_n']
# ngx_http_copy_filter
# ['dtls1_client_hello']
# ngx_http_post_action
# ['ERR_put_error', 'CRYPTO_free']
# ngx_hextoi
# ['BN_copy']
# asn1_template_ex_i2d
# ['ASN1_item_ex_i2d']
# ngx_mail_imap_init_protocol
# ['ssl3_client_hello']
# X509_NAME_add_entry_by_NID
# ['X509_add1_trust_object', 'X509_add1_reject_object', 'ASN1_TYPE_set1', 'OBJ_create']
# BN_bn2bin
# [('dtls1_set_message_header', 'libssl')]
# X509_subject_name_hash_old
# [('X509_NAME_hash_old', 'libcrypto'), ('X509_issuer_and_serial_hash', 'libcrypto'), ('SRP_Calc_x', 'libcrypto')]
# PKCS5_pbe2_set
# ['PKCS5_pbe2_set_iv']
# ngx_shm_alloc
# ['custom_ext_init', 'SSL_get_srtp_profiles', 'ssl_parse_clienthello_renegotiate_ext']
# ngx_http_add_variable
# ['ec_mul_consttime']
# ENGINE_load_cswift
# ['ENGINE_load_chil']
# ngx_epoll_eventfd_handler
# ['ssl23_connect']
# ngx_ssl_crl
# ['BUF_MEM_grow', 'BUF_MEM_grow_clean']
# ngx_http_v2_send_rst_stream
# ['dtls1_client_hello', 'ssl3_client_hello']
# sub_5c8900
# [('sub_f7130', 'libcrypto'), ('sub_1165b0', 'libcrypto'), ('sub_f83b0', 'libcrypto'), ('sub_f7ef0', 'libcrypto'), ('sub_14ff00', 'libcrypto'), ('sub_f6ff0', 'libcrypto'), ('sub_115910', 'libcrypto'), ('sub_116180', 'libcrypto'), ('sub_114c10', 'libcrypto'), ('sub_115b90', 'libcrypto'), ('sub_f6630', 'libcrypto'), ('sub_f7280', 'libcrypto'), ('sub_114d90', 'libcrypto'), ('sub_f70e0', 'libcrypto'), ('sub_115900', 'libcrypto'), ('sub_116700', 'libcrypto'), ('sub_f7a00', 'libcrypto'), ('sub_f82b0', 'libcrypto'), ('sub_114dd0', 'libcrypto'), ('sub_115ee0', 'libcrypto'), ('sub_f6730', 'libcrypto'), ('sub_f6700', 'libcrypto'), ('sub_f7150', 'libcrypto'), ('sub_f7e80', 'libcrypto'), ('sub_f71f0', 'libcrypto'), ('sub_116000', 'libcrypto'), ('sub_f7730', 'libcrypto'), ('sub_f72c0', 'libcrypto'), ('sub_f61a0', 'libcrypto'), ('sub_c8e70', 'libcrypto'), ('sub_c6120', 'libcrypto'), ('sub_c66b0', 'libcrypto'), ('sub_cd0c0', 'libcrypto'), ('sub_c6dc0', 'libcrypto'), ('sub_ccf90', 'libcrypto'), ('sub_ccf40', 'libcrypto'), ('sub_c6b50', 'libcrypto'), ('sub_ccea0', 'libcrypto'), ('sub_cce20', 'libcrypto'), ('sub_cced0', 'libcrypto'), ('sub_c9400', 'libcrypto'), ('sub_c9600', 'libcrypto'), ('sub_c6090', 'libcrypto'), 'sub_115910', 'sub_114c10', 'sub_116180', 'sub_115900', 'sub_14ff00', 'sub_114dd0', 'sub_115ee0', 'sub_1165b0', 'sub_116000', 'sub_116700', 'sub_114d90', 'sub_115b90']
# ngx_slab_init
# ['tls1_save_sigalgs', 'custom_ext_parse', 'custom_ext_init']
# EVP_MD_CTX_destroy
# [('EVP_MD_CTX_cleanup', 'libcrypto'), 'EVP_MD_CTX_cleanup']
# RSA_verify_PKCS1_PSS_mgf1
# ['RSA_verify_PKCS1_PSS']
# cswift_finish
# [('atalla_finish', 'libcrypto'), ('nuron_finish', 'libcrypto'), 'atalla_finish', 'nuron_finish']
# ngx_epoll_notify_handler
# ['ssl3_client_hello']
# ngx_http_output_filter
# ['ssl_init_wbio_buffer']
# ngx_gmtime
# ['ssl_add_clienthello_renegotiate_ext']
# aep_destroy
# ['ibm_4758_cca_destroy']
# cswift_init
# ['atalla_init']
# pkey_ec_init
# [('nbiof_new', 'libcrypto')]
# ngx_create_pool
# ['ssl_parse_clienthello_renegotiate_ext']
# ngx_http_get_variable_index
# ['ec_mul_consttime']
# ngx_udp_unix_send
# ['dtls1_client_hello', 'ssl3_client_hello']
# ec_GF2m_simple_dbl
# [('ec_GF2m_simple_add', 'libcrypto')]
# ngx_http_file_cache_loader
# ['dtls1_client_hello', 'ssl3_client_hello']
# BN_mod_sub
# [('BN_reciprocal', 'libcrypto'), ('BN_nnmod', 'libcrypto'), 'BN_nnmod']
# EVP_PKEY_CTX_dup
# ['X509_PUBKEY_set']
# do_caselesscmp.isra.44
# ['ssl3_init_finished_mac']
# ngx_conf_split_clients_block
# ['ssl3_client_hello']
# ngx_http_find_virtual_server.isra.2.part.3
# ['ssl3_client_hello']
# ngx_ssl_client_certificate
# ['ssl3_send_alert']
# ngx_http_upstream_init_least_conn
# ['tls1_set_server_sigalgs']
# dtls1_output_cert_chain
# [('OCSP_request_verify', 'libcrypto')]
# BN_add_word
# [('BN_rshift', 'libcrypto'), 'BN_rshift']
# X509_print_fp
# ['X509_REQ_print_ex']
# X509_STORE_get1_crls
# ['X509_STORE_CTX_get1_issuer', 'X509_STORE_get1_certs']
# ssl_get_prev_session
# [('ssl_get_new_session', 'libssl')]
# PEM_write
# ['PEM_write_bio']
# add_to_class.isra.8
# ['SSL_get_srtp_profiles']
# ngx_ssl_trusted_certificate
# ['ssl3_send_alert']
# SHA384_Update
# [('SHA512_Update', 'libcrypto'), 'SHA512_Update']
# ASN1_STRING_new
# [('ASN1_STRING_type_new', 'libcrypto'), ('ERR_add_error_data', 'libcrypto'), ('CRYPTO_free', 'libcrypto')]
# X509V3_EXT_CRL_add_nconf
# ['add_attribute', 'v2i_BASIC_CONSTRAINTS']
# ngx_resolver_udp_read
# ['ssl23_connect']
# _pcre_was_newline
# ['SSL_get_srtp_profiles']
# EVP_PKEY_base_id
# [('EVP_PKEY_type', 'libcrypto')]
# engine_cleanup_add_last
# ['pkey_rsa_copy', 'pkey_ec_copy']
# ngx_epoll_add_connection
# ['ssl3_client_hello']
# EVP_PKEY_CTX_new_id
# ['X509_PUBKEY_set']
# surewarehk_rsa_sign
# ['ibm_4758_load_privkey']
# EVP_Digest
# [('BN_MONT_CTX_set', 'libcrypto')]
# SRP_Calc_A_param
# [('ssl3_send_finished', 'libssl'), ('ssl3_init_finished_mac', 'libssl'), ('ssl3_send_alert', 'libssl')]
# expand_workspace
# ['tls1_save_sigalgs', 'ssl_parse_clienthello_renegotiate_ext', 'SSL_get_srtp_profiles', 'custom_ext_init']
# X509_check_trust
# [('NAME_CONSTRAINTS_check', 'libcrypto'), ('X509_get_pubkey_parameters', 'libcrypto'), ('X509_check_ca', 'libcrypto')]
# PKCS5_pbe_set
# ['PKCS5_pbe_set0_algor']
# ngx_http_v2_send_output_queue
# ['ssl23_connect']
# ngx_http_upstream_upgraded_read_upstream
# ['sub_180080', 'sub_181390', 'sub_181240', 'sub_180000', 'sub_182b30', 'sub_1800e0', 'sub_180230', 'str_copy', 'sub_1802a0', 'sub_182b00', 'sub_180050', 'sub_182c70']
# flush_pending
# ['ssl3_do_uncompress']
# PKCS12_item_decrypt_d2i
# ['ASN1_item_verify']
# X509_NAME_add_entry_by_OBJ
# ['X509_add1_trust_object', 'ASN1_TYPE_set1', 'X509_add1_reject_object', 'OBJ_create']
# deflate
# ['ssl3_read_bytes']
# BN_nnmod
# [('BN_set_word', 'libcrypto'), ('BN_new', 'libcrypto'), ('BN_is_bit_set', 'libcrypto'), ('BN_num_bits', 'libcrypto'), ('BN_reciprocal', 'libcrypto'), ('BN_mod_sqr', 'libcrypto'), ('BN_mod_lshift1_quick', 'libcrypto'), ('BN_mod_sub_quick', 'libcrypto'), ('BN_CTX_new', 'libcrypto'), ('BN_mod_add_quick', 'libcrypto'), ('ERR_peek_last_error', 'libcrypto'), ('EC_POINT_set_affine_coordinates_GFp', 'libcrypto'), ('EC_POINT_free', 'libcrypto'), ('BN_MONT_CTX_new', 'libcrypto'), ('BN_MONT_CTX_free', 'libcrypto')]
# ngx_inet_resolve_host
# ['ssl_parse_serverhello_tlsext']
# X509V3_EXT_CRL_add_conf
# ['ocsp_match_issuerid']
# pqueue_size
# [('ssl3_setup_buffers', 'libssl')]
# ngx_http_dav_copy_dir
# ['ssl3_client_hello']
# RSA_padding_add_PKCS1_PSS
# [('RSA_padding_add_PKCS1_PSS_mgf1', 'libcrypto'), 'RSA_padding_add_PKCS1_PSS_mgf1']
# X509V3_add_value_int
# ['i2s_ASN1_ENUMERATED', 'i2s_ASN1_INTEGER']
# ERR_CSWIFT_error.constprop.3
# ['EC_pre_comp_free', 'bn_copy_words']
# pitem_new
# [('ssl3_setup_buffers', 'libssl'), 'ssl3_setup_buffers']
# BIO_pop
# [('SSL_clear', 'libssl'), ('ssl2_get_cipher_by_char', 'libssl'), ('ssl_sess_cert_free', 'libssl'), ('ssl_verify_cert_chain', 'libssl'), ('ssl_init_wbio_buffer', 'libssl')]
# X509V3_EXT_add_nconf
# ['add_attribute', 'v2i_BASIC_CONSTRAINTS']
# ngx_http_geo_value.isra.4
# ['ssl2_new', 'ssl3_setup_buffers']
# add_not_list_to_class.isra.10
# ['tls1_save_sigalgs', 'ssl_parse_clienthello_renegotiate_ext', 'SSL_get_srtp_profiles', 'custom_ext_init']
# ngx_http_upstream_rewrite_location
# ['dtls1_client_hello', 'ssl3_client_hello']
# X509_NAME_get_index_by_NID
# ['X509_NAME_get_entry']
# updatewindow
# ['BIO_gets']
# ngx_ssl_get_cached_session
# [('tls_decrypt_ticket', 'libssl')]
# ngx_cycle_modules
# ['custom_ext_init', 'SSL_get_srtp_profiles', 'ssl_parse_clienthello_renegotiate_ext']
# ngx_writev
# ['dtls1_client_hello', 'ssl3_client_hello']
# ASN1_item_new
# [('sk_value', 'libcrypto')]
# ubsec_dh_generate_key
# ['hwcrhk_insert_card']
# ssl_get_server_send_cert
# ['ssl3_write_bytes']
# ngx_close_channel
# ['ssl_parse_clienthello_renegotiate_ext']
# v2i_GENERAL_NAME
# ['v2i_GENERAL_NAME_ex']
# EVP_CIPHER_asn1_to_param
# [('CRYPTO_malloc', 'libcrypto'), ('X509_NAME_cmp', 'libcrypto'), ('BIO_ctrl', 'libcrypto'), ('OBJ_obj2nid', 'libcrypto')]
# ngx_slab_alloc_locked
# ['ssl_cipher_process_rulestr.isra.3']
# ngx_write_channel
# ['dtls1_client_hello', 'ssl3_client_hello']
# ngx_http_upstream_set_round_robin_peer_session
# [('tls_decrypt_ticket', 'libssl')]
# ENGINE_load_atalla
# ['ENGINE_load_chil']
# DHparams_print
# ['dh_param_print']
# ngx_http_dav_handler
# ['ssl3_get_server_hello']
# ngx_http_upstream_rewrite_set_cookie
# ['dtls1_client_hello', 'ssl3_client_hello']
# ngx_create_temp_file
# ['dtls1_client_hello']
# sk_find
# [('SSL_clear', 'libssl'), ('ssl_verify_cert_chain', 'libssl'), ('ssl_init_wbio_buffer', 'libssl')]
# DSA_new
# ['DSA_new_method']
# dtls1_write_app_data_bytes
# ['do_dtls1_write']
# encode_gost_algor_params
# ['eckey_pub_encode']
# ngx_shm_free
# ['custom_ext_init', 'SSL_get_srtp_profiles', 'ssl_parse_clienthello_renegotiate_ext']
# compile_iterator_matchingpath.isra.45
# ['ssl3_get_client_hello']
# BN_sub_word
# [('BN_rshift', 'libcrypto'), 'BN_rshift']
# SSL_get_wfd
# ['PKCS7_final', 'BIO_asn1_get_suffix', 'BIO_asn1_get_prefix', 'PEM_ASN1_read', 'PEM_read_PrivateKey', 'ASN1_item_d2i_fp', 'ASN1_d2i_fp', 'PEM_X509_INFO_read', 'PEM_read_DHparams']
# EVP_MD_CTX_create
# [('dtls1_set_message_header', 'libssl')]
# X509_ATTRIBUTE_create_by_txt
# ['X509_ATTRIBUTE_create_by_OBJ', 'CMS_set1_eContentType']
# SSL_get_rfd
# ['PKCS7_final', 'BIO_asn1_get_suffix', 'BIO_asn1_get_prefix', 'PEM_ASN1_read', 'PEM_read_PrivateKey', 'ASN1_item_d2i_fp', 'ASN1_d2i_fp', 'PEM_X509_INFO_read', 'PEM_read_DHparams']
# ngx_log_abort
# ['tls1_set_server_sigalgs']
# SSL_CTX_use_PrivateKey
# ['X509_load_cert_crl_file']
# ngx_init_signals
# ['ssl3_client_hello']
# sub_5c86e8
# ['sub_f70b8', 'sub_f6de8', 'sub_f6ed8', 'sub_c94b0', 'sub_114b88', 'sub_1156f8', 'sub_f64f8', 'sub_c92b0', 'sub_f6428', 'sub_115f78', 'sub_1163a8', 'sub_f80a8', 'sub_c5fd0', 'sub_f6fe8', 'sub_154000', 'sub_c6a00', 'sub_115988', 'sub_c5f40', 'sub_cccc8', 'sub_114bc8', 'sub_154088', 'sub_114a08', 'sub_f7c78', 'sub_f7078', 'sub_f6528', 'sub_c8d20', 'sub_115cd8', 'sub_f77f8', 'sub_115df8', 'sub_f7ce8', 'sub_f7528', 'sub_ccc18', 'sub_c6560', 'sub_152720', 'sub_c6c70', 'sub_f6f28', 'sub_1527a8', 'sub_f5f98', 'sub_f6f48']
# ngx_ssl_create
# ['custom_ext_parse', 'ssl3_send_alert']
# ngx_http_read_discarded_request_body
# ['bn_sqr_fixed_top']
# CONF_free
# [('CRYPTO_free', 'libcrypto'), ('ERR_add_error_data', 'libcrypto'), ('_CONF_add_string', 'libcrypto'), ('BIO_snprintf', 'libcrypto')]
# ngx_epoll_add_event
# ['ssl3_client_hello']
# X509at_add1_attr_by_txt
# ['OCSP_cert_id_new', 'TS_CONF_set_digests', 'X509v3_add_ext', 'v2i_POLICY_MAPPINGS', 'eckey_pub_print', 'eckey_pub_encode']
# BIO_int_ctrl
# [('CRYPTO_malloc', 'libcrypto'), ('BIO_write', 'libcrypto'), 'BIO_write']
# ngx_http_geo_cidr_add
# ['ssl2_new', 'ssl3_setup_buffers']
# deflateParams
# ['ssl3_do_write']
# ngx_http_mp4_read_ctts_atom
# ['tls1_set_server_sigalgs']
# EVP_CipherInit
# ['EVP_CipherInit_ex']
# pkey_hmac_init
# [('enc_new', 'libcrypto')]
# ngx_resolver_process_srv
# ['str_copy']
# ngx_ssl_get_fingerprint
# ['CRYPTO_malloc', 'CRYPTO_realloc']
# pqueue_pop
# [('ssl3_setup_buffers', 'libssl'), ('ssl3_renegotiate', 'libssl'), ('dtls1_reset_seq_numbers', 'libssl')]
# dtls1_write_bytes
# ['do_dtls1_write']
# ngx_http_v2_send_goaway
# ['dtls1_client_hello', 'ssl3_client_hello']
# dtls1_retransmit_buffered_messages
# [('ssl3_do_change_cipher_spec', 'libssl')]
# ngx_http_file_cache_init
# ['dtls1_client_hello', 'ssl3_client_hello']
# aep_init
# ['hwcrhk_init']
# ngx_http_do_read_client_request_body
# ['ssl23_connect']
# RAND_egd
# [('RAND_egd_bytes', 'libcrypto'), 'RAND_egd_bytes']
# ngx_http_script_complex_value_code
# ['dtls1_client_hello', 'ssl3_client_hello']
# ENGINE_load_ubsec
# ['ENGINE_load_chil']
# RSA_verify
# ['int_rsa_verify']
# emit_mov_half
# ['BIO_gets']
# ERR_GOST_error
# ['ENGINE_set_default_string']
# ssl3_send_change_cipher_spec
# [('ssl3_send_server_certificate', 'libssl'), ('ssl3_send_finished', 'libssl'), ('ssl3_init_finished_mac', 'libssl'), ('ssl_free_wbio_buffer', 'libssl'), ('SRP_Calc_A_param', 'libssl'), ('ssl3_get_server_done', 'libssl'), ('ssl3_check_finished', 'libssl'), 'ssl_free_wbio_buffer']
# X509V3_EXT_get
# ['X509V3_EXT_get_nid']
# sub_5c87d0
# ['sub_91788']
# ngx_http_script_not_equal_code
# ['tls1_set_server_sigalgs']
# ngx_ssl_password_callback
# ['ssl3_client_hello']
# EC_POINT_mul
# [('EC_POINT_get_affine_coordinates_GF2m', 'libcrypto'), ('EC_POINT_get_affine_coordinates_GFp', 'libcrypto'), ('EC_POINT_free', 'libcrypto'), ('BN_CTX_new', 'libcrypto'), ('BN_new', 'libcrypto')]
# EVP_DecryptInit
# ['EVP_CipherInit_ex']
# ngx_parse_url
# ['ssl_add_clienthello_tlsext']
# md_free
# [('ok_free', 'libcrypto')]
# BN_BLINDING_create_param
# [('dsa_sign_setup', 'libcrypto')]
# ngx_read_glob
# ['CRYPTO_free']
# RAND_pseudo_bytes
# [('BN_CTX_free', 'libcrypto'), ('BN_add', 'libcrypto'), ('EVP_Digest', 'libcrypto'), ('BN_dup', 'libcrypto'), ('BN_lshift1', 'libcrypto'), ('ssl3_finish_mac', 'libssl'), ('ssl2_new', 'libssl'), ('ssl_cipher_list_to_bytes', 'libssl'), ('ssl2_part_read', 'libssl'), ('BIO_ctrl', 'libcrypto'), ('OBJ_obj2nid', 'libcrypto'), ('EVP_PKEY_encrypt_init', 'libcrypto'), ('BIO_new_mem_buf', 'libcrypto'), ('ssl3_send_alert', 'libssl'), ('ssl3_digest_cached_records', 'libssl')]
# SSL_connect
# [('SSL_clear', 'libssl')]
# X509_issuer_name_hash_old
# [('X509_NAME_hash_old', 'libcrypto'), ('X509_issuer_and_serial_hash', 'libcrypto'), ('SRP_Calc_x', 'libcrypto')]
# ngx_resolver_process_a
# ['str_copy']
# ENGINE_load_nuron
# ['ENGINE_load_chil']
# X509_STORE_add_crl
# ['DSA_new_method', 'DH_new_method', 'EVP_PKEY_CTX_new_id']
# ngx_http_dav_copy_dir_time
# ['dtls1_client_hello', 'ssl3_client_hello']
# EVP_PKEY_meth_add0
# [('EVP_PKEY_asn1_add0', 'libcrypto')]
# ECParameters_print_fp
# ['CMS_final']
# int_free_ex_data
# ['int_dup_ex_data']
# PKCS12_item_i2d_encrypt
# ['ASN1_item_verify']
# ngx_http_compile_complex_value
# ['ssl_add_clienthello_tlsext']
# ssl_replace_hash
# [('srp_Calc_k', 'libcrypto')]
# eckey_param_decode
# ['old_ec_priv_decode']
# X509_time_adj
# ['X509_time_adj_ex']
# RAND_add
# [('ssl3_send_server_certificate', 'libssl'), ('SSL_srp_server_param_with_username', 'libssl'), ('ssl3_send_finished', 'libssl'), ('ssl3_send_alert', 'libssl'), ('ssl3_finish_mac', 'libssl'), ('ssl2_new', 'libssl'), ('ssl3_init_finished_mac', 'libssl'), ('ssl3_get_server_done', 'libssl'), ('ssl3_check_finished', 'libssl'), ('ssl2_part_read', 'libssl'), ('ssl_cipher_list_to_bytes', 'libssl')]
# ngx_ssl_dhparam
# ['BUF_MEM_grow', 'BUF_MEM_grow_clean']
# ngx_http_core_post_access_phase
# ['ssl3_client_hello']
# ngx_thread_cond_destroy
# ['tls1_set_server_sigalgs']
# X509_STORE_get1_certs
# ['X509_STORE_CTX_get1_issuer']
# ngx_resolver_lookup_name.isra.1
# ['BUF_MEM_free', 'BUF_MEM_new']
# sljit_emit_cmp
# ['ssl3_send_alert']
# ngx_http_v2_send_chain
# ['ssl_parse_clienthello_tlsext']
# ngx_resolver_free_node.isra.5
# ['BUF_MEM_grow', 'BUF_MEM_free', 'BUF_MEM_grow_clean']
# ngx_directio_on
# ['SSL_get_ciphers', 'ssl_verify_cert_chain', 'ssl2_part_read']
# ngx_palloc
# ['CRYPTO_malloc']
# ngx_stream_upstream_set_round_robin_peer_session
# [('tls_decrypt_ticket', 'libssl')]
# COMP_compress_block
# ['ssl3_do_compress']
# X509_STORE_add_cert
# ['DSA_new_method', 'DH_new_method', 'EVP_PKEY_CTX_new_id']
# ngx_log_stderr
# ['tls1_save_sigalgs', 'custom_ext_parse']
# add_list_to_class.isra.9.constprop.13
# ['tls1_save_sigalgs', 'custom_ext_init', 'ssl_parse_clienthello_renegotiate_ext', 'SSL_get_srtp_profiles']
# ngx_master_process_cycle
# ['ssl_parse_clienthello_tlsext']
# BN_is_prime_ex
# ['BN_is_prime_fasttest_ex']
# ngx_thread_cond_signal
# ['tls1_set_server_sigalgs']
# check_anynewline.isra.26
# ['ssl3_init_finished_mac']
# EVP_DigestFinal
# ['EVP_DigestFinal_ex']
# sk_set_cmp_func
# [('ssl2_return_error', 'libssl')]
# ngx_http_script_compile
# ['ssl_parse_serverhello_tlsext']
# RSA_verify_PKCS1_PSS
# ['RSA_padding_add_PKCS1_PSS_mgf1']
# ngx_ssl_get_subject_dn
# ['X509_CRL_print', 'X509_issuer_and_serial_hash', 'x509_cb']
# ngx_log_open_default
# ['ssl3_send_alert', 'tls1_save_sigalgs']
# ngx_pnalloc
# ['CRYPTO_malloc']
# EVP_CipherFinal_ex
# ['EVP_DecryptFinal_ex']
# ngx_alloc_chain_link
# ['SSL_get_srtp_profiles']
# CRYPTO_push_info_
# [('doapr_outch.constprop.5', 'libcrypto'), ('CRYPTO_pop_info', 'libcrypto'), ('doapr_outch', 'libcrypto'), ('BIO_write', 'libcrypto'), 'CRYPTO_pop_info', 'doapr_outch', 'doapr_outch.constprop.5', 'BIO_write']
# ngx_create_path
# ['dtls1_client_hello']
# sub_5df230
# ['sub_139278']
# ssl3_generate_master_secret
# [('srp_Calc_k', 'libcrypto')]
# X509V3_add_value_uchar
# [('X509V3_add_value', 'libcrypto'), 'X509V3_add_value']
# SSL_CTX_use_PrivateKey_file
# ['X509_load_crl_file', 'X509_load_cert_crl_file', 'X509_load_cert_file']
# ngx_http_split_clients_variable
# ['ssl3_client_hello']
# pitem_free
# [('ssl3_setup_buffers', 'libssl'), ('ssl3_renegotiate', 'libssl'), 'ssl3_setup_buffers']
# ngx_http_v2_process_request_body
# ['ssl23_connect']
# X509_REQ_add_extensions
# ['X509_REQ_add_extensions_nid']
# ngx_ssl_init
# ['tls1_save_sigalgs', 'ssl3_send_alert']
# EVP_CipherFinal
# ['EVP_DecryptFinal_ex']
# sk_dup
# [('X509_check_purpose', 'libcrypto'), ('sk_delete_ptr', 'libcrypto'), ('ssl_cipher_list_to_bytes', 'libssl'), ('ssl2_part_read', 'libssl'), ('ssl3_send_alert', 'libssl'), ('ssl_fill_hello_random', 'libssl'), ('ssl3_digest_cached_records', 'libssl')]
# ENGINE_init
# ['CRYPTO_malloc']
# X509_ATTRIBUTE_create_by_NID
# ['X509_ATTRIBUTE_create_by_OBJ', 'CMS_set1_eContentType']
# ngx_setproctitle
# ['ssl_parse_clienthello_renegotiate_ext']
# X509V3_EXT_print_fp
# ['X509V3_EXT_print']
# EVP_EncryptInit_ex
# ['EVP_CipherInit_ex']
# pcre_free_study
# ['ssl3_write_pending']
# ssl3_setup_buffers
# [('SSL_srp_server_param_with_username', 'libssl'), ('SSL_clear', 'libssl'), ('ssl3_digest_cached_records', 'libssl'), ('ssl_init_wbio_buffer', 'libssl'), ('ssl3_setup_read_buffer', 'libssl'), ('SSL_CTX_remove_session', 'libssl'), ('ssl3_send_finished', 'libssl')]
# EVP_PKEY_CTX_new
# ['X509_PUBKEY_set']
# _pcre_is_newline
# ['SSL_get_srtp_profiles']
# ngx_http_script_equal_code
# ['tls1_set_server_sigalgs']
# ngx_epoll_del_event
# ['ssl3_client_hello']
# CRYPTO_add_lock
# [('X509_NAME_cmp', 'libcrypto'), ('crl_extension_match', 'libcrypto'), ('X509_check_ca', 'libcrypto'), ('X509_check_purpose', 'libcrypto'), ('ssl2_part_read', 'libssl'), ('ssl_init_wbio_buffer', 'libssl')]
# int_err_set_item
# ['int_thread_set_item']
# ngx_thread_cond_create
# ['tls1_set_server_sigalgs']
# EVP_DecryptInit_ex
# ['EVP_CipherInit_ex']
# ssl3_output_cert_chain
# [('ssl3_send_certificate_request', 'libssl'), ('ssl3_send_server_hello', 'libssl'), ('ssl3_send_newsession_ticket', 'libssl'), ('ssl3_get_next_proto', 'libssl'), ('OCSP_request_verify', 'libcrypto'), ('TS_RESP_verify_signature', 'libcrypto')]
# EVP_CIPHER_CTX_rand_key
# [('BIO_new_mem_buf', 'libcrypto'), ('BIO_new', 'libcrypto'), ('CRYPTO_malloc', 'libcrypto'), ('EVP_CIPHER_CTX_set_key_length', 'libcrypto'), ('BIO_push', 'libcrypto'), ('EVP_PKEY_encrypt_init', 'libcrypto')]
# gost2001_param_decode
# ['OBJ_create']
# X509_print_ex_fp
# ['X509_REQ_print_ex']
# ngx_ssl_get_issuer_dn
# ['X509_CRL_print', 'X509_issuer_and_serial_hash', 'x509_cb']
# COMP_CTX_free
# [('ssl_replace_hash', 'libssl'), ('ssl_get_algorithm2', 'libssl')]
# ngx_epoll_del_connection
# ['ssl3_client_hello']
# compile_matchingpath
# ['ssl3_get_client_hello']
# ngx_ssl_info_callback
# ['ssl3_client_hello']
# X509V3_add_value_bool
# ['OBJ_dup']
# ssl2_return_error
# [('ssl2_part_read', 'libssl'), ('ssl2_write_error', 'libssl'), ('ssl_cipher_list_to_bytes', 'libssl')]
# BIO_dump_indent_cb.constprop.0
# ['BIO_dump_indent', 'BIO_dump_indent_cb']
# ngx_http_upstream_init_least_conn_peer
# ['tls1_set_server_sigalgs']
# EVP_CIPHER_CTX_free
# ['EVP_CIPHER_CTX_cleanup']
# EVP_DigestInit
# ['EVP_DigestInit_ex']
# ngx_http_read_client_request_body
# ['ssl23_connect']
# fill_window
# ['ssl3_read_n']
# ngx_http_core_access_phase
# ['dtls1_client_hello', 'ssl3_client_hello']
# COMP_expand_block
# [('ssl3_do_uncompress', 'libssl'), ('ssl3_renegotiate', 'libssl'), ('ssl3_renegotiate_check', 'libssl'), 'ssl3_do_uncompress']
# X509_check_purpose
# [('NAME_CONSTRAINTS_check', 'libcrypto'), ('X509_get_pubkey_parameters', 'libcrypto')]
# priv_print_gost94
# ['eckey_pub_print']
# SSL_SRP_CTX_free
# [('ok_free', 'libcrypto'), ('enc_free', 'libcrypto'), 'ok_free', 'enc_free']
# ngx_http_dav_copy_tree_file
# ['dtls1_client_hello', 'ssl3_client_hello']
# SSL_clear
# [('ssl3_send_server_hello', 'libssl'), ('ssl3_send_newsession_ticket', 'libssl'), ('dtls1_buffer_message', 'libssl'), ('ssl2_enc_init', 'libssl'), ('ssl_bytes_to_cipher_list', 'libssl'), ('ssl_get_prev_session', 'libssl'), ('ssl_sess_cert_free', 'libssl'), ('ssl_update_cache', 'libssl')]
# SSL_SESSION_free
# [('SSL_SESSION_new', 'libssl')]
# inflateStateCheck
# ['BIO_gets']
# ngx_utf8_length
# ['ssl_add_clienthello_use_srtp_ext']
# ngx_http_dav_error
# ['dtls1_client_hello', 'ssl3_client_hello']
# ngx_event_del_timer
# ['ERR_put_error', 'CRYPTO_free']
# ENGINE_finish
# ['CRYPTO_malloc']
# CMS_SignerInfo_cert_cmp
# [('cms_SignerIdentifier_cert_cmp', 'libcrypto')]
# ubsec_dsa_verify
# ['surewarehk_rsa_priv_dec']
# BIO_push
# [('OBJ_nid2sn', 'libcrypto'), ('OBJ_obj2nid', 'libcrypto'), ('ssl3_send_finished', 'libssl'), ('ssl_init_wbio_buffer', 'libssl'), ('EVP_PKEY_encrypt', 'libcrypto')]
# BIO_dump_indent_cb.constprop.1
# ['BIO_dump_indent']
# ngx_log_redirect_stderr
# ['ssl3_send_alert', 'tls1_save_sigalgs', 'custom_ext_parse', 'custom_ext_init']
# ngx_resolve_addr
# ['ssl23_connect']
# ASN1_item_i2d_fp
# ['ASN1_i2d_bio']
# DES_ofb64_encrypt
# ['DES_ede3_ofb64_encrypt']
# BN_num_bits
# [('BN_rshift1', 'libcrypto')]
# RAND_bytes
# [('CRYPTO_malloc', 'libcrypto')]
# sk_new_null
# [('ssl_parse_clienthello_renegotiate_ext', 'libssl'), ('SSL_get_srtp_profiles', 'libssl'), ('CRYPTO_free', 'libcrypto'), ('X509V3_get_section', 'libcrypto'), ('sk_pop_free', 'libcrypto'), ('CMS_add_smimecap', 'libcrypto'), ('CMS_add1_cert', 'libcrypto'), ('CMS_get0_SignerInfos', 'libcrypto'), ('sk_dup', 'libcrypto'), ('sk_free', 'libcrypto'), ('X509_check_trust', 'libcrypto'), ('BIO_free_all', 'libcrypto'), ('BIO_new', 'libcrypto'), ('BUF_strdup', 'libcrypto'), ('BN_clear_free', 'libcrypto'), ('SRP_user_pwd_set_sv.isra.4', 'libcrypto'), ('sk_num', 'libcrypto'), ('sk_value', 'libcrypto'), ('ssl_free_wbio_buffer', 'libssl'), ('ssl_cipher_list_to_bytes', 'libssl'), ('ssl2_get_cipher_by_char', 'libssl'), ('ssl_sess_cert_new', 'libssl')]
# BN_mod_exp
# ['BN_mod_exp_mont']
# ngx_pool_run_cleanup_file
# ['ssl_fill_hello_random']
# sk_push
# [('ssl_parse_clienthello_renegotiate_ext', 'libssl'), ('sk_pop_free', 'libcrypto'), ('ERR_put_error', 'libcrypto'), ('X509_check_purpose', 'libcrypto'), ('sk_dup', 'libcrypto'), ('ssl2_part_read', 'libssl'), ('ssl2_do_write', 'libssl')]
# ngx_http_file_cache_delete
# ['ssl3_client_hello']
# gost94_param_decode
# ['OBJ_create']
# is_startline
# ['ssl3_read_n']
# ngx_open_glob
# ['CRYPTO_free']
# X509_NAME_ENTRY_create_by_NID
# ['BN_exp', 'BN_BLINDING_create_param']
# BIO_indent
# ['BIO_write']
# X509at_add1_attr_by_NID
# ['v2i_POLICY_MAPPINGS', 'eckey_pub_encode', 'OCSP_cert_id_new', 'X509v3_add_ext']
# d2i_AutoPrivateKey
# ['d2i_PrivateKey']
# ngx_http_request_handler
# ['ssl3_client_hello']
# EVP_CIPHER_CTX_set_key_length
# [('X509_NAME_cmp', 'libcrypto'), ('BIO_ctrl', 'libcrypto'), ('OBJ_obj2nid', 'libcrypto'), ('CRYPTO_malloc', 'libcrypto'), ('BIO_new_mem_buf', 'libcrypto'), 'CRYPTO_malloc']
# check_hspace.isra.27
# ['ssl3_init_finished_mac']
# 1545

# %%
import factorgraph as fg
import numpy as np
g = fg.Graph()
global_dict = defaultdict(list)
for key in prediction:
    g.rv(key, len(prediction[key]))
    global_dict[key] = list(prediction[key])
    

for key in global_dict:
    idx = name_test_dict[key]
    (name_next, size) = name_test[idx+1]
    if name_next not in global_dict:
        continue
    #print '\n', key, name_next
    for (p_name, library) in global_dict[key]:
        for (p_name_next, library_next) in global_dict[name_next]:
            if library == 'libcrypto' and library_next == 'libcrypto':
                if nam_crypto_dict[p_name] - nam_crypto_dict[p_name_next] < -10 or nam_crypto_dict[p_name] - nam_crypto_dict[p_name_next] > 2:
                    continue
            if library == 'libssl' and library_next == 'libssl':
                if nam_ssl_dict[p_name] - nam_ssl_dict[p_name_next] < -10 and nam_ssl_dict[p_name] - nam_ssl_dict[p_name_next] > 2:
                    continue
            src_rv = g.get_rvs()[key]
            des_rv = g.get_rvs()[name_next]
            factor1 = None
            probability1 = None
            des_factor = des_rv.get_factors()
            for factor in des_factor:
                if src_rv in factor.get_rvs():
                    factor1 = factor
                    probability1 = factor1.get_potential()

            if factor1 == None and key != name_next:
                pot=np.full((len(global_dict[key]), len(global_dict[name_next])), 0.1)
                factor1 = g.factor([src_rv, des_rv], potential=pot)
                probability1 = factor1.get_potential()
            src_pind = global_dict[key].index((p_name, library))
            des_pind = global_dict[name_next].index((p_name_next, library_next))
            probability1[src_pind, des_pind] = 0.99
            factor1.set_potential(probability1)
g.global_dict = global_dict
iters, converged = g.lbp(global_dict, normalize=True, max_iters=20, progress=False)
results = g.accuracy_of_functions(normalize=True)
# Out:
# correct prediction, None prediction, total prediction, precision:
# 1666 0 2944 0.56589673913

# %%
tuples = g.rv_marginals(None, True)
for rv, marg in tuples:
    rv_label = str(rv)
    print rv_label
    names = global_dict[rv_label]
    for i, label in enumerate(marg):
        print '\t', i, names[i], label
# Out:
# SSL_srp_server_param_with_username
# 	0 ('ssl3_send_alert', 'libssl') 0.25
# 	1 ('ssl3_send_finished', 'libssl') 0.25
# 	2 ('SSL_srp_server_param_with_username', 'libssl') 0.25
# 	3 ('ssl3_digest_cached_records', 'libssl') 0.25
# read_string_inner
# 	0 ('read_string_inner', 'libcrypto') 1.0
# X509_PURPOSE_get_count
# 	0 ('EVP_PKEY_asn1_get_count', 'libcrypto') 0.07751937984496125
# 	1 ('X509_VERIFY_PARAM_get_count', 'libcrypto') 0.07751937984496125
# 	2 ('X509_TRUST_get_count', 'libcrypto') 0.07751937984496125
# 	3 ('X509_PURPOSE_get_count', 'libcrypto') 0.7674418604651163
# RSA_padding_check_PKCS1_type_2
# 	0 ('RSA_padding_check_PKCS1_type_2', 'libcrypto') 0.98000199980002
# 	1 ('BN_CTX_get', 'libcrypto') 0.009999000099990005
# 	2 ('BN_bin2bn', 'libcrypto') 0.009999000099990005
# cswift_rsa_mod_exp
# 	0 ('cswift_rsa_mod_exp', 'libcrypto') 1.0
# X509_PURPOSE_get0
# 	0 ('X509_PURPOSE_get0', 'libcrypto') 1.0
# ngx_mail_auth_http_read_handler
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# PEM_read_bio_Parameters
# 	0 ('PEM_read_bio_Parameters', 'libcrypto') 1.0
# ngx_http_copy_thread_handler
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# SRP_VBASE_new
# 	0 ('SRP_VBASE_new', 'libcrypto') 1.0
# PKCS7_get_attribute
# 	0 ('PKCS7_get_signed_attribute', 'libcrypto') 0.5
# 	1 ('PKCS7_get_attribute', 'libcrypto') 0.5
# EVP_MD_CTX_md
# 	0 ('EVP_MD_CTX_md', 'libcrypto') 1.0
# BN_mod_add_quick
# 	0 ('BN_mod_add_quick', 'libcrypto') 1.0
# print_qualifiers
# 	0 ('print_qualifiers', 'libcrypto') 1.0
# ngx_http_proxy_pass.part.4
# 	0 ('ssl3_get_server_hello', 'libssl') 1.0
# ENGINE_set_default_RSA
# 	0 ('ENGINE_set_default_DSA', 'libcrypto') 0.14285714285714285
# 	1 ('ENGINE_set_default_EC', 'libcrypto') 0.14285714285714285
# 	2 ('ENGINE_set_default_ECDSA', 'libcrypto') 0.14285714285714285
# 	3 ('ENGINE_set_default_RAND', 'libcrypto') 0.14285714285714285
# 	4 ('ENGINE_set_default_ECDH', 'libcrypto') 0.14285714285714285
# 	5 ('ENGINE_set_default_RSA', 'libcrypto') 0.14285714285714285
# 	6 ('ENGINE_set_default_DH', 'libcrypto') 0.14285714285714285
# RSA_generate_key_ex
# 	0 ('RSA_generate_key_ex', 'libcrypto') 1.0
# PKCS7_simple_smimecap
# 	0 ('PKCS7_simple_smimecap', 'libcrypto') 1.0
# asn1_check_tlen
# 	0 ('asn1_check_tlen', 'libcrypto') 1.0
# ngx_open_and_stat_file
# 	0 ('ssl2_accept', 'libssl') 1.0
# lh_doall_arg
# 	0 ('lh_doall_arg', 'libcrypto') 1.0
# X509_to_X509_REQ
# 	0 ('X509_to_X509_REQ', 'libcrypto') 1.0
# Camellia_Ekeygen
# 	0 ('Camellia_Ekeygen', 'libcrypto') 1.0
# EVP_PKEY_assign
# 	0 ('OBJ_add_object', 'libcrypto') 1.0
# X509_ALGOR_set0
# 	0 ('X509_ALGOR_set0', 'libcrypto') 1.0
# ngx_http_mp4_read_stss_atom
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# SSL_SESSION_new
# 	0 ('SSL_SESSION_new', 'libssl') 1.0
# ngx_http_fastcgi_create_request
# 	0 ('X509_NAME_oneline', 'libcrypto') 1.0
# ec_GFp_simple_group_get_curve
# 	0 ('ec_GFp_simple_group_get_curve', 'libcrypto') 1.0
# ssl3_record_sequence_update
# 	0 ('ssl3_record_sequence_update', 'libssl') 1.0
# PKCS7_add_certificate
# 	0 ('TS_RESP_CTX_set_certs', 'libcrypto') 1.0
# ASN1_d2i_fp
# 	0 ('ASN1_item_d2i_bio', 'libcrypto') 0.5
# 	1 ('ASN1_d2i_bio', 'libcrypto') 0.5
# X509_VERIFY_PARAM_lookup
# 	0 ('X509_VERIFY_PARAM_lookup', 'libcrypto') 1.0
# ssl_update_cache
# 	0 ('ssl_update_cache', 'libssl') 1.0
# do_revertframes.isra.42
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('ssl3_setup_read_buffer', 'libssl') 0.5
# ngx_http_block_reading
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# ASN1_UTCTIME_set
# 	0 ('ASN1_UTCTIME_set', 'libcrypto') 0.908256880733945
# 	1 ('ASN1_GENERALIZEDTIME_adj', 'libcrypto') 0.09174311926605506
# ec_GFp_simple_group_copy
# 	0 ('ec_GFp_simple_group_copy', 'libcrypto') 1.0
# rsa_item_sign
# 	0 ('rsa_item_sign', 'libcrypto') 1.0
# BN_mod_lshift1
# 	0 ('BN_nnmod', 'libcrypto') 0.5
# 	1 ('BN_reciprocal', 'libcrypto') 0.5
# BN_rshift1
# 	0 ('BN_rshift1', 'libcrypto') 1.0
# ssl3_renegotiate
# 	0 ('ssl3_renegotiate', 'libssl') 1.0
# CAST_cbc_encrypt
# 	0 ('CAST_cbc_encrypt', 'libcrypto') 1.0
# OBJ_cleanup
# 	0 ('OBJ_cleanup', 'libcrypto') 1.0
# ngx_create_temp_buf
# 	0 ('SSL_get_srtp_profiles', 'libssl') 1.0
# ssl3_get_cert_verify
# 	0 ('ssl3_get_cert_verify', 'libssl') 1.0
# PKCS7_get_smimecap
# 	0 ('PKCS7_get_smimecap', 'libcrypto') 1.0
# EVP_PKEY_free
# 	0 ('EVP_PKEY_free', 'libcrypto') 1.0
# ngx_array_create
# 	0 ('CRYPTO_free', 'libcrypto') 1.0
# ngx_http_v2_state_headers
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# OPENSSL_showfatal
# 	0 ('OPENSSL_showfatal', 'libcrypto') 1.0
# b64_free
# 	0 ('b64_free', 'libcrypto') 1.0
# ngx_reusable_connection
# 	0 ('dtls1_write_bytes', 'libssl') 1.0
# ERR_load_SSL_strings
# 	0 ('ERR_load_EC_strings', 'libcrypto') 0.03571428571428571
# 	1 ('ERR_load_ASN1_strings', 'libcrypto') 0.03571428571428571
# 	2 ('ERR_load_RSA_strings', 'libcrypto') 0.03571428571428571
# 	3 ('ERR_load_DSA_strings', 'libcrypto') 0.03571428571428571
# 	4 ('ERR_load_PKCS7_strings', 'libcrypto') 0.03571428571428571
# 	5 ('ERR_load_BUF_strings', 'libcrypto') 0.03571428571428571
# 	6 ('ERR_load_ECDH_strings', 'libcrypto') 0.03571428571428571
# 	7 ('ERR_load_DH_strings', 'libcrypto') 0.03571428571428571
# 	8 ('ERR_load_PEM_strings', 'libcrypto') 0.03571428571428571
# 	9 ('ERR_load_OBJ_strings', 'libcrypto') 0.03571428571428571
# 	10 ('ERR_load_DSO_strings', 'libcrypto') 0.03571428571428571
# 	11 ('ERR_load_CRYPTO_strings', 'libcrypto') 0.03571428571428571
# 	12 ('ERR_load_CONF_strings', 'libcrypto') 0.03571428571428571
# 	13 ('ERR_load_BN_strings', 'libcrypto') 0.03571428571428571
# 	14 ('ERR_load_ECDSA_strings', 'libcrypto') 0.03571428571428571
# 	15 ('ERR_load_EVP_strings', 'libcrypto') 0.03571428571428571
# 	16 ('ERR_load_OCSP_strings', 'libcrypto') 0.03571428571428571
# 	17 ('ERR_load_UI_strings', 'libcrypto') 0.03571428571428571
# 	18 ('ERR_load_ENGINE_strings', 'libcrypto') 0.03571428571428571
# 	19 ('ERR_load_STORE_strings', 'libcrypto') 0.03571428571428571
# 	20 ('ERR_load_CMS_strings', 'libcrypto') 0.03571428571428571
# 	21 ('ERR_load_PKCS12_strings', 'libcrypto') 0.03571428571428571
# 	22 ('ERR_load_TS_strings', 'libcrypto') 0.03571428571428571
# 	23 ('ERR_load_X509V3_strings', 'libcrypto') 0.03571428571428571
# 	24 ('ERR_load_RAND_strings', 'libcrypto') 0.03571428571428571
# 	25 ('ERR_load_BIO_strings', 'libcrypto') 0.03571428571428571
# 	26 ('ERR_load_X509_strings', 'libcrypto') 0.03571428571428571
# 	27 ('ERR_load_COMP_strings', 'libcrypto') 0.03571428571428571
# cca_rsa_sign
# 	0 ('cca_rsa_sign', 'libcrypto') 1.0
# ngx_http_process_request_headers
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# ngx_ssl_free_buffer
# 	0 ('dtls1_write_bytes', 'libssl') 1.0
# fast_forward_first_char2
# 	0 ('dh_private_print', 'libcrypto') 1.0
# engine_table_register
# 	0 ('engine_table_register', 'libcrypto') 1.0
# BUF_MEM_free
# 	0 ('BUF_MEM_free', 'libcrypto') 1.0
# file_ctrl
# 	0 ('file_ctrl', 'libcrypto') 1.0
# BN_RECP_CTX_free
# 	0 ('BN_RECP_CTX_free', 'libcrypto') 1.0
# pqueue_insert
# 	0 ('dtls1_buffer_record.isra.7.part.8', 'libssl') 0.2
# 	1 ('dtls1_buffer_record.isra.6.part.7', 'libssl') 0.2
# 	2 ('dtls1_buffer_record.isra.6', 'libssl') 0.2
# 	3 ('dtls1_buffer_record.isra.7', 'libssl') 0.2
# 	4 ('ssl3_setup_buffers', 'libssl') 0.2
# NCONF_free
# 	0 ('NCONF_free', 'libcrypto') 1.0
# DSA_generate_key
# 	0 ('DSA_generate_key', 'libcrypto') 1.0
# EC_POINT_set_affine_coordinates_GF2m
# 	0 ('EC_POINT_set_affine_coordinates_GF2m', 'libcrypto') 0.9899000100999898
# 	1 ('BN_CTX_new', 'libcrypto') 0.010099989900010105
# EC_KEY_set_public_key
# 	0 ('EC_KEY_set_public_key', 'libcrypto') 1.0
# RSA_padding_check_X931
# 	0 ('RSA_padding_check_X931', 'libcrypto') 1.0
# add_label_addr.isra.30
# 	0 ('ssl3_renegotiate', 'libssl') 0.3333333333333333
# 	1 ('ssl3_renegotiate_check', 'libssl') 0.3333333333333333
# 	2 ('ssl3_do_uncompress', 'libssl') 0.3333333333333333
# EVP_PKEY_size
# 	0 ('EVP_PKEY_size', 'libcrypto') 1.0
# CRYPTO_realloc
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# X509at_add1_attr_by_OBJ
# 	0 ('OCSP_cert_id_new', 'libcrypto') 0.2243835675489266
# 	1 ('UI_dup_input_boolean', 'libcrypto') 0.0910638848176567
# 	2 ('cms_EnvelopedData_init_bio', 'libcrypto') 0.0910638848176567
# 	3 ('ec_GFp_simple_make_affine', 'libcrypto') 0.0910638848176567
# 	4 ('TS_CONF_set_policies', 'libcrypto') 0.13902060522458834
# 	5 ('TS_CONF_set_digests', 'libcrypto') 0.13902060522458834
# 	6 ('X509v3_add_ext', 'libcrypto') 0.22438356754892663
# ASN1_BIT_STRING_set_bit
# 	0 ('ASN1_BIT_STRING_set_bit', 'libcrypto') 1.0
# ngx_escape_uri
# 	0 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 1.0
# sk_is_sorted
# 	0 ('sk_is_sorted', 'libcrypto') 0.9899000100999898
# 	1 ('sk_num', 'libcrypto') 0.010099989900010105
# ssl3_setup_read_buffer
# 	0 ('ssl3_setup_read_buffer', 'libssl') 1.0
# BIO_asn1_set_suffix
# 	0 ('BIO_asn1_set_suffix', 'libcrypto') 0.6449511400651466
# 	1 ('BIO_asn1_set_prefix', 'libcrypto') 0.35504885993485347
# aes_ccm_cipher
# 	0 ('aes_ccm_cipher', 'libcrypto') 1.0
# ssl3_write_bytes
# 	0 ('ssl3_write_bytes', 'libssl') 1.0
# bn_dup_expand
# 	0 ('X509V3_add1_i2d', 'libcrypto') 0.16666666666666666
# 	1 ('acpt_read', 'libcrypto') 0.16666666666666666
# 	2 ('BN_CTX_get', 'libcrypto') 0.16666666666666666
# 	3 ('c2i_ASN1_BIT_STRING', 'libcrypto') 0.16666666666666666
# 	4 ('acpt_puts', 'libcrypto') 0.16666666666666666
# 	5 ('acpt_write', 'libcrypto') 0.16666666666666666
# DES_ecb3_encrypt
# 	0 ('DES_ecb3_encrypt', 'libcrypto') 1.0
# ngx_close_connection
# 	0 ('ssl_get_prev_session', 'libssl') 1.0
# tree_find_sk
# 	0 ('tree_find_sk', 'libcrypto') 1.0
# ECDH_DATA_new_method.constprop.1
# 	0 ('SRP_gN_new_init', 'libcrypto') 1.0
# ec_GFp_simple_cmp
# 	0 ('ec_GFp_simple_cmp', 'libcrypto') 1.0
# _tr_align
# 	0 ('ssl3_renegotiate', 'libssl') 0.3333333333333333
# 	1 ('ssl3_renegotiate_check', 'libssl') 0.3333333333333333
# 	2 ('ssl3_setup_buffers', 'libssl') 0.3333333333333333
# EC_POINT_point2hex
# 	0 ('EC_POINT_point2hex', 'libcrypto') 1.0
# ngx_crc32_short
# 	0 ('ERR_put_error', 'libcrypto') 0.25
# 	1 ('BUF_MEM_free', 'libcrypto') 0.25
# 	2 ('CRYPTO_free', 'libcrypto') 0.25
# 	3 ('BUF_MEM_new', 'libcrypto') 0.25
# ngx_http_send_header
# 	0 ('ssl_init_wbio_buffer', 'libssl') 1.0
# dtls1_start_timer
# 	0 ('dtls1_write_bytes', 'libssl') 0.5
# 	1 ('dtls1_start_timer', 'libssl') 0.5
# dynamic_ctrl
# 	0 ('dynamic_ctrl', 'libcrypto') 1.0
# bn_c2i
# 	0 ('bn_c2i', 'libcrypto') 1.0
# aesni_xts_encrypt
# 	0 ('aesni_xts_encrypt', 'libcrypto') 1.0
# PEM_ASN1_read
# 	0 ('PEM_ASN1_read', 'libcrypto') 1.0
# ngx_http_dav_delete_path.isra.2
# 	0 ('ssl_get_prev_session', 'libssl') 0.5
# 	1 ('ssl_get_new_session', 'libssl') 0.5
# lh_doall
# 	0 ('lh_doall', 'libcrypto') 1.0
# ssl_set_cert
# 	0 ('ssl_set_pkey', 'libssl') 1.0
# pcre_study
# 	0 ('ssl3_write_bytes', 'libssl') 1.0
# ngx_http_ssl_handshake
# 	0 ('c2i_ASN1_OBJECT', 'libcrypto') 1.0
# check_wordboundary
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('ssl3_setup_read_buffer', 'libssl') 0.5
# BN_GF2m_mod_mul_arr
# 	0 ('BN_GF2m_mod_mul_arr', 'libcrypto') 1.0
# ngx_destroy_pool
# 	0 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 1.0
# ngx_http_script_full_name_code
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# i2d_ASN1_OBJECT
# 	0 ('i2d_ASN1_OBJECT', 'libcrypto') 1.0
# vpaes_cbc_encrypt
# 	0 ('vpaes_cbc_encrypt', 'libcrypto') 1.0
# ngx_ssl_certificate
# 	0 ('tls1_check_duplicate_extensions', 'libssl') 1.0
# pkey_ec_paramgen
# 	0 ('pkey_ec_paramgen', 'libcrypto') 1.0
# CAST_ofb64_encrypt
# 	0 ('DES_ofb64_encrypt', 'libcrypto') 1.0
# sljit_emit_fast_enter.constprop.57
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('ssl3_setup_read_buffer', 'libssl') 0.5
# ngx_http_discarded_request_body_handler
# 	0 ('bn_mul_mont_fixed_top', 'libcrypto') 0.8449612403100776
# 	1 ('BN_mod_mul_montgomery', 'libcrypto') 0.15503875968992245
# ECParameters_print
# 	0 ('ECParameters_print', 'libcrypto') 0.908256880733945
# 	1 ('DSAparams_print', 'libcrypto') 0.09174311926605506
# GENERAL_NAME_print
# 	0 ('GENERAL_NAME_print', 'libcrypto') 1.0
# cswift_mod_exp_dh
# 	0 ('cswift_mod_exp_dh', 'libcrypto') 0.5
# 	1 ('cswift_mod_exp_mont', 'libcrypto') 0.5
# engine_unlocked_init
# 	0 ('engine_unlocked_init', 'libcrypto') 1.0
# ERR_get_error_line_data
# 	0 ('ERR_get_error_line_data', 'libcrypto') 1.0
# RAND_poll
# 	0 ('RAND_poll', 'libcrypto') 1.0
# ASN1_OBJECT_create
# 	0 ('ASN1_OBJECT_create', 'libcrypto') 1.0
# EC_POINT_bn2point
# 	0 ('EC_POINT_bn2point', 'libcrypto') 1.0
# ngx_ext_rename_file
# 	0 ('EVP_CipherInit_ex', 'libcrypto') 1.0
# i2c_ASN1_BIT_STRING
# 	0 ('i2c_ASN1_BIT_STRING', 'libcrypto') 1.0
# ngx_ssl_get_serial_number
# 	0 ('CRYPTO_malloc', 'libcrypto') 0.5
# 	1 ('CRYPTO_realloc', 'libcrypto') 0.5
# EC_KEY_print_fp
# 	0 ('d2i_RSA_PUBKEY', 'libcrypto') 0.11834319526627218
# 	1 ('d2i_DSA_PUBKEY', 'libcrypto') 0.11834319526627218
# 	2 ('d2i_EC_PUBKEY', 'libcrypto') 0.11834319526627218
# 	3 ('CMS_final', 'libcrypto') 0.6449704142011834
# compile_regex
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# BN_div_word
# 	0 ('BN_div_word', 'libcrypto') 1.0
# dh_pub_decode
# 	0 ('dh_pub_decode', 'libcrypto') 1.0
# ngx_mail_auth_http
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# X509_NAME_add_entry_by_txt
# 	0 ('X509_add1_trust_object', 'libcrypto') 0.3551450781189871
# 	1 ('X509_add1_reject_object', 'libcrypto') 0.3551450781189871
# 	2 ('ASN1_TYPE_set1', 'libcrypto') 0.1448549218810129
# 	3 ('OBJ_create', 'libcrypto') 0.14485492188101284
# mime_hdr_new
# 	0 ('mime_hdr_new', 'libcrypto') 1.0
# emit_mov_byte
# 	0 ('BIO_gets', 'libcrypto') 1.0
# MD4_Update
# 	0 ('MD4_Update', 'libcrypto') 1.0
# ssl3_release_read_buffer
# 	0 ('ssl3_release_read_buffer', 'libssl') 1.0
# ngx_create_listening
# 	0 ('SHA1_Final', 'libcrypto') 1.0
# _pcre_is_newline
# 	0 ('SSL_get_srtp_profiles', 'libssl') 1.0
# SMIME_read_ASN1
# 	0 ('SMIME_read_ASN1', 'libcrypto') 1.0
# SSL_CTX_use_RSAPrivateKey_ASN1
# 	0 ('d2i_RSA_PUBKEY', 'libcrypto') 1.0
# ENGINE_register_all_RAND
# 	0 ('rc2_get_asn1_type_and_iv', 'libcrypto') 0.3333333333333333
# 	1 ('PKCS12_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# 	2 ('PKCS5_v2_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# ssl_check_serverhello_tlsext
# 	0 ('ssl_check_serverhello_tlsext', 'libssl') 1.0
# ngx_event_expire_timers
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# PKCS12_key_gen_asc
# 	0 ('PKCS12_key_gen_asc', 'libcrypto') 1.0
# X509V3_EXT_conf_nid
# 	0 ('X509V3_EXT_add_conf', 'libcrypto') 0.2361302154974782
# 	1 ('X509V3_EXT_REQ_add_conf', 'libcrypto') 0.15451627693718478
# 	2 ('X509V3_EXT_CRL_add_conf', 'libcrypto') 0.19532324621733146
# 	3 ('X509V3_EXT_conf_nid', 'libcrypto') 0.15451627693718478
# 	4 ('CONF_dump_bio', 'libcrypto') 0.07290233837689133
# 	5 ('CONF_free', 'libcrypto') 0.07290233837689133
# 	6 ('X509V3_EXT_conf', 'libcrypto') 0.11370930765703807
# atalla_mod_exp
# 	0 ('atalla_mod_exp', 'libcrypto') 1.0
# X509at_get_attr
# 	0 ('X509v3_get_ext', 'libcrypto') 0.08448207907679277
# 	1 ('X509at_delete_attr', 'libcrypto') 0.41412865462717474
# 	2 ('X509at_get_attr', 'libcrypto') 0.41412865462717474
# 	3 ('X509v3_delete_ext', 'libcrypto') 0.02129800312860322
# 	4 ('X509_NAME_get_entry', 'libcrypto') 0.06596260854025444
# PKCS5_v2_PBKDF2_keyivgen
# 	0 ('PKCS5_v2_PBKDF2_keyivgen', 'libcrypto') 1.0
# UI_ctrl
# 	0 ('UI_ctrl', 'libcrypto') 1.0
# aes_cfb1_cipher
# 	0 ('aes_cfb1_cipher', 'libcrypto') 0.5
# 	1 ('camellia_cfb1_cipher', 'libcrypto') 0.5
# obj_trust
# 	0 ('obj_trust', 'libcrypto') 1.0
# ngx_event_pipe_copy_input_filter
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# ngx_thread_task_post
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# SSL_CTX_use_certificate_file
# 	0 ('X509_load_crl_file', 'libcrypto') 0.25
# 	1 ('X509_load_cert_crl_file', 'libcrypto') 0.25
# 	2 ('X509_load_cert_file', 'libcrypto') 0.25
# 	3 ('PKCS7_decrypt', 'libcrypto') 0.25
# ngx_http_v2_state_save
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# ec_GFp_simple_dbl
# 	0 ('ec_GFp_simple_dbl', 'libcrypto') 1.0
# app_info_free
# 	0 ('app_info_free', 'libcrypto') 1.0
# ASN1_INTEGER_set
# 	0 ('ASN1_INTEGER_set', 'libcrypto') 1.0
# HMAC_Init
# 	0 ('HMAC_Init_ex', 'libcrypto') 1.0
# sljit_alloc_memory
# 	0 ('ssl3_renegotiate', 'libssl') 0.3333333333333333
# 	1 ('ssl3_renegotiate_check', 'libssl') 0.3333333333333333
# 	2 ('ssl3_do_uncompress', 'libssl') 0.3333333333333333
# ssl3_clear
# 	0 ('ssl3_clear', 'libssl') 1.0
# SXNET_add_id_ulong
# 	0 ('SXNET_add_id_ulong', 'libcrypto') 0.908256880733945
# 	1 ('SXNET_get_id_ulong', 'libcrypto') 0.09174311926605506
# ssl_sess_cert_new
# 	0 ('ssl_sess_cert_new', 'libssl') 1.0
# ngx_mail_core_listen
# 	0 ('str_copy', 'libcrypto') 1.0
# i2a_ASN1_STRING
# 	0 ('BIO_write', 'libcrypto') 1.0
# ngx_mail_smtp_greeting
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# BN_mod_exp_mont_word
# 	0 ('BN_mod_exp_mont_word', 'libcrypto') 1.0
# ngx_http_process_request_line
# 	0 ('asn1_ex_c2i', 'libcrypto') 1.0
# BN_CTX_start
# 	0 ('BN_CTX_start', 'libcrypto') 1.0
# tls1_process_heartbeat
# 	0 ('tls1_process_heartbeat', 'libssl') 1.0
# ngx_http_upstream_finalize_request
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# rc4_hmac_md5_ctrl
# 	0 ('rc4_hmac_md5_ctrl', 'libcrypto') 1.0
# tls1_ec_nid2curve_id
# 	0 ('tls1_ec_nid2curve_id', 'libssl') 1.0
# ngx_http_add_listen
# 	0 ('BN_div', 'libcrypto') 1.0
# dtls1_retransmit_message
# 	0 ('ssl3_do_write', 'libssl') 0.5
# 	1 ('tls1_heartbeat', 'libssl') 0.5
# ngx_init_modules
# 	0 ('tls1_save_sigalgs', 'libssl') 0.25
# 	1 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.25
# 	2 ('SSL_get_srtp_profiles', 'libssl') 0.25
# 	3 ('custom_ext_init', 'libssl') 0.25
# X509_STORE_load_locations
# 	0 ('X509_STORE_load_locations', 'libcrypto') 1.0
# atalla_dsa_mod_exp
# 	0 ('atalla_dsa_mod_exp', 'libcrypto') 1.0
# CMS_add0_RevocationInfoChoice
# 	0 ('ASN1_TYPE_get_int_octetstring', 'libcrypto') 1.0
# hwcrhk_load_pubkey
# 	0 ('hwcrhk_load_pubkey', 'libcrypto') 1.0
# EC_GROUP_copy
# 	0 ('d2i_PrivateKey', 'libcrypto') 1.0
# ssl23_read_bytes
# 	0 ('ssl23_read_bytes', 'libssl') 0.5
# 	1 ('ssl3_setup_buffers', 'libssl') 0.5
# ssl2_enc_init
# 	0 ('ssl2_enc_init', 'libssl') 1.0
# x509v3_cache_extensions.part.6
# 	0 ('x509v3_cache_extensions.part.6', 'libcrypto') 1.0
# RAND_add
# 	0 ('ssl3_send_alert', 'libssl') 0.25
# 	1 ('ssl3_init_finished_mac', 'libssl') 0.25
# 	2 ('ssl2_part_read', 'libssl') 0.25
# 	3 ('ssl_cipher_list_to_bytes', 'libssl') 0.25
# ec_GF2m_simple_add
# 	0 ('ec_GF2m_simple_add', 'libcrypto') 1.0
# eckey_pub_decode
# 	0 ('eckey_pub_decode', 'libcrypto') 1.0
# ssl_set_pkey
# 	0 ('ssl_set_pkey', 'libssl') 1.0
# ngx_time_update
# 	0 ('custom_ext_parse', 'libssl') 0.5
# 	1 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.5
# ngx_stream_proxy_next_upstream
# 	0 ('dtls1_client_hello', 'libssl') 1.0
# v2i_AUTHORITY_INFO_ACCESS
# 	0 ('v2i_AUTHORITY_INFO_ACCESS', 'libcrypto') 1.0
# aep_get_connection
# 	0 ('aep_get_connection', 'libcrypto') 1.0
# BN_set_bit
# 	0 ('EC_POINT_oct2point', 'libcrypto') 0.07751937984496124
# 	1 ('BN_set_bit', 'libcrypto') 0.7674418604651162
# 	2 ('EC_GROUP_new_curve_GFp', 'libcrypto') 0.07751937984496124
# 	3 ('CRYPTO_malloc', 'libcrypto') 0.07751937984496124
# gost_init
# 	0 ('sk_num', 'libcrypto') 1.0
# i2d_PKCS8PrivateKey_nid_fp
# 	0 ('i2d_PKCS8PrivateKey_fp', 'libcrypto') 0.2827154474417743
# 	1 ('i2d_PKCS8PrivateKey_nid_fp', 'libcrypto') 0.2153932405593183
# 	2 ('PEM_write_PKCS8PrivateKey_nid', 'libcrypto') 0.2191758645571331
# 	3 ('PEM_write_PKCS8PrivateKey', 'libcrypto') 0.2827154474417743
# X509_PKEY_new
# 	0 ('X509_PKEY_new', 'libcrypto') 1.0
# CRYPTO_get_ex_data_implementation
# 	0 ('ERR_get_implementation', 'libcrypto') 0.07751937984496125
# 	1 ('CRYPTO_get_mem_functions', 'libcrypto') 0.07751937984496125
# 	2 ('CRYPTO_get_ex_data_implementation', 'libcrypto') 0.7674418604651163
# 	3 ('CRYPTO_free', 'libcrypto') 0.07751937984496125
# ecdsa_check
# 	0 ('BN_clear_free', 'libcrypto') 0.5
# 	1 ('BN_mod_mul', 'libcrypto') 0.5
# X509_policy_check
# 	0 ('X509_policy_check', 'libcrypto') 1.0
# X509_NAME_add_entry
# 	0 ('X509_NAME_add_entry', 'libcrypto') 1.0
# ssl3_cbc_record_digest_supported
# 	0 ('ssl3_cbc_record_digest_supported', 'libssl') 1.0
# pub_decode_gost94
# 	0 ('ASN1_TIME_adj', 'libcrypto') 0.5
# 	1 ('SRP_Calc_x', 'libcrypto') 0.5
# ngx_output_chain_to_iovec
# 	0 ('ssl_cipher_list_to_bytes', 'libssl') 1.0
# dsa_cmp_parameters
# 	0 ('dh_pub_cmp', 'libcrypto') 0.5
# 	1 ('dsa_cmp_parameters', 'libcrypto') 0.5
# d2i_ASN1_OBJECT
# 	0 ('ASN1_template_d2i', 'libcrypto') 0.2
# 	1 ('d2i_ASN1_UINTEGER', 'libcrypto') 0.2
# 	2 ('d2i_ASN1_type_bytes', 'libcrypto') 0.2
# 	3 ('hwcrhk_load_privkey', 'libcrypto') 0.2
# 	4 ('ASN1_get_object', 'libcrypto') 0.2
# getbnfrombuf
# 	0 ('EVP_DigestFinal_ex', 'libcrypto') 1.0
# tls1_enc
# 	0 ('tls1_enc', 'libssl') 1.0
# UI_dup_verify_string
# 	0 ('UI_dup_verify_string', 'libcrypto') 1.0
# RSA_blinding_on
# 	0 ('RSA_setup_blinding', 'libcrypto') 1.0
# asn1_bio_write
# 	0 ('ok_write', 'libcrypto') 0.09174311926605506
# 	1 ('asn1_bio_write', 'libcrypto') 0.908256880733945
# CMS_RecipientInfo_ktri_get0_algs
# 	0 ('CMS_RecipientInfo_ktri_get0_algs', 'libcrypto') 1.0
# pkey_ec_sign
# 	0 ('pkey_ec_sign', 'libcrypto') 1.0
# EVP_CipherInit_ex
# 	0 ('EVP_CipherInit_ex', 'libcrypto') 1.0
# TXT_DB_create_index
# 	0 ('TXT_DB_create_index', 'libcrypto') 1.0
# ssl_cert_type
# 	0 ('ssl_cert_type', 'libssl') 1.0
# ngx_atotm
# 	0 ('BN_copy', 'libcrypto') 1.0
# BUF_strdup
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# PKCS5_PBKDF2_HMAC
# 	0 ('PKCS5_PBKDF2_HMAC', 'libcrypto') 1.0
# ngx_conf_include
# 	0 ('d2i_ASN1_bytes', 'libcrypto') 1.0
# sha256_block_data_order
# 	0 ('sha256_block_data_order', 'libcrypto') 1.0
# ssl3_send_certificate_request
# 	0 ('ssl3_send_certificate_request', 'libssl') 1.0
# dtls1_dispatch_alert
# 	0 ('dgram_read', 'libcrypto') 0.5
# 	1 ('BIO_get_accept_socket', 'libcrypto') 0.5
# X509_get_pubkey
# 	0 ('X509_get_pubkey', 'libcrypto') 1.0
# OBJ_NAME_get
# 	0 ('OBJ_NAME_get', 'libcrypto') 1.0
# EVP_MD_CTX_copy
# 	0 ('EVP_MD_CTX_copy_ex', 'libcrypto') 1.0
# emit_load_imm64
# 	0 ('ssl_verify_cert_chain', 'libssl') 1.0
# ngx_log_error_core
# 	0 ('ssl_add_clienthello_tlsext', 'libssl') 1.0
# _aesni_decrypt3
# 	0 ('_aesni_decrypt3', 'libcrypto') 1.0
# _aesni_decrypt4
# 	0 ('_aesni_decrypt4', 'libcrypto') 1.0
# EVP_PKEY_missing_parameters
# 	0 ('EVP_PKEY_missing_parameters', 'libcrypto') 1.0
# RAND_egd_bytes
# 	0 ('RAND_egd_bytes', 'libcrypto') 1.0
# ASN1_STRING_cmp
# 	0 ('ASN1_STRING_cmp', 'libcrypto') 1.0
# ASN1_i2d_fp
# 	0 ('i2a_ASN1_OBJECT', 'libcrypto') 1.0
# fill_GOST2001_params
# 	0 ('ec_GF2m_simple_group_check_discriminant', 'libcrypto') 1.0
# ssl_cert_new
# 	0 ('ENGINE_new', 'libcrypto') 0.08333333333333336
# 	1 ('ASN1_STRING_type_new', 'libcrypto') 0.08333333333333336
# 	2 ('ssl_cert_new', 'libssl') 0.08333333333333336
# 	3 ('CRYPTO_strdup', 'libcrypto') 0.08333333333333336
# 	4 ('BN_MONT_CTX_new', 'libcrypto') 0.08333333333333336
# 	5 ('b64_new', 'libcrypto') 0.08333333333333336
# 	6 ('BN_RECP_CTX_new', 'libcrypto') 0.08333333333333336
# 	7 ('SSL_get_ex_data_X509_STORE_CTX_idx', 'libssl') 0.08333333333333336
# 	8 ('CMAC_CTX_new', 'libcrypto') 0.08333333333333336
# 	9 ('EVP_CIPHER_CTX_new', 'libcrypto') 0.08333333333333336
# 	10 ('TS_VERIFY_CTX_new', 'libcrypto') 0.08333333333333336
# 	11 ('EVP_MD_CTX_create', 'libcrypto') 0.08333333333333336
# EC_POINT_clear_free
# 	0 ('EC_POINT_clear_free', 'libcrypto') 1.0
# EC_EX_DATA_free_data
# 	0 ('EC_EX_DATA_free_data', 'libcrypto') 1.0
# ngx_http_map_uri_to_path
# 	0 ('ssl_get_new_session', 'libssl') 1.0
# ngx_http_cache_send
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# X509_REQ_add_extensions_nid
# 	0 ('X509_REQ_add_extensions_nid', 'libcrypto') 1.0
# v2i_GENERAL_NAME_ex
# 	0 ('i2d_ECPrivateKey', 'libcrypto') 1.0
# X509_LOOKUP_ctrl
# 	0 ('X509_LOOKUP_ctrl', 'libcrypto') 1.0
# trust_1oid
# 	0 ('trust_1oid', 'libcrypto') 1.0
# EVP_EncryptFinal_ex
# 	0 ('EVP_EncryptFinal_ex', 'libcrypto') 0.5
# 	1 ('PEM_def_callback', 'libcrypto') 0.5
# ERR_load_ECDSA_strings
# 	0 ('ERR_load_EC_strings', 'libcrypto') 0.036369162192280396
# 	1 ('ERR_load_ASN1_strings', 'libcrypto') 0.036369162192280396
# 	2 ('ERR_load_RSA_strings', 'libcrypto') 0.036369162192280396
# 	3 ('ERR_load_DSA_strings', 'libcrypto') 0.036369162192280396
# 	4 ('ERR_load_PKCS7_strings', 'libcrypto') 0.036369162192280396
# 	5 ('ERR_load_BUF_strings', 'libcrypto') 0.036369162192280396
# 	6 ('ERR_load_ECDH_strings', 'libcrypto') 0.036369162192280396
# 	7 ('ERR_load_DH_strings', 'libcrypto') 0.036369162192280396
# 	8 ('ERR_load_PEM_strings', 'libcrypto') 0.036369162192280396
# 	9 ('ERR_load_OBJ_strings', 'libcrypto') 0.036369162192280396
# 	10 ('ERR_load_DSO_strings', 'libcrypto') 0.036369162192280396
# 	11 ('ERR_load_CRYPTO_strings', 'libcrypto') 0.036369162192280396
# 	12 ('ERR_load_CONF_strings', 'libcrypto') 0.036369162192280396
# 	13 ('ERR_load_BN_strings', 'libcrypto') 0.036369162192280396
# 	14 ('ERR_load_ECDSA_strings', 'libcrypto') 0.036369162192280396
# 	15 ('ERR_load_EVP_strings', 'libcrypto') 0.036369162192280396
# 	16 ('ERR_load_OCSP_strings', 'libcrypto') 0.04538547259649476
# 	17 ('ERR_load_UI_strings', 'libcrypto') 0.04538547259649476
# 	18 ('ERR_load_ENGINE_strings', 'libcrypto') 0.036369162192280396
# 	19 ('ERR_load_CMS_strings', 'libcrypto') 0.036369162192280396
# 	20 ('ERR_load_PKCS12_strings', 'libcrypto') 0.036369162192280396
# 	21 ('ERR_load_TS_strings', 'libcrypto') 0.036369162192280396
# 	22 ('ERR_load_X509V3_strings', 'libcrypto') 0.036369162192280396
# 	23 ('ERR_load_RAND_strings', 'libcrypto') 0.036369162192280396
# 	24 ('ERR_load_BIO_strings', 'libcrypto') 0.036369162192280396
# 	25 ('ERR_load_X509_strings', 'libcrypto') 0.036369162192280396
# 	26 ('ERR_load_COMP_strings', 'libcrypto') 0.036369162192280396
# EC_POINT_set_affine_coordinates_GFp
# 	0 ('EC_POINT_set_affine_coordinates_GFp', 'libcrypto') 1.0
# enc_write
# 	0 ('enc_write', 'libcrypto') 1.0
# OTHERNAME_cmp
# 	0 ('OTHERNAME_cmp', 'libcrypto') 1.0
# a2i_IPADDRESS_NC
# 	0 ('a2i_ipadd', 'libcrypto') 0.5
# 	1 ('a2i_IPADDRESS', 'libcrypto') 0.5
# lh_delete
# 	0 ('lh_delete', 'libcrypto') 1.0
# EC_POINT_new
# 	0 ('EC_POINT_new', 'libcrypto') 1.0
# OBJ_obj2nid
# 	0 ('BIO_puts', 'libcrypto') 1.0
# BN_BLINDING_new
# 	0 ('CRYPTO_dbg_malloc', 'libcrypto') 0.3333333333333333
# 	1 ('d2i_ECPrivateKey', 'libcrypto') 0.3333333333333333
# 	2 ('TS_REQ_to_TS_VERIFY_CTX', 'libcrypto') 0.3333333333333333
# dtls1_do_write
# 	0 ('dtls1_do_write', 'libssl') 1.0
# dh_priv_decode
# 	0 ('dh_priv_decode', 'libcrypto') 1.0
# ngx_http_upstream_upgraded_write_downstream
# 	0 ('sub_180080', 'libcrypto') 0.08936412424784515
# 	1 ('sub_181390', 'libcrypto') 0.08936412424784515
# 	2 ('sub_181240', 'libcrypto') 0.08936412424784515
# 	3 ('sub_180000', 'libcrypto') 0.08936412424784515
# 	4 ('sub_182b30', 'libcrypto') 0.08936412424784515
# 	5 ('sub_1800e0', 'libcrypto') 0.08936412424784515
# 	6 ('sub_180230', 'libcrypto') 0.08936412424784515
# 	7 ('str_copy', 'libcrypto') 0.016994633273703038
# 	8 ('sub_1802a0', 'libcrypto') 0.08936412424784515
# 	9 ('sub_182b00', 'libcrypto') 0.08936412424784515
# 	10 ('sub_180050', 'libcrypto') 0.08936412424784515
# 	11 ('sub_182c70', 'libcrypto') 0.08936412424784515
# ENGINE_add
# 	0 ('ENGINE_add', 'libcrypto') 1.0
# CRYPTO_gcm128_decrypt_ctr32
# 	0 ('CRYPTO_gcm128_decrypt_ctr32', 'libcrypto') 1.0
# OPENSSL_DIR_end
# 	0 ('EVP_PKEY_free', 'libcrypto') 1.0
# UI_set_result
# 	0 ('UI_set_result', 'libcrypto') 1.0
# ssl3_client_hello
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# do_casefulcmp.isra.43
# 	0 ('ssl3_init_finished_mac', 'libssl') 1.0
# is_counted_repeat.part.0
# 	0 ('tls1_save_sigalgs', 'libssl') 0.25
# 	1 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.25
# 	2 ('SSL_get_srtp_profiles', 'libssl') 0.25
# 	3 ('custom_ext_init', 'libssl') 0.25
# X509at_get0_data_by_OBJ
# 	0 ('internal_verify', 'libcrypto') 1.0
# BN_MONT_CTX_free
# 	0 ('BN_MONT_CTX_free', 'libcrypto') 1.0
# rc2_cfb64_cipher
# 	0 ('idea_cfb64_cipher', 'libcrypto') 0.17750997475775593
# 	1 ('rc2_cfb64_cipher', 'libcrypto') 0.8224900252422441
# HMAC_Final
# 	0 ('HMAC_Final', 'libcrypto') 1.0
# ENGINE_load_sureware
# 	0 ('ENGINE_load_sureware', 'libcrypto') 1.0
# ec_GF2m_simple_group_copy
# 	0 ('ec_GF2m_simple_group_copy', 'libcrypto') 1.0
# EVP_PKEY_asn1_free
# 	0 ('EVP_PKEY_asn1_free', 'libcrypto') 1.0
# RSA_padding_add_PKCS1_PSS_mgf1
# 	0 ('RSA_padding_add_PKCS1_PSS_mgf1', 'libcrypto') 1.0
# engine_pkey_meths_free
# 	0 ('engine_pkey_meths_free', 'libcrypto') 1.0
# aesni_cbc_hmac_sha1_cipher
# 	0 ('aesni_cbc_hmac_sha1_cipher', 'libcrypto') 1.0
# OCSP_resp_find
# 	0 ('OCSP_resp_find', 'libcrypto') 1.0
# ssl_prepare_serverhello_tlsext
# 	0 ('ssl_prepare_serverhello_tlsext', 'libssl') 1.0
# hwcrhk_finish
# 	0 ('hwcrhk_finish', 'libcrypto') 1.0
# ENGINE_register_all_pkey_asn1_meths
# 	0 ('BIO_free', 'libcrypto') 1.0
# bf_cfb64_cipher
# 	0 ('cast5_cfb64_cipher', 'libcrypto') 0.5
# 	1 ('bf_cfb64_cipher', 'libcrypto') 0.5
# SSL_do_handshake
# 	0 ('ASN1_STRING_free', 'libcrypto') 0.5
# 	1 ('CMS_RecipientInfo_ktri_get0_algs', 'libcrypto') 0.5
# EVP_Digest
# 	0 ('BN_MONT_CTX_set', 'libcrypto') 1.0
# X509V3_EXT_add_nconf_sk
# 	0 ('X509V3_EXT_add_nconf_sk', 'libcrypto') 1.0
# UI_get0_output_string
# 	0 ('UI_get0_output_string', 'libcrypto') 1.0
# param_copy_gost01
# 	0 ('OBJ_create', 'libcrypto') 1.0
# asn1_i2d_ex_primitive
# 	0 ('asn1_i2d_ex_primitive', 'libcrypto') 1.0
# EVP_DigestSignInit
# 	0 ('EVP_DigestSignInit', 'libcrypto') 1.0
# inflate
# 	0 ('mime_parse_hdr', 'libcrypto') 1.0
# rsa_sig_print
# 	0 ('rsa_sig_print', 'libcrypto') 1.0
# EC_POINT_free
# 	0 ('EC_POINT_free', 'libcrypto') 1.0
# CMS_add1_crl
# 	0 ('cms_set1_ias', 'libcrypto') 1.0
# compile_recurse
# 	0 ('ssl3_get_client_hello', 'libssl') 1.0
# ec_copy_parameters
# 	0 ('ec_copy_parameters', 'libcrypto') 1.0
# X509V3_parse_list
# 	0 ('X509V3_parse_list', 'libcrypto') 1.0
# dh_pub_cmp
# 	0 ('dh_pub_cmp', 'libcrypto') 0.908256880733945
# 	1 ('dsa_cmp_parameters', 'libcrypto') 0.09174311926605506
# X509_ATTRIBUTE_set1_data
# 	0 ('X509_ATTRIBUTE_set1_data', 'libcrypto') 1.0
# ASN1_template_d2i
# 	0 ('ASN1_template_d2i', 'libcrypto') 1.0
# ERR_unload_strings
# 	0 ('ERR_unload_strings', 'libcrypto') 1.0
# ssl3_get_cert_status
# 	0 ('ssl3_get_cert_status', 'libssl') 0.5
# 	1 ('ssl3_get_new_session_ticket', 'libssl') 0.5
# BN_ucmp
# 	0 ('BN_ucmp', 'libcrypto') 1.0
# EC_GROUP_set_seed
# 	0 ('EC_GROUP_set_seed', 'libcrypto') 1.0
# adjust_recurse.isra.5
# 	0 ('ssl_parse_clienthello_use_srtp_ext', 'libssl') 0.5
# 	1 ('SSL_get_srtp_profiles', 'libssl') 0.5
# CMAC_Init
# 	0 ('CMAC_Init', 'libcrypto') 1.0
# BIO_set_cipher
# 	0 ('BIO_set_cipher', 'libcrypto') 1.0
# ngx_mail_smtp_parse_command
# 	0 ('mime_parse_hdr', 'libcrypto') 1.0
# check_policy
# 	0 ('check_policy', 'libcrypto') 1.0
# ngx_start_cache_manager_processes
# 	0 ('ssl_parse_clienthello_use_srtp_ext', 'libssl') 0.5
# 	1 ('tls1_process_sigalgs', 'libssl') 0.5
# t_tob64
# 	0 ('t_tob64', 'libcrypto') 1.0
# BN_from_montgomery_word
# 	0 ('BN_from_montgomery_word', 'libcrypto') 1.0
# SSL_dup
# 	0 ('SSL_dup', 'libssl') 1.0
# RC4
# 	0 ('RC4', 'libcrypto') 1.0
# BN_mod_exp2_mont
# 	0 ('BN_mod_exp2_mont', 'libcrypto') 1.0
# def_load_bio
# 	0 ('def_load_bio', 'libcrypto') 1.0
# ngx_pool_cleanup_add
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('custom_ext_parse', 'libssl') 0.5
# ngx_calloc
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# dtls1_read_failed
# 	0 ('dtls1_read_failed', 'libssl') 1.0
# EVP_PKEY_asn1_add0
# 	0 ('EVP_PKEY_asn1_add0', 'libcrypto') 1.0
# X509V3_conf_free
# 	0 ('X509V3_conf_free', 'libcrypto') 0.908256880733945
# 	1 ('BIO_ACCEPT_free', 'libcrypto') 0.09174311926605506
# find_firstassertedchar
# 	0 ('ssl3_setup_write_buffer', 'libssl') 1.0
# surewarehk_rand_bytes
# 	0 ('surewarehk_rand_bytes', 'libcrypto') 1.0
# priv_decode_gost
# 	0 ('PKCS5_PBE_keyivgen', 'libcrypto') 1.0
# OBJ_find_sigid_algs
# 	0 ('OBJ_find_sigid_algs', 'libcrypto') 1.0
# X509_NAME_oneline
# 	0 ('X509_NAME_oneline', 'libcrypto') 1.0
# tls12_get_req_sig_algs
# 	0 ('tls12_get_req_sig_algs', 'libssl') 1.0
# DH_new
# 	0 ('DSA_new_method', 'libcrypto') 0.09174311926605506
# 	1 ('DH_new_method', 'libcrypto') 0.908256880733945
# BN_BLINDING_convert_ex
# 	0 ('BN_CTX_get', 'libcrypto') 1.0
# ngx_http_core_server_name
# 	0 ('dtls1_get_message_fragment', 'libssl') 1.0
# BN_mod_add
# 	0 ('BN_nnmod', 'libcrypto') 0.908256880733945
# 	1 ('BN_reciprocal', 'libcrypto') 0.09174311926605506
# bn_GF2m_mul_2x2
# 	0 ('bn_GF2m_mul_2x2', 'libcrypto') 1.0
# bn_sub_words
# 	0 ('bn_sub_words', 'libcrypto') 1.0
# ngx_resolver_send_query
# 	0 ('dtls1_get_record', 'libssl') 1.0
# X509V3_get_value_int
# 	0 ('s2i_ASN1_INTEGER', 'libcrypto') 1.0
# ubsec_finish
# 	0 ('cswift_finish', 'libcrypto') 0.3333333333333333
# 	1 ('atalla_finish', 'libcrypto') 0.3333333333333333
# 	2 ('nuron_finish', 'libcrypto') 0.3333333333333333
# BIO_read
# 	0 ('BIO_read', 'libcrypto') 1.0
# ngx_strncasecmp
# 	0 ('CRYPTO_free', 'libcrypto') 1.0
# detect_partial_match
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# old_hmac_decode
# 	0 ('EVP_PKEY_assign', 'libcrypto') 0.5
# 	1 ('RSA_blinding_on', 'libcrypto') 0.5
# ngx_ssl_session_ticket_key_callback
# 	0 ('rc2_get_asn1_type_and_iv', 'libcrypto') 0.3333333333333333
# 	1 ('PKCS12_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# 	2 ('PKCS5_v2_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# rsa_pub_print
# 	0 ('rsa_pub_print', 'libcrypto') 1.0
# RC2_ofb64_encrypt
# 	0 ('RC2_ofb64_encrypt', 'libcrypto') 0.9592874919627049
# 	1 ('idea_ofb64_encrypt', 'libcrypto') 0.019377587960058684
# 	2 ('BF_ofb64_encrypt', 'libcrypto') 0.010667460038618163
# 	3 ('CAST_ofb64_encrypt', 'libcrypto') 0.010667460038618163
# PKCS7_digest_from_attributes
# 	0 ('PKCS7_digest_from_attributes', 'libcrypto') 1.0
# ngx_http_script_file_code
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# ngx_http_upstream_rewrite_refresh
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# enc_read
# 	0 ('enc_read', 'libcrypto') 1.0
# aep_mod_exp_dh
# 	0 ('aep_mod_exp_mont', 'libcrypto') 0.3333333333333333
# 	1 ('aep_mod_exp_dsa', 'libcrypto') 0.3333333333333333
# 	2 ('aep_mod_exp_dh', 'libcrypto') 0.3333333333333333
# bn_mul_recursive.constprop.0
# 	0 ('bn_mul_recursive', 'libcrypto') 1.0
# ssl3_handshake_mac
# 	0 ('do_PVK_body.isra.3', 'libcrypto') 1.0
# ngx_master_process_exit
# 	0 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 1.0
# X509_PUBKEY_set
# 	0 ('OBJ_nid2sn', 'libcrypto') 0.5
# 	1 ('X509V3_EXT_get_nid', 'libcrypto') 0.5
# ngx_http_free_request
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# cryptopro_key_meshing
# 	0 ('SSL_CTX_remove_session', 'libssl') 1.0
# ngx_http_fastcgi_merge_loc_conf
# 	0 ('ssl_parse_serverhello_tlsext', 'libssl') 1.0
# ngx_http_file_cache_forced_expire
# 	0 ('dtls1_client_hello', 'libssl') 0.3333333333333333
# 	1 ('tls_construct_client_hello', 'libssl') 0.3333333333333333
# 	2 ('ssl3_client_hello', 'libssl') 0.3333333333333333
# ibm_4758_cca_finish
# 	0 ('cswift_finish', 'libcrypto') 0.33333333333333337
# 	1 ('atalla_finish', 'libcrypto') 0.33333333333333337
# 	2 ('nuron_finish', 'libcrypto') 0.33333333333333337
# CMS_add_smimecap
# 	0 ('CMS_add_smimecap', 'libcrypto') 1.0
# ngx_blocking
# 	0 ('ssl3_setup_buffers', 'libssl') 1.0
# ERR_load_COMP_strings
# 	0 ('ERR_load_EC_strings', 'libcrypto') 0.037037037037037056
# 	1 ('ERR_load_ASN1_strings', 'libcrypto') 0.037037037037037056
# 	2 ('ERR_load_RSA_strings', 'libcrypto') 0.037037037037037056
# 	3 ('ERR_load_DSA_strings', 'libcrypto') 0.037037037037037056
# 	4 ('ERR_load_PKCS7_strings', 'libcrypto') 0.037037037037037056
# 	5 ('ERR_load_BUF_strings', 'libcrypto') 0.037037037037037056
# 	6 ('ERR_load_ECDH_strings', 'libcrypto') 0.037037037037037056
# 	7 ('ERR_load_DH_strings', 'libcrypto') 0.037037037037037056
# 	8 ('ERR_load_PEM_strings', 'libcrypto') 0.037037037037037056
# 	9 ('ERR_load_OBJ_strings', 'libcrypto') 0.037037037037037056
# 	10 ('ERR_load_DSO_strings', 'libcrypto') 0.037037037037037056
# 	11 ('ERR_load_CRYPTO_strings', 'libcrypto') 0.037037037037037056
# 	12 ('ERR_load_CONF_strings', 'libcrypto') 0.037037037037037056
# 	13 ('ERR_load_BN_strings', 'libcrypto') 0.037037037037037056
# 	14 ('ERR_load_ECDSA_strings', 'libcrypto') 0.037037037037037056
# 	15 ('ERR_load_EVP_strings', 'libcrypto') 0.037037037037037056
# 	16 ('ERR_load_OCSP_strings', 'libcrypto') 0.037037037037037056
# 	17 ('ERR_load_UI_strings', 'libcrypto') 0.037037037037037056
# 	18 ('ERR_load_ENGINE_strings', 'libcrypto') 0.037037037037037056
# 	19 ('ERR_load_CMS_strings', 'libcrypto') 0.037037037037037056
# 	20 ('ERR_load_PKCS12_strings', 'libcrypto') 0.037037037037037056
# 	21 ('ERR_load_TS_strings', 'libcrypto') 0.037037037037037056
# 	22 ('ERR_load_X509V3_strings', 'libcrypto') 0.037037037037037056
# 	23 ('ERR_load_RAND_strings', 'libcrypto') 0.037037037037037056
# 	24 ('ERR_load_BIO_strings', 'libcrypto') 0.037037037037037056
# 	25 ('ERR_load_X509_strings', 'libcrypto') 0.037037037037037056
# 	26 ('ERR_load_COMP_strings', 'libcrypto') 0.037037037037037056
# ngx_conf_flush_files
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# RIPEMD160_Update
# 	0 ('RIPEMD160_Update', 'libcrypto') 0.5
# 	1 ('MD4_Update', 'libcrypto') 0.5
# ENGINE_load_rsax
# 	0 ('ENGINE_load_dynamic', 'libcrypto') 0.09174311926605506
# 	1 ('ENGINE_load_rsax', 'libcrypto') 0.908256880733945
# check_newlinechar
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# ngx_open_file_add_event
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# tls1_heartbeat
# 	0 ('tls1_heartbeat', 'libssl') 1.0
# ngx_ssl_remove_session
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# ngx_http_v2_header_filter
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# DSO_merge
# 	0 ('DSO_merge', 'libcrypto') 1.0
# dtls1_enc
# 	0 ('BN_bn2dec', 'libcrypto') 1.0
# ssl_create_cipher_list
# 	0 ('ssl_create_cipher_list', 'libssl') 1.0
# ngx_http_process_unique_header_line
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# BN_mod_exp_recp
# 	0 ('BN_mod_exp_recp', 'libcrypto') 1.0
# d2i_SSL_SESSION
# 	0 ('d2i_SSL_SESSION', 'libssl') 1.0
# cswift_rand_bytes
# 	0 ('c2i_ASN1_OBJECT', 'libcrypto') 0.0100999899000101
# 	1 ('hwcrhk_insert_card', 'libcrypto') 0.9899000100999898
# EVP_PKEY_get1_RSA
# 	0 ('EVP_PKEY_get1_RSA', 'libcrypto') 1.0
# ssl_free_wbio_buffer
# 	0 ('ssl_free_wbio_buffer', 'libssl') 1.0
# cca_rsa_verify
# 	0 ('cca_rsa_verify', 'libcrypto') 1.0
# EVP_PKEY_sign_init
# 	0 ('EVP_PKEY_sign_init', 'libcrypto') 1.0
# EC_GROUP_new_curve_GFp
# 	0 ('EC_GROUP_new_curve_GFp', 'libcrypto') 1.0
# bn_rand_range
# 	0 ('bn_rand_range', 'libcrypto') 1.0
# X509_NAME_print_ex
# 	0 ('X509_NAME_print_ex', 'libcrypto') 1.0
# SSL_set_wfd
# 	0 ('EVP_DigestInit_ex', 'libcrypto') 1.0
# EC_KEY_set_public_key_affine_coordinates
# 	0 ('EC_KEY_set_public_key_affine_coordinates', 'libcrypto') 1.0
# PKCS7_get_issuer_and_serial
# 	0 ('PKCS7_get_issuer_and_serial', 'libcrypto') 1.0
# PEM_bytes_read_bio
# 	0 ('PEM_bytes_read_bio', 'libcrypto') 1.0
# BN_asc2bn
# 	0 ('BN_asc2bn', 'libcrypto') 1.0
# bn_sub_part_words
# 	0 ('bn_sub_part_words', 'libcrypto') 1.0
# ngx_stream_upstream_init_least_conn
# 	0 ('tls1_set_server_sigalgs', 'libssl') 0.3333333333333333
# 	1 ('BN_GF2m_mod_inv_arr', 'libcrypto') 0.3333333333333333
# 	2 ('BN_GF2m_mod_div', 'libcrypto') 0.3333333333333333
# ENGINE_remove
# 	0 ('ENGINE_remove', 'libcrypto') 1.0
# get_cert_by_subject
# 	0 ('get_cert_by_subject', 'libcrypto') 1.0
# ec_GFp_simple_oct2point
# 	0 ('ec_GFp_simple_oct2point', 'libcrypto') 1.0
# ASN1_TYPE_get
# 	0 ('sk_num', 'libcrypto') 1.0
# ngx_http_v2_state_settings_params
# 	0 ('str_copy', 'libcrypto') 1.0
# ec_GFp_simple_point_get_affine_coordinates
# 	0 ('ec_GFp_simple_point_get_affine_coordinates', 'libcrypto') 1.0
# keyUnwrapCryptoPro
# 	0 ('ENGINE_set_default_string', 'libcrypto') 0.25
# 	1 ('ENGINE_init', 'libcrypto') 0.25
# 	2 ('NCONF_get_section', 'libcrypto') 0.25
# 	3 ('NCONF_get_number_e', 'libcrypto') 0.25
# DSA_free
# 	0 ('DSA_free', 'libcrypto') 1.0
# CRYPTO_xts128_encrypt
# 	0 ('CRYPTO_xts128_encrypt', 'libcrypto') 1.0
# X509_NAME_ENTRY_create_by_txt
# 	0 ('BN_exp', 'libcrypto') 0.5
# 	1 ('BN_BLINDING_create_param', 'libcrypto') 0.5
# inflateInit2_
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# _aesni_encrypt6
# 	0 ('_aesni_encrypt6', 'libcrypto') 1.0
# X509at_add1_attr
# 	0 ('X509at_add1_attr', 'libcrypto') 1.0
# ENGINE_register_all_DH
# 	0 ('rc2_get_asn1_type_and_iv', 'libcrypto') 0.3333333333333333
# 	1 ('PKCS12_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# 	2 ('PKCS5_v2_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# ASN1_INTEGER_get
# 	0 ('ASN1_INTEGER_get', 'libcrypto') 1.0
# ASN1_tag2bit
# 	0 ('ASN1_tag2bit', 'libcrypto') 1.0
# BIO_free_all
# 	0 ('PKCS7_ctrl', 'libcrypto') 0.3333333333333333
# 	1 ('EVP_PKEY_CTX_ctrl', 'libcrypto') 0.3333333333333333
# 	2 ('EVP_PKEY_encrypt', 'libcrypto') 0.3333333333333333
# X509_STORE_new
# 	0 ('X509_STORE_new', 'libcrypto') 1.0
# v2i_issuer_alt
# 	0 ('TS_RESP_create_response', 'libcrypto') 1.0
# compile_ref_matchingpath
# 	0 ('TS_RESP_verify_signature', 'libcrypto') 0.5
# 	1 ('check_crl', 'libcrypto') 0.5
# ngx_http_ssi_include
# 	0 ('ec_GFp_simple_points_make_affine', 'libcrypto') 1.0
# whirlpool_block
# 	0 ('whirlpool_block', 'libcrypto') 1.0
# ASN1_STRING_set_by_NID
# 	0 ('ASN1_STRING_to_UTF8', 'libcrypto') 0.09174311926605506
# 	1 ('ASN1_STRING_set_by_NID', 'libcrypto') 0.908256880733945
# OPENSSL_cpuid_setup
# 	0 ('OPENSSL_cpuid_setup', 'libcrypto') 1.0
# EVP_DigestSignFinal
# 	0 ('EVP_DigestSignFinal', 'libcrypto') 1.0
# i2r_PKEY_USAGE_PERIOD
# 	0 ('i2r_PKEY_USAGE_PERIOD', 'libcrypto') 1.0
# ngx_pfree
# 	0 ('tls1_save_sigalgs', 'libssl') 0.2
# 	1 ('ssl3_send_alert', 'libssl') 0.2
# 	2 ('custom_ext_parse', 'libssl') 0.2
# 	3 ('SSL_get_srtp_profiles', 'libssl') 0.2
# 	4 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.2
# dsa_pub_decode
# 	0 ('dsa_pub_decode', 'libcrypto') 1.0
# dlfcn_bind_var
# 	0 ('dlfcn_bind_var', 'libcrypto') 0.5
# 	1 ('dlfcn_bind_func', 'libcrypto') 0.5
# str_copy
# 	0 ('str_copy', 'libcrypto') 1.0
# ENGINE_register_all_ECDH
# 	0 ('rc2_get_asn1_type_and_iv', 'libcrypto') 0.3333333333333333
# 	1 ('PKCS12_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# 	2 ('PKCS5_v2_PBE_keyivgen', 'libcrypto') 0.3333333333333333
# EVP_MD_do_all
# 	0 ('EVP_CIPHER_do_all', 'libcrypto') 0.35504885993485347
# 	1 ('EVP_MD_do_all', 'libcrypto') 0.6449511400651466
# MDC2_Update
# 	0 ('MDC2_Update', 'libcrypto') 1.0
# RSA_padding_check_none
# 	0 ('RSA_padding_check_none', 'libcrypto') 1.0
# ngx_file_info_wrapper
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# EVP_DecryptFinal
# 	0 ('EVP_DecryptFinal_ex', 'libcrypto') 1.0
# X509V3_EXT_add_conf
# 	0 ('ocsp_match_issuerid', 'libcrypto') 1.0
# cms_ri_cb
# 	0 ('cms_ri_cb', 'libcrypto') 1.0
# EC_KEY_set_private_key
# 	0 ('EC_KEY_set_private_key', 'libcrypto') 1.0
# pub_encode_gost94
# 	0 ('CMS_dataInit', 'libcrypto') 1.0
# sljit_emit_op_flags.isra.22.part.23.constprop.59
# 	0 ('ssl3_setup_read_buffer', 'libssl') 1.0
# aesni_cbc_hmac_sha1_ctrl
# 	0 ('aesni_cbc_hmac_sha1_ctrl', 'libcrypto') 1.0
# CMS_add0_crl
# 	0 ('cms_set1_ias', 'libcrypto') 1.0
# ngx_log_stderr
# 	0 ('ssl3_send_alert', 'libssl') 0.25
# 	1 ('tls1_save_sigalgs', 'libssl') 0.25
# 	2 ('custom_ext_parse', 'libssl') 0.25
# 	3 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.25
# ssl2_connect
# 	0 ('ssl2_connect', 'libssl') 1.0
# ssl3_get_client_certificate
# 	0 ('ssl3_get_client_certificate', 'libssl') 1.0
# ngx_stream_core_merge_srv_conf
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# ngx_http_cleanup_add
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# BN_gcd
# 	0 ('BN_gcd', 'libcrypto') 1.0
# ngx_http_v2_idle_handler
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# ssl3_get_new_session_ticket
# 	0 ('ssl3_get_new_session_ticket', 'libssl') 1.0
# CRYPTO_dbg_malloc
# 	0 ('CRYPTO_dbg_malloc', 'libcrypto') 1.0
# compile_matchingpath
# 	0 ('ssl3_get_client_hello', 'libssl') 1.0
# AES_cbc_encrypt
# 	0 ('AES_cbc_encrypt', 'libcrypto') 1.0
# tls1_setup_key_block
# 	0 ('tls1_setup_key_block', 'libssl') 1.0
# seed_ecb_cipher
# 	0 ('seed_ecb_cipher', 'libcrypto') 1.0
# CRYPTO_ctr128_encrypt_ctr32
# 	0 ('CRYPTO_ctr128_encrypt_ctr32', 'libcrypto') 1.0
# X509_NAME_ENTRY_get_data
# 	0 ('X509_NAME_ENTRY_get_data', 'libcrypto') 1.0
# ngx_openat_file_owner
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# atalla_finish
# 	0 ('atalla_finish', 'libcrypto') 0.5
# 	1 ('nuron_finish', 'libcrypto') 0.5
# PKCS7_set_type
# 	0 ('PKCS7_set_type', 'libcrypto') 1.0
# oid_module_init
# 	0 ('oid_module_init', 'libcrypto') 1.0
# EC_POINT_invert
# 	0 ('EC_POINT_set_to_infinity', 'libcrypto') 0.004809542131589075
# 	1 ('EC_POINT_cmp', 'libcrypto') 0.04761446710273184
# 	2 ('BN_CTX_new', 'libcrypto') 0.004809542131589075
# 	3 ('EC_POINT_dbl', 'libcrypto') 0.47138322431704505
# 	4 ('EC_POINT_invert', 'libcrypto') 0.47138322431704505
# buffer_read
# 	0 ('buffer_read', 'libcrypto') 1.0
# dtls1_heartbeat
# 	0 ('dtls1_heartbeat', 'libssl') 1.0
# ngx_proxy_protocol_write
# 	0 ('ssl_fill_hello_random', 'libssl') 0.25
# 	1 ('SSL_get_ciphers', 'libssl') 0.25
# 	2 ('SSL_connect', 'libssl') 0.25
# 	3 ('ssl3_init_finished_mac', 'libssl') 0.25
# ASN1_TYPE_set
# 	0 ('ASN1_TYPE_set', 'libcrypto') 1.0
# ssl3_get_finished
# 	0 ('ssl3_get_finished', 'libssl') 0.3333333333333333
# 	1 ('SSL_clear', 'libssl') 0.3333333333333333
# 	2 ('ssl_init_wbio_buffer', 'libssl') 0.3333333333333333
# tls1_free
# 	0 ('ASN1_STRING_set0', 'libcrypto') 1.0
# dtls1_new
# 	0 ('DHparams_dup', 'libcrypto') 1.0
# cms_si_cb
# 	0 ('cms_si_cb', 'libcrypto') 1.0
# X509V3_EXT_d2i
# 	0 ('PKCS7_set_type', 'libcrypto') 0.5
# 	1 ('ASN1_INTEGER_set', 'libcrypto') 0.5
# CRYPTO_dbg_free
# 	0 ('EVP_CipherInit_ex', 'libcrypto') 0.5
# 	1 ('DH_check_pub_key', 'libcrypto') 0.5
# ngx_memalign
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# ENGINE_register_ciphers
# 	0 ('ENGINE_register_ciphers', 'libcrypto') 0.125
# 	1 ('ENGINE_register_pkey_asn1_meths', 'libcrypto') 0.125
# 	2 ('ENGINE_set_default_pkey_meths', 'libcrypto') 0.125
# 	3 ('ENGINE_set_default_pkey_asn1_meths', 'libcrypto') 0.125
# 	4 ('ENGINE_set_default_digests', 'libcrypto') 0.125
# 	5 ('ENGINE_register_pkey_meths', 'libcrypto') 0.125
# 	6 ('ENGINE_set_default_ciphers', 'libcrypto') 0.125
# 	7 ('ENGINE_register_digests', 'libcrypto') 0.125
# ibm_4758_load_pubkey
# 	0 ('ibm_4758_load_privkey', 'libcrypto') 0.5
# 	1 ('ibm_4758_load_pubkey', 'libcrypto') 0.5
# i2o_ECPublicKey
# 	0 ('i2o_ECPublicKey', 'libcrypto') 1.0
# is_anchored
# 	0 ('ssl3_read_n', 'libssl') 0.5
# 	1 ('SSL_CTX_remove_session', 'libssl') 0.5
# ASN1_item_ex_d2i
# 	0 ('ASN1_item_ex_d2i', 'libcrypto') 1.0
# X509_TRUST_add
# 	0 ('pkey_rsa_verifyrecover', 'libcrypto') 0.1
# 	1 ('v2i_AUTHORITY_KEYID', 'libcrypto') 0.1
# 	2 ('SRP_VBASE_get_by_user', 'libcrypto') 0.1
# 	3 ('dsa_do_verify', 'libcrypto') 0.1
# 	4 ('ASN1_UTCTIME_adj', 'libcrypto') 0.1
# 	5 ('ubsec_rsa_mod_exp', 'libcrypto') 0.1
# 	6 ('c2i_ASN1_OBJECT', 'libcrypto') 0.1
# 	7 ('hwcrhk_insert_card', 'libcrypto') 0.1
# 	8 ('engine_table_select', 'libcrypto') 0.1
# 	9 ('engine_table_register', 'libcrypto') 0.1
# ngx_http_variable_server_addr
# 	0 ('dtls1_dispatch_alert', 'libssl') 1.0
# ngx_http_upstream_process_downstream
# 	0 ('ssl3_do_write', 'libssl') 0.3333333333333333
# 	1 ('ssl3_write', 'libssl') 0.3333333333333333
# 	2 ('tls1_process_heartbeat', 'libssl') 0.3333333333333333
# DSA_SIG_new
# 	0 ('DSA_SIG_new', 'libcrypto') 1.0
# inflateReset
# 	0 ('dtls1_reset_seq_numbers', 'libssl') 0.2
# 	1 ('dtls1_handle_timeout', 'libssl') 0.2
# 	2 ('ssl3_renegotiate_check', 'libssl') 0.2
# 	3 ('dtls1_read_failed', 'libssl') 0.2
# 	4 ('ssl3_renegotiate', 'libssl') 0.2
# NCONF_get_string
# 	0 ('NCONF_get_string', 'libcrypto') 1.0
# ASN1_GENERALIZEDTIME_check
# 	0 ('ASN1_GENERALIZEDTIME_check', 'libcrypto') 1.0
# SSL_get_error
# 	0 ('BN_CTX_get', 'libcrypto') 1.0
# ngx_set_environment
# 	0 ('BN_div', 'libcrypto') 1.0
# pkey_dsa_sign
# 	0 ('pkey_dsa_sign', 'libcrypto') 1.0
# ngx_http_proxy_create_key
# 	0 ('X509_VERIFY_PARAM_inherit', 'libcrypto') 1.0
# X509_NAME_hash_old
# 	0 ('X509_NAME_hash_old', 'libcrypto') 1.0
# ngx_http_set_keepalive
# 	0 ('dtls1_do_write', 'libssl') 1.0
# aesni_set_encrypt_key
# 	0 ('aesni_set_encrypt_key', 'libcrypto') 1.0
# compile_simple_assertion_matchingpath
# 	0 ('RSA_check_key', 'libcrypto') 1.0
# BN_set_word
# 	0 ('BN_set_word', 'libcrypto') 1.0
# dsa_sign_setup
# 	0 ('dsa_sign_setup', 'libcrypto') 1.0
# CRYPTO_gcm128_setiv
# 	0 ('CRYPTO_gcm128_setiv', 'libcrypto') 1.0
# atalla_init
# 	0 ('aep_init', 'libcrypto') 0.5
# 	1 ('atalla_init', 'libcrypto') 0.5
# EC_POINT_is_at_infinity
# 	0 ('EC_POINT_is_at_infinity', 'libcrypto') 1.0
# ngx_event_process_init
# 	0 ('d2i_SSL_SESSION', 'libssl') 1.0
# get_encryption_params
# 	0 ('ENGINE_ctrl_cmd_string', 'libcrypto') 0.5
# 	1 ('ENGINE_by_id', 'libcrypto') 0.5
# engine_cleanup_add_first
# 	0 ('pkey_rsa_copy', 'libcrypto') 0.4579831932773109
# 	1 ('engine_cleanup_add_first', 'libcrypto') 0.08403361344537816
# 	2 ('pkey_ec_copy', 'libcrypto') 0.4579831932773109
# dynamic_load
# 	0 ('dynamic_load', 'libcrypto') 1.0
# pkey_GOST01cp_decrypt
# 	0 ('int_engine_module_init', 'libcrypto') 1.0
# UI_add_verify_string
# 	0 ('UI_add_input_string', 'libcrypto') 1.0
# ngx_http_referer_merge_conf
# 	0 ('ssl_parse_serverhello_tlsext', 'libssl') 1.0
# ngx_ssl_handshake
# 	0 ('rsa_pkey_ctrl', 'libcrypto') 1.0
# RSA_verify_ASN1_OCTET_STRING
# 	0 ('RSA_verify_ASN1_OCTET_STRING', 'libcrypto') 1.0
# d2i_ASN1_type_bytes
# 	0 ('d2i_ASN1_type_bytes', 'libcrypto') 1.0
# bn_gather5
# 	0 ('BN_num_bits', 'libcrypto') 0.1104575163398693
# 	1 ('BN_MONT_CTX_new', 'libcrypto') 0.11045751633986932
# 	2 ('CRYPTO_free', 'libcrypto') 0.11045751633986929
# 	3 ('bn_gather5', 'libcrypto') 0.16862745098039214
# 	4 ('bn_scatter5', 'libcrypto') 0.16862745098039214
# 	5 ('BN_set_word', 'libcrypto') 0.11045751633986928
# 	6 ('BN_is_bit_set', 'libcrypto') 0.11045751633986928
# 	7 ('BN_MONT_CTX_free', 'libcrypto') 0.11045751633986932
# X509_load_crl_file
# 	0 ('X509_load_crl_file', 'libcrypto') 0.908256880733945
# 	1 ('X509_load_cert_file', 'libcrypto') 0.09174311926605506
# ngx_event_accept
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# dtls1_listen
# 	0 ('BIO_nwrite0', 'libcrypto') 0.16666666666666666
# ...
# ngx_thread_mutex_destroy
# 	0 ('tls1_set_server_sigalgs', 'libssl') 1.0
# ssl2_write_error
# 	0 ('ssl2_write_error', 'libssl') 1.0
# ngx_hash_key_lc
# 	0 ('ASN1_STRING_free', 'libcrypto') 0.5
# 	1 ('CRYPTO_free', 'libcrypto') 0.5
# int_engine_module_init
# 	0 ('int_engine_module_init', 'libcrypto') 1.0
# compile_ref_iterator_matchingpath.isra.46
# 	0 ('ssl_get_prev_session', 'libssl') 1.0
# eckey_priv_decode
# 	0 ('eckey_priv_decode', 'libcrypto') 1.0
# ASN1_item_i2d_fp
# 	0 ('PKCS12_item_i2d_encrypt', 'libcrypto') 0.009707795359673817
# 	1 ('ASN1_i2d_bio', 'libcrypto') 0.951461023201631
# 	2 ('pkcs7_decrypt_rinfo', 'libcrypto') 0.009707795359673817
# 	3 ('X509_load_cert_crl_file', 'libcrypto') 0.009707795359673817
# 	4 ('PKCS7_encrypt', 'libcrypto') 0.009707795359673817
# 	5 ('CMS_SignerInfo_verify', 'libcrypto') 0.009707795359673817
# ec_GF2m_simple_cmp
# 	0 ('ec_GF2m_simple_cmp', 'libcrypto') 1.0
# dlfcn_load
# 	0 ('dlfcn_load', 'libcrypto') 1.0
# idea_ecb_cipher
# 	0 ('idea_ecb_cipher', 'libcrypto') 1.0
# DES_ofb64_encrypt
# 	0 ('DES_ofb64_encrypt', 'libcrypto') 0.5
# 	1 ('DES_ede3_ofb64_encrypt', 'libcrypto') 0.5
# EVP_PKEY_CTX_ctrl
# 	0 ('EVP_PKEY_CTX_ctrl', 'libcrypto') 1.0
# ngx_http_file_cache_create
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# pkey_rsa_verifyrecover
# 	0 ('pkey_rsa_verifyrecover', 'libcrypto') 1.0
# ngx_http_proxy_process_header
# 	0 ('ssl23_connect', 'libssl') 1.0
# SMIME_write_ASN1
# 	0 ('RSA_eay_private_decrypt', 'libcrypto') 1.0
# ssl3_dispatch_alert
# 	0 ('ssl3_dispatch_alert', 'libssl') 1.0
# tls12_get_sigandhash
# 	0 ('tls12_get_sigandhash', 'libssl') 1.0
# set_start_bits
# 	0 ('ssl3_write_pending', 'libssl') 0.3333333333333333
# 	1 ('ssl3_release_write_buffer', 'libssl') 0.3333333333333333
# 	2 ('ssl3_setup_write_buffer', 'libssl') 0.3333333333333333
# dh_param_decode
# 	0 ('old_ec_priv_decode', 'libcrypto') 1.0
# ngx_http_set_disable_symlinks
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# ngx_http_parse_unsafe_uri
# 	0 ('ssl_cipher_process_rulestr', 'libssl') 1.0
# ERR_load_BN_strings
# 	0 ('ERR_load_EC_strings', 'libcrypto') 0.02785515320334261
# 	1 ('ERR_load_ASN1_strings', 'libcrypto') 0.02785515320334261
# 	2 ('ERR_load_RSA_strings', 'libcrypto') 0.02785515320334261
# 	3 ('ERR_load_DSA_strings', 'libcrypto') 0.02785515320334261
# 	4 ('ERR_load_PKCS7_strings', 'libcrypto') 0.02785515320334261
# 	5 ('ERR_load_BUF_strings', 'libcrypto') 0.02785515320334261
# 	6 ('ERR_load_ECDH_strings', 'libcrypto') 0.02785515320334261
# 	7 ('ERR_load_DH_strings', 'libcrypto') 0.02785515320334261
# 	8 ('ERR_load_PEM_strings', 'libcrypto') 0.02785515320334261
# 	9 ('ERR_load_OBJ_strings', 'libcrypto') 0.02785515320334261
# 	10 ('ERR_load_DSO_strings', 'libcrypto') 0.02785515320334261
# 	11 ('ERR_load_CRYPTO_strings', 'libcrypto') 0.02785515320334261
# 	12 ('ERR_load_CONF_strings', 'libcrypto') 0.02785515320334261
# 	13 ('ERR_load_BN_strings', 'libcrypto') 0.27576601671309187
# 	14 ('ERR_load_ECDSA_strings', 'libcrypto') 0.02785515320334261
# 	15 ('ERR_load_EVP_strings', 'libcrypto') 0.02785515320334261
# 	16 ('ERR_load_OCSP_strings', 'libcrypto') 0.02785515320334261
# 	17 ('ERR_load_X509_strings', 'libcrypto') 0.02785515320334261
# 	18 ('ERR_load_ENGINE_strings', 'libcrypto') 0.02785515320334261
# 	19 ('ERR_load_UI_strings', 'libcrypto') 0.02785515320334261
# 	20 ('ERR_load_PKCS12_strings', 'libcrypto') 0.02785515320334261
# 	21 ('ERR_load_TS_strings', 'libcrypto') 0.02785515320334261
# 	22 ('ERR_load_X509V3_strings', 'libcrypto') 0.02785515320334261
# 	23 ('ERR_load_RAND_strings', 'libcrypto') 0.02785515320334261
# 	24 ('ERR_load_CMS_strings', 'libcrypto') 0.02785515320334261
# 	25 ('ERR_load_BIO_strings', 'libcrypto') 0.02785515320334261
# 	26 ('ERR_load_COMP_strings', 'libcrypto') 0.02785515320334261
# ngx_http_charset_body_filter
# 	0 ('ssl_add_clienthello_tlsext', 'libssl') 1.0
# ASN1_GENERALIZEDTIME_print
# 	0 ('ASN1_GENERALIZEDTIME_print', 'libcrypto') 1.0
# dsa_pub_print
# 	0 ('dsa_pub_print', 'libcrypto') 1.0
# BUF_MEM_grow
# 	0 ('BUF_MEM_grow', 'libcrypto') 1.0
# RAND_bytes
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# ngx_http_flv_handler
# 	0 ('ssl23_connect', 'libssl') 1.0
# d2i_PrivateKey
# 	0 ('d2i_PrivateKey', 'libcrypto') 1.0
# s2i_ASN1_OCTET_STRING
# 	0 ('s2i_ASN1_OCTET_STRING', 'libcrypto') 1.0
# ngx_process_events_and_timers
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# ssl3_change_cipher_state
# 	0 ('ASN1_sign', 'libcrypto') 1.0
# aes_ccm_ctrl
# 	0 ('aes_ccm_ctrl', 'libcrypto') 1.0
# ngx_shmtx_create
# 	0 ('custom_ext_init', 'libssl') 0.3333333333333333
# 	1 ('SSL_get_srtp_profiles', 'libssl') 0.3333333333333333
# 	2 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.3333333333333333
# write_string
# 	0 ('write_string', 'libcrypto') 1.0
# ASN1_INTEGER_cmp
# 	0 ('ASN1_INTEGER_cmp', 'libcrypto') 1.0
# d2i_PUBKEY
# 	0 ('d2i_PublicKey', 'libcrypto') 1.0
# ngx_pool_run_cleanup_file
# 	0 ('ssl_fill_hello_random', 'libssl') 0.3333333333333333
# 	1 ('SSL_connect', 'libssl') 0.3333333333333333
# 	2 ('ssl3_init_finished_mac', 'libssl') 0.3333333333333333
# OCSP_single_get0_status
# 	0 ('OCSP_single_get0_status', 'libcrypto') 1.0
# PKCS7_dataInit
# 	0 ('PKCS7_dataInit', 'libcrypto') 1.0
# sk_push
# 	0 ('ERR_put_error', 'libcrypto') 1.0
# SSL_use_RSAPrivateKey_file
# 	0 ('X509_load_crl_file', 'libcrypto') 0.125
# 	1 ('PKCS7_decrypt', 'libcrypto') 0.125
# 	2 ('eckey_pub_encode', 'libcrypto') 0.125
# 	3 ('EVP_PKEY_free', 'libcrypto') 0.125
# 	4 ('X509_load_cert_crl_file', 'libcrypto') 0.125
# 	5 ('EC_GROUP_check', 'libcrypto') 0.125
# 	6 ('RSA_generate_key', 'libcrypto') 0.125
# 	7 ('X509_load_cert_file', 'libcrypto') 0.125
# SSL_CTX_use_certificate
# 	0 ('SSL_CTX_use_certificate', 'libssl') 0.5
# 	1 ('SSL_use_certificate', 'libssl') 0.5
# ngx_http_dav_copy_move_handler.part.5
# 	0 ('ssl2_accept', 'libssl') 1.0
# deflate_stored
# 	0 ('ssl3_read_n', 'libssl') 1.0
# EC_GROUP_get_basis_type
# 	0 ('EC_GROUP_get_basis_type', 'libcrypto') 0.3333333333333333
# 	1 ('BN_free', 'libcrypto') 0.3333333333333333
# 	2 ('EC_POINT_point2bn', 'libcrypto') 0.3333333333333333
# int_dup_ex_data
# 	0 ('get_cert_by_subject', 'libcrypto') 1.0
# find_fixedlength
# 	0 ('ssl_parse_clienthello_use_srtp_ext', 'libssl') 0.5
# 	1 ('tls1_process_sigalgs', 'libssl') 0.5
# ERR_put_error
# 	0 ('ERR_put_error', 'libcrypto') 1.0
# bn_mul_low_normal
# 	0 ('bn_mul_low_normal', 'libcrypto') 1.0
# tls_decrypt_ticket
# 	0 ('tls_decrypt_ticket', 'libssl') 1.0
# dh_param_print
# 	0 ('dh_param_print', 'libcrypto') 0.5
# 	1 ('dh_public_print', 'libcrypto') 0.5
# ECPKParameters_print
# 	0 ('ECPKParameters_print', 'libcrypto') 1.0
# dsa_pkey_ctrl
# 	0 ('ec_pkey_ctrl', 'libcrypto') 0.5
# 	1 ('dsa_pkey_ctrl', 'libcrypto') 0.5
# ngx_http_file_cache_delete
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# set_reasons
# 	0 ('set_reasons', 'libcrypto') 1.0
# ngx_ssl_init
# 	0 ('ssl_parse_clienthello_use_srtp_ext', 'libssl') 0.25
# 	1 ('tls1_save_sigalgs', 'libssl') 0.25
# 	2 ('ssl3_send_alert', 'libssl') 0.25
# 	3 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.25
# ngx_mail_proxy_imap_handler
# 	0 ('ssl_bytes_to_cipher_list', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# gost94_param_decode
# 	0 ('OBJ_create', 'libcrypto') 1.0
# is_startline
# 	0 ('ssl3_read_n', 'libssl') 1.0
# ngx_mail_auth_http_init
# 	0 ('fmtint', 'libcrypto') 1.0
# Camellia_ecb_encrypt
# 	0 ('AES_ecb_encrypt', 'libcrypto') 0.5
# 	1 ('Camellia_ecb_encrypt', 'libcrypto') 0.5
# nuron_destroy
# 	0 ('ubsec_destroy', 'libcrypto') 0.2
# 	1 ('atalla_destroy', 'libcrypto') 0.2
# 	2 ('cswift_destroy', 'libcrypto') 0.2
# 	3 ('hwcrhk_destroy', 'libcrypto') 0.2
# 	4 ('nuron_destroy', 'libcrypto') 0.2
# rsa_pub_cmp
# 	0 ('dh_cmp_parameters', 'libcrypto') 0.010099989900010105
# 	1 ('rsa_pub_cmp', 'libcrypto') 0.9899000100999898
# ngx_stream_limit_conn_handler
# 	0 ('BN_div', 'libcrypto') 1.0
# dh_private_print
# 	0 ('dh_private_print', 'libcrypto') 0.9818032936038578
# 	1 ('dh_public_print', 'libcrypto') 0.018196706396142303
# EC_GROUP_set_generator
# 	0 ('EC_GROUP_set_generator', 'libcrypto') 1.0
# _CONF_new_data
# 	0 ('_CONF_new_data', 'libcrypto') 0.9899000100999898
# 	1 ('BUF_MEM_free', 'libcrypto') 0.010099989900010105
# BN_CTX_free
# 	0 ('BN_CTX_free', 'libcrypto') 1.0
# pcre_exec
# 	0 ('_dopr', 'libcrypto') 1.0
# ngx_http_gzip_ok
# 	0 ('mime_parse_hdr', 'libcrypto') 1.0
# ngx_cache_manager_process_cycle
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# md_ctrl
# 	0 ('md_ctrl', 'libcrypto') 1.0
# OBJ_obj2txt
# 	0 ('OBJ_obj2txt', 'libcrypto') 1.0
# ngx_event_pipe
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# X509_NAME_ENTRY_create_by_NID
# 	0 ('BN_exp', 'libcrypto') 0.5
# 	1 ('BN_BLINDING_create_param', 'libcrypto') 0.5
# ssl_check_clienthello_tlsext_late
# 	0 ('ssl_check_clienthello_tlsext_late', 'libssl') 1.0
# int_err_set_item
# 	0 ('int_thread_set_item', 'libcrypto') 0.908256880733945
# 	1 ('_CONF_new_section', 'libcrypto') 0.09174311926605506
# RSA_padding_add_none
# 	0 ('RSA_padding_add_none', 'libcrypto') 1.0
# cms_SignerIdentifier_cert_cmp
# 	0 ('cms_SignerIdentifier_cert_cmp', 'libcrypto') 1.0
# ngx_stream_upstream_add
# 	0 ('dtls1_client_hello', 'libssl') 1.0
# ngx_mail_pop3_init_session
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# sljit_emit_ijump
# 	0 ('ssl3_send_alert', 'libssl') 1.0
# EC_POINT_point2bn
# 	0 ('EC_POINT_point2bn', 'libcrypto') 1.0
# X509_NAME_print
# 	0 ('X509_NAME_print', 'libcrypto') 1.0
# X509at_add1_attr_by_NID
# 	0 ('v2i_POLICY_MAPPINGS', 'libcrypto') 0.1658548150702647
# 	1 ('PKCS7_get0_signers', 'libcrypto') 0.0987154065005604
# 	2 ('eckey_pub_encode', 'libcrypto') 0.23299422363996894
# 	3 ('X509v3_add_ext', 'libcrypto') 0.251217777394603
# 	4 ('OCSP_cert_id_new', 'libcrypto') 0.25121777739460294
# ssl3_get_server_done
# 	0 ('ssl3_get_server_done', 'libssl') 1.0
# ngx_http_upstream_get_keepalive_peer
# 	0 ('ssl3_client_hello', 'libssl') 1.0
# ngx_http_empty_gif_handler
# 	0 ('ssl3_do_write', 'libssl') 0.3333333333333333
# 	1 ('tls1_heartbeat', 'libssl') 0.3333333333333333
# 	2 ('ssl3_write', 'libssl') 0.3333333333333333
# ngx_http_upstream_upgraded_write_upstream
# 	0 ('sub_180080', 'libcrypto') 0.08333333333333336
# 	1 ('sub_181390', 'libcrypto') 0.08333333333333336
# 	2 ('sub_181240', 'libcrypto') 0.08333333333333336
# 	3 ('sub_180000', 'libcrypto') 0.08333333333333336
# 	4 ('sub_182b30', 'libcrypto') 0.08333333333333336
# 	5 ('sub_1800e0', 'libcrypto') 0.08333333333333336
# 	6 ('sub_180230', 'libcrypto') 0.08333333333333336
# 	7 ('str_copy', 'libcrypto') 0.08333333333333336
# 	8 ('sub_1802a0', 'libcrypto') 0.08333333333333336
# 	9 ('sub_182b00', 'libcrypto') 0.08333333333333336
# 	10 ('sub_180050', 'libcrypto') 0.08333333333333336
# 	11 ('sub_182c70', 'libcrypto') 0.08333333333333336
# ngx_http_fastcgi_path_info_variable
# 	0 ('tls_construct_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# ASN1_PRINTABLE_type
# 	0 ('ASN1_PRINTABLE_type', 'libcrypto') 1.0
# _pcre_find_bracket
# 	0 ('tls1_save_sigalgs', 'libssl') 0.25
# 	1 ('ssl_parse_clienthello_renegotiate_ext', 'libssl') 0.25
# 	2 ('SSL_get_srtp_profiles', 'libssl') 0.25
# 	3 ('custom_ext_init', 'libssl') 0.25
# ENGINE_load_public_key
# 	0 ('ENGINE_load_private_key', 'libcrypto') 0.5
# 	1 ('ENGINE_load_public_key', 'libcrypto') 0.5
# bn_expand_internal
# 	0 ('bn_expand_internal', 'libcrypto') 1.0
# aes_gcm_cleanup
# 	0 ('aes_gcm_cleanup', 'libcrypto') 1.0
# EVP_SignFinal
# 	0 ('EVP_SignFinal', 'libcrypto') 1.0
# d2i_AutoPrivateKey
# 	0 ('d2i_PrivateKey', 'libcrypto') 1.0
# policy_cache_find_data
# 	0 ('policy_cache_find_data', 'libcrypto') 1.0
# OCSP_REQUEST_print
# 	0 ('OCSP_REQUEST_print', 'libcrypto') 1.0
# ENGINE_set_default_ciphers
# 	0 ('ENGINE_set_default_pkey_meths', 'libcrypto') 0.25
# 	1 ('ENGINE_set_default_pkey_asn1_meths', 'libcrypto') 0.25
# 	2 ('ENGINE_set_default_ciphers', 'libcrypto') 0.25
# 	3 ('ENGINE_set_default_digests', 'libcrypto') 0.25
# get_issuer_sk
# 	0 ('get_issuer_sk', 'libcrypto') 1.0
# ngx_tcp_connect
# 	0 ('ssl23_connect', 'libssl') 1.0
# PEM_read_DSAPrivateKey
# 	0 ('PEM_read_DSAPrivateKey', 'libcrypto') 1.0
# ngx_http_core_listen
# 	0 ('BN_mod_exp_mont_consttime', 'libcrypto') 1.0
# ngx_http_upstream_resolve_handler
# 	0 ('tls_process_server_hello', 'libssl') 0.3333333333333333
# 	1 ('dtls1_client_hello', 'libssl') 0.3333333333333333
# 	2 ('ssl3_client_hello', 'libssl') 0.3333333333333333
# ENGINE_free
# 	0 ('ENGINE_set_default_string', 'libcrypto') 0.3333333333333333
# 	1 ('NCONF_get_section', 'libcrypto') 0.3333333333333333
# 	2 ('NCONF_get_number_e', 'libcrypto') 0.3333333333333333
# eckey_priv_encode
# 	0 ('eckey_priv_encode', 'libcrypto') 1.0
# ngx_array_push_n
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# ibm_4758_load_privkey
# 	0 ('ibm_4758_load_privkey', 'libcrypto') 1.0
# c2i_ASN1_BIT_STRING
# 	0 ('c2i_ASN1_BIT_STRING', 'libcrypto') 1.0
# ENGINE_register_pkey_asn1_meths
# 	0 ('ENGINE_register_ciphers', 'libcrypto') 0.125
# 	1 ('ENGINE_register_pkey_asn1_meths', 'libcrypto') 0.125
# 	2 ('ENGINE_set_default_pkey_meths', 'libcrypto') 0.125
# 	3 ('ENGINE_set_default_pkey_asn1_meths', 'libcrypto') 0.125
# 	4 ('ENGINE_set_default_digests', 'libcrypto') 0.125
# 	5 ('ENGINE_register_pkey_meths', 'libcrypto') 0.125
# 	6 ('ENGINE_set_default_ciphers', 'libcrypto') 0.125
# 	7 ('ENGINE_register_digests', 'libcrypto') 0.125
# sxnet_i2r
# 	0 ('sxnet_i2r', 'libcrypto') 1.0
# ngx_http_proxy_input_filter_init
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# ngx_list_push
# 	0 ('ERR_put_error', 'libcrypto') 1.0
# ssl3_free_digest_list
# 	0 ('ssl3_free_digest_list', 'libssl') 1.0
# X509V3_EXT_REQ_add_nconf
# 	0 ('print_qualifiers', 'libcrypto') 0.5
# 	1 ('ocsp_match_issuerid', 'libcrypto') 0.5
# RSA_sign
# 	0 ('RSA_sign', 'libcrypto') 1.0
# CONF_modules_free
# 	0 ('CONF_modules_finish', 'libcrypto') 1.0
# PKCS12_key_gen_uni
# 	0 ('PKCS12_key_gen_uni', 'libcrypto') 1.0
# ngx_http_proxy_create_request
# 	0 ('aesni_cbc_hmac_sha256_cipher', 'libcrypto') 1.0
# ngx_http_request_handler
# 	0 ('dtls1_client_hello', 'libssl') 0.5
# 	1 ('ssl3_client_hello', 'libssl') 0.5
# X509_NAME_ENTRY_set_data
# 	0 ('X509_NAME_ENTRY_set_data', 'libcrypto') 1.0
# BIO_find_type
# 	0 ('BIO_find_type', 'libcrypto') 1.0
# ubsec_dsa_verify
# 	0 ('surewarehk_rsa_priv_dec', 'libcrypto') 1.0
# witness
# 	0 ('BN_copy', 'libcrypto') 1.0
# EVP_CIPHER_CTX_set_key_length
# 	0 ('CRYPTO_malloc', 'libcrypto') 1.0
# keyWrapCryptoPro
# 	0 ('EVP_CIPHER_param_to_asn1', 'libcrypto') 0.5
# 	1 ('EVP_CIPHER_asn1_to_param', 'libcrypto') 0.5
# ngx_http_log_compile_format.isra.4
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# PKCS7_signatureVerify
# 	0 ('PKCS7_signatureVerify', 'libcrypto') 1.0
# OBJ_bsearch_ex_
# 	0 ('OBJ_bsearch_ex_', 'libcrypto') 1.0
# multi_split
# 	0 ('multi_split', 'libcrypto') 1.0
# i2d_PKCS8PrivateKeyInfo_fp
# 	0 ('i2d_PKCS8PrivateKeyInfo_fp', 'libcrypto') 0.5
# 	1 ('i2d_PKCS8PrivateKeyInfo_bio', 'libcrypto') 0.5
# EC_GROUP_set_curve_GF2m
# 	0 ('EC_GROUP_set_curve_GF2m', 'libcrypto') 1.0
# EC_KEY_insert_key_method_data
# 	0 ('EC_KEY_insert_key_method_data', 'libcrypto') 1.0
# ngx_http_upstream_add
# 	0 ('ssl_parse_serverhello_tlsext', 'libssl') 1.0
# GENERAL_NAME_cmp
# 	0 ('crl_extension_match', 'libcrypto') 0.07194244604316549
# 	1 ('GENERAL_NAME_cmp', 'libcrypto') 0.7122302158273381
# 	2 ('X509_cmp_time', 'libcrypto') 0.07194244604316549
# 	3 ('X509_check_akid', 'libcrypto') 0.07194244604316549
# 	4 ('X509_NAME_cmp', 'libcrypto') 0.07194244604316549
# EC_POINT_point2oct
# 	0 ('EC_POINT_point2oct', 'libcrypto') 1.0
# ngx_http_upstream_hide_headers_hash
# 	0 ('ssl_parse_serverhello_use_srtp_ext', 'libssl') 0.5
# 	1 ('tls1_check_duplicate_extensions', 'libssl') 0.5
# EVP_DecodeBlock
# 	0 ('EVP_DecodeBlock', 'libcrypto') 1.0
# ngx_slprintf
# 	0 ('ssl_add_clienthello_renegotiate_ext', 'libssl') 0.5
# 	1 ('ssl_add_clienthello_use_srtp_ext', 'libssl') 0.5
# SXNET_get_id_INTEGER
# 	0 ('SXNET_get_id_INTEGER', 'libcrypto') 1.0
# OCSP_cert_status_str
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('dtls1_set_message_header', 'libssl') 0.5
# ngx_init_cycle
# 	0 ('ssl_parse_clienthello_tlsext', 'libssl') 1.0
# check_hspace.isra.27
# 	0 ('ssl3_init_finished_mac', 'libssl') 1.0
# X509_signature_print
# 	0 ('EVP_PKEY_free', 'libcrypto') 0.5
# 	1 ('X509V3_extensions_print', 'libcrypto') 0.5
# ngx_conf_merge_path_value
# 	0 ('ssl3_send_alert', 'libssl') 0.5
# 	1 ('custom_ext_parse', 'libssl') 0.5
# NCONF_dump_fp
# 	0 ('BIO_new_connect', 'libcrypto') 0.3333333333333333
# 	1 ('BIO_new_accept', 'libcrypto') 0.3333333333333333
# 	2 ('def_load', 'libcrypto') 0.3333333333333333
# DSO_new
# 	0 ('DSO_bind_func', 'libcrypto') 1.0

# %%
count=0
total=0
for i, (testname, size) in enumerate(name_test):
    if testname in nam_crypto_dict and name_test[i+1][0] in nam_crypto_dict:
        total += 1
        #print nam_crypto_dict[testname], nam_crypto_dict[name_test[i+1][0]]
        if nam_crypto_dict[testname] - nam_crypto_dict[name_test[i+1][0]] > -3 and nam_crypto_dict[testname] - nam_crypto_dict[name_test[i+1][0]] < 0:
            count += 1
    if testname in nam_ssl_dict and name_test[i+1][0] in nam_ssl_dict:
        total += 1
        #print nam_ssl_dict[testname], nam_ssl_dict[name_test[i+1][0]]
        if nam_ssl_dict[testname] - nam_ssl_dict[name_test[i+1][0]] > -3 and nam_ssl_dict[testname] - nam_ssl_dict[name_test[i+1][0]] < 0:
            count += 1
    if i+2 == len(name_test):
        break
print count, total
# Out:
# 3764 4584
