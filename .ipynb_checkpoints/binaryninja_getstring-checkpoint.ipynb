# %%
import binaryninja as binja
import glob
from collections import defaultdict
import mongowrapper.MongoWrapper as mdb
import os
import pdb
import numpy as np
import pickle as p
import factorgraph as fg

# %%
def build_string_table(bv, db = None):
    addr = []
    string_dict = defaultdict(list)
    for key in bv.sections.keys():
        if 'rodata' in key:
            start = bv.sections[key].start
            end = bv.sections[key].end
            for string in bv.get_strings(start, end):
                addr.append(string.start)
    if addr == []:
        for string in bv.get_strings():
            addr.append(string.start)
    
    for func in bv.functions:
        
        string_list = []
        for block in func.low_level_il.basic_blocks:
            for instr in block:
                for oper in instr.operands:
                    if isinstance(oper, binja.LowLevelILInstruction):
                        if oper.operation == binja.LowLevelILOperation.LLIL_CONST_PTR or oper.operation == binja.LowLevelILOperation.LLIL_CONST:
                            if int(str(oper), 16) in addr:
                                string_list.append(bv.get_string_at(int(str(oper), 16)).value)
                
        if len(string_list) > 0:
            string_list_strip = list(set(string_list))
            my_dict = {"name": func.name, "strings": string_list_strip}
            string_dict[func.name] = string_list_strip
            if db is not None:
                db.save(my_dict)
    return string_dict

# %%
#string_table = build_string_table(binaryview)
p.dump(string_table, open('string_dict.p','wb'))

# %%
binaryview.get_string_at(9871340)
# Out:
# <StringType.AsciiString: 0x969fc7, len 0xb9>

# %%
# libraryName = 'libcrypto'
# db = mdb('oss', libraryName + '_stringtable')
# global path_lib
#path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl/'
# path_lib = '/home/yijiufly/Downloads/codesearch/data/zlib/zlib-O2/'
# for folder in os.listdir(path_lib):
#     folder = 'zlib_1_2_11'
#     print folder
#     bv = binja.BinaryViewType.get_view_of_file(path_lib + folder + '/libz.so')
#     build_string_table(bv, db)
#     break
libraryName = 'library'
db = mdb('oss', libraryName + '_stringtable')

# %%
def loadFiles(PATH, ext=None):  # use .ida or .emb for ida file and embedding file
    filenames = []
    filenames = [PATH + f for f in os.listdir(PATH) if f.endswith(ext)]
    return filenames
libraryName = 'library'
mongodb = mdb('oss', libraryName + '_stringtable')
global path_lib
path_lib = '/home/yijiufly/Downloads/codesearch/data/openssl/openssl-1.0.1d/objfiles-libcrypto/'
#path_lib = '/home/yijiufly/Downloads/codesearch/data/zlib/zlib-O2/'
stringfiles = loadFiles(path_lib, ext='.str')
stringfiles.extend(loadFiles('/home/yijiufly/Downloads/codesearch/data/openssl/openssl-1.0.1d/objfiles-libssl/', ext='.str'))
stringfiles.extend(loadFiles('/home/yijiufly/Downloads/codesearch/data/zlib/zlib-O2/zlib-1.2.11/objfiles/', ext='.str'))
globalstring_dict = defaultdict(list)
for s in stringfiles:
    string_dict = p.load(open(s, 'rb'))
    for key in string_dict.keys():
        my_dict = {"name": key, "strings": string_dict[key]}
        globalstring_dict[key] = string_dict[key]
        print my_dict
        mongodb.save(my_dict)
# Out:
# {'name': u'mdc2_body', 'strings': [u'WAVAUATUSH']}
# {'name': u'MDC2_Final', 'strings': [u'WAVAUATUSH']}
# {'name': u'MDC2_Init', 'strings': [u'WAVAUATUSH']}
# {'name': u'MDC2_Update', 'strings': [u'WAVAUATUSH']}
# {'name': u'OPENSSL_config', 'strings': [u'Auto configuration failed\n']}
# {'name': u'DES_ofb64_encrypt', 'strings': [u'WAVI']}
# {'name': u'CRYPTO_cfb128_1_encrypt', 'strings': [u'WAVI']}
# {'name': u'a2i_ASN1_INTEGER', 'strings': [u'f_int.c']}
# {'name': u'hash_block', 'strings': [u'WAVI']}
# {'name': u'finish_hash', 'strings': [u'WAVI']}
# {'name': u'hash_step', 'strings': [u'WAVI']}
# {'name': u'init_gost_hash_ctx', 'strings': [u'WAVI']}
# {'name': u'start_hash', 'strings': [u'WAVI']}
# {'name': u'int_ctrl_helper.isra.1', 'strings': [u'eng_ctrl.c']}
# {'name': u'ENGINE_ctrl', 'strings': [u'eng_ctrl.c']}
# {'name': u'ENGINE_ctrl_cmd', 'strings': [u'eng_ctrl.c']}
# {'name': u'ENGINE_cmd_is_executable', 'strings': [u'eng_ctrl.c']}
# {'name': u'ENGINE_ctrl_cmd_string', 'strings': [u'eng_ctrl.c']}
# {'name': u'FIPS_mode_set', 'strings': [u'o_fips.c']}
# {'name': u'sk_push', 'strings': [u'stack.c']}
# {'name': u'sk_new_null', 'strings': [u'stack.c']}
# {'name': u'sk_dup', 'strings': [u'stack.c']}
# {'name': u'sk_unshift', 'strings': [u'stack.c']}
# {'name': u'sk_insert', 'strings': [u'stack.c']}
# {'name': u'sk_new', 'strings': [u'stack.c']}
# {'name': u'PEM_read_X509', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_write_bio_X509', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_write_X509', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_read_bio_X509', 'strings': [u'CERTIFICATE']}
# {'name': u'sha1_block_data_order', 'strings': [u'SUATH']}
# {'name': u'NETSCAPE_SPKI_print', 'strings': [u'UNKNOWN', u'  Unable to load public key\n', u'\n      ', u'%02x%s', u'  Challenge String: %s\n', u'Netscape SPKI:\n', u'  Public Key Algorithm: %s\n', u'  Signature Algorithm: %s']}
# {'name': u'DH_new', 'strings': [u'dh_lib.c']}
# {'name': u'DH_free', 'strings': [u'dh_lib.c']}
# {'name': u'DH_up_ref', 'strings': [u'dh_lib.c']}
# {'name': u'DH_new_method', 'strings': [u'dh_lib.c']}
# {'name': u'X509_get_default_cert_dir_env', 'strings': [u'SSL_CERT_DIR']}
# {'name': u'X509_get_default_cert_area', 'strings': [u'/usr/local/ssl']}
# {'name': u'X509_get_default_cert_file', 'strings': [u'/usr/local/ssl/cert.pem']}
# {'name': u'X509_get_default_cert_dir', 'strings': [u'/usr/local/ssl/certs']}
# {'name': u'X509_get_default_private_dir', 'strings': [u'/usr/local/ssl/private']}
# {'name': u'PKCS7_simple_smimecap', 'strings': [u'pk7_attr.c']}
# {'name': u'PKCS7_add0_attrib_signing_time', 'strings': [u'pk7_attr.c']}
# {'name': u'PKCS7_add_attrib_smimecap', 'strings': [u'pk7_attr.c']}
# {'name': u'OPENSSL_asc2uni', 'strings': [u'p12_utl.c']}
# {'name': u'OPENSSL_uni2asc', 'strings': [u'p12_utl.c']}
# {'name': u'OCSP_sendreq_new', 'strings': [u'ocsp_ht.c', u'POST %s HTTP/1.0\r\n', u'Content-Type: application/ocsp-request\r\nContent-Length: %d\r\n\r\n']}
# {'name': u'OCSP_REQ_CTX_set1_req', 'strings': [u'Content-Type: application/ocsp-request\r\nContent-Length: %d\r\n\r\n']}
# {'name': u'OCSP_sendreq_nbio', 'strings': [u'Code=', u'ocsp_ht.c', u',Reason=']}
# {'name': u'ENGINE_init', 'strings': [u'eng_init.c']}
# {'name': u'engine_unlocked_finish', 'strings': [u'eng_init.c']}
# {'name': u'ENGINE_finish', 'strings': [u'eng_init.c']}
# {'name': u'bn_mul_mont', 'strings': [u'SUATAUAVAWA', u'SUATAUAVAWE']}
# {'name': u'lh_new', 'strings': [u'lhash.c']}
# {'name': u'lh_delete', 'strings': [u'lhash.c']}
# {'name': u'lh_insert', 'strings': [u'lhash.c']}
# {'name': u'RSA_padding_check_PKCS1_type_2', 'strings': [u'rsa_pk1.c']}
# {'name': u'RSA_padding_add_PKCS1_type_2', 'strings': [u'rsa_pk1.c']}
# {'name': u'RSA_padding_add_PKCS1_type_1', 'strings': [u'rsa_pk1.c']}
# {'name': u'RSA_padding_check_PKCS1_type_1', 'strings': [u'rsa_pk1.c']}
# {'name': u'BN_X931_generate_Xpq', 'strings': [u'WAVM']}
# {'name': u'BN_X931_generate_prime_ex', 'strings': [u'WAVM']}
# {'name': u'BN_X931_derive_prime_ex.part.0', 'strings': [u'WAVM']}
# {'name': u'TS_REQ_print_bio', 'strings': [u'unspecified\n', u'unspecified', u'Certificate required: %s\n', u'Policy OID: ', u'Version: %d\n', u'Nonce: ']}
# {'name': u'PKCS12_set_mac', 'strings': [u'p12_mutl.c']}
# {'name': u'PKCS12_setup_mac', 'strings': [u'p12_mutl.c']}
# {'name': u'PKCS12_gen_mac.part.0', 'strings': [u'p12_mutl.c']}
# {'name': u'PKCS12_verify_mac', 'strings': [u'p12_mutl.c']}
# {'name': u'PKCS12_gen_mac', 'strings': [u'p12_mutl.c']}
# {'name': u'DSA_SIG_new', 'strings': [u'dsa_sign.c']}
# {'name': u'PEM_SealInit', 'strings': [u'pem_seal.c']}
# {'name': u'PEM_SealFinal', 'strings': [u'pem_seal.c']}
# {'name': u'des_ede_cfb64_cipher', 'strings': [u'UATH']}
# {'name': u'des_ede_cbc_cipher', 'strings': [u'UATH']}
# {'name': u'des3_ctrl', 'strings': [u'UATH']}
# {'name': u'des_ede_ecb_cipher', 'strings': [u'UATH']}
# {'name': u'des_ede_ofb_cipher', 'strings': [u'UATH']}
# {'name': u'des_ede_init_key', 'strings': [u'UATH']}
# {'name': u'des_ede3_init_key', 'strings': [u'UATH']}
# {'name': u'des_ede3_cfb8_cipher', 'strings': [u'UATH']}
# {'name': u'des_ede3_cfb1_cipher', 'strings': [u'UATH']}
# {'name': u'd2i_AutoPrivateKey', 'strings': [u'd2i_pr.c']}
# {'name': u'd2i_PrivateKey', 'strings': [u'd2i_pr.c']}
# {'name': u'EVP_VerifyFinal', 'strings': [u'p_verify.c']}
# {'name': u'BN_div_recp', 'strings': [u'bn_recp.c']}
# {'name': u'BN_RECP_CTX_new', 'strings': [u'bn_recp.c']}
# {'name': u'BN_mod_mul_reciprocal', 'strings': [u'bn_recp.c']}
# {'name': u'a2i_ASN1_ENUMERATED', 'strings': [u'f_enum.c']}
# {'name': u'alg_module_init', 'strings': [u'name=', u'evp_cnf.c', u', value=', u'fips_mode']}
# {'name': u'EVP_add_alg_module', 'strings': [u'alg_section']}
# {'name': u'RSA_sign_ASN1_OCTET_STRING', 'strings': [u'rsa_saos.c']}
# {'name': u'RSA_verify_ASN1_OCTET_STRING', 'strings': [u'rsa_saos.c']}
# {'name': u'OCSP_response_get1_basic', 'strings': [u'ocsp_cl.c']}
# {'name': u'OCSP_request_sign', 'strings': [u'ocsp_cl.c']}
# {'name': u'OCSP_check_validity', 'strings': [u'ocsp_cl.c']}
# {'name': u'OCSP_request_add1_cert', 'strings': [u'ocsp_cl.c']}
# {'name': u'BN_to_ASN1_ENUMERATED', 'strings': [u'a_enum.c']}
# {'name': u'ASN1_ENUMERATED_set', 'strings': [u'a_enum.c']}
# {'name': u'ASN1_ENUMERATED_to_BN', 'strings': [u'a_enum.c']}
# {'name': u'PKCS12_init', 'strings': [u'p12_init.c']}
# {'name': u'EVP_PKEY_derive_set_peer', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_sign', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_derive_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_verify', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_encrypt_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_sign_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_verify_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_decrypt', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_derive', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_verify_recover_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_verify_recover', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_encrypt', 'strings': [u'pmeth_fn.c']}
# {'name': u'EVP_PKEY_decrypt_init', 'strings': [u'pmeth_fn.c']}
# {'name': u'PKCS5_PBE_keyivgen', 'strings': [u'p5_crpt.c', u'EVP_CIPHER_iv_length(cipher) <= 16', u'EVP_CIPHER_key_length(cipher) <= (int)sizeof(md_tmp)']}
# {'name': u'pkey_GOST94cp_encrypt', 'strings': [u'gost94_keyx.c']}
# {'name': u'pkey_GOST94cp_decrypt', 'strings': [u'gkt->key_info->encrypted_key->length==32', u'gkt->key_agreement_info->eph_iv->length==8', u'gost94_keyx.c', u'gkt->key_info->imit->length==4']}
# {'name': u'X509_check_private_key', 'strings': [u'x509_cmp.c']}
# {'name': u'TS_TST_INFO_set_time', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_msg_imprint', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_policy_id', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_ACCURACY_set_micros', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_ACCURACY_set_seconds', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_accuracy', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_nonce', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_serial', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_RESP_set_status_info', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_TST_INFO_set_tsa', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'TS_ACCURACY_set_millis', 'strings': [u'ts_rsp_utils.c']}
# {'name': u'BN_mpi2bn', 'strings': [u'bn_mpi.c']}
# {'name': u'COMP_CTX_new', 'strings': [u'comp_lib.c']}
# {'name': u'CMS_SignerInfo_verify_content', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_SignerInfo_verify', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_SignedData_init', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_set1_signers_certs', 'strings': [u'cms_sd.c']}
# {'name': u'cms_SignedData_init_bio', 'strings': [u'cms_sd.c']}
# {'name': u'cms_SignedData_final', 'strings': [u'cms_sd.c']}
# {'name': u'cms_set1_SignerIdentifier', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_get0_signers', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_add1_signer', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_SignerInfo_sign', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_get0_SignerInfos', 'strings': [u'cms_sd.c']}
# {'name': u'CMS_SignerInfo_set1_signer_cert', 'strings': [u'cms_sd.c']}
# {'name': u'cswift_ctrl', 'strings': [u'e_cswift.c']}
# {'name': u'ENGINE_load_cswift', 'strings': [u'CryptoSwift hardware engine support', u'cswift']}
# {'name': u'cswift_dsa_verify', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'cswift_mod_exp_mont', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'cswift_rand_bytes', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'cswift_init', 'strings': [u'swift', u'swSimpleRequest', u'swAcquireAccContext', u'swAttachKeyParam', u'e_cswift.c', u'swReleaseAccContext']}
# {'name': u'cswift_rsa_mod_exp', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'ERR_CSWIFT_error.constprop.3', 'strings': [u'e_cswift.c']}
# {'name': u'cswift_dsa_sign', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'cswift_mod_exp_dh', 'strings': [u'CryptoSwift error number is ', u'e_cswift.c']}
# {'name': u'cswift_finish', 'strings': [u'e_cswift.c']}
# {'name': u'v2i_EXTENDED_KEY_USAGE', 'strings': [u',value:', u',name:', u'v3_extku.c', u'section:']}
# {'name': u'BN_mod_lshift_quick', 'strings': [u'bn_mod.c']}
# {'name': u'policy_cache_set_mapping', 'strings': [u'WAVI']}
# {'name': u'pkey_gost01cp_keygen', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_mac_keygen', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost94cp_keygen', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_init', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost94_paramgen', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost01_paramgen', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_mac_ctrl_str', 'strings': [u'gost_pmeth.c', u'hexkey']}
# {'name': u'pkey_gost_mac_init', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_ctrl94_str', 'strings': [u'gost_pmeth.c', u'paramset']}
# {'name': u'pkey_gost_mac_copy', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_ctrl', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_copy', 'strings': [u'gost_pmeth.c']}
# {'name': u'pkey_gost_ctrl01_str', 'strings': [u'gost_pmeth.c', u'paramset']}
# {'name': u'EC_KEY_copy', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_generate_key', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_set_public_key_affine_coordinates', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_check_key', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_insert_key_method_data', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_new', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_free', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_up_ref', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_dup', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_new_by_curve_name', 'strings': [u'ec_key.c']}
# {'name': u'EC_KEY_get_key_method_data', 'strings': [u'ec_key.c']}
# {'name': u'ENGINE_get_pkey_meth', 'strings': [u'tb_pkmeth.c']}
# {'name': u'PKCS7_decrypt', 'strings': [u'pk7_smime.c']}
# {'name': u'PKCS7_sign_add_signer', 'strings': [u'pk7_smime.c']}
# {'name': u'PKCS7_final', 'strings': [u'pk7_smime.c']}
# {'name': u'PKCS7_verify', 'strings': [u'smime_sign', u'Verify error:', u'pk7_smime.c']}
# {'name': u'PKCS7_sign', 'strings': [u'pk7_smime.c']}
# {'name': u'PKCS7_get0_signers', 'strings': [u'pk7_smime.c']}
# {'name': u'PKCS7_encrypt', 'strings': [u'pk7_smime.c']}
# {'name': u'i2r_crldp', 'strings': [u'<EMPTY>\n', u'%*sFull Name:\n', u'%*s%s:\n%*s', u'Reasons', u'%*sCRL Issuer:\n', u'%*sRelative Name:\n%*s']}
# {'name': u'v2i_idp', 'strings': [u',name:', u'relativename', u'onlyCA', u'fullname', u'indirectCRL', u'onlysomereasons', u',value:', u'section:', u'onlyAA', u'v3_crld.c', u'onlyuser']}
# {'name': u'i2r_idp', 'strings': [u'%*sOnly CA Certificates\n', u'<EMPTY>\n', u'%*sIndirect CRL\n', u'%*sFull Name:\n', u'%*sOnly Attribute Certificates\n', u'%*s<EMPTY>\n', u'Only Some Reasons', u'%*s%s:\n%*s', u'%*sRelative Name:\n%*s', u'%*sOnly User Certificates\n']}
# {'name': u'v2i_crld', 'strings': [u'v3_crld.c', u'fullname', u'CRLissuer', u'relativename', u'reasons']}
# {'name': u'PKCS5_v2_PBKDF2_keyivgen', 'strings': [u'p5_crpt2.c', u'keylen <= sizeof key']}
# {'name': u'PKCS5_v2_PBE_keyivgen', 'strings': [u'p5_crpt2.c']}
# {'name': u'DES_enc_read', 'strings': [u'enc_read.c']}
# {'name': u'DH_check', 'strings': [u'VAUI']}
# {'name': u'DH_check_pub_key', 'strings': [u'VAUI']}
# {'name': u'ASN1_primitive_new', 'strings': [u'tasn_new.c']}
# {'name': u'ASN1_template_new', 'strings': [u'tasn_new.c']}
# {'name': u'BN_bn2hex', 'strings': [u'bn_print.c']}
# {'name': u'BN_bn2dec', 'strings': [u'%019lu', u'bn_print.c']}
# {'name': u'BN_options', 'strings': [u'bn(%d,%d)']}
# {'name': u'EVP_BytesToKey', 'strings': [u'nkey <= EVP_MAX_KEY_LENGTH', u'niv <= EVP_MAX_IV_LENGTH', u'evp_key.c']}
# {'name': u'asn1_ex_c2i', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_check_tlen.constprop.1', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_template_noexp_d2i', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_d2i_ex_primitive', 'strings': [u'tasn_dec.c']}
# {'name': u'ASN1_template_d2i', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_collect.constprop.0', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_check_tlen', 'strings': [u'tasn_dec.c']}
# {'name': u'asn1_template_ex_d2i', 'strings': [u'tasn_dec.c']}
# {'name': u'X509_INFO_new', 'strings': [u'x_info.c']}
# {'name': u'X509_INFO_free', 'strings': [u'x_info.c']}
# {'name': u'EVP_DigestFinal_ex', 'strings': [u'digest.c', u'ctx->digest->md_size <= EVP_MAX_MD_SIZE']}
# {'name': u'EVP_DigestInit_ex', 'strings': [u'digest.c']}
# {'name': u'EVP_Digest', 'strings': [u'digest.c', u'ctx->digest->md_size <= EVP_MAX_MD_SIZE']}
# {'name': u'EVP_DigestFinal', 'strings': [u'digest.c', u'ctx->digest->md_size <= EVP_MAX_MD_SIZE']}
# {'name': u'EVP_DigestInit', 'strings': [u'digest.c']}
# {'name': u'EVP_MD_CTX_copy', 'strings': [u'digest.c']}
# {'name': u'EVP_MD_CTX_create', 'strings': [u'digest.c']}
# {'name': u'EVP_MD_CTX_copy_ex', 'strings': [u'digest.c']}
# {'name': u'PKCS5_pbe2_set', 'strings': [u'p5_pbev2.c']}
# {'name': u'PKCS5_pbe2_set_iv', 'strings': [u'p5_pbev2.c']}
# {'name': u'PKCS5_pbkdf2_set', 'strings': [u'p5_pbev2.c']}
# {'name': u'RSA_generate_key', 'strings': [u'WAVI']}
# {'name': u'cast5_ecb_cipher', 'strings': [u'WAVI']}
# {'name': u'cast5_ofb_cipher', 'strings': [u'WAVI']}
# {'name': u'cast5_cbc_cipher', 'strings': [u'WAVI']}
# {'name': u'cast5_cfb64_cipher', 'strings': [u'WAVI']}
# {'name': u'cast_init_key', 'strings': [u'WAVI']}
# {'name': u'EVP_CIPHER_CTX_new', 'strings': [u'evp_enc.c']}
# {'name': u'EVP_CipherInit', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_CIPHER_CTX_copy', 'strings': [u'evp_enc.c']}
# {'name': u'EVP_CipherFinal_ex', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->buf', u'b <= sizeof ctx->final']}
# {'name': u'EVP_CipherFinal', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->buf', u'b <= sizeof ctx->final']}
# {'name': u'EVP_EncryptUpdate', 'strings': [u'bl <= (int)sizeof(ctx->buf)', u'evp_enc.c']}
# {'name': u'EVP_EncryptInit_ex', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_EncryptFinal', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->buf']}
# {'name': u'EVP_CipherInit_ex', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_EncryptInit', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_CipherUpdate', 'strings': [u'bl <= (int)sizeof(ctx->buf)', u'evp_enc.c', u'b <= sizeof ctx->final']}
# {'name': u'EVP_DecryptFinal_ex', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->final']}
# {'name': u'EVP_DecryptUpdate', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->final', u'bl <= (int)sizeof(ctx->buf)']}
# {'name': u'EVP_EncryptFinal_ex', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->buf']}
# {'name': u'EVP_CIPHER_CTX_set_key_length', 'strings': [u'evp_enc.c']}
# {'name': u'EVP_DecryptInit_ex', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_CIPHER_CTX_ctrl', 'strings': [u'evp_enc.c']}
# {'name': u'EVP_DecryptInit', 'strings': [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c']}
# {'name': u'EVP_CIPHER_CTX_rand_key', 'strings': [u'evp_enc.c']}
# {'name': u'EVP_DecryptFinal', 'strings': [u'evp_enc.c', u'b <= sizeof ctx->final']}
# {'name': u'ts_resp_cb', 'strings': [u'ts_asn1.c']}
# {'name': u'PKCS7_to_TS_TST_INFO', 'strings': [u'ts_asn1.c']}
# {'name': u'ENGINE_load_public_key', 'strings': [u'eng_pkey.c']}
# {'name': u'ENGINE_load_private_key', 'strings': [u'eng_pkey.c']}
# {'name': u'ENGINE_load_ssl_client_cert', 'strings': [u'eng_pkey.c']}
# {'name': u'PEM_write_bio_DSAPrivateKey', 'strings': [u'DSA PRIVATE KEY']}
# {'name': u'PEM_write_bio_X509_CRL', 'strings': [u'X509 CRL']}
# {'name': u'PEM_write_PKCS7', 'strings': [u'PKCS7']}
# {'name': u'PEM_write_bio_ECPKParameters', 'strings': [u'EC PARAMETERS']}
# {'name': u'PEM_write_bio_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_ECPKParameters', 'strings': [u'EC PARAMETERS']}
# {'name': u'PEM_read_DSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_X509_CRL', 'strings': [u'X509 CRL']}
# {'name': u'PEM_read_NETSCAPE_CERT_SEQUENCE', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_write_bio_EC_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_RSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_bio_RSAPublicKey', 'strings': [u'RSA PUBLIC KEY']}
# {'name': u'PEM_write_ECPrivateKey', 'strings': [u'EC PRIVATE KEY']}
# {'name': u'PEM_write_ECPKParameters', 'strings': [u'EC PARAMETERS']}
# {'name': u'PEM_read_bio_DHparams', 'strings': [u'DH PARAMETERS']}
# {'name': u'PEM_write_bio_ECPrivateKey', 'strings': [u'EC PRIVATE KEY']}
# {'name': u'PEM_read_bio_X509_REQ', 'strings': [u'CERTIFICATE REQUEST']}
# {'name': u'PEM_write_NETSCAPE_CERT_SEQUENCE', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_write_X509_REQ_NEW', 'strings': [u'NEW CERTIFICATE REQUEST']}
# {'name': u'PEM_read_PKCS7', 'strings': [u'PKCS7']}
# {'name': u'PEM_read_bio_EC_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_bio_PKCS7', 'strings': [u'PKCS7']}
# {'name': u'PEM_write_bio_NETSCAPE_CERT_SEQUENCE', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_read_RSAPublicKey', 'strings': [u'RSA PUBLIC KEY']}
# {'name': u'PEM_write_DHparams', 'strings': [u'DH PARAMETERS']}
# {'name': u'PEM_read_bio_ECPKParameters', 'strings': [u'EC PARAMETERS']}
# {'name': u'PEM_write_RSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_DSAparams', 'strings': [u'DSA PARAMETERS']}
# {'name': u'PEM_read_EC_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_bio_DSAparams', 'strings': [u'DSA PARAMETERS']}
# {'name': u'PEM_read_bio_X509_CRL', 'strings': [u'X509 CRL']}
# {'name': u'PEM_write_X509_REQ', 'strings': [u'CERTIFICATE REQUEST']}
# {'name': u'PEM_write_bio_X509_REQ_NEW', 'strings': [u'NEW CERTIFICATE REQUEST']}
# {'name': u'PEM_write_EC_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_bio_PKCS7', 'strings': [u'PKCS7']}
# {'name': u'PEM_read_bio_NETSCAPE_CERT_SEQUENCE', 'strings': [u'CERTIFICATE']}
# {'name': u'PEM_read_bio_RSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_DSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_bio_DSAparams', 'strings': [u'DSA PARAMETERS']}
# {'name': u'PEM_read_DHparams', 'strings': [u'DH PARAMETERS']}
# {'name': u'PEM_write_RSAPrivateKey', 'strings': [u'RSA PRIVATE KEY']}
# {'name': u'PEM_write_RSAPublicKey', 'strings': [u'RSA PUBLIC KEY']}
# {'name': u'PEM_read_X509_REQ', 'strings': [u'CERTIFICATE REQUEST']}
# {'name': u'PEM_write_DSAparams', 'strings': [u'DSA PARAMETERS']}
# {'name': u'PEM_write_bio_RSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_bio_DHparams', 'strings': [u'DH PARAMETERS']}
# {'name': u'PEM_write_DSAPrivateKey', 'strings': [u'DSA PRIVATE KEY']}
# {'name': u'PEM_write_bio_X509_REQ', 'strings': [u'CERTIFICATE REQUEST']}
# {'name': u'PEM_read_X509_CRL', 'strings': [u'X509 CRL']}
# {'name': u'PEM_read_bio_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_read_bio_DSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_bio_RSAPublicKey', 'strings': [u'RSA PUBLIC KEY']}
# {'name': u'PEM_write_bio_DSA_PUBKEY', 'strings': [u'PUBLIC KEY']}
# {'name': u'PEM_write_bio_RSAPrivateKey', 'strings': [u'RSA PRIVATE KEY']}
# {'name': u'PKCS12_parse', 'strings': [u'p12_kiss.c']}
# {'name': u'CRYPTO_cbc128_decrypt', 'strings': [u'AUATI', u'WAVI']}
# {'name': u'ASN1_TYPE_get_int_octetstring', 'strings': [u'evp_asn1.c']}
# {'name': u'ASN1_TYPE_get_octetstring', 'strings': [u'evp_asn1.c']}
# {'name': u'EVP_PKEY_CTX_ctrl_str', 'strings': [u'digest', u'pmeth_lib.c']}
# {'name': u'EVP_PKEY_CTX_ctrl', 'strings': [u'pmeth_lib.c']}
# {'name': u'EVP_PKEY_CTX_new', 'strings': [u'pmeth_lib.c']}
# {'name': u'EVP_PKEY_meth_new', 'strings': [u'pmeth_lib.c']}
# {'name': u'EVP_PKEY_CTX_new_id', 'strings': [u'pmeth_lib.c']}
# {'name': u'EVP_PKEY_CTX_dup', 'strings': [u'pmeth_lib.c']}
# {'name': u'DES_enc_write', 'strings': [u'enc_writ.c']}
# {'name': u'TXT_DB_read', 'strings': [u'txt_db.c', u'failure in sk_push\n', u"wrong number of fields on line %ld (looking for field %d, got %d, '%s' left)\n", u'OPENSSL_malloc failure\n']}
# {'name': u'X509_REQ_to_X509', 'strings': [u'x509_r2x.c']}
# {'name': u'TS_TST_INFO_print_bio', 'strings': [u'TSA: ', u'Ordering: %s\n', u' millis, ', u' micros', u'Nonce: ', u'unspecified', u'Time stamp: ', u'Policy OID: ', u'Version: %d\n', u' seconds, ', u'Serial number: ', u'Accuracy: ']}
# {'name': u'TS_RESP_print_bio', 'strings': [u'\nTST info:\n', u'Status info:\n', u'Not included.\n']}
# {'name': u'TS_STATUS_INFO_print_bio', 'strings': [u'Failure info: ', u'unspecified\n', u'unspecified', u'out of bounds\n', u'Status: ', u'Status description: ']}
# {'name': u'X509at_get0_data_by_OBJ', 'strings': [u'x509_att.c']}
# {'name': u'X509at_add1_attr_by_NID', 'strings': [u'x509_att.c']}
# {'name': u'X509at_add1_attr', 'strings': [u'x509_att.c']}
# {'name': u'X509_ATTRIBUTE_get0_data', 'strings': [u'x509_att.c']}
# {'name': u'X509_ATTRIBUTE_set1_data', 'strings': [u'x509_att.c']}
# {'name': u'X509_ATTRIBUTE_create_by_NID', 'strings': [u'x509_att.c']}
# {'name': u'X509_ATTRIBUTE_create_by_OBJ', 'strings': [u'x509_att.c']}
# {'name': u'X509at_add1_attr_by_txt', 'strings': [u'name=', u'x509_att.c']}
# {'name': u'X509at_add1_attr_by_OBJ', 'strings': [u'x509_att.c']}
# {'name': u'X509_ATTRIBUTE_create_by_txt', 'strings': [u'name=', u'x509_att.c']}
# {'name': u'ecdsa_do_sign', 'strings': [u'ecs_ossl.c']}
# {'name': u'ecdsa_sign_setup', 'strings': [u'ecs_ossl.c']}
# {'name': u'ecdsa_do_verify', 'strings': [u'ecs_ossl.c']}
# {'name': u'X509_CERT_AUX_print', 'strings': [u'%*sNo Rejected Uses.\n', u'%*sNo Trusted Uses.\n', u'%*sKey Id: ', u'%*sRejected Uses:\n%*s', u'%*sTrusted Uses:\n%*s', u'%*sAlias: %s\n', u'%s%02X']}
# {'name': u'BN_dup', 'strings': [u'bn_lib.c']}
# {'name': u'BN_new', 'strings': [u'bn_lib.c']}
# {'name': u'bn_dup_expand', 'strings': [u'bn_lib.c']}
# {'name': u'BN_bin2bn', 'strings': [u'bn_lib.c']}
# {'name': u'bn_expand_internal', 'strings': [u'bn_lib.c']}
# {'name': u'ASN1_UTCTIME_adj', 'strings': [u'%02d%02d%02d%02d%02d%02dZ', u'a_utctm.c']}
# {'name': u'ASN1_UTCTIME_set', 'strings': [u'%02d%02d%02d%02d%02d%02dZ', u'a_utctm.c']}
# {'name': u'DSA_generate_key', 'strings': [u'VAUATUSH']}
# {'name': u'BN_mod_sqrt', 'strings': [u'bn_sqrt.c']}
# {'name': u'PEM_ASN1_read_bio', 'strings': [u'pem_oth.c']}
# {'name': u'TS_REQ_set_policy_id', 'strings': [u'ts_req_utils.c']}
# {'name': u'TS_REQ_set_msg_imprint', 'strings': [u'ts_req_utils.c']}
# {'name': u'TS_MSG_IMPRINT_set_algo', 'strings': [u'ts_req_utils.c']}
# {'name': u'TS_REQ_set_nonce', 'strings': [u'ts_req_utils.c']}
# {'name': u'OCSP_cert_to_id', 'strings': [u'ocsp_lib.c']}
# {'name': u'OCSP_parse_url', 'strings': [u'https', u'ocsp_lib.c', u'http']}
# {'name': u'OCSP_cert_id_new', 'strings': [u'ocsp_lib.c']}
# {'name': u'DHparams_print_fp', 'strings': [u'dh_prn.c']}
# {'name': u'c2i_ASN1_BIT_STRING', 'strings': [u'a_bitstr.c']}
# {'name': u'ASN1_BIT_STRING_set_bit', 'strings': [u'a_bitstr.c']}
# {'name': u'pkey_cmac_ctrl_str', 'strings': [u'hexkey', u'cipher']}
# {'name': u'SRP_create_verifier', 'strings': [u'srp_vfy.c']}
# {'name': u'SRP_VBASE_new', 'strings': [u'srp_vfy.c']}
# {'name': u'SRP_VBASE_init', 'strings': [u'srp_vfy.c']}
# {'name': u'SRP_gN_new_init', 'strings': [u'srp_vfy.c']}
# {'name': u'SRP_VBASE_get_by_user', 'strings': [u'srp_vfy.c']}
# {'name': u'EVP_SealInit', 'strings': [u'WAVI']}
# {'name': u'x509_name_ex_d2i', 'strings': [u'x_name.c']}
# {'name': u'x509_name_ex_i2d', 'strings': [u'x_name.c']}
# {'name': u'x509_name_ex_new', 'strings': [u'x_name.c']}
# {'name': u'x509_name_canon.part.0', 'strings': [u'x_name.c']}
# {'name': u'BF_options', 'strings': [u'blowfish(idx)']}
# {'name': u'X509_NAME_oneline', 'strings': [u'NO X509_NAME', u'x509_obj.c']}
# {'name': u'd2i_ASN1_type_bytes', 'strings': [u'a_bytes.c']}
# {'name': u'd2i_ASN1_bytes', 'strings': [u'a_bytes.c']}
# {'name': u'RSA_print_fp', 'strings': [u'rsa_prn.c']}
# {'name': u'ASN1_GENERALIZEDTIME_adj', 'strings': [u'%04d%02d%02d%02d%02d%02dZ', u'a_gentm.c']}
# {'name': u'ASN1_GENERALIZEDTIME_set', 'strings': [u'%04d%02d%02d%02d%02d%02dZ', u'a_gentm.c']}
# {'name': u'v2i_BASIC_CONSTRAINTS', 'strings': [u',name:', u',value:', u'pathlen', u'v3_bcons.c', u'section:']}
# {'name': u'i2v_BASIC_CONSTRAINTS', 'strings': [u'pathlen']}
# {'name': u'X509V3_EXT_i2d', 'strings': [u'v3_conf.c']}
# {'name': u'X509V3_get_section', 'strings': [u'v3_conf.c']}
# {'name': u'X509V3_EXT_nconf_nid', 'strings': [u'critical,', u'ASN1:', u'DER:']}
# {'name': u'X509V3_EXT_nconf', 'strings': [u', value=', u'ASN1:', u'name=', u'critical,', u'v3_conf.c', u'DER:']}
# {'name': u'do_ext_nconf', 'strings': [u'name=', u',section=', u'v3_conf.c']}
# {'name': u'X509V3_get_string', 'strings': [u'v3_conf.c']}
# {'name': u'v3_generic_extension', 'strings': [u'name=', u'value=', u'v3_conf.c']}
# {'name': u'gost2001_do_sign', 'strings': [u'gost2001.c', u'dlen==32']}
# {'name': u'gost2001_compute_public', 'strings': [u'gost2001.c']}
# {'name': u'gost2001_do_verify', 'strings': [u'gost2001.c']}
# {'name': u'fill_GOST2001_params', 'strings': [u'gost2001.c']}
# {'name': u'gost2001_keygen', 'strings': [u'gost2001.c']}
# {'name': u'BN_mul', 'strings': [u'VAUI', u'AWAVAUATUSH', u'AWAVI']}
# {'name': u'bn_sub_part_words', 'strings': [u'VAUI']}
# {'name': u'bn_mul_recursive.constprop.0', 'strings': [u'AWAVI']}
# {'name': u'bn_mul_part_recursive', 'strings': [u'AWAVI', u'AWAVAUATUSH']}
# {'name': u'bn_mul_high', 'strings': [u'VAUI']}
# {'name': u'bn_mul_low_recursive', 'strings': [u'AWAVI']}
# {'name': u'bn_mul_recursive', 'strings': [u'VAUI', u'AWAVI']}
# {'name': u'bn_add_part_words', 'strings': [u'VAUI']}
# {'name': u'RSA_padding_check_SSLv23', 'strings': [u'rsa_ssl.c']}
# {'name': u'RSA_padding_add_SSLv23', 'strings': [u'rsa_ssl.c']}
# {'name': u'X509_verify_cert_error_string', 'strings': [u'error number %ld']}
# {'name': u'CRYPTO_pop_info', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_dbg_realloc', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_dbg_free', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_mem_ctrl', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_push_info_', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_dbg_malloc', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_mem_leaks', 'strings': [u'mem_dbg.c', u'%ld bytes leaked in %d chunks\n']}
# {'name': u'CRYPTO_is_mem_check_on', 'strings': [u'mem_dbg.c']}
# {'name': u'print_leak_doall_arg', 'strings': [u'thread=%lu, ', u'%5lu file=%s, line=%d, ', u' thread=%lu, file=%s, line=%d, info="', u'number=%d, address=%08lX\n', u'[%02d:%02d:%02d] ']}
# {'name': u'CRYPTO_remove_all_info', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_mem_leaks_fp', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_mem_leaks_cb', 'strings': [u'mem_dbg.c']}
# {'name': u'CRYPTO_mem_ctrl.constprop.5', 'strings': [u'mem_dbg.c']}
# {'name': u'RSA_check_key', 'strings': [u'rsa_chk.c']}
# {'name': u'int_engine_module_init', 'strings': [u', name=', u'init', u'dynamic_path', u'EMPTY', u', value=', u'SO_PATH', u'eng_cnf.c', u'LOAD', u'section=', u'LIST_ADD', u'default_algorithms', u'dynamic', u'soft_load', u'engine_id']}
# {'name': u'ENGINE_add_conf_module', 'strings': [u'engines']}
# {'name': u'DES_options', 'strings': [u'cisc', u'des(%s,%s,%s,%s)']}
# {'name': u'ec_GFp_simple_set_compressed_coordinates', 'strings': [u'ecp_oct.c']}
# {'name': u'ec_GFp_simple_point2oct', 'strings': [u'ecp_oct.c']}
# {'name': u'ec_GFp_simple_oct2point', 'strings': [u'ecp_oct.c']}
# {'name': u'i2v_AUTHORITY_KEYID', 'strings': [u'keyid', u'serial']}
# {'name': u'v2i_AUTHORITY_KEYID', 'strings': [u'name=', u'always', u'keyid', u'issuer', u'v3_akey.c']}
# {'name': u'a2i_ASN1_STRING', 'strings': [u'f_string.c']}
# {'name': u'DES_cfb64_encrypt', 'strings': [u'WAVI']}
# {'name': u'DH_generate_parameters_ex', 'strings': [u'dh_gen.c']}
# {'name': u'dh_private_print', 'strings': [u'private-key:', u'recommended-private-length: %d bits\n', u'dh_ameth.c', u'%s: (%d bit)\n', u'generator:', u'public-key:', u'PKCS#3 DH Private-Key', u'prime:']}
# {'name': u'dh_param_print', 'strings': [u'private-key:', u'recommended-private-length: %d bits\n', u'PKCS#3 DH Parameters', u'dh_ameth.c', u'%s: (%d bit)\n', u'generator:', u'public-key:', u'prime:']}
# {'name': u'dh_priv_decode', 'strings': [u'dh_ameth.c']}
# {'name': u'dh_priv_encode', 'strings': [u'dh_ameth.c']}
# {'name': u'dh_pub_decode', 'strings': [u'dh_ameth.c']}
# {'name': u'dh_public_print', 'strings': [u'private-key:', u'recommended-private-length: %d bits\n', u'dh_ameth.c', u'%s: (%d bit)\n', u'generator:', u'public-key:', u'PKCS#3 DH Public-Key', u'prime:']}
# {'name': u'DHparams_print', 'strings': [u'private-key:', u'recommended-private-length: %d bits\n', u'PKCS#3 DH Parameters', u'dh_ameth.c', u'%s: (%d bit)\n', u'generator:', u'public-key:', u'prime:']}
# {'name': u'dh_pub_encode', 'strings': [u'dh_ameth.c']}
# {'name': u'dh_param_decode', 'strings': [u'dh_ameth.c']}
# {'name': u'BIO_dump_indent_cb.constprop.0', 'strings': [u'%02x%c', u'%04x - ', u'%s%04x - <SPACES/NULS>\n']}
# {'name': u'BIO_dump_indent_cb.constprop.1', 'strings': [u'%02x%c', u'%04x - ', u'%s%04x - <SPACES/NULS>\n']}
# {'name': u'BIO_dump_indent_cb', 'strings': [u'%02x%c', u'%04x - ', u'%s%04x - <SPACES/NULS>\n']}
# {'name': u'EC_POINT_point2bn', 'strings': [u'ec_print.c']}
# {'name': u'EC_POINT_hex2point', 'strings': [u'ec_print.c']}
# {'name': u'EC_POINT_point2hex', 'strings': [u'ec_print.c']}
# {'name': u'EC_POINT_bn2point', 'strings': [u'ec_print.c']}
# {'name': u'policy_data_new', 'strings': [u'pcy_data.c']}
# {'name': u'WHIRLPOOL_Final', 'strings': [u'AWAV']}
# {'name': u'WHIRLPOOL_Update', 'strings': [u'AWAV']}
# {'name': u'WHIRLPOOL', 'strings': [u'AWAV']}
# {'name': u'BN_GF2m_mod_sqr', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_exp', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_mul', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_solve_quad_arr', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_div_arr', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_sqrt', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_inv', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_solve_quad', 'strings': [u'bn_gf2m.c']}
# {'name': u'BN_GF2m_mod_div', 'strings': [u'bn_gf2m.c']}
# {'name': u'X509_VERIFY_PARAM_new', 'strings': [u'x509_vpm.c']}
# {'name': u'ASN1_BIT_STRING_set_asc', 'strings': [u'UAT1']}
# {'name': u'ASN1_BIT_STRING_name_print', 'strings': [u'UAT1']}
# {'name': u'BN_pseudo_rand', 'strings': [u'bn_rand.c']}
# {'name': u'bn_rand_range', 'strings': [u'bn_rand.c']}
# {'name': u'BN_rand', 'strings': [u'bn_rand.c']}
# {'name': u'BN_bntest_rand', 'strings': [u'bn_rand.c']}
# {'name': u'dsa_builtin_paramgen', 'strings': [u'WAVH']}
# {'name': u'ASN1_TIME_set', 'strings': [u'a_time.c']}
# {'name': u'ASN1_TIME_adj', 'strings': [u'a_time.c']}
# {'name': u'DES_ofb_encrypt', 'strings': [u'WAVA']}
# {'name': u'ibm_4758_cca_ctrl', 'strings': [u'e_4758cca.c']}
# {'name': u'ENGINE_load_4758cca', 'strings': [u'4758cca', u'IBM 4758 CCA hardware engine support']}
# {'name': u'ibm_4758_load_pubkey', 'strings': [u'e_4758cca.c']}
# {'name': u'ibm_4758_load_privkey', 'strings': [u'e_4758cca.c']}
# {'name': u'ibm_4758_cca_init', 'strings': [u'CSUNSAPI', u'CSNDPKD', u'IBM 4758 CCA RSA key handle', u'CSNDDSG', u'CSNBRNG', u'e_4758cca.c', u'CSNDDSV', u'CSNDPKE', u'CSNDPKX', u'CSNDKRR']}
# {'name': u'cca_rsa_verify', 'strings': [u'e_4758cca.c']}
# {'name': u'ibm_4758_cca_finish', 'strings': [u'e_4758cca.c']}
# {'name': u'cca_rsa_sign', 'strings': [u'e_4758cca.c']}
# {'name': u'ec_GF2m_simple_mul', 'strings': [u'ec2_mult.c']}
# {'name': u'BIO_callback_ctrl', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_free', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_ctrl', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_read', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_ctrl_pending', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_free_all', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_pop', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_new', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_dup_chain', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_ctrl_wpending', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_write', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_gets', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_indent', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_ptr_ctrl', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_int_ctrl', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_push', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_vfree', 'strings': [u'bio_lib.c']}
# {'name': u'BIO_puts', 'strings': [u'bio_lib.c']}
# {'name': u'PKCS12_key_gen_uni', 'strings': [u'p12_key.c']}
# {'name': u'PKCS12_key_gen_asc', 'strings': [u'p12_key.c']}
# {'name': u'i2d_PublicKey', 'strings': [u'i2d_pu.c']}
# {'name': u'pqueue_new', 'strings': [u'pqueue.c']}
# {'name': u'pqueue_print', 'strings': [u'item\t%02x%02x%02x%02x%02x%02x%02x%02x\n']}
# {'name': u'pitem_new', 'strings': [u'pqueue.c']}
# {'name': u'PEM_write_bio_Parameters', 'strings': [u'%s PARAMETERS']}
# {'name': u'PEM_write_PrivateKey', 'strings': [u'pem_pkey.c', u'%s PRIVATE KEY']}
# {'name': u'PEM_write_bio_PrivateKey', 'strings': [u'%s PRIVATE KEY']}
# {'name': u'PEM_read_PrivateKey', 'strings': [u'pem_pkey.c']}
# {'name': u'PEM_read_bio_Parameters', 'strings': [u'pem_pkey.c', u'PARAMETERS']}
# {'name': u'PEM_read_bio_PrivateKey', 'strings': [u'ENCRYPTED PRIVATE KEY', u'ANY PRIVATE KEY', u'pem_pkey.c', u'PRIVATE KEY']}
# {'name': u'do_pk8pkey', 'strings': [u'ENCRYPTED PRIVATE KEY', u'PRIVATE KEY', u'pem_pk8.c']}
# {'name': u'PEM_write_PKCS8PrivateKey', 'strings': [u'pem_pk8.c']}
# {'name': u'PEM_read_bio_PKCS8', 'strings': [u'ENCRYPTED PRIVATE KEY']}
# {'name': u'i2d_PKCS8PrivateKey_fp', 'strings': [u'pem_pk8.c']}
# {'name': u'PEM_read_PKCS8_PRIV_KEY_INFO', 'strings': [u'PRIVATE KEY']}
# {'name': u'PEM_write_bio_PKCS8_PRIV_KEY_INFO', 'strings': [u'PRIVATE KEY']}
# {'name': u'PEM_write_PKCS8PrivateKey_nid', 'strings': [u'pem_pk8.c']}
# {'name': u'i2d_PKCS8PrivateKey_nid_fp', 'strings': [u'pem_pk8.c']}
# {'name': u'PEM_read_bio_PKCS8_PRIV_KEY_INFO', 'strings': [u'PRIVATE KEY']}
# {'name': u'd2i_PKCS8PrivateKey_fp', 'strings': [u'pem_pk8.c']}
# {'name': u'PEM_write_PKCS8', 'strings': [u'ENCRYPTED PRIVATE KEY']}
# {'name': u'PEM_write_PKCS8_PRIV_KEY_INFO', 'strings': [u'PRIVATE KEY']}
# {'name': u'PEM_write_bio_PKCS8', 'strings': [u'ENCRYPTED PRIVATE KEY']}
# {'name': u'PEM_read_PKCS8', 'strings': [u'ENCRYPTED PRIVATE KEY']}
# {'name': u'd2i_PKCS8PrivateKey_bio', 'strings': [u'pem_pk8.c']}
# {'name': u'rsa_priv_encode', 'strings': [u'rsa_ameth.c']}
# {'name': u'rsa_priv_print', 'strings': [u'Exponent:', u'exponent2:', u'coefficient:', u'exponent1:', u'privateExponent:', u'Modulus:', u'modulus:', u'rsa_ameth.c', u'prime1:', u'Public-Key: (%d bit)\n', u'Private-Key: (%d bit)\n', u'publicExponent:', u'prime2:']}
# {'name': u'rsa_item_verify', 'strings': [u'rsa_ameth.c']}
# {'name': u'rsa_priv_decode', 'strings': [u'rsa_ameth.c']}
# {'name': u'rsa_pub_decode', 'strings': [u'rsa_ameth.c']}
# {'name': u'rsa_pub_print', 'strings': [u'rsa_ameth.c', u'Public-Key: (%d bit)\n', u'Exponent:', u'Modulus:']}
# {'name': u'rsa_sig_print', 'strings': [u'0xbc (default)', u' with ', u'sha1 (default)', u'Hash Algorithm: ', u'Salt Length: ', u'INVALID', u'Mask Algorithm: ', u'Trailer Field: ', u'20 (default)', u' (INVALID PSS PARAMETERS)\n', u'mgf1 with sha1 (default)']}
# {'name': u'old_rsa_priv_decode', 'strings': [u'rsa_ameth.c']}
# {'name': u'X509_CRL_print_fp', 'strings': [u't_crl.c']}
# {'name': u'X509_CRL_print', 'strings': [u'CRL extensions', u'Revoked Certificates:\n', u'\n        Revocation Date: ', u'%8sLast Update: ', u'\n%8sNext Update: ', u'NONE', u'%8sVersion %lu (0x%lx)\n', u'%8sIssuer: %s\n', u'Certificate Revocation List (CRL):\n', u'No Revoked Certificates.\n', u'CRL entry extensions', u'    Serial Number: ']}
# {'name': u'EVP_EncodeUpdate', 'strings': [u'ctx->length <= (int)sizeof(ctx->enc_data)', u'encode.c']}
# {'name': u'EVP_DecodeUpdate', 'strings': [u'encode.c', u'n < (int)sizeof(ctx->enc_data)']}
# {'name': u'bio_write', 'strings': [u'bss_bio.c']}
# {'name': u'BIO_nread', 'strings': [u'bss_bio.c']}
# {'name': u'BIO_nwrite0', 'strings': [u'bss_bio.c']}
# {'name': u'BIO_nwrite', 'strings': [u'bss_bio.c']}
# {'name': u'bio_new', 'strings': [u'bss_bio.c']}
# {'name': u'BIO_nread0', 'strings': [u'bss_bio.c']}
# {'name': u'acpt_puts', 'strings': [u'bss_acpt.c']}
# {'name': u'acpt_ctrl', 'strings': [u'bss_acpt.c']}
# {'name': u'acpt_read', 'strings': [u'bss_acpt.c']}
# {'name': u'acpt_write', 'strings': [u'bss_acpt.c']}
# {'name': u'acpt_new', 'strings': [u'bss_acpt.c']}
# {'name': u'atalla_ctrl', 'strings': [u'e_atalla.c']}
# {'name': u'ENGINE_load_atalla', 'strings': [u'Atalla hardware engine support', u'atalla']}
# {'name': u'atalla_init', 'strings': [u'ASI_GetHardwareConfig', u'ASI_GetPerformanceStatistics', u'e_atalla.c', u'ASI_RSAPrivateKeyOpFn', u'atasi']}
# {'name': u'atalla_rsa_mod_exp', 'strings': [u'e_atalla.c']}
# {'name': u'atalla_mod_exp', 'strings': [u'e_atalla.c']}
# {'name': u'atalla_finish', 'strings': [u'e_atalla.c']}
# {'name': u'int_def_cb', 'strings': [u'DIGESTS', u'PKEY_ASN1', u'CIPHERS', u'PKEY', u'PKEY_CRYPTO', u'ECDH', u'ECDSA', u'RAND']}
# {'name': u'ENGINE_set_default_string', 'strings': [u'eng_fat.c', u'str=']}
# {'name': u'long_print', 'strings': [u'%ld\n']}
# {'name': u'long_c2i', 'strings': [u'x_long.c']}
# {'name': u'ENGINE_load_rdrand', 'strings': [u'rdrand', u'Intel RDRAND engine']}
# {'name': u'DES_ede3_cbcm_encrypt', 'strings': [u'WAVAUATUSH']}
# {'name': u'ec_GF2m_simple_group_set_curve', 'strings': [u'ec2_smpl.c']}
# {'name': u'ec_GF2m_simple_point_set_affine_coordinates', 'strings': [u'ec2_smpl.c']}
# {'name': u'ec_GF2m_simple_group_check_discriminant', 'strings': [u'ec2_smpl.c']}
# {'name': u'ec_GF2m_simple_point_get_affine_coordinates', 'strings': [u'ec2_smpl.c']}
# {'name': u'surewarehk_rand_add', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_error_handling', 'strings': [u'e_sureware.c']}
# {'name': u'sureware_load_public', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_ctrl', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_load_pubkey', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_mod_exp_mont', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_load_privkey', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_modexp_dh', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_ex_free', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_dsa_mod_exp', 'strings': [u'e_sureware.c']}
# {'name': u'ERR_SUREWARE_error.constprop.5', 'strings': [u'e_sureware.c']}
# {'name': u'ENGINE_load_sureware', 'strings': [u'SureWare hardware engine support', u'sureware']}
# {'name': u'surewarehk_finish', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_init', 'strings': [u'SureWareHook_Rand_Bytes', u'SureWareHook_Mod_Exp', u'SureWareHook_Load_Rsa_Pubkey', u'SureWareHook DSA key handle', u'SureWareHook_Dsa_Sign', u'SureWareHook_Free', u'e_sureware.c', u'SureWareHook_Rsa_Priv_Dec', u'SureWareHook RSA key handle', u'SureWareHook_Rsa_Sign', u'SureWareHook_Load_Dsa_Pubkey', u'SureWareHook_Finish', u'SureWareHook_Init', u'SureWareHook_Rand_Seed', u'SureWareHook_Load_Privkey', u'SureWareHook_Info_Pubkey', u'SureWareHook']}
# {'name': u'surewarehk_dsa_do_sign', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_rsa_priv_dec', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_rsa_sign', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_rand_bytes', 'strings': [u'e_sureware.c']}
# {'name': u'surewarehk_rand_seed', 'strings': [u'e_sureware.c']}
# {'name': u'BUF_MEM_grow', 'strings': [u'buffer.c']}
# {'name': u'BUF_MEM_new', 'strings': [u'buffer.c']}
# {'name': u'BUF_MEM_grow_clean', 'strings': [u'buffer.c']}
# {'name': u'SSLeay_version', 'strings': [u'linux-x86_64', u'gcc -DOPENSSL_THREADS -D_REENTRANT -DDSO_DLFCN -DHAVE_DLFCN_H -Wa,--noexecstack -m64 -DL_ENDIAN -DTERMIO -O3 -Wall -DOPENSSL_IA32_SSE2 -DOPENSSL_BN_ASM_MONT -DOPENSSL_BN_ASM_MONT5 -DOPENSSL_BN_ASM_GF2m -DSHA1_ASM -DSHA256_ASM -DSHA512_ASM -DMD5_ASM -DAES_ASM -DVPAES_ASM -DBSAES_ASM -DWHIRLPOOL_ASM -DGHASH_ASM', u'OpenSSL 1.0.1d 5 Feb 2013', u'built on: %s', u'compiler: %s', u'Mon Oct 21 00:18:05 PDT 2019', u'platform: %s', u'not available', u'OPENSSLDIR: "/usr/local/ssl"']}
# {'name': u'by_file_ctrl', 'strings': [u'by_file.c']}
# {'name': u'X509_load_cert_file', 'strings': [u'by_file.c']}
# {'name': u'X509_load_crl_file', 'strings': [u'by_file.c']}
# {'name': u'X509_load_cert_crl_file', 'strings': [u'by_file.c']}
# {'name': u'X509_load_cert_crl_file.part.0', 'strings': [u'by_file.c']}
# {'name': u'BIO_new_file', 'strings': [u'bss_file.c', u"fopen('"]}
# {'name': u'file_read', 'strings': [u'bss_file.c']}
# {'name': u'file_ctrl', 'strings': [u'bss_file.c', u"fopen('"]}
# {'name': u'Camellia_DecryptBlock', 'strings': [u'SUAUAVAWI']}
# {'name': u'Camellia_EncryptBlock', 'strings': [u'SUAUAVAWI']}
# {'name': u'Camellia_cbc_encrypt', 'strings': [u'SUAUAVAWI']}
# {'name': u'BN_div', 'strings': [u'bn_div.c']}
# {'name': u'i2r_PKEY_USAGE_PERIOD', 'strings': [u'Not Before: ', u'Not After: ']}
# {'name': u'sub_d8f', 'strings': [u'T$PL']}
# {'name': u'sub_98d', 'strings': [u'UATAUAVAWI']}
# {'name': u'sub_d5e', 'strings': [u'T$PL']}
# {'name': u'ASN1_tag2str', 'strings': [u'(unknown)']}
# {'name': u'asn1_parse2', 'strings': [u'appl [ %d ]', u'BAD ENUMERATED', u'length is greater than %ld\n', u'(unknown)', u'%5ld:', u'Bad boolean\n', u'prim: ', u':BAD OBJECT', u'%02X', u'cont [ %d ]', u'cons: ', u'Error in encoding\n', u'<ASN1 %d>', u'd=%-2d hl=%ld l=%4ld ', u'[HEX DUMP]:', u'd=%-2d hl=%ld l=inf  ', u'%-18s', u'priv [ %d ] ', u'BAD INTEGER']}
# {'name': u'pkey_dsa_init', 'strings': [u'dsa_pmeth.c']}
# {'name': u'pkey_dsa_ctrl_str', 'strings': [u'dsa_paramgen_md', u'dsa_paramgen_q_bits', u'dsa_paramgen_bits']}
# {'name': u'pkey_dsa_keygen', 'strings': [u'dsa_pmeth.c']}
# {'name': u'pkey_dsa_ctrl', 'strings': [u'dsa_pmeth.c']}
# {'name': u'pkey_dsa_copy', 'strings': [u'dsa_pmeth.c']}
# {'name': u'X509_verify_cert', 'strings': [u'OPENSSL_ALLOW_PROXY_CERTS', u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_set_trust', 'strings': [u'x509_vfy.c']}
# {'name': u'get_crl_sk', 'strings': [u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_set_purpose', 'strings': [u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_purpose_inherit', 'strings': [u'x509_vfy.c']}
# {'name': u'check_policy', 'strings': [u'x509_vfy.c']}
# {'name': u'get_issuer_sk', 'strings': [u'x509_vfy.c']}
# {'name': u'X509_get_pubkey_parameters', 'strings': [u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_new', 'strings': [u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_init', 'strings': [u'default', u'x509_vfy.c']}
# {'name': u'X509_STORE_CTX_get1_chain', 'strings': [u'x509_vfy.c']}
# {'name': u'BN_kronecker', 'strings': [u'WAVI']}
# {'name': u'EVP_SignFinal', 'strings': [u'p_sign.c']}
# {'name': u'ASN1_i2d_fp', 'strings': [u'a_i2d_fp.c']}
# {'name': u'ASN1_item_i2d_fp', 'strings': [u'a_i2d_fp.c']}
# {'name': u'ASN1_item_i2d_bio', 'strings': [u'a_i2d_fp.c']}
# {'name': u'ASN1_i2d_bio', 'strings': [u'a_i2d_fp.c']}
# {'name': u'X509_NAME_add_entry_by_OBJ', 'strings': [u'x509name.c']}
# {'name': u'X509_NAME_add_entry_by_NID', 'strings': [u'x509name.c']}
# {'name': u'X509_NAME_ENTRY_create_by_txt', 'strings': [u'name=', u'x509name.c']}
# {'name': u'X509_NAME_ENTRY_set_object', 'strings': [u'x509name.c']}
# {'name': u'X509_NAME_ENTRY_create_by_NID', 'strings': [u'x509name.c']}
# {'name': u'X509_NAME_add_entry_by_txt', 'strings': [u'name=', u'x509name.c']}
# {'name': u'X509_NAME_add_entry', 'strings': [u'x509name.c']}
# {'name': u'X509_NAME_ENTRY_create_by_OBJ', 'strings': [u'x509name.c']}
# {'name': u'BN_mod_exp2_mont', 'strings': [u'bn_exp2.c']}
# {'name': u'RSA_padding_check_none', 'strings': [u'rsa_none.c']}
# {'name': u'RSA_padding_add_none', 'strings': [u'rsa_none.c']}
# {'name': u'DES_xcbc_encrypt', 'strings': [u'WAVM']}
# {'name': u'idea_set_decrypt_key', 'strings': [u'UATUS']}
# {'name': u'ASN1_STRING_dup', 'strings': [u'asn1_lib.c']}
# {'name': u'ASN1_STRING_type_new', 'strings': [u'asn1_lib.c']}
# {'name': u'ASN1_STRING_new', 'strings': [u'asn1_lib.c']}
# {'name': u'asn1_GetSequence', 'strings': [u'asn1_lib.c']}
# {'name': u'ASN1_STRING_copy', 'strings': [u'asn1_lib.c']}
# {'name': u'asn1_add_error', 'strings': [u' offset=', u'address=']}
# {'name': u'ASN1_STRING_set', 'strings': [u'asn1_lib.c']}
# {'name': u'ASN1_get_object', 'strings': [u'asn1_lib.c']}
# {'name': u'OCSP_cert_status_str', 'strings': [u'revoked', u'good', u'(UNKNOWN)', u'unknown']}
# {'name': u'ocsp_certid_print', 'strings': [u'\n%*sIssuer Name Hash: ', u'%*sHash Algorithm: ', u'\n%*sIssuer Key Hash: ', u'%*sCertificate ID:\n', u'\n%*sSerial Number: ']}
# {'name': u'OCSP_RESPONSE_print', 'strings': [u'OCSP Response Data:\n', u'    Responder Id: ', u'\n    This Update: ', u'(UNKNOWN)', u'\n    Version: %lu (0x%lx)\n', u'Response Single Extensions', u'    OCSP Response Status: %s (0x%lx)\n', u'\n    Revocation Time: ', u'\n    Produced At: ', u'\n    Next Update: ', u'    Cert Status: %s', u'\n    Revocation Reason: %s (0x%lx)', u'    Response Type: ', u'Response Extensions', u'\n    Responses:\n', u' (unknown response type)\n']}
# {'name': u'OCSP_crl_reason_str', 'strings': [u'(UNKNOWN)']}
# {'name': u'OCSP_REQUEST_print', 'strings': [u'OCSP Request Data:\n', u'\n    Requestor Name: ', u'    Version: %lu (0x%lx)', u'\n    Requestor List:\n', u'Request Extensions', u'Request Single Extensions']}
# {'name': u'OCSP_response_status_str', 'strings': [u'(UNKNOWN)']}
# {'name': u'process_pci_value', 'strings': [u'text:', u'hex:', u'language', u'v3_pci.c', u',name:', u',value:', u'policy', u'section:', u'file:', u'pathlen']}
# {'name': u'i2r_pci', 'strings': [u'%*sPolicy Text: %s\n', u'%*sPath Length Constraint: ', u'infinite', u'%*sPolicy Language: ']}
# {'name': u'r2i_pci', 'strings': [u'v3_pci.c', u',value:', u',name:', u'section:']}
# {'name': u'DES_cbc_cksum', 'strings': [u'UATI']}
# {'name': u'PKCS8_encrypt', 'strings': [u'p12_p8e.c']}
# {'name': u'asn1_do_lock', 'strings': [u'tasn_utl.c']}
# {'name': u'asn1_do_adb', 'strings': [u'tasn_utl.c']}
# {'name': u'asn1_enc_save', 'strings': [u'tasn_utl.c']}
# ...
# {'name': u'SSL_CTX_use_certificate', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_RSAPrivateKey_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_PrivateKey', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_certificate_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_certificate_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_certificate_chain_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_PrivateKey_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_certificate', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_PrivateKey_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_PrivateKey_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_PrivateKey_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_certificate_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'ssl_set_cert', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_RSAPrivateKey_ASN1', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_RSAPrivateKey_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_use_RSAPrivateKey_file', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_RSAPrivateKey', 'strings': [u'ssl_rsa.c']}
# {'name': u'SSL_CTX_use_PrivateKey', 'strings': [u'ssl_rsa.c']}
# {'name': u'ssl_sess_cert_new', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl_sess_cert_free', 'strings': [u'ssl_cert.c']}
# {'name': u'SSL_add_file_cert_subjects_to_stack', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl_cert_dup', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl_verify_cert_chain', 'strings': [u'ssl_server', u'ssl_client', u'ssl_cert.c']}
# {'name': u'ssl_cert_free', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl_cert_new', 'strings': [u'ssl_cert.c']}
# {'name': u'SSL_get_ex_data_X509_STORE_CTX_idx', 'strings': [u'SSL for verify callback', u'ssl_cert.c']}
# {'name': u'SSL_add_dir_cert_subjects_to_stack', 'strings': [u"OPENSSL_DIR_read(&ctx, '", u'ssl_cert.c', u'%s/%s']}
# {'name': u'SSL_load_client_CA_file', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl_cert_inst', 'strings': [u'ssl_cert.c']}
# {'name': u'ssl3_read_n', 'strings': [u's3_pkt.c']}
# {'name': u'ssl3_read_bytes', 'strings': [u'mac_size <= EVP_MAX_MD_SIZE', u'SSL alert number ', u's3_pkt.c']}
# {'name': u'ssl3_do_change_cipher_spec', 'strings': [u's3_pkt.c']}
# {'name': u'ssl3_write_bytes', 'strings': [u's3_pkt.c']}
# {'name': u'ssl3_dispatch_alert', 'strings': [u's3_pkt.c']}
# {'name': u'ssl3_write_pending', 'strings': [u's3_pkt.c']}
# {'name': u'do_ssl3_write', 'strings': [u's3_pkt.c']}
# {'name': u'PEM_write_SSL_SESSION', 'strings': [u'SSL SESSION PARAMETERS']}
# {'name': u'PEM_read_SSL_SESSION', 'strings': [u'SSL SESSION PARAMETERS']}
# {'name': u'timeout_LHASH_DOALL_ARG', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_SESSION_free', 'strings': [u'ssl_sess.c']}
# {'name': u'PEM_write_bio_SSL_SESSION', 'strings': [u'SSL SESSION PARAMETERS']}
# {'name': u'SSL_CTX_add_session', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_get1_session', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_CTX_flush_sessions', 'strings': [u'ssl_sess.c']}
# {'name': u'ssl_clear_bad_session', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_CTX_set_client_cert_engine', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_SESSION_set1_id_context', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_SESSION_new', 'strings': [u'ssl_sess.c']}
# {'name': u'PEM_read_bio_SSL_SESSION', 'strings': [u'SSL SESSION PARAMETERS']}
# {'name': u'SSL_CTX_remove_session', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_set_session', 'strings': [u'ssl_sess.c']}
# {'name': u'ssl_get_new_session', 'strings': [u'ssl_sess.c']}
# {'name': u'SSL_set_session_ticket_ext', 'strings': [u'ssl_sess.c']}
# {'name': u'ssl3_check_cert_and_algorithm', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_new_session_ticket', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_server_certificate', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_connect', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_key_exchange', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_server_done', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_certificate_request', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_send_client_certificate', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_client_hello', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_cert_status', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_send_client_key_exchange', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_get_server_hello', 'strings': [u's3_clnt.c']}
# {'name': u'ssl3_send_client_verify', 'strings': [u's3_clnt.c']}
# {'name': u'ssl23_read', 'strings': [u's23_lib.c']}
# {'name': u'ssl23_peek', 'strings': [u's23_lib.c']}
# {'name': u'ssl23_write', 'strings': [u's23_lib.c']}
# {'name': u'read_n', 'strings': [u's2_pkt.c']}
# {'name': u'ssl2_part_read', 'strings': [u's2_pkt.c']}
# {'name': u'ssl2_write', 'strings': [u's2_pkt.c']}
# {'name': u'write_pending', 'strings': [u's2_pkt.c']}
# {'name': u'ssl2_read_internal', 'strings': [u's2_pkt.c', u'mac_size <= MAX_MAC_SIZE']}
# {'name': u'ssl23_accept', 'strings': [u's23_srvr.c']}
# {'name': u'ssl23_get_client_hello', 'strings': [u'HEAD ', u'POST ', u's23_srvr.c', u'CONNECT', u'GET ', u'PUT ']}
# {'name': u'SSL_COMP_add_compression_method', 'strings': [u'ssl_ciph.c']}
# {'name': u'ssl_cipher_strength_sort', 'strings': [u'ssl_ciph.c']}
# {'name': u'ssl_cipher_process_rulestr', 'strings': [u'ssl_ciph.c', u'STRENGTH']}
# {'name': u'ssl_create_cipher_list', 'strings': [u'gost94', u'gost2001', u'ssl_ciph.c', u'ALL:!aNULL:!eNULL:!SSLv2', u'DEFAULT']}
# {'name': u'SSL_CIPHER_get_name', 'strings': [u'(NONE)']}
# {'name': u'SSL_CIPHER_description', 'strings': [u'AEAD', u'AES(128)', u'Camellia(128)', u'KRB5', u'DH/RSA', u'DH/DSS', u'SHA1', u'AESGCM(256)', u'RC2(40)', u'ECDSA', u'SHA384', u'RC4(40)', u'RSA(1024)', u'ssl_ciph.c', u'ECDH/RSA', u'OPENSSL_malloc Error', u'IDEA(128)', u'3DES(168)', u'unknown', u'SSLv2', u'RC4(56)', u'TLSv1.2', u'DH(1024)', u' export', u'ECDH/ECDSA', u'SEED(128)', u'None', u'%-23s %s Kx=%-8s Au=%-4s Enc=%-9s Mac=%-4s%s\n', u'RC4(128)', u'SSLv3', u'SHA256', u'DES(56)', u'RC4(64)', u'DH(512)', u'ECDH', u'AES(256)', u'Camellia(256)', u'AESGCM(128)', u'RC2(56)', u'DES(40)', u'RSA(512)', u'RC2(128)', u'Buffer too small']}
# {'name': u'ssl_load_ciphers', 'strings': [u'IDEA-CBC', u'ssl_mac_secret_size[SSL_MD_GOST94_IDX] >= 0', u'RC2-CBC', u'AES-256-CBC', u'ssl_ciph.c', u'CAMELLIA-128-CBC', u'id-aes128-GCM', u'gost89-cnt', u'DES-EDE3-CBC', u'CAMELLIA-256-CBC', u'md_gost94', u'gost-mac', u'SHA256', u'SEED-CBC', u'SHA1', u'id-aes256-GCM', u'DES-CBC', u'ssl_mac_secret_size[SSL_MD_MD5_IDX] >= 0', u'AES-128-CBC', u'ssl_mac_secret_size[SSL_MD_SHA1_IDX] >= 0', u'SHA384']}
# {'name': u'SSL_CIPHER_get_version', 'strings': [u'(NONE)', u'unknown', u'SSLv2', u'TLSv1/SSLv3']}
# {'name': u'load_builtin_compressions', 'strings': [u'ssl_ciph.c']}
# {'name': u'ssl_cipher_get_evp', 'strings': [u'AES-256-CBC-HMAC-SHA1', u'RC4-HMAC-MD5', u'AES-128-CBC-HMAC-SHA1']}
# {'name': u'SSL_COMP_get_compression_methods', 'strings': [u'ssl_ciph.c']}
# {'name': u'SSL_SESSION_print_fp', 'strings': [u'ssl_txt.c']}
# {'name': u'SSL_SESSION_print', 'strings': [u'DTLSv1-bad', u'\n    Start Time: %ld', u'\n    Master-Key: ', u'%ld (%s)\n', u'    Cipher    : %04lX\n', u'\n    Compression: %d', u'\n    Compression: %d (%s)', u'    Cipher    : %s\n', u'\n    Timeout   : %ld (sec)', u'unknown', u'    Cipher    : %06lX\n', u'    Protocol  : %s\n', u'TLSv1.1', u'SSLv2', u'TLSv1', u'    Session-ID: ', u'TLSv1.2', u'%02X', u'\n    TLS session ticket lifetime hint: %ld (seconds)', u'\n    TLS session ticket:\n', u'\n    PSK identity: ', u'None', u'SSLv3', u'    Verify return code: ', u'\n    Key-Arg   : ', u'\n    SRP username: ', u'DTLSv1', u'\n    Session-ID-ctx: ', u'SSL-Session:\n', u'\n    PSK identity hint: ']}
# {'name': u'ssl2_accept', 'strings': [u's2_srvr.c']}
# {'name': u'ssl3_cbc_digest_record', 'strings': [u'data_plus_mac_plus_padding_size < 1024*1024', u'mac_secret_length <= sizeof(hmac_pad)', u's3_cbc.c', u'6666666666666666jjjjjjjjjjjjjjjj']}
# {'name': u'ssl3_cbc_copy_mac', 'strings': [u'md_size <= EVP_MAX_MD_SIZE', u'orig_len >= md_size', u's3_cbc.c']}
# {'name': u'ssl23_connect', 'strings': [u's23_clnt.c']}
# {'name': u'dtls1_handle_timeout', 'strings': [u'd1_lib.c']}
# {'name': u'dtls1_new', 'strings': [u'd1_lib.c']}
# {'name': u'dtls1_check_timeout_num', 'strings': [u'd1_lib.c']}
# {'name': u'ssl_parse_clienthello_renegotiate_ext', 'strings': [u't1_reneg.c']}
# {'name': u'ssl_add_serverhello_renegotiate_ext', 'strings': [u't1_reneg.c']}
# {'name': u'ssl_parse_serverhello_renegotiate_ext', 'strings': [u'!expected_len || s->s3->previous_client_finished_len', u't1_reneg.c', u'!expected_len || s->s3->previous_server_finished_len']}
# {'name': u'ssl_add_clienthello_renegotiate_ext', 'strings': [u't1_reneg.c']}
# {'name': u'ssl2_enc_init', 'strings': [u's->s2->key_material_length <= sizeof s->s2->key_material', u's2_enc.c', u'c->iv_len <= (int)sizeof(s->session->key_arg)']}
# {'name': u'ssl2_set_certificate', 'strings': [u's2_clnt.c']}
# {'name': u'ssl2_connect', 'strings': [u's2_clnt.c']}
# {'name': u'tls1_mac', 'strings': [u't > 0', u't >= 0', u't1_enc.c']}
# {'name': u'tls1_enc', 'strings': [u'%s:%d: rec->data != rec->input\n', u't1_enc.c', u'n >= 0']}
# {'name': u'tls1_P_hash.constprop.2', 'strings': [u'chunk >= 0', u't1_enc.c']}
# {'name': u'tls1_change_cipher_state', 'strings': [u'IV block', u't1_enc.c']}
# {'name': u'tls1_setup_key_block', 'strings': [u'key expansion', u't1_enc.c']}
# {'name': u'tls1_export_keying_material', 'strings': [u'client finished', u'master secret', u'server finished', u'key expansion', u't1_enc.c']}
# {'name': u'tls1_final_finish_mac', 'strings': [u't1_enc.c']}
# {'name': u'tls1_generate_master_secret', 'strings': [u'master secret', u't1_enc.c']}
# {'name': u'tls1_cert_verify_mac', 'strings': [u't1_enc.c']}
# {'name': u'tls1_PRF.constprop.1', 'strings': [u't1_enc.c']}
# {'name': u'ssl_get_server_send_cert', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_bytes_to_cipher_list', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_get_certificate', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_update_cache', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_write', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_generate_session_id', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_has_matching_session_id', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_cipher_list', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_fd', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_wfd', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_set_cipher_list', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_get_version', 'strings': [u'TLSv1', u'SSLv3', u'TLSv1.2', u'unknown', u'TLSv1.1', u'SSLv2']}
# {'name': u'SSL_set_rfd', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_set_session_id_context', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_shutdown', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_peek', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_undefined_function', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_get_sign_pkey', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_use_psk_identity_hint', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_check_srvr_ecc_cert_and_alg', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_init_wbio_buffer', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_bad_method', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_copy_session_id', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_use_psk_identity_hint', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_SSL_CTX', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_set_generate_session_id', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_new', 'strings': [u'ALL:!aNULL:!eNULL:!SSLv2', u'ssl2-md5', u'ssl3-sha1', u'ssl3-md5', u'ssl_lib.c', u'SSLv2']}
# {'name': u'ssl_undefined_const_function', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_set_ssl_version', 'strings': [u'ALL:!aNULL:!eNULL:!SSLv2', u'ssl_lib.c', u'SSLv2']}
# {'name': u'SSL_do_handshake', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl_undefined_void_function', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_read', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_new', 'strings': [u'ssl_lib.c', u's->sid_ctx_length <= sizeof s->sid_ctx']}
# {'name': u'ssl_get_server_send_pkey', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_free', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_get_peer_certificate', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_dup', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_check_private_key', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_free', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_clear', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_CTX_check_private_key', 'strings': [u'ssl_lib.c']}
# {'name': u'SSL_set_session_id_context', 'strings': [u'ssl_lib.c']}
# {'name': u'ssl3_get_message', 'strings': [u's3_both.c']}
# {'name': u'ssl3_setup_buffers', 'strings': [u's3_both.c']}
# {'name': u'ssl3_release_read_buffer', 'strings': [u's3_both.c']}
# {'name': u'ssl3_release_write_buffer', 'strings': [u's3_both.c']}
# {'name': u'ssl3_get_finished', 'strings': [u'i <= EVP_MAX_MD_SIZE', u's3_both.c']}
# {'name': u'ssl3_setup_write_buffer', 'strings': [u's3_both.c']}
# {'name': u'ssl3_output_cert_chain', 'strings': [u's3_both.c']}
# {'name': u'ssl3_send_finished', 'strings': [u'i <= EVP_MAX_MD_SIZE', u's3_both.c']}
# {'name': u'ssl3_setup_read_buffer', 'strings': [u's3_both.c']}
# {'name': u'ssl2_generate_key_material', 'strings': [u's->session->master_key_length >= 0 && s->session->master_key_length < (int)sizeof(s->session->master_key)', u's2_lib.c']}
# {'name': u'ssl2_write_error', 'strings': [u'error >= 0 && error <= (int)sizeof(buf)', u's2_lib.c']}
# {'name': u'ssl2_new', 'strings': [u's2_lib.c']}
# {'name': u'dtls1_get_message', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_do_write', 'strings': [u's->d1->mtu >= dtls1_min_mtu()', u's->init_num == (int)s->d1->w_msg_hdr.msg_len + DTLS1_HM_HEADER_LENGTH', u'len == (unsigned int)ret', u'd1_both.c', u'len >= DTLS1_HM_HEADER_LENGTH', u's->init_off > DTLS1_HM_HEADER_LENGTH']}
# {'name': u'dtls1_retransmit_buffered_messages', 'strings': [u'retransmit:  message %d non-existant\n', u'dtls1_retransmit_message() failed\n']}
# {'name': u'dtls1_get_message_fragment', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_heartbeat', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_buffer_message', 'strings': [u's->init_off == 0', u'd1_both.c', u's->d1->w_msg_hdr.msg_len + DTLS1_HM_HEADER_LENGTH == (unsigned int)s->init_num', u's->d1->w_msg_hdr.msg_len + ((s->version==DTLS1_VERSION)?DTLS1_CCS_HEADER_LENGTH:3) == (unsigned int)s->init_num']}
# {'name': u'dtls1_output_cert_chain', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_process_heartbeat', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_retransmit_message', 'strings': [u'retransmit:  message %d non-existant\n']}
# {'name': u'dtls1_send_change_cipher_spec', 'strings': [u's->d1->mtu >= dtls1_min_mtu()', u'd1_both.c', u'len == (unsigned int)ret']}
# {'name': u'dtls1_send_finished', 'strings': [u'd1_both.c', u's->d1->w_msg_hdr.msg_len + DTLS1_HM_HEADER_LENGTH == (unsigned int)s->init_num', u'i <= EVP_MAX_MD_SIZE']}
# {'name': u'dtls1_read_failed', 'strings': [u'invalid state reached %s:%d', u'd1_both.c']}
# {'name': u'dtls1_preprocess_fragment', 'strings': [u'd1_both.c']}
# {'name': u'dtls1_reassemble_fragment', 'strings': [u'd1_both.c', u'((long)msg_hdr->msg_len) > 0']}
# {'name': u'gz_comp', 'strings': [u'internal error: deflate stream corrupt']}
# {'name': u'gzfwrite', 'strings': [u'request does not fit in a size_t']}
# {'name': u'gz_init', 'strings': [u'out of memory']}
# {'name': u'gzwrite', 'strings': [u'requested length does not fit in int']}
# {'name': u'zlibVersion', 'strings': [u'1.2.11']}
# {'name': u'compress2', 'strings': [u'1.2.11']}
# {'name': u'uncompress2', 'strings': [u'1.2.11']}
# {'name': u'gz_error', 'strings': [u'%s%s%s']}
# {'name': u'gzdopen', 'strings': [u'<fd:%d>']}
# {'name': u'gzerror', 'strings': [u'out of memory']}
# {'name': u'gz_look', 'strings': [u'out of memory', u'1.2.11']}
# {'name': u'gzread', 'strings': [u'request does not fit in an int']}
# {'name': u'gz_decomp', 'strings': [u'out of memory', u'unexpected end of file', u'internal error: inflate stream corrupt', u'compressed data error']}
# {'name': u'gzfread', 'strings': [u'request does not fit in a size_t']}
# {'name': u'gzungetc', 'strings': [u'out of room to push characters']}

# %%
for key in string_table.keys():
    if key in globalstring_dict:
        if set(globalstring_dict[key]) != set(string_table[key]):
            print key, globalstring_dict[key], string_table[key]
# Out:
# dynamic_ctrl [u'eng_dyn.c'] ['v_check', 'eng_dyn.c', 'bind_engine']
# SMIME_read_ASN1 [u'application/x-pkcs7-signature', u'application/x-pkcs7-mime', u'asn_mime.c', u'multipart/signed', u'application/pkcs7-mime', u'application/pkcs7-signature', u'type: '] ['application/x-pkcs7-signature', 'application/pkcs7-signature', 'asn_mime.c', 'multipart/signed', 'type: ', 'application/x-pkcs7-mime', 'application/pkcs7-mime', 'content-type']
# HMAC_Init [u'len>=0 && len<=(int)sizeof(ctx->key)', u'j <= (int)sizeof(ctx->key)', u'hmac.c', u'6666666666666666\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\'] ['6666666666666666jjjjjjjjjjjjjjjjd1_both.c', 'hmac.c', '\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\bn_lib.c', 'len>=0 && len<=(int)sizeof(ctx->key)', u'6666666666666666\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\', u'j <= (int)sizeof(ctx->key)']
# rc4_hmac_md5_ctrl [u'6666666666666666jjjjjjjjjjjjjjjj'] ['6666666666666666jjjjjjjjjjjjjjjjd1_both.c', u'6666666666666666jjjjjjjjjjjjjjjj']
# EVP_CipherInit_ex [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# ssl3_handshake_mac [u's3_enc.c'] ['666666666666666666666666666666666666666666666666', '\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\', 's3_enc.c']
# aesni_cbc_hmac_sha1_ctrl [u'6666666666666666jjjjjjjjjjjjjjjj'] ['6666666666666666jjjjjjjjjjjjjjjjd1_both.c', u'6666666666666666jjjjjjjjjjjjjjjj']
# asn1_template_print_ctx [u'Unprocessed type %d\n', u'%*s%s:\n', u'%*s<EMPTY>\n', u'%*s}\n', u'%*s%s OF %s {\n', u'SEQUENCE', u'<ABSENT>\n'] ['%*s%s:\n', 'FALSE', '%s (%s)', 'ERROR: selector [%d] invalid\n', ':EXTERNAL TYPE %s\n', 'NULL\n', ' (%ld unused bits)\n', '%*s%s OF %s {\n', '%*s}\n', '<ABSENT>\n', 'TRUE', '%*s<EMPTY>\n', 'BOOL ABSENT', 'Unprocessed type %d\n', u'SEQUENCE']
# EVP_DecryptInit [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# HMAC_Init_ex [u'len>=0 && len<=(int)sizeof(ctx->key)', u'j <= (int)sizeof(ctx->key)', u'hmac.c', u'6666666666666666\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\'] ['6666666666666666jjjjjjjjjjjjjjjjd1_both.c', 'hmac.c', '\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\bn_lib.c', 'len>=0 && len<=(int)sizeof(ctx->key)', u'6666666666666666\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\', u'j <= (int)sizeof(ctx->key)']
# X509_get_default_cert_file [u'/usr/local/ssl/cert.pem'] ['/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/ssl/cert.pem', u'/usr/local/ssl/cert.pem']
# EVP_CipherInit [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# SMIME_text [u'text/plain', u'asn_mime.c', u'type: '] ['type: ', 'asn_mime.c', 'content-type', 'text/plain']
# X509_verify_cert_error_string [u'error number %ld'] ['certificate has expired', 'unsupported or invalid name constraint syntax', 'authority and subject key identifier mismatch', "RFC 3779 resource not subset of parent's resources", 'out of memory', 'certificate signature failure', 'invalid or inconsistent certificate policy extension', "format error in CRL's nextUpdate field", 'certificate not trusted', 'CRL is not yet valid', 'proxy certificates not allowed, please set the appropriate flag', 'key usage does not include digital signature', 'unsupported name constraint type', 'self signed certificate in certificate chain', "format error in certificate's notBefore field", 'unsupported certificate purpose', 'key usage does not include CRL signing', 'Different CRL scope', 'unhandled critical extension', 'application verification failure', 'proxy path length constraint exceeded', 'subject issuer mismatch', 'path length constraint exceeded', 'unsupported or invalid name syntax', 'CRL path validation error', 'unable to get certificate CRL', "format error in certificate's notAfter field", 'certificate revoked', 'certificate chain too long', 'excluded subtree violation', 'invalid non-CA certificate (has CA markings)', 'Unsupported extension feature', "unable to decrypt CRL's signature", 'invalid CA certificate', 'CRL signature failure', 'authority and issuer serial number mismatch', 'unable to verify the first certificate', 'self signed certificate', 'invalid or inconsistent certificate extension', "format error in CRL's lastUpdate field", 'name constraints minimum and maximum not supported', 'permitted subtree violation', 'unable to get local issuer certificate', "unable to decrypt certificate's signature", 'unable to get issuer certificate', 'certificate is not yet valid', 'certificate rejected', 'error number %ld', 'unable to decode issuer public key', 'unhandled critical CRL extension', 'unable to get CRL issuer certificate', 'CRL has expired', 'key usage does not include certificate signing', 'no explicit policy']
# SSLeay_version [u'linux-x86_64', u'gcc -DOPENSSL_THREADS -D_REENTRANT -DDSO_DLFCN -DHAVE_DLFCN_H -Wa,--noexecstack -m64 -DL_ENDIAN -DTERMIO -O3 -Wall -DOPENSSL_IA32_SSE2 -DOPENSSL_BN_ASM_MONT -DOPENSSL_BN_ASM_MONT5 -DOPENSSL_BN_ASM_GF2m -DSHA1_ASM -DSHA256_ASM -DSHA512_ASM -DMD5_ASM -DAES_ASM -DVPAES_ASM -DBSAES_ASM -DWHIRLPOOL_ASM -DGHASH_ASM', u'OpenSSL 1.0.1d 5 Feb 2013', u'built on: %s', u'compiler: %s', u'Mon Oct 21 00:18:05 PDT 2019', u'platform: %s', u'not available', u'OPENSSLDIR: "/usr/local/ssl"'] ['not available', 'linux-x86_64', 'compiler: %s', 'platform: %s', 'OpenSSL 1.0.1d 5 Feb 2013', 'built on: %s', 'gcc -DOPENSSL_THREADS -D_REENTRANT -DDSO_DLFCN -DHAVE_DLFCN_H -Wa,--noexecstack -m64 -DL_ENDIAN -DTERMIO -O3 -Wall -DOPENSSL_IA32_SSE2 -DOPENSSL_BN_ASM_MONT -DOPENSSL_BN_ASM_MONT5 -DOPENSSL_BN_ASM_GF2m -DSHA1_ASM -DSHA256_AS', 'Thu Mar  7 21:41:33 PST 2019', 'OPENSSLDIR: "/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/ssl"', u'OPENSSLDIR: "/usr/local/ssl"', u'gcc -DOPENSSL_THREADS -D_REENTRANT -DDSO_DLFCN -DHAVE_DLFCN_H -Wa,--noexecstack -m64 -DL_ENDIAN -DTERMIO -O3 -Wall -DOPENSSL_IA32_SSE2 -DOPENSSL_BN_ASM_MONT -DOPENSSL_BN_ASM_MONT5 -DOPENSSL_BN_ASM_GF2m -DSHA1_ASM -DSHA256_ASM -DSHA512_ASM -DMD5_ASM -DAES_ASM -DVPAES_ASM -DBSAES_ASM -DWHIRLPOOL_ASM -DGHASH_ASM', u'Mon Oct 21 00:18:05 PDT 2019']
# asn1_cb [u'tag=', u'asn1_gen.c'] ['tag=', 'asn1_gen.c', 'ASCII', 'BITLIST', 'UTF8']
# X509_get_default_private_dir [u'/usr/local/ssl/private'] ['/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/ssl/private', u'/usr/local/ssl/private']
# EVP_EncryptInit [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# ASN1_item_print [u'Unprocessed type %d\n', u'<ABSENT>\n'] ['BOOL ABSENT', 'FALSE', '%s (%s)', 'ERROR: selector [%d] invalid\n', ':EXTERNAL TYPE %s\n', ' (%ld unused bits)\n', 'NULL\n', '%*s}\n', 'Unprocessed type %d\n', 'TRUE', '<ABSENT>\n']
# BIO_vprintf [u'b_print.c', u'doapr()'] ['<NULL>', 'doapr()', 'b_print.c']
# EVP_EncryptInit_ex [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# asn1_print_fsname.isra.4 [u' (%s)'] ['                    ', u' (%s)']
# tls1_change_cipher_state [u'IV block', u't1_enc.c'] ['t1_enc.c', 'server write key', 'IV block', 'client write key']
# X509_get_default_cert_dir [u'/usr/local/ssl/certs'] ['/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/ssl/certs', u'/usr/local/ssl/certs']
# ssl3_cbc_digest_record [u'data_plus_mac_plus_padding_size < 1024*1024', u'mac_secret_length <= sizeof(hmac_pad)', u's3_cbc.c', u'6666666666666666jjjjjjjjjjjjjjjj'] ['s3_cbc.c', '6666666666666666jjjjjjjjjjjjjjjjd1_both.c', 'data_plus_mac_plus_padding_size < 1024*1024', 'mac_secret_length <= sizeof(hmac_pad)', u'6666666666666666jjjjjjjjjjjjjjjj']
# SMIME_write_ASN1 [u'------%s%s', u'Content-Transfer-Encoding: base64%s', u'%s------%s%s', u'\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t77777777777777770000000000000000', u'Content-Transfer-Encoding: base64%s%s', u'sha-384', u'application/x-pkcs7-', u'signed-receipt', u'%s------%s--%s%s', u'sha1', u' filename="%s"%s', u'smime.p7m', u'Content-Type: %smime;', u' name="%s"%s', u'asn_mime.c', u'compressed-data', u' micalg="', u' smime-type=%s;', u'Content-Disposition: attachment;', u'unknown', u'Content-Type: %ssignature;', u'smime.p7z', u'enveloped-data', u'signed-data', u'application/pkcs7-', u'sha-256', u'MIME-Version: 1.0%s', u'sha-512', u'This is an S/MIME signed message%s%s', u' filename="smime.p7s"%s%s', u'Content-Type: multipart/signed;', u'gostr3411-94', u' name="smime.p7s"%s', u' protocol="%ssignature";', u'certs-only', u'"; boundary="----%s"%s%s'] [' protocol="%ssignature";', 'signed-data', ' filename="%s"%s', 'sha-384', 'sha-256', 'Content-Type: %smime;', '%s------%s%s', 'application/pkcs7-', 'asn_mime.c', 'smime.p7z', 'MIME-Version: 1.0%s', ' micalg="', 'smime.p7m', 'Content-Transfer-Encoding: base64%s%s', 'sha-512', 'enveloped-data', 'signed-receipt', '%s------%s--%s%s', '\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t77777777777777770000000000000000bio_b64.c', 'certs-only', ' smime-type=%s;', 'This is an S/MIME signed message%s%s', 'Content-Type: multipart/signed;', ' name="smime.p7s"%s', '"; boundary="----%s"%s%s', 'Content-Transfer-Encoding: base64%s', ' name="%s"%s', 'compressed-data', ' filename="smime.p7s"%s%s', 'Content-Type: %ssignature;', 'application/x-pkcs7-', 'Content-Disposition: attachment;', u'\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t77777777777777770000000000000000', u'unknown', u'sha1', u'------%s%s', u'gostr3411-94']
# ENGINE_by_id [u'/usr/local/ssl/lib/engines', u'LOAD', u'OPENSSL_ENGINES', u'DIR_ADD', u'dynamic', u'DIR_LOAD', u'eng_list.c'] ['OPENSSL_ENGINES', 'DIR_LOAD', 'dynamic', 'DIR_ADD', '/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/lib/engines', 'eng_list.c', u'LOAD', u'/usr/local/ssl/lib/engines']
# EVP_DecryptInit_ex [u'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16', u'evp_enc.c'] ['EVP_CIPHER_CTX_iv_length(ctx) <= (int)sizeof(ctx->iv)', 'evp_enc.c', 'ctx->cipher->block_size == 1 || ctx->cipher->block_size == 8 || ctx->cipher->block_size == 16']
# X509_get_default_cert_area [u'/usr/local/ssl'] ['/home/yijiufly/Downloads/codesearch/data/nginx/nginx-1.10.3/../openssl-1.0.1d/.openssl/ssl', u'/usr/local/ssl']

# %%
string_table['ENGINE_get_last']
# Out:
# ['eng_list.c']

# %%
global LBP_MAX_ITERS
global THRES
LBP_MAX_ITERS =40
THRES = 0.99
knn = p.load(open('/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/test_kNN_1021_2gram.p', 'r'))
binaryview = binja.BinaryViewType.get_view_of_file('/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/nginx-{openssl-1.0.1d}{zlib-1.2.11}')
string_table = build_string_table(binaryview)

# %%
def BP_with_strings(queryPath_1gram, queryPath_2gram, string_dict, db):
    global LBP_MAX_ITERS
    global THRES
    threshold=THRES
    g = fg.Graph()
    global_node_dict = dict()
    global_edge_dict = dict()
    global_sim_dict = defaultdict(float)
    rvlabels = defaultdict(list)
    if type(queryPath_2gram) == type(''):
        query_2gram = p.load(open(queryPath_2gram, 'rb'))
        query_1gram = p.load(open(queryPath_1gram, 'rb'))
    else:
        query_2gram = queryPath_2gram
        query_1gram = queryPath_1gram
    hasDistance = False
    if type(query_2gram[0][0][0]) == type((1,2)):
        hasDistance = True

    global_node_dict, global_prior_dict = get_node_prior_belief(query_1gram)
    for i in query_2gram:
        if i[2] > threshold:
            if not hasDistance:
                test_src = i[0][0]
                test_des = i[0][1]
            else:
                test_src = i[0][0][0]
                test_des = i[0][0][1]
            if test_src == test_des:
                continue
#             # initialize the dictionary
            if not global_node_dict.has_key(test_src):
                global_node_dict[test_src] = []
            if not global_node_dict.has_key(test_des):
                global_node_dict[test_des] = []
            if not global_edge_dict.has_key((test_src, test_des)):
                global_edge_dict[(test_src, test_des)] = []

            funcList = i[1]
            for predicted_func in funcList:
                if hasDistance:
                    querydistance = i[0][1]
                    resultdistance = predicted_func[3]
                    if querydistance != resultdistance:
                        continue

                src_funcname = predicted_func[2][0]
                des_funcname = predicted_func[2][1]
                libraryname = predicted_func[0]

                # find the src function if it's already in the dict,
                # otherwise, add it to the dict
                if (src_funcname, libraryname) not in global_node_dict[test_src]:
                    continue
                # do the same thing to des function
                if (des_funcname, libraryname) not in global_node_dict[test_des]:
                    continue
                
                # add this edge to the edge dictionary
                if (src_funcname, des_funcname, libraryname) not in global_edge_dict[(test_src, test_des)]:
                    global_edge_dict[(test_src, test_des)].append((src_funcname, des_funcname, libraryname))
                    if global_sim_dict[(src_funcname, des_funcname, libraryname)] < i[2]:
                        global_sim_dict[(src_funcname, des_funcname, libraryname)] = i[2]
                    
    string_count = defaultdict(int)
    # add functions as random variables and add factors between function and string nodes
    for key in global_node_dict:
        rvlabels[test_src].append('None')
        length = len(global_node_dict[key])
        if length > 0:
            #rv_func = g.rv(key, length + 1, prior = global_prior_dict[key])
            rv_func = g.rv(key, length + 1)
        else:
            rv_func = g.rv(key, length + 1) # None label is the last item
        for idx, (prediction, library) in enumerate(global_node_dict[key]):
            query = db.load({"name":prediction})
            if not query:
                string_list = []
            else:
                string_list = query['strings']
            string_shared = set(string_dict[key]) & set(string_list)
            string_differ = set(string_dict[key]) | set(string_list) - string_shared
#             string_shared = set()
#             string_differ = set()
            #string_differ = set(string_list) - set(string_dict[key])
            for string in string_shared:
                count = string_count[string]
                string_count[string] += 1
                rv_string = g.rv('str_' + string + str(count), 1)
                fillvalue = 1.0
                pot=np.full((length + 1, 1), fillvalue)
                pot[idx, 0] = 5 * fillvalue
                factor = g.factor([rv_func, rv_string], potential=pot, name = '')
                
            for string in string_differ:
                count = string_count[string]
                string_count[string] += 1
                rv_string = g.rv('str_' + string + str(count), 1)    
                fillvalue = 1.0
                pot=np.full((length + 1, 1), 5 * fillvalue)
                pot[idx, 0] = fillvalue
                factor = g.factor([rv_func, rv_string], potential=pot, name = '')
        global_node_dict[key].append(('None', 'None'))
    p.dump(global_node_dict, open('global_node_dict','w'))


    # add factors
    for (test_src, test_des) in global_edge_dict.keys():
        src_rv = g.get_rvs()[test_src]
        des_rv = g.get_rvs()[test_des]
        src_list = global_node_dict[test_src]
        des_list = global_node_dict[test_des]
        # set the probability for src_rv and des_rv
        # first find if there is an existing probability, if so, add to it
        # otherwise, initialize a new probability matrix
        factor1 = None
        probability1 = None

        if test_src != test_des:
            pot=np.full((len(src_list), len(des_list)), 0.01)
            #pot[-1, -1] = 0.1
            factor1 = g.factor([src_rv, des_rv], potential=pot, name = '')
            probability1 = factor1.get_potential()

        # if there is an matching edge
        if len(global_edge_dict[(test_src, test_des)]) > 0:
            for (src_funcname, des_funcname, libraryname) in global_edge_dict[(test_src, test_des)]:
                sim = global_sim_dict[(src_funcname, des_funcname, libraryname)]
                src_ind = src_list.index((src_funcname, libraryname))
                des_ind = des_list.index((des_funcname, libraryname))
                if src_rv == factor1.get_rvs()[0]:
                    #probability1[src_ind, des_ind] = 2**(sim + 2) - 7
                    probability1[src_ind, des_ind] = 0.9
                else:
                    #probability1[des_ind, src_ind] = 2**(sim + 2) - 7
                    probability1[des_ind, src_ind] = 0.9
#         else:
#             if len(src_list) > 0 and len(des_list) > 0:
#                 probability1[:, -1] = 0.3
#                 probability1[-1, :] = 0.3
                
        factor1.set_potential(probability1)
        #factor1.name += src_funcname + '->' + des_funcname + '\n'

    iters, converged = g.lbp(global_node_dict, normalize=True, max_iters=LBP_MAX_ITERS, progress=False)
    g.global_dict = global_node_dict
    print 'LBP ran for %d iterations. Converged = %r' % (iters, converged)
#     results = g.get_func_prediction(normalize=True)
#     p.dump(results, open('prediction','w'))
#     results = g.accuracy_of_functions(normalize=True)
    return g

# %%
global THRES
THRES = 0.95
global LBP_MAX_ITERS
LBP_MAX_ITERS =40
g = BP_with_strings(knn_all, knn, string_table, mongodb)
# Out:
# LBP ran for 5 iterations. Converged = 0.9966208476517755

# %%
# input: [(func, sim), (func, sim)...]
def getRank(prediction):
    predict = sorted(prediction, key=lambda x: x[1])
    rank = 1
    lastsim = -1
    predicts = []
    ranks = []
    for (func, sim) in predict:
        if np.isclose(sim, lastsim):
            predicts.append(func)
            ranks.append(rank)
        else:
            predicts.append(func)
            ranks.append(rank)
            rank += 1
        lastsim = sim
    sm = softmax(range(ranks[-1]+1))
    for i in range(len(ranks)):
        ranks[i] = sm[ranks[i]]
    ranks.append(sm[0])
    return predicts, ranks

def softmax(x):
    return np.exp(x)/np.sum(np.exp(x))

def get_node_prior_belief(knn_all):
    prediction = defaultdict(set)
    sim_dict = defaultdict(float)
    for [(name, distance), predict, sim] in knn_all:
        if sim > 0.95:
            for [lib, version, func] in predict:
                prediction[name].add((func, lib))
                if sim_dict[(name, func, lib)] < sim:
                    sim_dict[(name, func, lib)] = sim
                    
    prediction_with_sim = defaultdict(list)
    
    for name in prediction.keys():
        for (func, lib) in prediction[name]:
            prediction_with_sim[name].append(((func, lib), sim_dict[(name, func, lib)]))
            
    global_dict = defaultdict(list)
    global_beliefs = defaultdict(list)
    for func in prediction_with_sim.keys():
        predicts, beliefs = getRank(prediction_with_sim[func])
        global_dict[func] = predicts
        global_beliefs[func] = beliefs
        
    return global_dict, global_beliefs

get_node_prior_belief(knn_all)
# Out:
# (defaultdict(list,
#              {'ENGINE_get_last': [('ENGINE_get_first', 'libcrypto'),
#                ('ENGINE_get_last', 'libcrypto')],
#               'SSL_srp_server_param_with_username': [('SSL_srp_server_param_with_username',
#                 'libssl')],
#               'read_string_inner': [('read_string_inner', 'libcrypto')],
#               'RSA_padding_check_PKCS1_type_2': [('RSA_padding_check_PKCS1_type_2',
#                 'libcrypto')],
#               'X509_VERIFY_PARAM_table_cleanup': [('X509_VERIFY_PARAM_table_cleanup',
#                 'libcrypto')],
#               'X509_PURPOSE_get0': [('X509_PURPOSE_get0', 'libcrypto')],
#               'PEM_read_bio_Parameters': [('PEM_read_bio_PrivateKey',
#                 'libcrypto'),
#                ('x509_name_ex_d2i', 'libcrypto'),
#                ('PEM_read_bio_Parameters', 'libcrypto')],
#               'DSO_set_name_converter': [('DSO_set_name_converter',
#                 'libcrypto')],
#               'PKCS7_get_attribute': [('PKCS7_get_signed_attribute',
#                 'libcrypto'),
#                ('PKCS7_get_attribute', 'libcrypto')],
#               'dtls1_reset_seq_numbers': [('dtls1_reset_seq_numbers',
#                 'libssl')],
#               'BN_mod_add_quick': [('BN_mod_add_quick', 'libcrypto'),
#                ('BN_mod_lshift1_quick', 'libcrypto')],
#               'print_qualifiers': [('print_qualifiers', 'libcrypto')],
#               'asn1_enc_init': [('asn1_enc_init', 'libcrypto')],
#               'RSA_generate_key_ex': [('RSA_eay_private_decrypt', 'libcrypto'),
#                ('X509_verify_cert', 'libcrypto')],
#               'PKCS7_simple_smimecap': [('PKCS7_simple_smimecap',
#                 'libcrypto')],
#               'SSL_CTX_set_client_cert_engine': [('SSL_CTX_set_client_cert_engine',
#                 'libssl')],
#               'asn1_check_tlen': [('asn1_check_tlen.constprop.1', 'libcrypto'),
#                ('asn1_check_tlen', 'libcrypto')],
#               'lh_doall_arg': [('OPENSSL_LH_doall', 'libcrypto'),
#                ('lh_doall', 'libcrypto'),
#                ('OPENSSL_LH_doall_arg', 'libcrypto'),
#                ('lh_doall_arg', 'libcrypto')],
#               'X509_to_X509_REQ': [('X509_to_X509_REQ', 'libcrypto')],
#               'Camellia_Ekeygen': [('Camellia_Ekeygen', 'libcrypto')],
#               'inflateCodesUsed': [('inflateCodesUsed', 'libz')],
#               'X509_ALGOR_set0': [('X509_ALGOR_set0', 'libcrypto')],
#               'ASN1_template_new': [('ASN1_template_new', 'libcrypto')],
#               'DES_ede3_cfb64_encrypt': [('DES_ede3_cfb64_encrypt',
#                 'libcrypto')],
#               'ngx_http_fastcgi_create_request': [('EC_POINTs_mul',
#                 'libcrypto')],
#               'ec_GFp_simple_group_get_curve': [('o2i_SCT_LIST', 'libcrypto'),
#                ('PKCS12_add_key', 'libcrypto'),
#                ('ec_GFp_simple_group_get_curve_GFp', 'libcrypto'),
#                ('ec_GFp_simple_group_get_curve', 'libcrypto')],
#               'dtls1_retransmit_message': [('dtls1_retransmit_message',
#                 'libssl')],
#               'PKCS7_add_certificate': [('PKCS7_add_crl', 'libcrypto'),
#                ('PKCS7_add_certificate', 'libcrypto')],
#               'ASN1_d2i_fp': [('ASN1_item_d2i_fp', 'libcrypto'),
#                ('ASN1_d2i_fp', 'libcrypto')],
#               'X509_VERIFY_PARAM_lookup': [('X509_VERIFY_PARAM_lookup',
#                 'libcrypto')],
#               'bn_extract_to_array_512': [('bn_extract_to_array_512',
#                 'libcrypto')],
#               'ssl_update_cache': [('ssl_update_cache', 'libssl')],
#               'ERR_load_CONF_strings': [('ERR_load_PEM_strings', 'libcrypto'),
#                ('ERR_load_X509V3_strings', 'libcrypto'),
#                ('ERR_load_EVP_strings', 'libcrypto'),
#                ('ERR_load_X509_strings', 'libcrypto')],
#               'ssl2_read_internal': [('ssl3_get_client_hello', 'libssl'),
#                ('ssl2_read_internal', 'libssl')],
#               'ASN1_UTCTIME_set': [('ASN1_GENERALIZEDTIME_set', 'libcrypto'),
#                ('ASN1_UTCTIME_set', 'libcrypto')],
#               'ec_GFp_simple_group_copy': [('ec_GFp_simple_group_copy',
#                 'libcrypto')],
#               'X509_LOOKUP_by_fingerprint': [('X509_LOOKUP_by_alias',
#                 'libcrypto'),
#                ('X509_LOOKUP_by_fingerprint', 'libcrypto')],
#               'rsa_item_sign': [('rsa_item_sign', 'libcrypto')],
#               'BN_mod_lshift1': [('BN_mod_add', 'libcrypto'),
#                ('BN_mod_sub', 'libcrypto'),
#                ('BN_mod_lshift1', 'libcrypto')],
#               'UI_new': [('UI_new', 'libcrypto')],
#               'BN_rshift1': [('BN_rshift1', 'libcrypto')],
#               'ssl3_renegotiate': [('ssl3_renegotiate', 'libssl')],
#               'OBJ_cleanup': [('OBJ_cleanup', 'libcrypto')],
#               'ssl3_get_cert_verify': [('ssl3_get_cert_verify', 'libssl')],
#               'PKCS7_get_smimecap': [('PKCS7_get_smimecap', 'libcrypto')],
#               'ngx_http_rewrite_if': [('ssl_cert_dup', 'libssl')],
#               'EVP_PKEY_free': [('EVP_PKEY_free', 'libcrypto')],
#               'SSL_get_current_compression': [('SSL_get_privatekey', 'libssl'),
#                ('SSL_get_certificate', 'libssl'),
#                ('SSL_get_current_compression', 'libssl')],
#               'OPENSSL_showfatal': [('BIO_snprintf', 'libcrypto'),
#                ('BIO_printf', 'libcrypto'),
#                ('gzprintf', 'libz'),
#                ('OPENSSL_showfatal', 'libcrypto')],
#               'b64_free': [('SSL_SRP_CTX_free', 'libssl'),
#                ('def_destroy', 'libcrypto')],
#               'EC_GROUP_get_trinomial_basis': [('EC_GROUP_get_trinomial_basis',
#                 'libcrypto')],
#               'do_print_ex.constprop.4': [('tls1_enc', 'libssl'),
#                ('do_print_ex.constprop.3', 'libcrypto'),
#                ('do_print_ex.constprop.4', 'libcrypto')],
#               'cca_rsa_sign': [('cca_rsa_verify', 'libcrypto'),
#                ('cca_rsa_sign', 'libcrypto')],
#               'X509_OBJECT_free_contents': [('X509_OBJECT_up_ref_count',
#                 'libcrypto'),
#                ('X509_OBJECT_free_contents', 'libcrypto')],
#               'BN_get_word': [('BN_get_word', 'libcrypto')],
#               'fast_forward_first_char2': [('int_rsa_verify', 'libcrypto')],
#               'mime_param_cmp': [('mime_param_cmp', 'libcrypto')],
#               'EVP_MD_CTX_md': [('SSL_CTX_get_timeout', 'libssl'),
#                ('X509_EXTENSION_get_object', 'libcrypto'),
#                ('X509_NAME_ENTRY_get_object', 'libcrypto'),
#                ('EVP_MD_CTX_md', 'libcrypto'),
#                ('X509_ATTRIBUTE_get0_object', 'libcrypto')],
#               'engine_table_register': [('engine_table_register',
#                 'libcrypto')],
#               'BIO_sock_non_fatal_error': [('BIO_fd_non_fatal_error',
#                 'libcrypto'),
#                ('BIO_sock_non_fatal_error', 'libcrypto')],
#               'BUF_MEM_free': [('BUF_MEM_free', 'libcrypto')],
#               'file_ctrl': [('d2i_ASN1_OBJECT', 'libcrypto'),
#                ('CMS_dataFinal', 'libcrypto'),
#                ('file_ctrl', 'libcrypto')],
#               'BN_RECP_CTX_free': [('SSL_SESSION_free', 'libssl'),
#                ('BN_MONT_CTX_free', 'libcrypto'),
#                ('BN_RECP_CTX_free', 'libcrypto')],
#               'NCONF_free': [('NCONF_free', 'libcrypto')],
#               'DSA_generate_key': [('DSA_generate_key', 'libcrypto')],
#               'EC_POINT_set_affine_coordinates_GF2m': [('EC_POINT_oct2point',
#                 'libcrypto'),
#                ('EC_POINT_get_affine_coordinates_GF2m', 'libcrypto'),
#                ('EC_POINT_set_compressed_coordinates_GF2m', 'libcrypto'),
#                ('EC_POINT_set_affine_coordinates_GF2m', 'libcrypto')],
#               'EC_KEY_set_public_key': [('TS_RESP_CTX_set_signer_key',
#                 'libcrypto'),
#                ('EC_KEY_set_public_key', 'libcrypto')],
#               'RSA_padding_check_X931': [('RSA_padding_check_X931',
#                 'libcrypto')],
#               'EVP_PKEY_asn1_get0_info': [('EVP_PKEY_asn1_get0_info',
#                 'libcrypto')],
#               'DSA_set_method': [('RSA_set_method', 'libcrypto'),
#                ('DH_set_method', 'libcrypto'),
#                ('DSA_set_method', 'libcrypto')],
#               'file_gets': [('file_gets', 'libcrypto')],
#               'CRYPTO_realloc': [('CRYPTO_realloc', 'libcrypto')],
#               'X509at_add1_attr_by_OBJ': [('CMS_sign', 'libcrypto'),
#                ('PKCS7_sign', 'libcrypto'),
#                ('X509at_add1_attr_by_OBJ', 'libcrypto')],
#               'dtls1_listen': [('dtls1_listen', 'libssl')],
#               'ASN1_BIT_STRING_set_bit': [('ASN1_BIT_STRING_set_bit',
#                 'libcrypto')],
#               'PKCS7_add_signature': [('v2i_GENERAL_NAMES', 'libcrypto'),
#                ('X509V3_EXT_i2d', 'libcrypto'),
#                ('CMS_sign_receipt', 'libcrypto'),
#                ('eckey_pub_print', 'libcrypto'),
#                ('ecdsa_do_sign', 'libcrypto'),
#                ('v2i_TLS_FEATURE', 'libcrypto'),
#                ('PKCS7_add_signature', 'libcrypto')],
#               'sk_is_sorted': [('OPENSSL_sk_is_sorted', 'libcrypto'),
#                ('sk_is_sorted', 'libcrypto')],
#               'ssl3_setup_read_buffer': [('ssl3_setup_read_buffer', 'libssl')],
#               'BIO_asn1_set_suffix': [('EVP_MD_do_all', 'libcrypto'),
#                ('EVP_MD_do_all_sorted', 'libcrypto'),
#                ('EVP_CIPHER_do_all', 'libcrypto'),
#                ('EVP_CIPHER_do_all_sorted', 'libcrypto'),
#                ('BN_is_prime_fasttest', 'libcrypto'),
#                ('BN_is_prime', 'libcrypto'),
#                ('OBJ_NAME_do_all', 'libcrypto'),
#                ('engine_table_doall', 'libcrypto'),
#                ('BIO_asn1_set_suffix', 'libcrypto'),
#                ('BIO_asn1_set_prefix', 'libcrypto')],
#               'ssl3_write_bytes': [('deflate', 'libz'),
#                ('ssl3_write_bytes', 'libssl')],
#               'bn_dup_expand': [('bn_dup_expand', 'libcrypto')],
#               'ngx_output_chain': [('ssl3_get_certificate_request', 'libssl'),
#                ('dtls1_get_record', 'libssl')],
#               'v2i_POLICY_CONSTRAINTS': [('v2i_BASIC_CONSTRAINTS',
#                 'libcrypto'),
#                ('v2i_POLICY_CONSTRAINTS', 'libcrypto')],
#               'ec_GFp_simple_cmp': [('ecp_nistz256_mult_precompute',
#                 'libcrypto'),
#                ('ec_GFp_simple_set_compressed_coordinates', 'libcrypto'),
#                ('BN_mod_mul_reciprocal', 'libcrypto'),
#                ('ec_GFp_simple_cmp', 'libcrypto')],
#               '_tr_align': [('_tr_align', 'libz')],
#               'dtls1_start_timer': [('dtls1_double_timeout', 'libssl'),
#                ('dtls1_start_timer', 'libssl')],
#               'ERR_print_errors_cb': [('ERR_print_errors_cb', 'libcrypto')],
#               'dynamic_ctrl': [('dh_private_print', 'libcrypto'),
#                ('tls_process_server_hello', 'libssl'),
#                ('EVP_CipherInit_ex', 'libcrypto'),
#                ('rsa_ossl_private_decrypt', 'libcrypto')],
#               'aesni_xts_encrypt': [('aesni_xts_decrypt', 'libcrypto'),
#                ('aesni_xts_encrypt', 'libcrypto')],
#               'PEM_ASN1_read': [('PEM_ASN1_read', 'libcrypto')],
#               'i2v_EXTENDED_KEY_USAGE': [('i2v_EXTENDED_KEY_USAGE',
#                 'libcrypto')],
#               'ssl_set_cert': [('SSL_CTX_use_certificate', 'libssl'),
#                ('SSL_use_certificate', 'libssl')],
#               '_vpaes_encrypt_core': [('_vpaes_decrypt_core', 'libcrypto'),
#                ('_vpaes_encrypt_core', 'libcrypto')],
#               'X509V3_add_value_bool_nf': [('X509V3_add_value_bool',
#                 'libcrypto'),
#                ('X509V3_add_value_bool_nf', 'libcrypto')],
#               'EVP_PKEY_CTX_get_keygen_info': [('EVP_PKEY_CTX_get_keygen_info',
#                 'libcrypto')],
#               'OBJ_find_sigid_by_algs': [('OBJ_find_sigid_by_algs',
#                 'libcrypto')],
#               'i2d_ASN1_OBJECT': [('i2d_ASN1_OBJECT', 'libcrypto')],
#               'vpaes_cbc_encrypt': [('vpaes_cbc_encrypt', 'libcrypto')],
#               'OCSP_crl_reason_str': [('OCSP_crl_reason_str', 'libcrypto')],
#               'pkey_ec_paramgen': [('pkey_ec_paramgen', 'libcrypto')],
#               'CAST_ofb64_encrypt': [('BF_ofb64_encrypt', 'libcrypto'),
#                ('CAST_ofb64_encrypt', 'libcrypto')],
#               'ECParameters_print': [('PKCS7_add_recipient', 'libcrypto'),
#                ('DSAparams_print', 'libcrypto'),
#                ('ECParameters_print', 'libcrypto')],
#               'GENERAL_NAME_print': [('GENERAL_NAME_print', 'libcrypto')],
#               'cswift_mod_exp_dh': [('cswift_mod_exp_mont', 'libcrypto'),
#                ('cswift_mod_exp_dh', 'libcrypto')],
#               'sock_read': [('sock_read', 'libcrypto'),
#                ('fd_read', 'libcrypto')],
#               'bi_windup': [('bi_windup', 'libz')],
#               'engine_unlocked_init': [('engine_unlocked_init', 'libcrypto')],
#               'ERR_get_error_line_data': [('ERR_get_error_line_data',
#                 'libcrypto')],
#               'RAND_poll': [('BN_generate_prime_ex', 'libcrypto'),
#                ('ssl23_connect', 'libssl'),
#                ('X509_policy_check', 'libcrypto'),
#                ('RAND_poll', 'libcrypto'),
#                ('get_crl_sk', 'libcrypto'),
#                ('X509_verify_cert', 'libcrypto')],
#               'ASN1_OBJECT_create': [('ASN1_OBJECT_create', 'libcrypto')],
#               'GENERAL_NAME_get0_value': [('GENERAL_NAME_get0_value',
#                 'libcrypto')],
#               'private_RC4_set_key': [('RC4_set_key', 'libcrypto'),
#                ('private_RC4_set_key', 'libcrypto')],
#               'ngx_http_scgi_init_params.isra.3': [('ec_GFp_simple_points_make_affine',
#                 'libcrypto')],
#               'ngx_ssl_get_serial_number': [('BIO_new_buffer_ssl_connect',
#                 'libssl')],
#               'EC_KEY_print_fp': [('DSAparams_print_fp', 'libcrypto'),
#                ('ECParameters_print_fp', 'libcrypto')],
#               'CRYPTO_get_new_dynlockid': [('ec_asn1_parameters2group',
#                 'libcrypto'),
#                ('EC_GROUP_new_from_ecparameters', 'libcrypto'),
#                ('CRYPTO_get_new_dynlockid', 'libcrypto')],
#               'names_lh_free_LHASH_DOALL': [('names_lh_free_LHASH_DOALL',
#                 'libcrypto')],
#               'compile_regex': [('ssl_cipher_process_rulestr', 'libssl'),
#                ('ssl_set_cert_masks', 'libssl'),
#                ('ssl_get_server_send_cert', 'libssl'),
#                ('BN_mod_exp_mont', 'libcrypto'),
#                ('ssl_cipher_process_rulestr.isra.3', 'libssl'),
#                ('inflate_table', 'libz'),
#                ('ssl_parse_clienthello_tlsext', 'libssl')],
#               'X509_OBJECT_up_ref_count': [('X509_OBJECT_up_ref_count',
#                 'libcrypto')],
#               'BN_div_word': [('BN_div_word', 'libcrypto')],
#               'eckey_pub_print': [('ecdsa_sign_setup', 'libcrypto'),
#                ('rsa_pss_to_ctx', 'libcrypto'),
#                ('eckey_priv_print', 'libcrypto'),
#                ('eckey_pub_print', 'libcrypto')],
#               'dh_pub_decode': [('dh_priv_decode', 'libcrypto'),
#                ('eckey_priv_decode', 'libcrypto'),
#                ('dh_pub_decode', 'libcrypto')],
#               'SSL_CIPHER_get_name': [('SSL_CIPHER_get_name', 'libssl')],
#               'X509_NAME_add_entry_by_txt': [('X509_NAME_add_entry_by_txt',
#                 'libcrypto')],
#               'rc2_ctrl': [('rc2_ctrl', 'libcrypto')],
#               'MD4_Update': [('MD4_Update', 'libcrypto')],
#               'ssl3_release_read_buffer': [('ssl3_release_write_buffer',
#                 'libssl'),
#                ('ssl3_release_read_buffer', 'libssl')],
#               'SMIME_read_ASN1': [('SMIME_read_PKCS7', 'libcrypto'),
#                ('SMIME_read_ASN1', 'libcrypto')],
#               'SSL_CTX_use_RSAPrivateKey_ASN1': [('SSL_use_RSAPrivateKey_ASN1',
#                 'libssl'),
#                ('SSL_CTX_use_RSAPrivateKey_ASN1', 'libssl')],
#               'ssl_check_serverhello_tlsext': [('ssl_check_serverhello_tlsext',
#                 'libssl')],
#               'SSL_get_cipher_list': [('SSL_get_cipher_list', 'libssl')],
#               'PKCS12_key_gen_asc': [('PKCS12_key_gen_asc', 'libcrypto')],
#               'X509V3_EXT_conf_nid': [('X509_NAME_hash', 'libcrypto'),
#                ('SHA512', 'libcrypto'),
#                ('SHA256', 'libcrypto'),
#                ('print_fp', 'libcrypto'),
#                ('X509V3_EXT_conf', 'libcrypto'),
#                ('X509V3_EXT_conf_nid', 'libcrypto')],
#               'atalla_mod_exp': [('atalla_mod_exp', 'libcrypto')],
#               'X509at_get_attr': [('X509at_delete_attr', 'libcrypto'),
#                ('X509v3_get_ext', 'libcrypto')],
#               'PKCS5_v2_PBKDF2_keyivgen': [('ssl3_get_client_key_exchange',
#                 'libssl'),
#                ('dtls1_send_client_key_exchange', 'libssl'),
#                ('PKCS5_v2_PBKDF2_keyivgen', 'libcrypto')],
#               'UI_ctrl': [('UI_ctrl', 'libcrypto')],
#               'aes_cfb1_cipher': [('camellia_cfb1_cipher', 'libcrypto'),
#                ('aes_cfb1_cipher', 'libcrypto')],
#               'obj_trust': [('trust_1oid', 'libcrypto'),
#                ('obj_trust', 'libcrypto')],
#               'SSL_CTX_use_certificate_file': [('SSL_CTX_use_PrivateKey_file',
#                 'libssl'),
#                ('SSL_use_PrivateKey_file', 'libssl'),
#                ('SSL_CTX_use_certificate_file', 'libssl')],
#               'NCONF_free_data': [('NCONF_free_data', 'libcrypto')],
#               'app_info_free': [('app_info_free', 'libcrypto')],
#               'ASN1_INTEGER_set': [('ASN1_ENUMERATED_set', 'libcrypto'),
#                ('ASN1_INTEGER_set', 'libcrypto')],
#               'ERR_release_err_state_table': [('ERR_release_err_state_table',
#                 'libcrypto')],
#               'HMAC_Init': [('HMAC_Init', 'libcrypto')],
#               'ssl3_clear': [('ssl3_clear', 'libssl')],
#               'SXNET_add_id_ulong': [('SXNET_add_id_ulong', 'libcrypto')],
#               'SSL_CTX_use_psk_identity_hint': [('SSL_CTX_use_psk_identity_hint',
#                 'libssl')],
#               'ssl_sess_cert_new': [('ssl_cert_new', 'libssl'),
#                ('X509_STORE_CTX_new', 'libcrypto'),
#                ('ssl_sess_cert_new', 'libssl')],
#               'ngx_mail_core_listen': [('ssl_create_cipher_list', 'libssl'),
#                ('ssl3_read_bytes', 'libssl'),
#                ('do_dtls1_write', 'libssl'),
#                ('ssl3_get_server_hello', 'libssl'),
#                ('dtls_get_message', 'libssl'),
#                ('ssl_parse_clienthello_tlsext', 'libssl')],
#               'i2a_ASN1_STRING': [('i2a_ASN1_ENUMERATED', 'libcrypto'),
#                ('i2a_ASN1_STRING', 'libcrypto')],
#               'SSL_get_fd': [('SSL_get_fd', 'libssl'),
#                ('SSL_get_rfd', 'libssl')],
#               'BN_mod_exp_mont_word': [('ec_GF2m_simple_mul', 'libcrypto'),
#                ('BN_mod_exp_mont_word', 'libcrypto')],
#               'ENGINE_ctrl_cmd_string': [('ENGINE_ctrl_cmd_string',
#                 'libcrypto')],
#               'pbe_cmp': [('pbe_cmp', 'libcrypto')],
#               'tls1_process_heartbeat': [('tls1_process_heartbeat', 'libssl')],
#               'BN_bntest_rand': [('BN_bntest_rand', 'libcrypto')],
#               'X509_EXTENSION_set_critical': [('X509_EXTENSION_set_critical',
#                 'libcrypto')],
#               'dtls1_ctrl': [('dtls1_ctrl', 'libssl')],
#               'rc4_hmac_md5_ctrl': [('rc4_hmac_md5_ctrl', 'libcrypto')],
#               'tls1_ec_nid2curve_id': [('tls1_ec_nid2curve_id', 'libssl')],
#               'ssl_clear_cipher_ctx': [('ssl_clear_cipher_ctx', 'libssl')],
#               'ssl3_record_sequence_update': [('ssl3_record_sequence_update',
#                 'libssl')],
#               'ngx_ssl_check_host': [('TS_CONF_set_digests', 'libcrypto')],
#               'X509_STORE_load_locations': [('X509_STORE_load_locations',
#                 'libcrypto')],
#               'atalla_dsa_mod_exp': [('atalla_dsa_mod_exp', 'libcrypto')],
#               'CMS_add0_RevocationInfoChoice': [('CMS_add0_CertificateChoices',
#                 'libcrypto'),
#                ('CMS_add0_RevocationInfoChoice', 'libcrypto')],
#               'hwcrhk_load_pubkey': [('hwcrhk_load_pubkey', 'libcrypto')],
#               'EC_GROUP_copy': [('d2i_PrivateKey', 'libcrypto'),
#                ('d2i_ASN1_HEADER', 'libcrypto'),
#                ('cms_EncryptedContent_init_bio', 'libcrypto'),
#                ('d2i_AutoPrivateKey', 'libcrypto'),
#                ('EC_GROUP_copy', 'libcrypto')],
#               'WHIRLPOOL_Update': [('WHIRLPOOL_Update', 'libcrypto')],
#               'PEM_write': [('PEM_write_bio', 'libcrypto'),
#                ('PEM_write', 'libcrypto')],
#               'SSL_get_psk_identity_hint': [('SSL_get_psk_identity_hint',
#                 'libssl')],
#               'ssl3_cbc_remove_padding': [('ssl3_cbc_remove_padding',
#                 'libssl')],
#               'SHA384_Update': [('MD4_Update', 'libcrypto'),
#                ('SHA384_Update', 'libcrypto'),
#                ('SHA512_Update', 'libcrypto')],
#               'NCONF_load_bio': [('NCONF_load_bio', 'libcrypto')],
#               'eckey_pub_decode': [('eckey_priv_decode', 'libcrypto'),
#                ('eckey_pub_decode', 'libcrypto')],
#               'engine_table_unregister': [('engine_table_unregister',
#                 'libcrypto')],
#               'cms_content_bio': [('CMS_is_detached', 'libcrypto'),
#                ('cms_content_bio', 'libcrypto')],
#               'v2i_AUTHORITY_INFO_ACCESS': [('v2i_AUTHORITY_INFO_ACCESS',
#                 'libcrypto')],
#               'SSL_get_peer_finished': [('SSL_get_peer_finished', 'libssl'),
#                ('SSL_get_finished', 'libssl')],
#               'aep_get_connection': [('aep_get_connection', 'libcrypto')],
#               'BN_set_bit': [('BN_set_bit', 'libcrypto')],
#               'BN_GF2m_mod': [('BN_GF2m_mod_inv', 'libcrypto'),
#                ('BN_GF2m_mod', 'libcrypto')],
#               'i2d_PKCS8PrivateKey_nid_fp': [('i2d_PKCS8PrivateKey_fp',
#                 'libcrypto'),
#                ('PEM_write_PKCS8PrivateKey', 'libcrypto'),
#                ('PEM_write_PKCS8PrivateKey_nid', 'libcrypto'),
#                ('i2d_PKCS8PrivateKey_nid_fp', 'libcrypto')],
#               'DES_set_key_unchecked': [('DES_set_key_unchecked',
#                 'libcrypto')],
#               'X509_PKEY_new': [('X509_PKEY_new', 'libcrypto')],
#               'SSL_get_shared_ciphers': [('SSL_get_shared_ciphers', 'libssl')],
#               'ngx_http_fastcgi_non_buffered_filter': [('BN_nist_mod_384',
#                 'libcrypto'),
#                ('ssl3_client_hello', 'libssl'),
#                ('d2i_SSL_SESSION', 'libssl')],
#               'X509_alias_set1': [('X509_keyid_set1', 'libcrypto'),
#                ('X509_alias_set1', 'libcrypto')],
#               'CRYPTO_get_ex_data_implementation': [('ERR_get_implementation',
#                 'libcrypto'),
#                ('CRYPTO_get_ex_data_implementation', 'libcrypto')],
#               'X509V3_get_string': [('X509V3_get_section', 'libcrypto'),
#                ('X509V3_get_string', 'libcrypto')],
#               'ecdsa_check': [('dtls1_buffer_record.isra.6.part.7', 'libssl'),
#                ('EVP_PKEY_CTX_new_id', 'libcrypto')],
#               'PEM_X509_INFO_read': [('PEM_read_DHparams', 'libcrypto'),
#                ('PEM_read_PrivateKey', 'libcrypto'),
#                ('PEM_X509_INFO_read', 'libcrypto')],
#               'X509_policy_check': [('ssl_create_cipher_list', 'libssl'),
#                ('CMS_verify', 'libcrypto'),
#                ('PKCS7_verify', 'libcrypto'),
#                ('tls_process_key_exchange', 'libssl'),
#                ('TS_RESP_create_response', 'libcrypto'),
#                ('X509_policy_check', 'libcrypto')],
#               'ssl3_cbc_record_digest_supported': [('ssl3_cbc_record_digest_supported',
#                 'libssl')],
#               'UI_method_get_writer': [('RSA_flags', 'libcrypto'),
#                ('BIO_ADDRINFO_sockaddr', 'libcrypto'),
#                ('OBJ_get0_data', 'libcrypto'),
#                ('UI_method_get_flusher', 'libcrypto'),
#                ('BIO_ADDRINFO_address', 'libcrypto'),
#                ('X509_EXTENSION_get_data', 'libcrypto'),
#                ('UI_method_get_writer', 'libcrypto')],
#               'dsa_cmp_parameters': [('dh_pub_cmp', 'libcrypto'),
#                ('dsa_cmp_parameters', 'libcrypto')],
#               'PKCS12_unpack_authsafes': [('PKCS12_unpack_authsafes',
#                 'libcrypto')],
#               'd2i_ASN1_OBJECT': [('d2i_ASN1_OBJECT', 'libcrypto')],
#               'tls1_enc': [('crl_cb', 'libcrypto'),
#                ('get_crl_sk', 'libcrypto'),
#                ('internal_verify', 'libcrypto'),
#                ('tls1_enc', 'libssl')],
#               'ERR_remove_thread_state': [('ERR_remove_thread_state',
#                 'libcrypto')],
#               'UI_dup_verify_string': [('UI_add_input_string', 'libcrypto'),
#                ('UI_dup_input_string', 'libcrypto'),
#                ('UI_dup_verify_string', 'libcrypto')],
#               'RSA_blinding_on': [('v2i_TLS_FEATURE', 'libcrypto'),
#                ('RSA_setup_blinding', 'libcrypto'),
#                ('RSA_blinding_on', 'libcrypto')],
#               'CRYPTO_get_locked_mem_ex_functions': [('CRYPTO_get_locked_mem_functions',
#                 'libcrypto'),
#                ('CRYPTO_get_locked_mem_ex_functions', 'libcrypto')],
#               'CMS_RecipientInfo_ktri_get0_algs': [('CMS_RecipientInfo_ktri_get0_algs',
#                 'libcrypto')],
#               'pkey_ec_sign': [('pkey_ec_sign', 'libcrypto')],
#               'EVP_CipherInit_ex': [('EVP_EncryptInit', 'libcrypto'),
#                ('EVP_CipherInit_ex', 'libcrypto')],
#               'TXT_DB_create_index': [('TXT_DB_create_index', 'libcrypto')],
#               'ssl_cert_type': [('ssl_cert_type', 'libssl')],
#               'BUF_strdup': [('BUF_strndup', 'libcrypto'),
#                ('BUF_strdup', 'libcrypto')],
#               'PKCS5_PBKDF2_HMAC': [('PKCS5_PBKDF2_HMAC', 'libcrypto')],
#               'sha256_block_data_order': [('sha256_block_data_order',
#                 'libcrypto')],
#               'ngx_http_memcached_process_header': [('ssl3_get_certificate_request',
#                 'libssl')],
#               'dtls1_dispatch_alert': [('dtls1_dispatch_alert', 'libssl')],
#               'X509_REQ_extension_nid': [('X509_REQ_extension_nid',
#                 'libcrypto')],
#               'X509_get_pubkey': [('X509_get_pubkey', 'libcrypto')],
#               'OBJ_NAME_get': [('PKCS7_encrypt', 'libcrypto'),
#                ('SCT_validate', 'libcrypto'),
#                ('OBJ_NAME_get', 'libcrypto')],
#               'EVP_MD_CTX_copy': [('EVP_MD_CTX_copy_ex', 'libcrypto'),
#                ('EVP_MD_CTX_copy', 'libcrypto')],
#               '_aesni_decrypt3': [('_aesni_encrypt3', 'libcrypto'),
#                ('_aesni_decrypt3', 'libcrypto')],
#               '_aesni_decrypt4': [('_aesni_encrypt4', 'libcrypto'),
#                ('_aesni_decrypt4', 'libcrypto')],
#               '_aesni_decrypt6': [('_aesni_decrypt8', 'libcrypto'),
#                ('_aesni_encrypt8', 'libcrypto'),
#                ('_aesni_encrypt6', 'libcrypto'),
#                ('_aesni_decrypt6', 'libcrypto')],
#               'ASN1_STRING_cmp': [('ASN1_STRING_cmp', 'libcrypto')],
#               'ASN1_i2d_fp': [('ASN1_item_i2d_fp', 'libcrypto'),
#                ('ASN1_i2d_fp', 'libcrypto')],
#               'aes_ecb_cipher': [('des_ede_ecb_cipher', 'libcrypto'),
#                ('camellia_ecb_cipher', 'libcrypto'),
#                ('aes_ecb_cipher', 'libcrypto')],
#               'BN_options': [('BN_options', 'libcrypto')],
#               'ssl_cert_new': [('ssl_cert_new', 'libssl')],
#               'EC_KEY_new': [('ASN1_OBJECT_new', 'libcrypto'),
#                ('EVP_PKEY_new', 'libcrypto'),
#                ('EC_KEY_new', 'libcrypto')],
#               'gost_cipher_do_cnt': [('RSA_verify_PKCS1_PSS_mgf1',
#                 'libcrypto'),
#                ('b64_read', 'libcrypto')],
#               'SSL_CTX_set_client_CA_list': [('SSL_set_client_CA_list',
#                 'libssl'),
#                ('SSL_CTX_set_client_CA_list', 'libssl')],
#               'file_write': [('file_write', 'libcrypto')],
#               'SSL_set_fd': [('SSL_set_fd', 'libssl')],
#               'X509_REQ_add_extensions_nid': [('X509_REQ_add_extensions',
#                 'libcrypto'),
#                ('X509_REQ_add_extensions_nid', 'libcrypto')],
#               'X509_LOOKUP_ctrl': [('X509_LOOKUP_ctrl', 'libcrypto')],
#               'trust_1oid': [('trust_1oid', 'libcrypto')],
#               'EVP_EncryptFinal_ex': [('EVP_EncryptFinal_ex', 'libcrypto'),
#                ('EVP_EncryptFinal', 'libcrypto')],
#               'ERR_load_ECDSA_strings': [('ERR_load_PEM_strings', 'libcrypto'),
#                ('ERR_load_X509V3_strings', 'libcrypto'),
#                ('ERR_load_EVP_strings', 'libcrypto'),
#                ('ERR_load_X509_strings', 'libcrypto')],
#               'EC_POINT_set_affine_coordinates_GFp': [('EC_POINT_get_affine_coordinates_GFp',
#                 'libcrypto'),
#                ('EC_POINT_set_compressed_coordinates_GFp', 'libcrypto'),
#                ('EC_POINT_get_affine_coordinates_GF2m', 'libcrypto'),
#                ('EC_POINT_set_affine_coordinates_GFp', 'libcrypto')],
#               'enc_write': [('enc_write', 'libcrypto')],
#               'OTHERNAME_cmp': [('OTHERNAME_cmp', 'libcrypto')],
#               'a2i_IPADDRESS_NC': [('a2i_IPADDRESS_NC', 'libcrypto')],
#               'lh_delete': [('OPENSSL_LH_delete', 'libcrypto'),
#                ('lh_delete', 'libcrypto')],
#               'EC_POINT_new': [('EC_POINT_new', 'libcrypto')],
#               'OBJ_obj2nid': [('OBJ_obj2nid', 'libcrypto')],
#               'bn_cmp_part_words': [('bn_cmp_part_words', 'libcrypto')],
#               'dtls1_do_write': [('dtls1_do_write', 'libssl')],
#               'dh_priv_decode': [('tls_construct_cke_gost', 'libssl'),
#                ('eckey_priv_decode', 'libcrypto'),
#                ('dh_pub_decode', 'libcrypto'),
#                ('dh_priv_decode', 'libcrypto')],
#               'ENGINE_add': [('ENGINE_add', 'libcrypto')],
#               'ssl23_write_bytes': [('ssl23_write_bytes', 'libssl')],
#               'BN_free': [('BN_free', 'libcrypto')],
#               'UI_set_result': [('UI_set_result', 'libcrypto')],
#               'ssl3_client_hello': [('ssl3_client_hello', 'libssl')],
#               'X509at_get0_data_by_OBJ': [('check_trust', 'libcrypto')],
#               'BN_MONT_CTX_free': [('SSL_CTX_free', 'libssl'),
#                ('BN_RECP_CTX_free', 'libcrypto'),
#                ('BN_MONT_CTX_free', 'libcrypto')],
#               'pkey_rsa_ctrl_str': [('pkey_rsa_ctrl_str', 'libcrypto')],
#               'HMAC_Final': [('HMAC_Final', 'libcrypto')],
#               'X509_LOOKUP_by_alias': [('X509_LOOKUP_by_issuer_serial',
#                 'libcrypto'),
#                ('X509_LOOKUP_by_alias', 'libcrypto')],
#               'ngx_http_validate_host': [('d2i_SCT_LIST', 'libcrypto')],
#               'SSL_renegotiate': [('SSL_renegotiate_abbreviated', 'libssl'),
#                ('SSL_renegotiate', 'libssl')],
#               'EVP_PKEY_asn1_free': [('BIO_ACCEPT_free', 'libcrypto'),
#                ('BIO_CONNECT_free', 'libcrypto'),
#                ('EVP_PKEY_CTX_free', 'libcrypto'),
#                ('X509V3_conf_free', 'libcrypto'),
#                ('DSA_SIG_free', 'libcrypto'),
#                ('BN_BLINDING_free', 'libcrypto'),
#                ('EVP_PKEY_asn1_free', 'libcrypto')],
#               'RSA_padding_add_PKCS1_PSS_mgf1': [('RSA_verify_PKCS1_PSS',
#                 'libcrypto'),
#                ('ssleay_rand_bytes', 'libcrypto'),
#                ('RSA_padding_add_PKCS1_PSS', 'libcrypto'),
#                ('RSA_padding_add_PKCS1_PSS_mgf1', 'libcrypto')],
#               'engine_pkey_meths_free': [('engine_pkey_asn1_meths_free',
#                 'libcrypto'),
#                ('engine_pkey_meths_free', 'libcrypto')],
#               'aesni_cbc_hmac_sha1_cipher': [('aesni_cbc_hmac_sha256_cipher',
#                 'libcrypto'),
#                ('aesni_cbc_hmac_sha1_cipher', 'libcrypto')],
#               'X509V3_string_free': [('X509V3_section_free', 'libcrypto'),
#                ('X509V3_string_free', 'libcrypto')],
#               'cswift_rsa_mod_exp': [('dtls1_send_server_key_exchange',
#                 'libssl'),
#                ('cswift_rsa_mod_exp', 'libcrypto')],
#               'ssl_prepare_serverhello_tlsext': [('ssl_prepare_serverhello_tlsext',
#                 'libssl')],
#               'hwcrhk_finish': [('hwcrhk_finish', 'libcrypto')],
#               'OBJ_NAME_add': [('OBJ_NAME_add', 'libcrypto')],
#               'BN_BLINDING_convert': [('BN_BLINDING_convert', 'libcrypto')],
#               'BIO_callback_ctrl': [('BIO_callback_ctrl', 'libcrypto')],
#               'SSL_do_handshake': [('SSL_do_handshake', 'libssl')],
#               'X509V3_EXT_add_nconf_sk': [('X509V3_EXT_add_nconf',
#                 'libcrypto'),
#                ('X509V3_EXT_CRL_add_nconf', 'libcrypto'),
#                ('X509V3_EXT_add_nconf_sk', 'libcrypto')],
#               'X509_ATTRIBUTE_set1_object': [('X509_ATTRIBUTE_set1_object',
#                 'libcrypto'),
#                ('X509_EXTENSION_set_object', 'libcrypto')],
#               'UI_get0_output_string': [('UI_method_get_opener', 'libcrypto'),
#                ('X509_NAME_ENTRY_get_data', 'libcrypto'),
#                ('SSL_COMP_get_name', 'libssl'),
#                ('UI_get0_output_string', 'libcrypto'),
#                ('SSL_CTX_get_ciphers', 'libssl')],
#               'PKCS5_PBE_keyivgen': [('PKCS5_PBE_keyivgen', 'libcrypto')],
#               'asn1_i2d_ex_primitive': [('ASN1_item_i2d', 'libcrypto'),
#                ('ASN1_mbstring_ncopy', 'libcrypto'),
#                ('ASN1_item_ex_i2d', 'libcrypto'),
#                ('asn1_i2d_ex_primitive', 'libcrypto')],
#               'EVP_DigestSignInit': [('EVP_DigestSignInit', 'libcrypto'),
#                ('EVP_DigestVerifyInit', 'libcrypto')],
#               'inflate': [('ssl_parse_clienthello_tlsext', 'libssl'),
#                ('dtls1_do_write', 'libssl'),
#                ('ssl3_read_bytes', 'libssl'),
#                ('BN_div', 'libcrypto'),
#                ('do_print_ex.constprop.3', 'libcrypto')],
#               'rsa_sig_print': [('X509_print_ex', 'libcrypto'),
#                ('rsa_sig_print', 'libcrypto')],
#               'EC_POINT_free': [('EC_GROUP_free', 'libcrypto'),
#                ('X509_LOOKUP_free', 'libcrypto'),
#                ('COMP_CTX_free', 'libcrypto'),
#                ('EC_POINT_free', 'libcrypto')],
#               'hex_to_string': [('hex_to_string', 'libcrypto')],
#               'CMS_add1_crl': [('CMS_add0_crl', 'libcrypto'),
#                ('CMS_add1_crl', 'libcrypto')],
#               'compile_recurse': [('ssl_add_clienthello_tlsext', 'libssl')],
#               'ec_copy_parameters': [('ec_copy_parameters', 'libcrypto')],
#               'X509V3_parse_list': [('X509V3_parse_list', 'libcrypto')],
#               'X509_CRL_METHOD_free': [('X509_CRL_METHOD_free', 'libcrypto')],
#               'X509_ATTRIBUTE_set1_data': [('CMS_decrypt_set1_pkey',
#                 'libcrypto'),
#                ('BN_mod_exp_mont_word', 'libcrypto'),
#                ('pkey_dh_paramgen', 'libcrypto'),
#                ('X509_ATTRIBUTE_set1_data', 'libcrypto')],
#               'ASN1_template_d2i': [('ASN1_template_d2i', 'libcrypto')],
#               'ssl3_get_cert_status': [('ssl_prepare_clienthello_tlsext',
#                 'libssl'),
#                ('ssl3_get_cert_status', 'libssl')],
#               'BN_ucmp': [('BN_ucmp', 'libcrypto')],
#               'cms_EnvelopedData_init_bio': [('cms_EnvelopedData_init_bio',
#                 'libcrypto')],
#               'bn_sqr_words': [('bn_sqr_words', 'libcrypto')],
#               'CMAC_Init': [('aes_gcm_ctrl', 'libcrypto'),
#                ('BN_rshift', 'libcrypto'),
#                ('str_copy', 'libcrypto'),
#                ('CMAC_Init', 'libcrypto')],
#               'BIO_set_cipher': [('BIO_set_cipher', 'libcrypto')],
#               'check_policy': [('check_policy', 'libcrypto')],
#               't_tob64': [('t_tob64', 'libcrypto')],
#               'BN_from_montgomery_word': [('str_copy', 'libcrypto'),
#                ('BN_hex2bn', 'libcrypto'),
#                ('BN_from_montgomery_word', 'libcrypto')],
#               'BN_GF2m_mod_sqr': [('BN_GF2m_mod_solve_quad', 'libcrypto'),
#                ('BN_GF2m_mod_sqr', 'libcrypto')],
#               'SSL_dup': [('SSL_dup', 'libssl')],
#               'BN_mod_exp2_mont': [('BN_mod_exp', 'libcrypto'),
#                ('BN_mod_exp2_mont', 'libcrypto')],
#               'def_load_bio': [('def_load_bio', 'libcrypto')],
#               'dtls1_read_failed': [('dtls1_read_failed', 'libssl')],
#               'dtls1_preprocess_fragment': [('dtls1_preprocess_fragment',
#                 'libssl')],
#               'X509V3_conf_free': [('pkey_ec_cleanup', 'libcrypto'),
#                ('EVP_PKEY_asn1_free', 'libcrypto'),
#                ('BIO_ACCEPT_free', 'libcrypto'),
#                ('BN_BLINDING_free', 'libcrypto'),
#                ('DSA_SIG_free', 'libcrypto'),
#                ('BIO_CONNECT_free', 'libcrypto'),
#                ('X509V3_conf_free', 'libcrypto')],
#               'find_firstassertedchar': [('ssl_parse_clienthello_tlsext',
#                 'libssl'),
#                ('def_load_bio', 'libcrypto'),
#                ('EVP_DecodeUpdate', 'libcrypto')],
#               'DIST_POINT_set_dpname': [('DIST_POINT_set_dpname',
#                 'libcrypto')],
#               'priv_decode_gost': [('ssl_add_cert_chain', 'libssl'),
#                ('PKCS7_dataDecode', 'libcrypto'),
#                ('OCSP_cert_id_new', 'libcrypto'),
#                ('PKCS7_dataInit', 'libcrypto')],
#               'X509_NAME_oneline': [('X509_NAME_oneline', 'libcrypto')],
#               'dtls1_is_timer_expired': [('dtls1_is_timer_expired', 'libssl')],
#               'tls12_get_req_sig_algs': [('tls12_get_req_sig_algs', 'libssl')],
#               'DH_new': [('RSA_new_method', 'libcrypto'),
#                ('RSA_new', 'libcrypto'),
#                ('DH_new', 'libcrypto')],
#               'BN_BLINDING_convert_ex': [('BN_BLINDING_convert_ex',
#                 'libcrypto')],
#               'des_ctrl': [('des_ctrl', 'libcrypto')],
#               'hwcrhk_get_pass': [('hwcrhk_get_pass', 'libcrypto')],
#               'ECDSA_do_sign': [('ECDSA_do_sign', 'libcrypto')],
#               'bn_GF2m_mul_2x2': [('bn_GF2m_mul_2x2', 'libcrypto')],
#               'ENGINE_get_digest': [('ENGINE_get_cipher', 'libcrypto'),
#                ('ENGINE_get_digest', 'libcrypto'),
#                ('ENGINE_get_pkey_meth', 'libcrypto'),
#                ('ENGINE_get_pkey_asn1_meth', 'libcrypto')],
#               'X509V3_get_value_int': [('s2i_ASN1_INTEGER', 'libcrypto'),
#                ('X509V3_get_value_int', 'libcrypto')],
#               'ubsec_finish': [('nuron_finish', 'libcrypto'),
#                ('cswift_finish', 'libcrypto'),
#                ('ibm_4758_cca_finish', 'libcrypto'),
#                ('ubsec_finish', 'libcrypto')],
#               'BIO_read': [('BIO_read', 'libcrypto')],
#               'SSL_CIPHER_get_version': [('SSL_CIPHER_get_version', 'libssl')],
#               'rsa_pub_print': [('dsa_param_print', 'libcrypto'),
#                ('DSAparams_print', 'libcrypto'),
#                ('rsa_pub_print', 'libcrypto')],
#               'RC2_ofb64_encrypt': [('DES_ofb64_encrypt', 'libcrypto'),
#                ('CAST_ofb64_encrypt', 'libcrypto'),
#                ('idea_ofb64_encrypt', 'libcrypto'),
#                ('IDEA_ofb64_encrypt', 'libcrypto'),
#                ('RC2_ofb64_encrypt', 'libcrypto'),
#                ('RC5_32_ofb64_encrypt', 'libcrypto')],
#               'X509_reject_clear': [('X509_trust_clear', 'libcrypto'),
#                ('X509_reject_clear', 'libcrypto')],
#               'X509_EXTENSION_set_object': [('X509_ATTRIBUTE_set1_object',
#                 'libcrypto'),
#                ('X509_EXTENSION_set_object', 'libcrypto')],
#               'sig_cb': [('sig_cb', 'libcrypto')],
#               'enc_read': [('enc_read', 'libcrypto')],
#               'aep_mod_exp_dh': [('aep_mod_exp.part.0', 'libcrypto'),
#                ('aep_mod_exp_mont', 'libcrypto'),
#                ('aep_mod_exp_dh', 'libcrypto'),
#                ('aep_mod_exp_dsa', 'libcrypto')],
#               'ssl3_handshake_mac': [('ssl3_handshake_mac', 'libssl')],
#               'X509v3_get_ext': [('X509at_delete_attr', 'libcrypto'),
#                ('X509v3_get_ext', 'libcrypto')],
#               'X509_PUBKEY_set': [('X509_PUBKEY_set', 'libcrypto')],
#               'ibm_4758_cca_finish': [('atalla_finish', 'libcrypto'),
#                ('nuron_finish', 'libcrypto'),
#                ('ubsec_finish', 'libcrypto'),
#                ('cswift_finish', 'libcrypto'),
#                ('ibm_4758_cca_finish', 'libcrypto')],
#               'ngx_blocking': [('PKCS8_add_keyusage', 'libcrypto'),
#                ('BIO_int_ctrl', 'libcrypto')],
#               'ERR_load_COMP_strings': [('ERR_load_PEM_strings', 'libcrypto'),
#                ('ERR_load_X509V3_strings', 'libcrypto'),
#                ('ERR_load_EVP_strings', 'libcrypto'),
#                ('ERR_load_X509_strings', 'libcrypto')],
#               'X509_print_fp': [('X509_print', 'libcrypto'),
#                ('X509_print_fp', 'libcrypto')],
#               '_x86_64_Camellia_decrypt': [('_x86_64_Camellia_encrypt',
#                 'libcrypto'),
#                ('_x86_64_Camellia_decrypt', 'libcrypto')],
#               'RIPEMD160_Update': [('MD4_Update', 'libcrypto'),
#                ('MD5_Update', 'libcrypto'),
#                ('SHA1_Update', 'libcrypto'),
#                ('SHA_Update', 'libcrypto'),
#                ('RIPEMD160_Update', 'libcrypto')],
#               'dsa_param_print': [('rsa_pub_print', 'libcrypto'),
#                ('dsa_param_print', 'libcrypto')],
#               'ENGINE_load_rsax': [('ENGINE_load_cswift', 'libcrypto'),
#                ('ENGINE_load_chil', 'libcrypto'),
#                ('ENGINE_load_nuron', 'libcrypto'),
#                ('ENGINE_load_atalla', 'libcrypto'),
#                ('ENGINE_load_dynamic', 'libcrypto'),
#                ('ENGINE_load_ubsec', 'libcrypto'),
#                ('ENGINE_load_rsax', 'libcrypto')],
#               'check_purpose_ssl_client': [('check_purpose_smime_encrypt',
#                 'libcrypto'),
#                ('check_purpose_ns_ssl_server', 'libcrypto'),
#                ('check_purpose_ssl_client', 'libcrypto')],
#               'CRYPTO_ccm128_decrypt': [('CRYPTO_ccm128_encrypt', 'libcrypto'),
#                ('CRYPTO_ccm128_decrypt', 'libcrypto')],
#               'ssl3_cleanup_key_block': [('ssl3_cleanup_key_block', 'libssl')],
#               'DSO_merge': [('DSO_merge', 'libcrypto')],
#               'dtls1_enc': [('tls1_enc', 'libssl'),
#                ('ec_GF2m_simple_point2oct', 'libcrypto'),
#                ('dtls1_enc', 'libssl')],
#               'RSA_set_method': [('DH_set_method', 'libcrypto'),
#                ('DSA_set_method', 'libcrypto'),
#                ('RSA_set_method', 'libcrypto')],
#               'ssl_create_cipher_list': [('ssl_cipher_process_rulestr.isra.3',
#                 'libssl'),
#                ('ssl_create_cipher_list', 'libssl')],
#               'BN_GF2m_mod_sqrt': [('BN_GF2m_mod_sqrt', 'libcrypto')],
#               'ngx_http_v2_send_window_update': [('EC_GROUP_copy',
#                 'libcrypto')],
#               'BN_mod_exp_recp': [('BN_mod_exp_simple', 'libcrypto'),
#                ('BN_mod_exp_recp.part.1', 'libcrypto'),
#                ('BN_mod_exp_recp', 'libcrypto')],
#               'd2i_SSL_SESSION': [('d2i_SSL_SESSION', 'libssl')],
#               'X509_print_ex': [('X509_print_ex_fp', 'libcrypto'),
#                ('BN_GF2m_mod_solve_quad_arr', 'libcrypto'),
#                ('X509_print_ex', 'libcrypto')],
#               'ssl_free_wbio_buffer': [('ssl_free_wbio_buffer', 'libssl')],
#               'ssl_do_client_cert_cb': [('ssl_do_client_cert_cb', 'libssl')],
#               'EVP_PKEY_sign_init': [('EVP_PKEY_decrypt_init', 'libcrypto')],
#               'bn_rand_range': [('BN_rand_range', 'libcrypto'),
#                ('BN_pseudo_rand_range', 'libcrypto')],
#               'X509_NAME_print_ex': [('ssl3_write_bytes', 'libssl'),
#                ('X509_NAME_print_ex', 'libcrypto')],
#               'SSL_set_wfd': [('SSL_set_wfd', 'libssl')],
#               'ERR_load_ERR_strings': [('ERR_load_ERR_strings', 'libcrypto')],
#               'SSL_CTX_use_certificate_chain_file': [('SSL_CTX_use_certificate_chain_file',
#                 'libssl')],
#               'ssleay_rand_status': [('ssleay_rand_status', 'libcrypto')],
#               'ngx_http_parse_header_line': [('def_load_bio', 'libcrypto')],
#               'BN_asc2bn': [('BN_asc2bn', 'libcrypto')],
#               'bn_sub_part_words': [('bn_sub_part_words', 'libcrypto')],
#               'dh_bn_mod_exp': [('dh_bn_mod_exp', 'libcrypto')],
#               'ENGINE_remove': [('ENGINE_remove', 'libcrypto')],
#               'get_cert_by_subject': [('get_cert_by_subject', 'libcrypto')],
#               'idea_ofb64_encrypt': [('BF_ofb64_encrypt', 'libcrypto'),
#                ('RC2_ofb64_encrypt', 'libcrypto'),
#                ('RC5_32_ofb64_encrypt', 'libcrypto'),
#                ('idea_ofb64_encrypt', 'libcrypto'),
#                ('CAST_ofb64_encrypt', 'libcrypto')],
#               'OBJ_sn2nid': [('OBJ_ln2nid', 'libcrypto'),
#                ('OBJ_sn2nid', 'libcrypto')],
#               'int_err_del': [('int_err_del', 'libcrypto')],
#               'ec_GFp_simple_point_get_affine_coordinates': [('ssl_create_cipher_list',
#                 'libssl'),
#                ('OBJ_obj2txt', 'libcrypto'),
#                ('PKCS7_dataDecode', 'libcrypto'),
#                ('ec_GFp_simple_point_get_affine_coordinates_GFp', 'libcrypto'),
#                ('ec_GFp_simple_point_get_affine_coordinates', 'libcrypto')],
#               'DSA_free': [('RSA_free', 'libcrypto'),
#                ('DSA_free', 'libcrypto')],
#               'sk_shift': [('sk_shift', 'libcrypto')],
#               'X509_NAME_ENTRY_create_by_txt': [('X509at_add1_attr_by_OBJ',
#                 'libcrypto'),
#                ('X509_ATTRIBUTE_create_by_txt', 'libcrypto'),
#                ('X509_NAME_ENTRY_create_by_NID', 'libcrypto'),
#                ('X509_NAME_ENTRY_create_by_txt', 'libcrypto')],
#               'inflateInit2_': [('inflateInit2_', 'libz')],
#               'X509at_add1_attr': [('X509at_add1_attr', 'libcrypto')],
#               'ENGINE_register_all_DH': [('ENGINE_register_all_RAND',
#                 'libcrypto'),
#                ('ENGINE_register_all_DH', 'libcrypto')],
#               'ASN1_INTEGER_get': [('ASN1_INTEGER_get', 'libcrypto')],
#               'ASN1_tag2bit': [('ASN1_tag2bit', 'libcrypto')],
#               'BIO_free_all': [('BIO_free_all', 'libcrypto')],
#               'X509_STORE_new': [('X509_STORE_new', 'libcrypto')],
#               'UI_construct_prompt': [('UI_construct_prompt', 'libcrypto')],
#               'v2i_issuer_alt': [('v2i_subject_alt', 'libcrypto'),
#                ('v2i_GENERAL_NAMES', 'libcrypto'),
#                ('v2i_issuer_alt', 'libcrypto')],
#               'X509v3_get_ext_count': [('SSL_COMP_get_name', 'libssl')],
#               'ngx_http_ssi_include': [('BN_div', 'libcrypto'),
#                ('ASN1_item_print', 'libcrypto')],
#               'whirlpool_block': [('whirlpool_block', 'libcrypto')],
#               'ASN1_STRING_set_by_NID': [('ASN1_STRING_set_by_NID',
#                 'libcrypto')],
#               'ERR_load_DSO_strings': [('ERR_load_PEM_strings', 'libcrypto'),
#                ('ERR_load_X509V3_strings', 'libcrypto'),
#                ('ERR_load_EVP_strings', 'libcrypto'),
#                ('ERR_load_X509_strings', 'libcrypto')],
#               'i2r_PKEY_USAGE_PERIOD': [('i2r_PKEY_USAGE_PERIOD',
#                 'libcrypto')],
#               'dsa_pub_decode': [('eckey_type2param', 'libcrypto'),
#                ('v2i_NAME_CONSTRAINTS', 'libcrypto'),
#                ('X509V3_EXT_i2d', 'libcrypto'),
#                ('v2i_GENERAL_NAMES', 'libcrypto'),
#                ('d2i_ECParameters', 'libcrypto'),
#                ('dsa_pub_decode', 'libcrypto')],
#               'dlfcn_bind_var': [('dlfcn_bind_func', 'libcrypto'),
#                ('dlfcn_bind_var', 'libcrypto')],
# ...
#                0.6439142598879724,
#                0.03205860328008499],
#               'SSL_get_client_CA_list': [0.7310585786300049,
#                0.2689414213699951],
#               'ec_wNAF_precompute_mult': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'CMS_RecipientInfo_kekri_id_cmp': [0.7310585786300049,
#                0.2689414213699951],
#               'X509V3_section_free': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'UI_method_set_writer': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'OPENSSL_ia32_cpuid': [0.7310585786300049, 0.2689414213699951],
#               'X509_policy_tree_free': [0.7310585786300049,
#                0.2689414213699951],
#               'SSL_CTX_set_timeout': [0.7310585786300049, 0.2689414213699951],
#               'ERR_func_error_string': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'EC_GROUP_get_pentanomial_basis': [0.7310585786300049,
#                0.2689414213699951],
#               'UI_get0_result': [0.7310585786300049, 0.2689414213699951],
#               'SSL_free': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'int_unregister_cb_LHASH_DOALL_ARG': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'RSA_verify_ASN1_OCTET_STRING': [0.7310585786300049,
#                0.2689414213699951],
#               'SRP_Calc_server_key': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'BUF_memdup': [0.7310585786300049, 0.2689414213699951],
#               'surewarehk_load_pubkey': [0.7310585786300049,
#                0.2689414213699951],
#               'CMS_add1_recipient_cert': [0.7310585786300049,
#                0.2689414213699951],
#               'int_thread_set_item': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'SSL_set_rfd': [0.7310585786300049, 0.2689414213699951],
#               'DES_ecb_encrypt': [0.7310585786300049, 0.2689414213699951],
#               'ssl_add_clienthello_renegotiate_ext': [0.7310585786300049,
#                0.2689414213699951],
#               'X509_get1_ocsp': [0.7310585786300049, 0.2689414213699951],
#               'int_err_del_item': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'main': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'EVP_PKEY_CTX_dup': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'EVP_DecryptInit': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'EVP_cleanup': [0.7310585786300049, 0.2689414213699951],
#               'bf_cbc_cipher': [0.011606461431184656,
#                0.03154963320110001,
#                0.08576079462509835,
#                0.23312200962361299,
#                0.23312200962361299,
#                0.23312200962361299,
#                0.23312200962361299,
#                0.6336913225737218,
#                0.6336913225737218,
#                0.6336913225737218,
#                0.6336913225737218,
#                0.6336913225737218,
#                0.00426977854528211],
#               'EVP_CIPHER_do_all': [0.004263082250240778,
#                0.011588259014055805,
#                0.011588259014055805,
#                0.03150015390138463,
#                0.08562629594379713,
#                0.23275640430228017,
#                0.23275640430228017,
#                0.6326975042723549,
#                0.0015683003158864725],
#               'generate_key': [0.7310585786300049, 0.2689414213699951],
#               'EVP_PKEY_meth_new': [0.7310585786300049, 0.2689414213699951],
#               'ec_GFp_mont_field_decode': [0.7310585786300049,
#                0.2689414213699951],
#               'by_file_ctrl': [0.7310585786300049, 0.2689414213699951],
#               'asn1_bio_new': [0.7310585786300049, 0.2689414213699951],
#               'aesni_cbc_sha1_enc_avx': [0.7310585786300049,
#                0.2689414213699951],
#               'CONF_modules_unload': [0.7310585786300049, 0.2689414213699951],
#               'SSL_set_session_id_context': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'dsa_priv_decode': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'X509V3_EXT_print': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_policy_node_get0_parent': [0.24472847105479764,
#                0.6652409557748219,
#                0.6652409557748219,
#                0.6652409557748219,
#                0.6652409557748219,
#                0.09003057317038046],
#               'EVP_PKEY_derive_init': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'CRYPTO_lock': [0.7310585786300049, 0.2689414213699951],
#               'sha_block_data_order': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'SRP_gN_new_init': [0.7310585786300049, 0.2689414213699951],
#               'X509_get_pubkey_parameters': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'ec_GFp_simple_points_make_affine': [0.03168492079612427,
#                0.0861285444362687,
#                0.23412165725273662,
#                0.6364086465588308,
#                0.011656230956039607],
#               'camellia_128_cfb8_cipher': [0.08714431874203257,
#                0.23688281808991016,
#                0.23688281808991016,
#                0.23688281808991016,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_TRUST_get_by_id': [0.7310585786300049, 0.2689414213699951],
#               'X509_check_ca': [0.7310585786300049, 0.2689414213699951],
#               'find_minlength': [0.011606461431184656,
#                0.03154963320110001,
#                0.08576079462509835,
#                0.23312200962361299,
#                0.6336913225737218,
#                0.00426977854528211],
#               'def_create': [0.7310585786300049, 0.2689414213699951],
#               'EVP_PKEY_decrypt_init': [0.7310585786300049,
#                0.2689414213699951],
#               'ngx_http_uwsgi_init_params.isra.4': [0.7310585786300049,
#                0.2689414213699951],
#               'ENGINE_load_4758cca': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_PURPOSE_get_count': [0.7310585786300049,
#                0.2689414213699951],
#               'BIO_dup_chain': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'rsa_item_verify': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_OBJECT_retrieve_match': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'ECDSA_sign_setup': [0.7310585786300049, 0.2689414213699951],
#               'SSL_SESSION_new': [0.7310585786300049, 0.2689414213699951],
#               'dtls1_output_cert_chain': [0.7310585786300049,
#                0.2689414213699951],
#               'fmtint': [0.7310585786300049, 0.2689414213699951],
#               'ngx_parse_http_time': [0.7310585786300049, 0.2689414213699951],
#               'SSL_SRP_CTX_free': [0.7310585786300049, 0.2689414213699951],
#               'ssl3_get_server_hello': [0.7310585786300049,
#                0.2689414213699951],
#               'BN_mod_word': [0.7310585786300049, 0.2689414213699951],
#               'ssl_check_srvr_ecc_cert_and_alg': [0.7310585786300049,
#                0.2689414213699951],
#               'dynamic_data_ctx_free_func': [0.011606461431184656,
#                0.03154963320110001,
#                0.08576079462509835,
#                0.23312200962361299,
#                0.6336913225737218,
#                0.00426977854528211],
#               'RSA_padding_add_X931': [0.7310585786300049, 0.2689414213699951],
#               'old_ec_priv_decode': [0.03168492079612427,
#                0.0861285444362687,
#                0.23412165725273662,
#                0.6364086465588308,
#                0.011656230956039607],
#               'UI_create_method': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'ERR_get_err_state_table': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'aes_ccm_cipher': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'X509_check_issued': [0.7310585786300049, 0.2689414213699951],
#               'EVP_DecryptUpdate': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'ec_wNAF_mul': [0.7310585786300049, 0.2689414213699951],
#               'lh_doall': [0.08714431874203257,
#                0.23688281808991016,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'RSA_eay_finish': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'bsaes_cbc_encrypt': [0.7310585786300049, 0.2689414213699951],
#               'BN_add_word': [0.7310585786300049, 0.2689414213699951],
#               'tls1_heartbeat': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'SHA1_Update': [0.011606461431184656,
#                0.03154963320110001,
#                0.08576079462509835,
#                0.23312200962361299,
#                0.6336913225737218,
#                0.00426977854528211],
#               'ENGINE_pkey_asn1_find_str': [0.7310585786300049,
#                0.2689414213699951],
#               'mime_hdr_new': [0.7310585786300049, 0.2689414213699951],
#               'DSA_generate_parameters_ex': [0.7310585786300049,
#                0.2689414213699951],
#               'CRYPTO_gcm128_encrypt_ctr32': [0.7310585786300049,
#                0.2689414213699951],
#               'CONF_get_section': [0.7310585786300049, 0.2689414213699951],
#               'ec_GF2m_simple_mul': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'OBJ_nid2obj': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_add1_reject_object': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'SSL_get_current_expansion': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'BN_CTX_start': [0.7310585786300049, 0.2689414213699951],
#               'mime_hdr_addparam.isra.1': [0.7310585786300049,
#                0.2689414213699951],
#               'CONF_dump_bio': [0.7310585786300049, 0.2689414213699951],
#               'x509v3_cache_extensions.part.6': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'OPENSSL_ia32_rdrand': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'CRYPTO_dup_ex_data': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'sub_5c7c4f': [0.7310585786300049, 0.2689414213699951],
#               'camellia_init_key': [0.7310585786300049, 0.2689414213699951],
#               'CRYPTO_ccm128_setiv': [0.7310585786300049, 0.2689414213699951],
#               'eckey_pub_cmp': [0.7310585786300049, 0.2689414213699951],
#               'CRYPTO_gcm128_decrypt_ctr32': [0.7310585786300049,
#                0.2689414213699951],
#               'EC_POINT_set_Jprojective_coordinates_GFp': [0.7310585786300049,
#                0.2689414213699951],
#               'ENGINE_register_all_RSA': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'ECDH_compute_key': [0.7310585786300049, 0.2689414213699951],
#               'BIO_new_socket': [0.24472847105479764,
#                0.6652409557748219,
#                0.6652409557748219,
#                0.09003057317038046],
#               'doapr_outch.constprop.5': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'param_copy_gost01': [0.7310585786300049, 0.2689414213699951],
#               'md_write': [0.7310585786300049, 0.2689414213699951],
#               'DES_ede3_ofb64_encrypt': [0.7310585786300049,
#                0.2689414213699951],
#               'CRYPTO_gcm128_encrypt': [0.7310585786300049,
#                0.2689414213699951],
#               'X509_STORE_get1_certs': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'RC2_cbc_encrypt': [0.7310585786300049, 0.2689414213699951],
#               'bsaes_xts_encrypt': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'surewarehk_ex_free': [0.7310585786300049, 0.2689414213699951],
#               'X509_STORE_get1_crls': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'CAST_cfb64_encrypt': [0.03168492079612427,
#                0.0861285444362687,
#                0.0861285444362687,
#                0.23412165725273662,
#                0.6364086465588308,
#                0.6364086465588308,
#                0.011656230956039607],
#               'PEM_get_EVP_CIPHER_INFO': [0.7310585786300049,
#                0.2689414213699951],
#               'ssl_get_prev_session': [0.03168492079612427,
#                0.0861285444362687,
#                0.23412165725273662,
#                0.6364086465588308,
#                0.011656230956039607],
#               'pkey_dsa_init': [0.08714431874203257,
#                0.23688281808991016,
#                0.6439142598879724,
#                0.03205860328008499],
#               'X509_EXTENSION_get_critical': [0.7310585786300049,
#                0.2689414213699951],
#               'dtls1_process_heartbeat': [0.7310585786300049,
#                0.2689414213699951],
#               'ssl23_read_bytes': [0.7310585786300049, 0.2689414213699951],
#               'ssl2_connect': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'cleanup3_LHASH_DOALL': [0.7310585786300049, 0.2689414213699951],
#               'ssl3_send_server_key_exchange': [0.24472847105479764,
#                0.6652409557748219,
#                0.09003057317038046],
#               'CRYPTO_gcm128_release': [0.0015673960138976283,
#                0.004260624102577064,
#                0.01158157707592986,
#                0.03148199051039798,
#                0.08557692272813494,
#                0.23262219398733308,
#                0.6323326828120425,
#                0.0005766127696870058],
#               ...}))

# %%
def accuracy_of_functions(g, librarynames, rvs=None, normalize=True):
        # Extract
        global_dict = g.global_dict
        tuples = g.rv_marginals(rvs, normalize)
        prediction = dict()
        count = 0
        tn = 0
        fn = 0
        wp = 0
        fp = 0
        prior = defaultdict(list)
        # Display
        for rv, marg in tuples:
            rv_label = str(rv).split(' ')[0]
            if rv_label[:4] == 'str_':
                continue
            largest = -1
            for label in marg:
                if label > largest:
                    largest = label
            names = global_dict[rv_label]

            # if np.isclose(largest, 1.0/len(names)):
            #     continue
            for i, label in enumerate(marg):
                prior[rv_label].append((names[i], label))
                if np.isclose(label, largest):
                    #pdb.set_trace()
                    if rv_label in prediction:
                        prediction[rv_label].append(names[i])
                    else:
                        prediction[rv_label]=[names[i]]

        keylist = prior.keys()
        # for key in keylist:
        #     print key
        #     print prior[key]
        #     print
        keylist = prediction.keys()
        correct_set = set()
        for key in keylist:
            funclist = prediction[key]
            label=set()
            #print key
            for (func, lib) in funclist:
                if len(func.split('{')) > 1:
                    predicted_label = func.split('{')[1].split('}')[0]
                else:
                    predicted_label = func
                label.add(predicted_label)
            if 'None' in label and len(label)==1:
                if key in librarynames:
                    fn += 1
                else:
                    tn += 1
            elif key in label:
                count += 1
                correct_set.add(key)
            else:
                if key in librarynames:
                    wp += 1
                else:
                    fp += 1

        print "correct prediction, true negative, false negative, wrong prediction, false positives, total prediction, precision:"
        print count, tn, fn, wp, fp, len(keylist), count*1.0/(len(keylist)-tn-fn), count*1.0/2982
        return prediction, prior, correct_set

# %%
prediction, belief, correct_set = accuracy_of_functions(g, librarynames)
# Out:
# correct prediction, true negative, false negative, wrong prediction, false positives, total prediction, precision:
# 2446 1257 280 191 148 4322 0.878276481149 0.820254862508

# %%
filted = 1
def loadOneBinary(funcnamepath, embFile, filted_size=0):
    names = p.load(open(funcnamepath, 'r'))
    data = p.load(open(embFile, 'r'))
    funcName2emb=dict()
    for i in range(len(data)):
        (name, size) = names[i]
        if size > filted_size:
            funcName2emb[name]=data[i]
    return funcName2emb
#dir_openssl = '/home/yijiufly/Downloads/codesearch/Gemini/testingdataset/database/'
dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/'
dir_zlib = '/home/yijiufly/Downloads/codesearch/data/zlib/zlib-O2/'
#folder = '101d/'
folder = 'openssl-1.0.1d/'
embfile = 'libcrypto.so_newmodel.emb'
nam = 'libcrypto.so_newmodel_withsize.nam'
sslembfile = 'libssl.so_newmodel.emb'
sslnam = 'libssl.so_newmodel_withsize.nam'
func2emb_ssl = loadOneBinary(dir_openssl+folder+sslnam, dir_openssl+folder+sslembfile, filted)
#name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
func2emb_openssl = loadOneBinary(dir_openssl+folder+nam, dir_openssl+folder+embfile, filted)
func2emb_zlib = loadOneBinary(dir_zlib+'zlib-1.2.11/libz.so_newmodel_withsize.nam', dir_zlib+'zlib-1.2.11/libz.so_newmodel.emb', filted)
librarynames = func2emb_openssl.keys()
librarynames.extend(func2emb_ssl.keys())
librarynames.extend(func2emb_zlib.keys())
print len(librarynames)
# Out:
# defaultdict(<type 'list'>, {'ngx_http_parse_chunked': [(('None', 'None'), 1.0)], 'ngx_http_proxy_pass.part.4': [(('None', 'None'), 1.0)], 'PKCS7_simple_smimecap': [(('PKCS7_simple_smimecap', 'libcrypto'), 0.9999998938054196), (('def_serial_cb', 'libcrypto'), 1.0410202451344972e-09), (('ASN1_TYPE_set_int_octetstring', 'libcrypto'), 1.0410202451344972e-07), (('None', 'None'), 1.0515356011459563e-09)], 'ngx_execute': [(('None', 'None'), 1.0)], 'ngx_http_add_cache_control': [(('None', 'None'), 1.0)], 'RSA_padding_check_PKCS1_type_2': [(('RSA_padding_check_PKCS1_type_2', 'libcrypto'), 0.998980735908674), (('None', 'None'), 0.0010192640913260628)], 'X509_VERIFY_PARAM_table_cleanup': [(('X509_VERIFY_PARAM_table_cleanup', 'libcrypto'), 0.99), (('None', 'None'), 0.01)], 'RSA_padding_check_PKCS1_type_1': [(('RSA_padding_check_PKCS1_type_1', 'libcrypto'), 0.908256880733945), (('None', 'None'), 0.09174311926605508)], 'ngx_mail_auth_http_read_handler': [(('None', 'None'), 1.0)], 'ngx_open_file_cache_cleanup': [(('None', 'None'), 1.0)], 'pkey_gost2001_derive': [(('None', 'None'), 1.0)], 'ngx_http_copy_thread_handler': [(('None', 'None'), 1.0)], 'ec_GF2m_montgomery_point_multiply.part.0': [(('ec_GF2m_montgomery_point_multiply.part.0', 'libcrypto'), 1.0), (('None', 'None'), 1.1395750792401225e-24)], 'EVP_MD_CTX_md': [(('ssl3_do_compress', 'libssl'), 0.5014161686105763), (('EVP_MD_CTX_md', 'libcrypto'), 0.49842392720470863), (('ssl3_do_uncompress', 'libssl'), 5.136273938763694e-05), (('ssl3_cleanup_key_block', 'libssl'), 5.188165189211986e-07), (('ssl3_send_hello_request', 'libssl'), 5.188165189211986e-07), (('ssl3_send_cert_status', 'libssl'), 5.188165189211986e-07), (('ssl3_send_server_done', 'libssl'), 5.188165189211986e-07), (('ssl_free_wbio_buffer', 'libssl'), 5.188165189211986e-07), (('CRYPTO_free', 'libcrypto'), 5.188165189211986e-07), (('EVP_PKEY_size', 'libcrypto'), 5.188165189211986e-07), (('ssl2_enc', 'libssl'), 5.136272987223511e-05), (('ssl2_mac', 'libssl'), 5.136272987223511e-05), (('ssl3_renegotiate_check', 'libssl'), 5.188165189211985e-07), (('ssl3_renegotiate', 'libssl'), 5.188165189211985e-07), (('ssl3_release_read_buffer', 'libssl'), 5.1881651892119875e-08), (('ssl3_do_change_cipher_spec', 'libssl'), 5.188165189211985e-07), (('tls1_process_heartbeat', 'libssl'), 5.1881651892119875e-08), (('BIO_next', 'libcrypto'), 5.188165189211985e-07), (('None', 'None'), 5.240570898193925e-09)], 'BN_mod_add_quick': [(('BN_mod_add_quick', 'libcrypto'), 0.9997958762150094), (('BN_mod_lshift1_quick', 'libcrypto'), 0.00010200957822824293), (('BN_mod_sub_quick', 'libcrypto'), 0.00010200957822824293), (('BN_CTX_new', 'libcrypto'), 1.0303997800832627e-07), (('BN_set_word', 'libcrypto'), 1.0513210693635982e-10), (('BN_CTX_end', 'libcrypto'), 1.0513210693635982e-10), (('EC_POINT_is_at_infinity', 'libcrypto'), 1.0408078586699627e-09), (('EC_POINT_dbl', 'libcrypto'), 1.0513210693635984e-11), (('BN_mod_sqr', 'libcrypto'), 1.051321069363598e-10), (('ECDSA_sign_setup', 'libcrypto'), 1.0513210693635982e-10), (('ecdsa_check', 'libcrypto'), 1.0513210693635984e-11), (('EC_GROUP_get_order', 'libcrypto'), 1.0513210693635982e-10), (('None', 'None'), 1.0619404741046447e-12)], 'print_qualifiers': [(('print_qualifiers', 'libcrypto'), 0.9999999999999892), (('None', 'None'), 1.0729945095390933e-14)], 'SSL_srp_server_param_with_username': [(('SSL_srp_server_param_with_username', 'libssl'), 0.32153296524845737), (('ssl_init_wbio_buffer', 'libssl'), 0.03215329652484574), (('ssl3_setup_buffers', 'libssl'), 0.32153296524845737), (('ssl3_send_alert', 'libssl'), 0.32153296524845737), (('None', 'None'), 0.0032478077297823965)], 'ASN1_d2i_bio': [(('ASN1_d2i_bio', 'libcrypto'), 0.4999744936999439), (('ASN1_item_d2i_bio', 'libcrypto'), 0.4999744936999439), (('None', 'None'), 5.101260011222829e-05)], 'ngx_http_upstream_copy_last_modified': [(('None', 'None'), 1.0)], 'ENGINE_set_default_RSA': [(('ENGINE_set_default_RSA', 'libcrypto'), 0.12484329900946405), (('ENGINE_set_default ...

# %%
print len(g.global_dict.keys())
truth=[]
for key in g.global_dict:
    pre = [i[0] for i in g.global_dict[key]]
    if key in pre:
        truth.append(key)
print len(truth)

print set(truth)-correct_set, len(set(truth)-correct_set)
# Out:
# 4142
# 1820
# set(['name_cmp', 'X509V3_section_free', 'atalla_ctrl', 'dtls1_get_message_fragment', 'ENGINE_new', 'ENGINE_get_prev', 'PEM_ASN1_write', 'i2a_ASN1_OBJECT', 'X509_print_ex', 'ubsec_mod_exp_dh', 'surewarehk_rsa_priv_dec', 'RSA_padding_add_PKCS1_PSS', 'ecdsa_check', 'EC_KEY_insert_key_method_data', 'b64_write', 'SSL_CTX_use_certificate_chain_file', 'CRYPTO_add_lock', 'aep_finish', 'BIO_push', 'X509_EXTENSION_get_object', 'UI_dup_verify_string', 'EVP_PKEY_keygen', 'SSL_CTX_SRP_CTX_free', 'hwcrhk_load_privkey', 'dtls1_retransmit_message', 'ec_asn1_group2parameters.constprop.3', 'CRYPTO_pop_info', 'ASN1_item_d2i_fp', 'sk_dup', 'ENGINE_register_all_DH', 'DSO_load', 'BN_sub_word', 'DSA_new_method', 'BIO_vsnprintf', 'SSL_CTX_use_RSAPrivateKey_file', 'nuron_ctrl', 'CONF_get_number', 'i2r_pci', 'dtls1_do_write', 'RSA_verify_PKCS1_PSS_mgf1', 'ENGINE_init', 'EC_KEY_new', 'HMAC_Init_ex', 'str_copy', 'EC_KEY_new_by_curve_name', 'asn1_get_field_ptr', 'do_ssl3_write', 'surewarehk_ctrl', 'pkey_hmac_ctrl', 'HMAC_CTX_copy', 'surewarehk_rsa_sign', 'BN_print', 'CMS_get0_RecipientInfos', 'cswift_ctrl', 'ENGINE_set_id', 'MD5_Final', 'i2a_ASN1_INTEGER', 'BIO_free_all', 'ENGINE_add', 'DES_encrypt1', 'ASN1_item_new', 'X509_ATTRIBUTE_create_by_OBJ', 'atalla_finish', 'lh_doall', 'ssl3_cbc_digest_record', 'dtls1_retransmit_buffered_messages', 'EVP_Digest', 'SSL_use_RSAPrivateKey', 'X509_NAME_ENTRY_get_data', 'PEM_write_PKCS8PrivateKey_nid', 'UI_add_input_string', 'old_hmac_encode', 'v2i_POLICY_CONSTRAINTS', 'ERR_get_next_error_library', 'ssl_set_cert_masks', 'dtls1_start_timer', 'dynamic_ctrl', 'aep_init', 'EC_GROUP_cmp', 'OCSP_request_sign', 'tls1_cert_verify_mac', 'ssl_clear_bad_session', 'EVP_PKEY_CTX_new', 'ssl3_ctrl', 'CONF_modules_load_file', 'UI_dup_info_string', 'ec_asn1_parameters2group', 'SSL_CTX_set_cipher_list', 'SSL_SRP_CTX_free', 'ENGINE_register_all_RSA', 'ENGINE_by_id', 'surewarehk_dsa_mod_exp', 'ECDH_compute_key', 'asn1_i2d_ex_primitive', 'ECParameters_print', 'GENERAL_NAME_print', 'cswift_mod_exp_dh', 'SSL_CTX_use_PrivateKey_file', 'ubsec_ctrl', 'hwcrhk_insert_card', 'atalla_init', 'ASN1_template_free', 'cswift_rsa_mod_exp', 'ASN1_item_ex_new', 'aep_rsa_mod_exp', 'ERR_peek_error', 'ASN1_item_ex_i2d', 'dtls1_heartbeat', 'X509_EXTENSION_get_critical', 'ssl2_return_error', 'dtls1_read_failed', 'X509_NAME_ENTRY_create_by_OBJ', 'DSA_verify', 'ibm_4758_cca_ctrl', 'ASN1_GENERALIZEDTIME_set', 'aep_ctrl', 'X509_PURPOSE_add', 'PKCS5_pbe_set', 'n_ssl3_mac', 'DHparams_print', 'ASN1_TIME_set', 'BN_bn2bin', 'b64_new', 'hwcrhk_get_pass', 'ssl_verify_alarm_type', 'SSL_CTX_use_certificate_file', 'cswift_dsa_verify', 'ENGINE_set_default_pkey_meths', 'ssl3_setup_buffers', 'cswift_mod_exp_mont', 'X509_NAME_ENTRY_get_object', 'SSL_CTX_ctrl', 'SSL_use_RSAPrivateKey_file', 'aep_dsa_mod_exp', 'BN_GF2m_mod_sqr_arr', 'BN_mod_lshift', 'd2i_X509_PKEY', 'SSL_CTX_add_session', 'ubsec_mod_exp_mont', 'EVP_EncodeBlock', 'ibm_4758_cca_finish', 'nuron_finish', 'rc4_hmac_md5_ctrl', 'SRP_Calc_x', 'hwcrhk_init', 'asn1_const_Finish', 'BIO_int_ctrl', 'hwcrhk_load_pubkey', 'c2i_ASN1_OBJECT', 'ENGINE_set_name', 'SSL_get_client_CA_list', 'cswift_dsa_sign', 'sk_find']) 153

# %%
print prediction['ngx_snprintf']
# Out:
# [('des_ede_cbc_cipher.constprop.3', 'libcrypto'), ('des_ede_cbc_cipher.constprop.4', 'libcrypto')]

# %%
print belief['ngx_snprintf']
# Out:
# [(('ssl3_output_cert_chain', 'libssl'), 0.00830847411380814), (('SSL_use_certificate', 'libssl'), 0.008308474113808145), (('SSL_use_PrivateKey', 'libssl'), 0.00830847411380814), (('RIPEMD160', 'libcrypto'), 0.11726759582467496), (('MD4', 'libcrypto'), 0.11470638604968199), (('MD5', 'libcrypto'), 0.11470638604968202), (('des_ede_cbc_cipher.constprop.3', 'libcrypto'), 0.21400985991435587), (('des_ede_cbc_cipher.constprop.4', 'libcrypto'), 0.21400985991435587), (('idea_cbc_cipher', 'libcrypto'), 0.11729748085384512), (('None', 'None'), 0.0830770090519797)]

# %%
# Out:
# [(('BN_div', 'libcrypto'), 0.10824380223553921),
#  (('BN_generate_prime', 'libcrypto'), 0.020243849048146516),
#  (('ssl3_read_bytes', 'libssl'), 0.7993934659763151),
#  (('ASN1_item_free', 'libcrypto'), 0.0006476214819616707),
#  (('ssl3_write_bytes', 'libssl'), 0.012596098828642273),
#  (('do_ssl3_write', 'libssl'), 0.001768937875641718),
#  (('parse_bags.constprop.1', 'libcrypto'), 0.001251114814716462),
#  (('do_dtls1_write', 'libssl'), 0.0008966877847646794),
#  (('asn1_parse2', 'libcrypto'), 6.036906078289807e-17),
#  (('ssl_cipher_apply_rule.isra.1.constprop.3', 'libssl'),
#   0.0010030327505468795),
#  (('BN_generate_prime_ex', 'libcrypto'), 0.005721200369863713),
#  (('X509_verify_cert', 'libcrypto'), 2.399350780754784e-05),
#  (('ssl_cipher_get_evp', 'libssl'), 0.0006140690736818583),
#  (('BN_mod_inverse', 'libcrypto'), 0.0009071887791236199),
#  (('ssl_parse_clienthello_tlsext', 'libssl'), 0.03952635708815168),
#  (('ssl2_accept', 'libssl'), 0.005480928190500681),
#  (('dsa_builtin_paramgen2', 'libcrypto'), 0.0010675839107545896),
#  (('None', 'None'), 0.0006140682838416381)]

# %%
rvs = g.get_rvs()['ngx_snprintf']
for factor in rvs.get_factors():
    print factor
    print factor.get_outgoing_for(rvs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-294-61b7fa06fd24> in <module>()
# ----> 1 rvs = g.get_rvs()['ngx_snprintf']
#       2 for factor in rvs.get_factors():
#       3     print factor
#       4     print factor.get_outgoing_for(rvs)
#       5
#
# KeyError: 'ngx_snprintf'

# %%
belief['ENGINE_get_next']
# Out:
# [(('ENGINE_get_next', 'libcrypto'), 0.9970496531404276),
#  (('None', 'None'), 0.002950346859572456)]

# %%
if True:
    queryPath_2gram = knn
    global LBP_MAX_ITERS
    global THRES
    threshold=THRES
    g = fg.Graph()
    global_node_dict = dict()
    global_edge_dict = dict()
    rvlabels = defaultdict(list)
    if type(queryPath_2gram) == type(''):
        query_2gram = p.load(open(queryPath_2gram, 'rb'))
    else:
        query_2gram = queryPath_2gram
    hasDistance = False
    if type(query_2gram[0][0][0]) == type((1,2)):
        hasDistance = True

    for i in query_2gram:
        if i[2] > threshold:
            if not hasDistance:
                test_src = i[0][0]
                test_des = i[0][1]
            else:
                test_src = i[0][0][0]
                test_des = i[0][0][1]
            if test_src == test_des:
                continue
            # initialize the dictionary
            if not global_node_dict.has_key(test_src):
                global_node_dict[test_src] = []
            if not global_node_dict.has_key(test_des):
                global_node_dict[test_des] = []
            if not global_edge_dict.has_key((test_src, test_des)):
                global_edge_dict[(test_src, test_des)] = []

            funcList = i[1]
            for predicted_func in funcList:
                if hasDistance:
                    querydistance = i[0][1]
                    resultdistance = predicted_func[3]
                    if querydistance != resultdistance:
                        continue

                src_funcname = predicted_func[2][0]
                des_funcname = predicted_func[2][1]
                libraryname = predicted_func[0]

                # find the src function if it's already in the dict,
                # otherwise, add it to the dict
                if (src_funcname, libraryname) not in global_node_dict[test_src]:
                    global_node_dict[test_src].append((src_funcname, libraryname))
                    rvlabels[test_src].append(src_funcname + ', ' + '(' + src_funcname + ', ' + des_funcname + ')')
                # do the same thing to des function
                if (des_funcname, libraryname) not in global_node_dict[test_des]:
                    global_node_dict[test_des].append((des_funcname, libraryname))
                    rvlabels[test_des].append(des_funcname + ', ' + '(' + src_funcname + ', ' + des_funcname + ')')

                # add this edge to the edge dictionary
                if (src_funcname, des_funcname, libraryname) not in global_edge_dict[(test_src, test_des)]:
                    global_edge_dict[(test_src, test_des)].append((src_funcname, des_funcname, libraryname))

global_edge_dict[('ENGINE_register_all_RSA', 'engine_table_register')]
# Out:
# [('SSL_use_RSAPrivateKey', 'ssl_set_pkey', 'libssl'),
#  ('SSL_CTX_use_RSAPrivateKey', 'ssl_set_pkey', 'libssl'),
#  ('PEM_read_bio_DSAPrivateKey', 'PEM_read_bio_PrivateKey', 'libcrypto'),
#  ('PEM_read_bio_ECPrivateKey', 'PEM_read_bio_PrivateKey', 'libcrypto'),
#  ('PEM_read_bio_RSAPrivateKey', 'PEM_read_bio_PrivateKey', 'libcrypto'),
#  ('ENGINE_set_default_digests', 'engine_table_register', 'libcrypto'),
#  ('ENGINE_set_default_ciphers', 'engine_table_register', 'libcrypto'),
#  ('ENGINE_set_default_pkey_asn1_meths', 'engine_table_register', 'libcrypto'),
#  ('TS_CONF_load_key', 'PEM_read_bio_PrivateKey', 'libcrypto'),
#  ('ENGINE_set_default_pkey_meths', 'engine_table_register', 'libcrypto')]

# %%
filted = 1
def loadOneBinary(funcnamepath, embFile, filted_size=0):
    names = p.load(open(funcnamepath, 'r'))
    data = p.load(open(embFile, 'r'))
    funcName2emb=dict()
    for i in range(len(data)):
        (name, size) = names[i]
        if size > filted_size:
            funcName2emb[name]=data[i]
    return funcName2emb
#dir_openssl = '/home/yijiufly/Downloads/codesearch/Gemini/testingdataset/database/'
dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/'
dir_zlib = '/home/yijiufly/Downloads/codesearch/data/zlib/zlib-O2/'
#folder = '101d/'
folder = 'openssl-1.0.1d/'
embfile = 'libcrypto.so_newmodel.emb'
nam = 'libcrypto.so_newmodel_withsize.nam'
sslembfile = 'libssl.so_newmodel.emb'
sslnam = 'libssl.so_newmodel_withsize.nam'
func2emb_ssl = loadOneBinary(dir_openssl+folder+sslnam, dir_openssl+folder+sslembfile, filted)
#name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
func2emb_openssl = loadOneBinary(dir_openssl+folder+nam, dir_openssl+folder+embfile, filted)
func2emb_zlib = loadOneBinary(dir_zlib+'zlib-1.2.11/libz.so_newmodel_withsize.nam', dir_zlib+'zlib-1.2.11/libz.so_newmodel.emb', filted)

# %%
dir_openssl = '/home/yijiufly/Downloads/codesearch/data/openssl/openssl-1.0.1d/emb_sharedlib/'
func2emb_ssl_old = loadOneBinary(dir_openssl+'libssl.so.ida_newmodel_withsize.nam', dir_openssl+'libssl.so.ida_newmodel.emb', filted)
#name_filted = p.load(open(dir_openssl+'libcrypto.so.ida_filted1.nam','r'))
func2emb_openssl_old = loadOneBinary(dir_openssl+'libcrypto.so.ida_newmodel_withsize.nam', dir_openssl+'libcrypto.so.ida_newmodel.emb', filted)

# %%
print len(set(func2emb_openssl.keys()) - set(func2emb_openssl_old.keys()))
# Out:
# 399

# %%
global_node_dict = p.load(open('global_node_dict','r'))
predictcandidate = []
for key in global_node_dict.keys():
    if key in func2emb_openssl.keys() or key in func2emb_zlib.keys() or key in func2emb_ssl.keys():
        predict = [i[0] for i in global_node_dict[key]]
        if key in predict:
            predictcandidate.append(key)
print len(predictcandidate), len(global_node_dict.keys())
# Out:
# 2203 3315

# %%
keys = set()
for i in knn:
    test_src = i[0][0][0]
    test_des = i[0][0][1]
    keys.add(test_src)
    keys.add(test_des)
predictcandidate=[]
for key in keys:
    if key in func2emb_openssl.keys() or key in func2emb_zlib.keys() or key in func2emb_ssl.keys():
        predictcandidate.append(key)
print len(predictcandidate)
# Out:
# 2686

# %%
len(keys)
# Out:
# 4143

# %%
# Out:
# [(u'_init', 3), (u'__ctype_toupper_loc', 1), (u'sub_4426a6', 2), (u'__strcat_chk', 1), (u'getenv', 1), (u'sigprocmask', 1), (u'raise', 1), (u'free', 1), (u'recv', 1), (u'pthread_create', 1), (u'pthread_sigmask', 1), (u'strcasecmp', 1), (u'localtime', 1), (u'__vfprintf_chk', 1), (u'abort', 1), (u'__errno_location', 1), (u'srandom', 1), (u'unlink', 1), (u'strncpy', 1), (u'strncmp', 1), (u'localtime_r', 1), (u'strcpy', 1), (u'mkdir', 1), (u'sendmsg', 1), (u'writev', 1), (u'puts', 1), (u'ferror', 1), (u'qsort', 1), (u'sigaction', 1), (u'fread', 1), (u'strtod', 1), (u'setsockopt', 1), (u'fcntl', 1), (u'write', 1), (u'getpid', 1), (u'pthread_cond_wait', 1), (u'crypt_r', 1), (u'fclose', 1), (u'__xstat64', 1), (u'opendir', 1), (u'shutdown', 1), (u'globfree64', 1), (u'rmdir', 1), (u'strlen', 1), (u'chdir', 1), (u'pthread_mutexattr_destroy', 1), (u'__stack_chk_fail', 1), (u'getuid', 1), (u'mmap', 1), (u'accept4', 1), (u'dup2', 1), (u'send', 1), (u'strchr', 1), (u'pthread_mutex_destroy', 1), (u'pthread_mutexattr_init', 1), (u'strrchr', 1), (u'uname', 1), (u'gmtime_r', 1), (u'setrlimit64', 1), (u'dladdr', 1), (u'gettimeofday', 1), (u'fputs', 1), (u'setpriority', 1), (u'statfs64', 1), (u'__fxstatat64', 1), (u'memset', 1), (u'geteuid', 1), (u'ioctl', 1), (u'sendto', 1), (u'close', 1), (u'__realpath_chk', 1), (u'setsid', 1), (u'sched_setaffinity', 1), (u'closedir', 1), (u'fputc', 1), (u'epoll_ctl', 1), (u'sched_yield', 1), (u'read', 1), (u'__libc_start_main', 1), (u'memcmp', 1), (u'pthread_attr_init', 1), (u'fgets', 1), (u'pthread_cond_signal', 1), (u'getsockopt', 1), (u'execve', 1), (u'utimes', 1), (u'calloc', 1), (u'__fxstat64', 1), (u'strcmp', 1), (u'signal', 1), (u'getpwnam', 1), (u'gethostbyname', 1), (u'sem_wait', 1), (u'__memmove_chk', 1), (u'__memcpy_chk', 1), (u'syscall', 1), (u'sigemptyset', 1), (u'ftell', 1), (u'feof', 1), (u'umask', 1), (u'fopen64', 1), (u'strtol', 1), (u'memcpy', 1), (u'sigfillset', 1), (u'socketpair', 1), (u'getgrnam', 1), (u'glob64', 1), (u'prctl', 1), (u'__recv_chk', 1), (u'kill', 1), (u'sendfile64', 1), (u'time', 1), (u'fileno', 1), (u'openat64', 1), (u'pwrite64', 1), (u'__xstat', 1), (u'pthread_cond_init', 1), (u'getrlimit64', 1), (u'readdir', 1), (u'dlopen', 1), (u'random', 1), (u'mmap64', 1), (u'pthread_mutex_unlock', 1), (u'pthread_mutexattr_settype', 1), (u'pthread_exit', 1), (u'malloc', 1), (u'strncasecmp', 1), (u'fflush', 1), (u'__isoc99_sscanf', 1), (u'__fxstat', 1), (u'listen', 1), (u'mktime', 1), (u'sigsuspend', 1), (u'fseek', 1), (u'pwritev64', 1), (u'sem_post', 1), (u'dlclose', 1), (u'chown', 1), (u'setitimer', 1), (u'munmap', 1), (u'recvmsg', 1), (u'ftruncate64', 1), (u'__printf_chk', 1), (u'epoll_wait', 1), (u'poll', 1), (u'chmod', 1), (u'bind', 1), (u'readv', 1), (u'madvise', 1), (u'open64', 1), (u'strftime', 1), (u'memmove', 1), (u'readdir64', 1), (u'pread64', 1), (u'setgid', 1), (u'waitpid', 1), (u'sem_init', 1), (u'pthread_cond_destroy', 1), (u'open', 1), (u'fopen', 1), (u'sigdelset', 1), (u'sysconf', 1), (u'rename', 1), (u'accept', 1), (u'getsockname', 1), (u'strtoul', 1), (u'pthread_attr_destroy', 1), (u'__lxstat64', 1), (u'gethostname', 1), (u'getpagesize', 1), (u'epoll_create', 1), (u'__memset_chk', 1), (u'getppid', 1), (u'exit', 1), (u'connect', 1), (u'eventfd', 1), (u'fwrite', 1), (u'__fprintf_chk', 1), (u'posix_fadvise64', 1), (u'posix_memalign', 1), (u'setuid', 1), (u'sem_destroy', 1), (u'strerror', 1), (u'dlsym', 1), (u'initgroups', 1), (u'pthread_mutex_init', 1), (u'sigaddset', 1), (u'fork', 1), (u'strstr', 1), (u'pthread_mutex_lock', 1), (u'dlerror', 1), (u'__ctype_tolower_loc', 1), (u'__ctype_b_loc', 1), (u'usleep', 1), (u'__sprintf_chk', 1), (u'socket', 1), (u'__gmon_start__', 1), (u'ngx_shmtx_wakeup', 10), (u'ngx_crc32_short', 4), (u'ngx_resolver_copy', 24), (u'ngx_resolver_lookup_name.isra.1', 11), (u'ngx_resolver_free_node.isra.5', 15), (u'ngx_resolver_process_ptr', 76), (u'ngx_resolver_process_a', 112), (u'ngx_resolver_process_srv', 92), (u'add_not_list_to_class.isra.10', 1 ...

# %%
from binary import TestBinary
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/'
dotfiles = loadFiles(dir, ext='_bn.dot')
namfiles = loadFiles(dir, ext='.ida_newmodel_withsize.nam')
embfiles = loadFiles(dir, ext='.ida_newmodel.emb')
dotfile = dotfiles[0]
namfile = namfiles[0]
embfile = embfiles[0]
dotPath = os.path.join(dir, dotfile)
namPath = os.path.join(dir, namfile)
namPathFull = os.path.join(dir, namfile[:-13]+'.nam')
embPath = os.path.join(dir, embfile)
testbin = TestBinary('nginx', dotPath, embPath, namPath, 1)
testbin.loadOneBinary(namPathFull, testbin.embFile)
connectednodes = set()
for src in testbin.callgraphEdges.keys():
    for (des, distance) in testbin.callgraphEdges[src]:
        connectednodes.add(src)
        connectednodes.add(des)
# Out:
# init testing binary
# graph loaded
# /home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/nginx-{openssl-1.0.1d}{zlib-1.2.11}_bn.dot
# edges loaded

# %%
nodes = set()
for key in testbin.funcNameFilted.keys():
    if testbin.funcNameFilted[key] != -1:
        nodes.add(key)
print len(nodes-connectednodes)
# Out:
# 450

# %%
from redis import Redis
from db import db
def getHashMap(configname, storage_object, dim=64):
    db_instance = db()
    db_instance.loadHashMap(configname, storage_object, dim)

    return db_instance
redis_object3 = Redis(host='localhost', port=6379, db=1)
global hashMap3
hashMap3 = getHashMap(["filted1-1gram-binary0", "filted1-1gram-binary1", "filted1-1gram-binary2"], redis_object3, dim=64)
query = []
for node in nodes-connectednodes:
    emb = testbin.funcName2emb[node]
    query.append([emb, node, 1])
knn = hashMap3.querying(query)
# Out:
# using redis
# all has done, time: 28.8863739967

# %%
prediction = defaultdict(set)
cp = []
wp = []
fp = []
for [(name, distance), predict, sim] in knn_all:
    if sim > 0.99:
        for [lib, version, func] in predict:
            prediction[name].add((func, sim))
for func in prediction.keys():
    predict = sorted(prediction[func], key=lambda x: x[1], reverse=True)
    largest = predict[0][1]
    predicts = []
    for i in predict:
        if i[1] == largest:
            predicts.append(i[0])
    if func in predicts:
        cp.append(func)
    elif func in librarynames:
        wp.append(func)
    else:
        fp.append(func)
print len(cp), len(wp), len(fp), len(cp)*1.0/(len(cp) + len(wp) + len(fp)), len(cp)*1.0/2982
# Out:
# 2255 742 0.752419085752 0.756203890007

# %%
query = []
for node in nodes:
    emb = testbin.funcName2emb[node]
    query.append([emb, node, 1])
knn_all = hashMap3.querying(query)
# Out:
# all has done, time: 6.89403796196

# %%
len(knn_all)
# Out:
# 29343

# %%
def runBPversions(queryPath_2gram):
    global LBP_MAX_ITERS
    global THRES
    threshold = THRES
    if type(queryPath_2gram) == type(''):
        query_2gram = p.load(open(queryPath_2gram, 'rb'))
    else:
        query_2gram = queryPath_2gram
    hasDistance = False
    if type(query_2gram[0][0][0]) == type((1,2)):
        hasDistance = True
        
    global_node_dict = defaultdict(list)
    version_set = set()
    g = fg.Graph()
    global_edge_set = set()
    for i in query_2gram:
        if i[2] > threshold:
            if not hasDistance:
                test_src = i[0][0]
                test_des = i[0][1]
            else:
                test_src = i[0][0][0]
                test_des = i[0][0][1]
            if test_src == test_des:
                continue

            funcList = i[1]
            for predicted_func in funcList:
                if hasDistance:
                    querydistance = i[0][1]
                    resultdistance = predicted_func[3]
                    if querydistance != resultdistance:
                        continue

                version = predicted_func[1]
                libraryname = predicted_func[0]
                version_set.add((libraryname, version))
                if (libraryname, version) not in global_node_dict[test_src]:
                    global_node_dict[test_src].append((libraryname, version))

                if (libraryname, version) not in global_node_dict[test_des]:
                    global_node_dict[test_des].append((libraryname, version))
                
                global_edge_set.add((test_src, test_des))
                    
    version_list = list(version_set)
    for key in global_node_dict:
        length = len(version_set)
        priorsBelieve = np.zeros(len(version_set))
        for (libraryname, version) in global_node_dict[key]:
            ind = version_list.index((libraryname, version))
            priorsBelieve[ind] = 1
        rv_func = g.rv(key, length, prior = priorsBelieve)
        
    for (test_src, test_des) in global_edge_set:
        src_rv = g.get_rvs()[test_src]
        des_rv = g.get_rvs()[test_des]
        factor_probability = np.full((len(version_list), len(version_list)), 0.01)
        np.fill_diagonal(factor_probability, 0.99)
        factor1 = g.factor([src_rv, des_rv], potential=factor_probability, name = '')

    # run BP
    #pdb.set_trace()
    iters, converged = g.lbp(global_node_dict, normalize=True, max_iters=LBP_MAX_ITERS, progress=False)
    print 'LBP ran for %d iterations. Converged = %r' % (iters, converged)
    #print
    # Print out the final marginals
    #counts = g.print_rv_marginals(global_dict, normalize=True)
    #counts = count_rv_marginals2(version_list, normalize=True)
    #counts = g.accuracy_of_functions(global_dict, normalize=True)
    #counts = g.print_None_accuracy(global_dict, folder, normalize=True)
    return g, version_list
global LBP_MAX_ITERS
global THRES
LBP_MAX_ITERS =40
THRES = 0.999
knn = p.load(open('/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx/nginx-{openssl-1.0.1d}{zlib-1.2.11}/test_kNN_1021_2gram.p', 'r'))
g, version_list = runBPversions(knn)
# Out:
# LBP ran for 40 iterations. Converged = 0.9798598949211909

# %%
def count_rv_marginals2(g, global_dict, rvs=None, normalize=False):
        # Extract
        from collections import Counter
        tuples = g.rv_marginals(rvs, normalize)
        votes = Counter()
        prediction = dict()
        # Display
        for rv, marg in tuples:
            rv_label = str(rv)
            largest = 0
            for label in marg:
                if label > largest:
                    largest = label
            if type(global_dict)==type([]):
                names = global_dict
            else:
                names = global_dict[rv_label]
                names.append('None')
            for i, label in enumerate(marg):
                if np.isclose(label, largest):
                    if rv_label in prediction:
                        prediction[rv_label].append(names[i])
                    else:
                        prediction[rv_label]=[names[i]]

        keylist = prediction.keys()
        for key in keylist:
            funclist = prediction[key]
            label=set()
            #print key
            for (lib,func) in funclist:
                predicted_label = func.split('{')[0]
                #print '\t', predicted_label
                if predicted_label == 'None':
                    continue
                    # label=set()
                    # break
                label.add(predicted_label)
            votes += Counter(label)

        sorted_count = sorted(votes.items(), key=lambda x: x[1], reverse=True)
        print sorted_count
        return sorted_count
    
count_rv_marginals2(g, version_list)
# Out:
# [('openssl-1.0.1d', 1411), ('openssl-1.0.1f', 92), ('openssl-1.0.1h', 91), ('openssl-1.0.1m', 86), ('openssl-1.0.1c', 79), ('openssl-1.0.1e', 76), ('openssl-1.0.1a', 76), ('openssl-1.0.1b', 76), ('openssl-1.0.1g', 73), ('openssl-1.0.1', 73), ('openssl-1.0.1o', 72), ('openssl-1.0.1n', 72), ('openssl-1.0.0k', 72), ('openssl-1.0.1i', 71), ('openssl-1.0.1p', 70), ('openssl-1.0.1j', 69), ('openssl-1.0.1q', 69), ('openssl-1.0.1r', 69), ('openssl-1.0.1t', 68), ('openssl-1.0.1l', 67), ('openssl-1.0.1k', 67), ('openssl-1.0.1s', 67), ('openssl-1.0.0d', 67), ('openssl-1.0.0b', 65), ('openssl-1.0.0c', 65), ('openssl-1.0.0a', 65), ('openssl-1.0.0g', 64), ('openssl-1.0.0j', 64), ('openssl-1.0.0f', 62), ('openssl-1.0.0e', 62), ('openssl-1.0.0l', 62), ('openssl-1.0.0m', 62), ('openssl-1.0.0h', 62), ('openssl-1.0.0i', 62), ('openssl-1.0.0q', 62), ('openssl-1.0.0n', 61), ('openssl-1.0.0', 61), ('openssl-1.0.0o', 60), ('openssl-1.0.0p', 60), ('openssl-1.0.0t', 59), ('openssl-1.0.0s', 57), ('openssl-1.0.0r', 56), ('openssl-1.0.2', 54), ('openssl-1.0.2a', 51), ('openssl-1.0.2b', 48), ('openssl-1.0.2c', 48), ('openssl-1.0.2d', 48), ('openssl-1.0.2l', 47), ('openssl-1.0.2e', 46), ('openssl-1.0.2f', 46), ('openssl-1.0.2k', 45), ('openssl-1.0.2g', 44), ('openssl-1.0.2h', 44), ('openssl-0.9.7m', 43), ('openssl-1.0.2i', 43), ('openssl-1.0.2j', 43), ('openssl-1.0.2m', 43), ('openssl-1.0.2n', 38), ('openssl-1.0.2o', 38), ('openssl-1.0.2q', 35), ('openssl-0.9.8x', 25), ('openssl-0.9.8y', 25), ('openssl-0.9.8r', 25), ('openssl-0.9.8s', 25), ('openssl-0.9.8p', 25), ('openssl-0.9.8q', 25), ('openssl-0.9.8v', 25), ('openssl-0.9.8w', 25), ('openssl-0.9.8t', 25), ('openssl-0.9.8u', 25), ('openssl-0.9.8o', 23), ('openssl-0.9.7e', 22), ('zlib-1.2.11', 22), ('openssl-0.9.8n', 21), ('openssl-0.9.8m', 21), ('openssl-0.9.7d', 17), ('openssl-0.9.7i', 14), ('openssl-0.9.7g', 10), ('openssl-0.9.7f', 10), ('openssl-0.9.7c', 10), ('openssl-0.9.7j', 10), ('openssl-0.9.7h', 10), ('openssl-0.9.7a', 9), ('openssl-0.9.7l', 9), ('openssl-0.9.7k', 9), ('openssl-0.9.7', 9), ('openssl-0.9.7b', 9), ('openssl-1.1.0c', 2), ('openssl-1.1.0b', 2), ('openssl-1.1.0', 2), ('openssl-1.1.0e', 2), ('openssl-1.1.0d', 2), ('openssl-1.1.0f', 2), ('zlib-1.2.10', 2), ('zlib-1.2.9', 2), ('openssl-1.1.0a', 2), ('openssl-1.1.0g', 2)]
# [('openssl-1.0.1d', 1411),
#  ('openssl-1.0.1f', 92),
#  ('openssl-1.0.1h', 91),
#  ('openssl-1.0.1m', 86),
#  ('openssl-1.0.1c', 79),
#  ('openssl-1.0.1e', 76),
#  ('openssl-1.0.1a', 76),
#  ('openssl-1.0.1b', 76),
#  ('openssl-1.0.1g', 73),
#  ('openssl-1.0.1', 73),
#  ('openssl-1.0.1o', 72),
#  ('openssl-1.0.1n', 72),
#  ('openssl-1.0.0k', 72),
#  ('openssl-1.0.1i', 71),
#  ('openssl-1.0.1p', 70),
#  ('openssl-1.0.1j', 69),
#  ('openssl-1.0.1q', 69),
#  ('openssl-1.0.1r', 69),
#  ('openssl-1.0.1t', 68),
#  ('openssl-1.0.1l', 67),
#  ('openssl-1.0.1k', 67),
#  ('openssl-1.0.1s', 67),
#  ('openssl-1.0.0d', 67),
#  ('openssl-1.0.0b', 65),
#  ('openssl-1.0.0c', 65),
#  ('openssl-1.0.0a', 65),
#  ('openssl-1.0.0g', 64),
#  ('openssl-1.0.0j', 64),
#  ('openssl-1.0.0f', 62),
#  ('openssl-1.0.0e', 62),
#  ('openssl-1.0.0l', 62),
#  ('openssl-1.0.0m', 62),
#  ('openssl-1.0.0h', 62),
#  ('openssl-1.0.0i', 62),
#  ('openssl-1.0.0q', 62),
#  ('openssl-1.0.0n', 61),
#  ('openssl-1.0.0', 61),
#  ('openssl-1.0.0o', 60),
#  ('openssl-1.0.0p', 60),
#  ('openssl-1.0.0t', 59),
#  ('openssl-1.0.0s', 57),
#  ('openssl-1.0.0r', 56),
#  ('openssl-1.0.2', 54),
#  ('openssl-1.0.2a', 51),
#  ('openssl-1.0.2b', 48),
#  ('openssl-1.0.2c', 48),
#  ('openssl-1.0.2d', 48),
#  ('openssl-1.0.2l', 47),
#  ('openssl-1.0.2e', 46),
#  ('openssl-1.0.2f', 46),
#  ('openssl-1.0.2k', 45),
#  ('openssl-1.0.2g', 44),
#  ('openssl-1.0.2h', 44),
#  ('openssl-0.9.7m', 43),
#  ('openssl-1.0.2i', 43),
#  ('openssl-1.0.2j', 43),
#  ('openssl-1.0.2m', 43),
#  ('openssl-1.0.2n', 38),
#  ('openssl-1.0.2o', 38),
#  ('openssl-1.0.2q', 35),
#  ('openssl-0.9.8x', 25),
#  ('openssl-0.9.8y', 25),
#  ('openssl-0.9.8r', 25),
#  ('openssl-0.9.8s', 25),
#  ('openssl-0.9.8p', 25),
#  ('openssl-0.9.8q', 25),
#  ('openssl-0.9.8v', 25),
#  ('openssl-0.9.8w', 25),
#  ('openssl-0.9.8t', 25),
#  ('openssl-0.9.8u', 25),
#  ('openssl-0.9.8o', 23),
#  ('openssl-0.9.7e', 22),
#  ('zlib-1.2.11', 22),
#  ('openssl-0.9.8n', 21),
#  ('openssl-0.9.8m', 21),
#  ('openssl-0.9.7d', 17),
#  ('openssl-0.9.7i', 14),
#  ('openssl-0.9.7g', 10),
#  ('openssl-0.9.7f', 10),
#  ('openssl-0.9.7c', 10),
#  ('openssl-0.9.7j', 10),
#  ('openssl-0.9.7h', 10),
#  ('openssl-0.9.7a', 9),
#  ('openssl-0.9.7l', 9),
#  ('openssl-0.9.7k', 9),
#  ('openssl-0.9.7', 9),
#  ('openssl-0.9.7b', 9),
#  ('openssl-1.1.0c', 2),
#  ('openssl-1.1.0b', 2),
#  ('openssl-1.1.0', 2),
#  ('openssl-1.1.0e', 2),
#  ('openssl-1.1.0d', 2),
#  ('openssl-1.1.0f', 2),
#  ('zlib-1.2.10', 2),
#  ('zlib-1.2.9', 2),
#  ('openssl-1.1.0a', 2),
#  ('openssl-1.1.0g', 2)]

# %%
version_list
# Out:
# [('libssl', 'openssl-1.0.0m'),
#  ('libcrypto', 'openssl-1.0.2b'),
#  ('libssl', 'openssl-0.9.7b'),
#  ('libssl', 'openssl-0.9.8x'),
#  ('libcrypto', 'openssl-0.9.7h'),
#  ('libssl', 'openssl-1.0.0b'),
#  ('libssl', 'openssl-0.9.7'),
#  ('libz', 'zlib-1.2.7.1'),
#  ('libssl', 'openssl-1.0.2o'),
#  ('libcrypto', 'openssl-0.9.8u'),
#  ('libssl', 'openssl-1.0.1r'),
#  ('libssl', 'openssl-1.0.1f'),
#  ('libcrypto', 'openssl-1.1.0a'),
#  ('libcrypto', 'openssl-1.0.1b'),
#  ('libcrypto', 'openssl-1.0.0c'),
#  ('libcrypto', 'openssl-1.0.2l'),
#  ('libcrypto', 'openssl-1.0.0p'),
#  ('libssl', 'openssl-0.9.8n'),
#  ('libssl', 'openssl-1.0.0h'),
#  ('libcrypto', 'openssl-1.0.2a'),
#  ('libssl', 'openssl-1.0.1i'),
#  ('libcrypto', 'openssl-0.9.7g'),
#  ('libssl', 'openssl-1.0.2b'),
#  ('libssl', 'openssl-1.0.0r'),
#  ('libcrypto', 'openssl-0.9.8p'),
#  ('libssl', 'openssl-1.0.1l'),
#  ('libcrypto', 'openssl-1.1.0b'),
#  ('libcrypto', 'openssl-1.0.0i'),
#  ('libcrypto', 'openssl-1.0.1g'),
#  ('libcrypto', 'openssl-0.9.7a'),
#  ('libcrypto', 'openssl-1.0.0f'),
#  ('libcrypto', 'openssl-1.0.1r'),
#  ('libcrypto', 'openssl-1.0.2k'),
#  ('libcrypto', 'openssl-1.0.0s'),
#  ('libssl', 'openssl-0.9.8q'),
#  ('libcrypto', 'openssl-0.9.8s'),
#  ('libz', 'zlib-1.2.11'),
#  ('libssl', 'openssl-1.0.1'),
#  ('libcrypto', 'openssl-1.0.1i'),
#  ('libcrypto', 'openssl-1.0.2q'),
#  ('libcrypto', 'openssl-0.9.8n'),
#  ('libssl', 'openssl-1.0.2a'),
#  ('libcrypto', 'openssl-1.1.0h'),
#  ('libcrypto', 'openssl-0.9.7k'),
#  ('libcrypto', 'openssl-1.0.0l'),
#  ('libcrypto', 'openssl-0.9.7f'),
#  ('libcrypto', 'openssl-1.0.2f'),
#  ('libssl', 'openssl-0.9.8t'),
#  ('libssl', 'openssl-1.0.0f'),
#  ('libssl', 'openssl-1.0.0i'),
#  ('libssl', 'openssl-1.0.2k'),
#  ('libssl', 'openssl-1.0.1c'),
#  ('libcrypto', 'openssl-1.0.1d'),
#  ('libssl', 'openssl-1.0.2d'),
#  ('libcrypto', 'openssl-1.0.1'),
#  ('libcrypto', 'openssl-0.9.7l'),
#  ('libssl', 'openssl-1.0.2q'),
#  ('libcrypto', 'openssl-1.0.0o'),
#  ('libcrypto', 'openssl-1.0.1t'),
#  ('libssl', 'openssl-1.0.0l'),
#  ('libcrypto', 'openssl-1.0.2e'),
#  ('libssl', 'openssl-0.9.8w'),
#  ('libssl', 'openssl-1.0.1m'),
#  ('libssl', 'openssl-1.0.0a'),
#  ('libssl', 'openssl-1.0.2n'),
#  ('libcrypto', 'openssl-0.9.7j'),
#  ('libcrypto', 'openssl-0.9.8t'),
#  ('libssl', 'openssl-1.0.1s'),
#  ('libcrypto', 'openssl-0.9.8y'),
#  ('libcrypto', 'openssl-1.0.1c'),
#  ('libcrypto', 'openssl-1.0.0b'),
#  ('libcrypto', 'openssl-0.9.7'),
#  ('libcrypto', 'openssl-1.0.2o'),
#  ('libssl', 'openssl-0.9.8m'),
#  ('libssl', 'openssl-1.0.0o'),
#  ('libz', 'zlib-1.2.7'),
#  ('libssl', 'openssl-1.0.1j'),
#  ('libssl', 'openssl-0.9.7h'),
#  ('libssl', 'openssl-1.0.2m'),
#  ('libssl', 'openssl-1.0.0q'),
#  ('libcrypto', 'openssl-0.9.8w'),
#  ('libssl', 'openssl-1.1.0e'),
#  ('libssl', 'openssl-1.0.1p'),
#  ('libz', 'zlib-1.2.9'),
#  ('libcrypto', 'openssl-1.0.0h'),
#  ('libcrypto', 'openssl-0.9.7b'),
#  ('libcrypto', 'openssl-1.0.0e'),
#  ('libcrypto', 'openssl-1.0.1s'),
#  ('libcrypto', 'openssl-1.0.1a'),
#  ('libcrypto', 'openssl-1.0.2j'),
#  ('libcrypto', 'openssl-1.0.0r'),
#  ('libssl', 'openssl-0.9.8p'),
#  ('libssl', 'openssl-1.0.0j'),
#  ('libssl', 'openssl-1.0.2'),
#  ('libssl', 'openssl-1.0.1g'),
#  ('libcrypto', 'openssl-1.1.0f'),
#  ('libcrypto', 'openssl-0.9.8m'),
#  ('libcrypto', 'openssl-1.0.1o'),
#  ('libcrypto', 'openssl-0.9.8r'),
#  ('libcrypto', 'openssl-1.0.1j'),
#  ('libcrypto', 'openssl-1.0.0k'),
#  ('libcrypto', 'openssl-1.0.1e'),
#  ('libssl', 'openssl-0.9.7a'),
#  ('libcrypto', 'openssl-1.0.1p'),
#  ('libcrypto', 'openssl-1.0.2i'),
#  ('libssl', 'openssl-0.9.8s'),
#  ('libssl', 'openssl-1.0.0e'),
#  ('libssl', 'openssl-1.0.2j'),
#  ('libssl', 'openssl-1.0.1d'),
#  ('libssl', 'openssl-1.0.2g'),
#  ('libcrypto', 'openssl-1.0.2'),
#  ('libcrypto', 'openssl-0.9.7m'),
#  ('libz', 'zlib-1.2.8'),
#  ('libcrypto', 'openssl-1.0.0n'),
#  ('libssl', 'openssl-0.9.7m'),
#  ('libssl', 'openssl-0.9.7d'),
#  ('libssl', 'openssl-1.0.0g'),
#  ('libcrypto', 'openssl-1.0.2d'),
#  ('libssl', 'openssl-0.9.8v'),
#  ('libssl', 'openssl-1.0.1n'),
#  ('libz', 'zlib-1.2.7.3'),
#  ('libssl', 'openssl-1.0.2i'),
#  ('libssl', 'openssl-1.0.1a'),
#  ('libcrypto', 'openssl-1.1.0e'),
#  ('libcrypto', 'openssl-1.0.1n'),
#  ('libcrypto', 'openssl-0.9.8x'),
#  ('libcrypto', 'openssl-1.0.1l'),
#  ('libcrypto', 'openssl-1.0.0a'),
#  ('libcrypto', 'openssl-1.0.2n'),
#  ('libssl', 'openssl-1.1.0f'),
#  ('libssl', 'openssl-1.0.0n'),
#  ('libcrypto', 'openssl-1.0.2c'),
#  ('libssl', 'openssl-0.9.8y'),
#  ('libssl', 'openssl-1.0.1k'),
#  ('libssl', 'openssl-1.0.0c'),
#  ('libssl', 'openssl-1.0.2l'),
#  ('libssl', 'openssl-1.0.0p'),
#  ('libcrypto', 'openssl-0.9.8v'),
#  ('libssl', 'openssl-1.0.1q'),
#  ('libcrypto', 'openssl-0.9.7c'),
#  ('libcrypto', 'openssl-1.1.0'),
#  ('libcrypto', 'openssl-1.0.0d'),
#  ('libcrypto', 'openssl-1.0.2m'),
#  ('libcrypto', 'openssl-1.0.0q'),
#  ('libssl', 'openssl-0.9.8o'),
#  ('libcrypto', 'openssl-0.9.7e'),
#  ('libssl', 'openssl-0.9.7l'),
#  ('libssl', 'openssl-1.0.1h'),
#  ('libssl', 'openssl-1.0.2c'),
#  ('libcrypto', 'openssl-1.0.0'),
#  ('libcrypto', 'openssl-0.9.8q'),
#  ('libcrypto', 'openssl-1.0.1k'),
#  ('libssl', 'openssl-1.0.0s'),
#  ('libcrypto', 'openssl-1.0.0j'),
#  ('libcrypto', 'openssl-1.0.1f'),
#  ('libcrypto', 'openssl-1.0.0g'),
#  ('libcrypto', 'openssl-1.0.1q'),
#  ('libcrypto', 'openssl-1.0.2h'),
#  ('libssl', 'openssl-0.9.7c'),
#  ('libcrypto', 'openssl-1.0.0t'),
#  ('libssl', 'openssl-0.9.8r'),
#  ('libcrypto', 'openssl-0.9.7i'),
#  ('libssl', 'openssl-1.0.0d'),
#  ('libz', 'zlib-1.2.10'),
#  ('libssl', 'openssl-1.0.0'),
#  ('libssl', 'openssl-1.0.1e'),
#  ('libcrypto', 'openssl-0.9.8o'),
#  ('libssl', 'openssl-1.0.2f'),
#  ('libcrypto', 'openssl-1.1.0g'),
#  ('libcrypto', 'openssl-1.0.1h'),
#  ('libcrypto', 'openssl-1.0.0m'),
#  ('libcrypto', 'openssl-1.0.2g'),
#  ('libssl', 'openssl-1.0.1t'),
#  ('libssl', 'openssl-0.9.8u'),
#  ('libssl', 'openssl-1.0.1o'),
#  ('libcrypto', 'openssl-0.9.7d'),
#  ('libz', 'zlib-1.2.7.2'),
#  ('libssl', 'openssl-1.0.2h'),
#  ('libssl', 'openssl-1.0.1b'),
#  ('libssl', 'openssl-1.0.0t'),
#  ('libssl', 'openssl-1.0.2e'),
#  ('libcrypto', 'openssl-1.1.0c'),
#  ('libcrypto', 'openssl-1.1.0d'),
#  ('libcrypto', 'openssl-1.0.1m'),
#  ('libssl', 'openssl-1.0.0k')]

# %%
dir = '/home/yijiufly/Downloads/codesearch/data/versiondetect/test3/nginx'
folders = os.listdir(dir)
folders.sort()
folders.index('')
